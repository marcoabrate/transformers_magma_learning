# %% [markdown]
# #### For Colab

# %%
"""
function ClickConnect(){
    console.log("Working");
    document.querySelector("colab-toolbar-button").click() 
}
var i = setInterval(ClickConnect, 900000)
clearInterval(i)
"""
# Out:
# '\nfunction ClickConnect(){\n    console.log("Working");\n    document.querySelector("colab-toolbar-button").click() \n}\nvar i = setInterval(ClickConnect, 900000)\nclearInterval(i)\n'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
drive_dir = '/content/drive/My Drive/MAGMA: Summarization/'

# %% [markdown]
# #### Install Libraries

# %%
# !pip install transformers==4.1.1
# !pip install -U sentencepiece!=0.1.92
# !pip install -U datasets
# !pip install rouge_score
# !pip install -U gensim
# Out:
# Collecting transformers==4.1.1
#   Downloading https://files.pythonhosted.org/packages/50/0c/7d5950fcd80b029be0a8891727ba21e0cd27692c407c51261c3c921f6da3/transformers-4.1.1-py3-none-any.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 11.2MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers==4.1.1) (2.23.0)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 49.0MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers==4.1.1) (4.41.1)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers==4.1.1) (0.8)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers==4.1.1) (2019.12.20)
# Collecting tokenizers==0.9.4
#   Downloading https://files.pythonhosted.org/packages/0f/1c/e789a8b12e28be5bc1ce2156cf87cb522b379be9cadc7ad8091a4cc107c4/tokenizers-0.9.4-cp36-cp36m-manylinux2010_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 49.7MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers==4.1.1) (3.0.12)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers==4.1.1) (1.19.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers==4.1.1) (20.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==4.1.1) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==4.1.1) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==4.1.1) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==4.1.1) (2.10)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==4.1.1) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==4.1.1) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==4.1.1) (1.0.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers==4.1.1) (2.4.7)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893261 sha256=313c4529ef511d50317ba37019ad40f0926271f10cf78eaf23364e3608e9d6f2
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: sacremoses, tokenizers, transformers
# Successfully installed sacremoses-0.0.43 tokenizers-0.9.4 transformers-4.1.1
# Collecting sentencepiece!=0.1.92
#   Downloading https://files.pythonhosted.org/packages/14/67/e42bd1181472c95c8cda79305df848264f2a7f62740995a46945d9797b67/sentencepiece-0.1.95-cp36-cp36m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 11.3MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.95
# Collecting datasets
#   Downloading https://files.pythonhosted.org/packages/ee/78/5873ac1e27bf25a2cbf3447d6704edd3136b1b3ff0eb3bfab38a45d2a1ff/datasets-1.2.0-py3-none-any.whl (159kB)
#      |████████████████████████████████| 163kB 12.0MB/s
# Collecting xxhash
#   Downloading https://files.pythonhosted.org/packages/f7/73/826b19f3594756cb1c6c23d2fbd8ca6a77a9cd3b650c9dec5acc85004c38/xxhash-2.0.0-cp36-cp36m-manylinux2010_x86_64.whl (242kB)
#      |████████████████████████████████| 245kB 27.0MB/s
# Requirement already satisfied, skipping upgrade: requests>=2.19.0 in /usr/local/lib/python3.6/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.17 in /usr/local/lib/python3.6/dist-packages (from datasets) (1.19.4)
# Requirement already satisfied, skipping upgrade: dill in /usr/local/lib/python3.6/dist-packages (from datasets) (0.3.3)
# Requirement already satisfied, skipping upgrade: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from datasets) (0.8)
# Collecting pyarrow>=0.17.1
#   Downloading https://files.pythonhosted.org/packages/d7/e1/27958a70848f8f7089bff8d6ebe42519daf01f976d28b481e1bfd52c8097/pyarrow-2.0.0-cp36-cp36m-manylinux2014_x86_64.whl (17.7MB)
#      |████████████████████████████████| 17.7MB 261kB/s
# Requirement already satisfied, skipping upgrade: multiprocess in /usr/local/lib/python3.6/dist-packages (from datasets) (0.70.11.1)
# Requirement already satisfied, skipping upgrade: tqdm<4.50.0,>=4.27 in /usr/local/lib/python3.6/dist-packages (from datasets) (4.41.1)
# Requirement already satisfied, skipping upgrade: pandas in /usr/local/lib/python3.6/dist-packages (from datasets) (1.1.5)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.0->datasets) (2020.12.5)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->datasets) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->datasets) (2018.9)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: xxhash, pyarrow, datasets
#   Found existing installation: pyarrow 0.14.1
#     Uninstalling pyarrow-0.14.1:
#       Successfully uninstalled pyarrow-0.14.1
# Successfully installed datasets-1.2.0 pyarrow-2.0.0 xxhash-2.0.0
# Collecting rouge_score
#   Downloading https://files.pythonhosted.org/packages/1f/56/a81022436c08b9405a5247b71635394d44fe7e1dbedc4b28c740e09c2840/rouge_score-0.0.4-py2.py3-none-any.whl
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from rouge_score) (0.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from rouge_score) (1.19.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from rouge_score) (1.15.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.6/dist-packages (from rouge_score) (3.2.5)
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.0.4
# Collecting gensim
#   Downloading https://files.pythonhosted.org/packages/2b/e0/fa6326251692056dc880a64eb22117e03269906ba55a6864864d24ec8b4e/gensim-3.8.3-cp36-cp36m-manylinux1_x86_64.whl (24.2MB)
#      |████████████████████████████████| 24.2MB 1.3MB/s
# Requirement already satisfied, skipping upgrade: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied, skipping upgrade: smart-open>=1.8.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (4.0.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.19.4)
# Requirement already satisfied, skipping upgrade: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.15.0)
# Installing collected packages: gensim
#   Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
# Successfully installed gensim-3.8.3

# %% [markdown]
# ### **Config**

# %%
import os
import sys

sys.path.insert(0, drive_dir)
import config

# %%
# General configurations

MODEL = 'bart'

RE_SPLITTER = '\.(?!\d)|\n'     # do we split sentences of paragraphs?
                                # use '\.|\n' or '\n', respectively

TOKEN_MAX_LEN = 99              # max length of a word
PARA_MIN_LENGTH = 2             # minimum length for a sentence or
                                # a paragraph, in tokens

# Output path
OUTPUT_PATH = drive_dir+'datasets/karger_books_moc/'+MODEL+'/'
if not os.path.exists(OUTPUT_PATH):
    os.makedirs(OUTPUT_PATH)

# %% [markdown]
# ### **Init**

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import re
import pandas as pd
import gensim

if 'pegasus' in MODEL:
    from transformers import PegasusTokenizer
    tokenizer =\
        PegasusTokenizer.from_pretrained('google/pegasus-large')
elif 'bart' in MODEL:
    from transformers import BartTokenizer
    tokenizer =\
        BartTokenizer.from_pretrained('facebook/bart-large-cnn')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=898823.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=456318.0, style=ProgressStyle(descripti…

# %% [markdown]
# ### **Karger Books Base Dataset**

# %%
base_dataset = drive_dir+'datasets/karger_books_base/df.csv'
df = pd.read_csv(base_dataset)
df = df.set_index(['book', 'chapter', 'section', 'subsection'])
df.bullets = df.bullets.map(eval, na_action='ignore')

# %% [markdown]
# ### **Preprocessing**

# %% [markdown]
# #### Preprocessing
#
# * Split based on RE_SPLITTER
# * Explode the dataset
# * Remove unwanted chars at beginning or end of sentence
# * Remove multiple spaces
# * Remove long words (> TOKEN_MAX_LEN chars)
# * Remove short sentences / paragraphs (< PARA_MIN_LENGTH tokens)

# %%
# Split in sentences / paragraphs based on RE_SPLITTER
df.text =\
    df.text.map(lambda x: [p.strip() for p in re.split(RE_SPLITTER, x) if p!=''],
                na_action='ignore')
    
# explode to get one row for each paragraph /sentence
df = df.explode('text')
df = df.rename(columns={'text': 'para'})
df = df.dropna()

# Remove unwanted chars at beginning or end of sentence
df.para = df.para.map(lambda p: p.lstrip('.,;:-)] \n'))
df.para = df.para.map(lambda p: p.rstrip('.,;:-([ \n'))

# Remove multiple spaces
df.para = df.para.map(lambda p:
    re.sub('\s+', ' ', p).strip())

# Remove long words (> TOKEN_MAX_LEN chars)
def para2words(para):
    return gensim.utils.simple_preprocess(
        para, deacc=True, max_len=TOKEN_MAX_LEN)
df['para_proc'] = df.para.map(para2words)

# Remove short sentences / paragraphs (< PARA_MIN_LENGTH tokens)
df.loc[df.para_proc.map(len) <\
    PARA_MIN_LENGTH, 'para_proc'] = np.nan

df = df.dropna()

# %% [markdown]
# ### **Merge or Chunk Sections**

# %%
df = df.groupby(level=[0,1,2,3], sort=False).agg(
    {'para': lambda t: ''.join([p+'. ' for p in t]),
     'bullets': lambda b: list(b)[0]})
df = df.rename(columns={'para': 'text'})

# %%
df['text_enc'] = df.text.map(tokenizer.tokenize)
df['text_num_tokens'] = df.text_enc.map(len)

# %% [markdown]
# #### Chunk function

# %%
def chunk_text(text, num_tok):
    text_sent =\
        [sent.strip()+'.' for sent in re.split(RE_SPLITTER, text) if len(sent) > 1]

    # calculate number of tokens per sentence
    num_tok_sent = [len(tokenizer.tokenize(sent)) for sent in text_sent]
    
    # calculate chunk dimension to fit into model
    n = int(np.ceil(num_tok / config.MODEL_MAX_LEN))
    len_chunk = int(num_tok / n)
    # get a more uniform splitting to avoid splits
    # which are too short at the end
    if len_chunk+50 > config.MODEL_MAX_LEN:
        len_chunk = int(num_tok / (n+1))
    
    len_curr = 0
    text_curr = []
    text_chunk = []
    for te, len_sent in zip(text_sent, num_tok_sent):

        if len_curr + len_sent < len_chunk:
            text_curr.append(te)
            len_curr += len_sent

        elif len_curr + len_sent >= config.MODEL_MAX_LEN:
            text_chunk.append(text_curr)

            text_curr = [te]
            len_curr = len_sent

        else: # >= len_chunk && < MODEL_MAX_LEN
            text_curr.append(te)
            text_chunk.append(text_curr)
            
            text_curr = []
            len_curr = 0

    if len_curr > 0:
        text_chunk.append(text_curr)

    return text_chunk

# %% [markdown]
# #### Merge or Chunk

# %%
def chunk_or_merge(df_merge, num_row, num_tok, bid, cpt, i, index):
    print('num_tok MOC', num_tok)

    # if the text fits perfectly, we just add it to df_merge
    if num_tok >= CHUNK_MIN_LEN and num_tok < config.MODEL_MAX_LEN:
        id_merged = index[i-num_row:i]
        print('summ', id_merged)

        data_merged = []
        for c in df.columns:
            if c == 'bullets':
                data_merged.append(df.loc[id_merged, c].iloc[0])
            else:
                data_merged.append(df.loc[id_merged, c].sum())

        new_index = pd.MultiIndex.from_arrays(
            [[bid], [cpt], [str(id_merged)], [False]])
        df_merge_add = pd.DataFrame(
            data = [data_merged],
            index = new_index,
            columns = df.columns)
        df_merge = df_merge.append(df_merge_add)
        return False, df_merge

    # if the text is too long, we chunk it
    elif num_tok >= config.MODEL_MAX_LEN:
        id_merged = index[i-num_row:i]
        print('chunking', id_merged)

        new_index = pd.MultiIndex.from_arrays(
            [[bid], [cpt], [str(id_merged)], [True]])

        text_merged = df.loc[id_merged, 'text'].sum()
        text_chunked = chunk_text(text_merged, num_tok)
        for tc in text_chunked:
            t = ' '.join(tc)
            df_merge_add = pd.DataFrame(
                data = [[t,
                        df.iloc[i-1].bullets,
                        tokenizer.tokenize(t),
                        len(tokenizer.tokenize(t))]],
                index = new_index,
                columns = df.columns)
            df_merge = df_merge.append(df_merge_add)
        return False, df_merge

    # if the text is too short, we merge it
    elif num_tok < CHUNK_MIN_LEN:
        print('skipping', index[i-num_row:i])
        return True, df_merge

# %% [markdown]
# #### Create the new dataset

# %%
# define new dataset for the chapters
indices = pd.MultiIndex.from_arrays(
    [[], [], [], []],
    names = ['book', 'chapter', 'merge', 'chunk'])
df_moc = pd.DataFrame(index = indices, columns = df.columns.tolist())

# minimum length of a chunk
CHUNK_MIN_LEN = np.ceil(config.BULLETS_MED_LEN / config.MAX_RATIO)
print('Chunk minimum length:', CHUNK_MIN_LEN)
print()

index = df.index.tolist()

i_cpt = 0
for bid in sorted(list(set(df.index.get_level_values(0)))):
    cpts = config.get_cpts(df, bid)
    for cpt in cpts:
        print('book', bid, 'chapter', cpt)
        print()

        merge = False
        num_row, num_row_past = 0, 0
        num_tok, num_tok_past = 0, 0
        max_i = i_cpt + len(df.loc[bid, cpt])

        # for each section in chapter
        for i in range(i_cpt, max_i):
            # if previous section is too short, 
            # we merge it with the one below
            if merge: 
                num_row += 1
                print('merging', num_tok, '+', df.iloc[i].text_num_tokens)
                num_tok += df.iloc[i].text_num_tokens
            else:
                num_row_past = num_row
                num_row = 1
                num_tok_past = num_tok
                num_tok = df.iloc[i].text_num_tokens
            '''
                after merging or considering a new section, we call this function
                to study the length. Then we either add the row to the dataset, chunk it 
                or do nothing if it is still too short
            '''
            merge, df_moc =\
                chunk_or_merge(df_moc, num_row, num_tok, bid, cpt, i+1, index)

            print()
            
            '''
                if the last chunk of the chapter is too small, we merge it
                with the above and repeat one last time the process
            '''
            if merge and (i+1 == max_i):
                print('EXCEPTION, last chunk too small.')
                if num_row_past == 0:
                    _, df_moc =\
                        chunk_or_merge(df_moc, num_row, config.MODEL_MAX_LEN-1, bid, cpt, i+1, index)
                else:
                    num_row += num_row_past
                    num_tok += num_tok_past
                    # drop last row added and re-calculate for new, bigger chunk
                    df_moc = df_moc.drop(df_moc.index[-1])
                    _, df_moc =\
                        chunk_or_merge(df_moc, num_row, num_tok, bid, cpt, i+1, index)
                 
        i_cpt += len(df.loc[bid, cpt])
        print('\n############################')
        print()
        print()

for idx, r in df_moc.groupby(level=[0,1,2,3]).text.apply(list).iteritems():
    idx_merged = eval(idx[2])
    old_txt = ''.join(df.loc[idx_merged].text.tolist()).strip()
    new_txt = ' '.join(r).strip()
    assert old_txt == new_txt
# Out:
# Chunk minimum length: 720.0
#
# book 9781905832729 chapter ch_2
#
# num_tok MOC 11
# skipping [(9781905832729, 'ch_2', 'ch_2', 'ch_2')]
#
# merging 11 + 198
# num_tok MOC 209
# skipping [(9781905832729, 'ch_2', 'ch_2', 'ch_2'), (9781905832729, 'ch_2', '1.i', '1.i')]
#
# merging 209 + 609
# num_tok MOC 818
# summ [(9781905832729, 'ch_2', 'ch_2', 'ch_2'), (9781905832729, 'ch_2', '1.i', '1.i'), (9781905832729, 'ch_2', '1.ii', '1.ii')]
#
#
# ############################
#
#
# book 9781905832729 chapter ch_3
#
# num_tok MOC 85
# skipping [(9781905832729, 'ch_3', '2.i', '2.i')]
#
# merging 85 + 231
# num_tok MOC 316
# skipping [(9781905832729, 'ch_3', '2.i', '2.i'), (9781905832729, 'ch_3', '2.ii', '2.ii')]
#
# merging 316 + 417
# num_tok MOC 733
# summ [(9781905832729, 'ch_3', '2.i', '2.i'), (9781905832729, 'ch_3', '2.ii', '2.ii'), (9781905832729, 'ch_3', '2.iii', '2.iii')]
#
# num_tok MOC 383
# skipping [(9781905832729, 'ch_3', '2.iv', '2.iv')]
#
# merging 383 + 758
# num_tok MOC 1141
# chunking [(9781905832729, 'ch_3', '2.iv', '2.iv'), (9781905832729, 'ch_3', '2.v', '2.v')]
#
# num_tok MOC 932
# summ [(9781905832729, 'ch_3', '2.vi', '2.vi')]
#
# num_tok MOC 189
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: PerformanceWarning: indexing past lexsort depth may impact performance.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:63: PerformanceWarning: indexing past lexsort depth may impact performance.
# Streaming output truncated to the last 5000 lines.
#
#
# ############################
#
#
# book 9781910797495 chapter chp4
#
# num_tok MOC 53
# skipping [(9781910797495, 'chp4', 'chp4', 'chp4')]
#
# merging 53 + 329
# num_tok MOC 382
# skipping [(9781910797495, 'chp4', 'chp4', 'chp4'), (9781910797495, 'chp4', 'sect27', 'sect27')]
#
# merging 382 + 500
# num_tok MOC 882
# summ [(9781910797495, 'chp4', 'chp4', 'chp4'), (9781910797495, 'chp4', 'sect27', 'sect27'), (9781910797495, 'chp4', 'sect28', 'sect28')]
#
# num_tok MOC 300
# skipping [(9781910797495, 'chp4', 'sect29', 'sect29')]
#
# merging 300 + 427
# num_tok MOC 727
# summ [(9781910797495, 'chp4', 'sect29', 'sect29'), (9781910797495, 'chp4', 'sect30', 'sect30')]
#
#
# ############################
#
#
# book 9781910797495 chapter chp5
#
# num_tok MOC 375
# skipping [(9781910797495, 'chp5', 'chp5', 'chp5')]
#
# merging 375 + 1142
# num_tok MOC 1517
# chunking [(9781910797495, 'chp5', 'chp5', 'chp5'), (9781910797495, 'chp5', 'sect33', 'sect33')]
#
# num_tok MOC 160
# skipping [(9781910797495, 'chp5', 'sect34', 'sect34')]
#
# merging 160 + 74
# num_tok MOC 234
# skipping [(9781910797495, 'chp5', 'sect34', 'sect34'), (9781910797495, 'chp5', 'sect35', 'sect35')]
#
# merging 234 + 130
# num_tok MOC 364
# skipping [(9781910797495, 'chp5', 'sect34', 'sect34'), (9781910797495, 'chp5', 'sect35', 'sect35'), (9781910797495, 'chp5', 'sect36', 'sect36')]
#
# merging 364 + 79
# num_tok MOC 443
# skipping [(9781910797495, 'chp5', 'sect34', 'sect34'), (9781910797495, 'chp5', 'sect35', 'sect35'), (9781910797495, 'chp5', 'sect36', 'sect36'), (9781910797495, 'chp5', 'sect37', 'sect37')]
#
# merging 443 + 877
# num_tok MOC 1320
# chunking [(9781910797495, 'chp5', 'sect34', 'sect34'), (9781910797495, 'chp5', 'sect35', 'sect35'), (9781910797495, 'chp5', 'sect36', 'sect36'), (9781910797495, 'chp5', 'sect37', 'sect37'), (9781910797495, 'chp5', 'sect38', 'sect38')]
#
# num_tok MOC 551
# skipping [(9781910797495, 'chp5', 'sect39', 'sect39')]
#
# merging 551 + 211
# num_tok MOC 762
# summ [(9781910797495, 'chp5', 'sect39', 'sect39'), (9781910797495, 'chp5', 'sect40', 'sect40')]
#
# num_tok MOC 102
# skipping [(9781910797495, 'chp5', 'sect41', 'sect41')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 864
# summ [(9781910797495, 'chp5', 'sect39', 'sect39'), (9781910797495, 'chp5', 'sect40', 'sect40'), (9781910797495, 'chp5', 'sect41', 'sect41')]
#
# ############################
#
#
# book 9781910797495 chapter chp6
#
# num_tok MOC 12
# skipping [(9781910797495, 'chp6', 'chp6', 'chp6')]
#
# merging 12 + 2603
# num_tok MOC 2615
# chunking [(9781910797495, 'chp6', 'chp6', 'chp6'), (9781910797495, 'chp6', 'sect44', 'sect44')]
#
# num_tok MOC 1729
# chunking [(9781910797495, 'chp6', 'sect45', 'sect45')]
#
#
# ############################
#
#
# book 9781910797495 chapter chp7
#
# num_tok MOC 151
# skipping [(9781910797495, 'chp7', 'chp7', 'chp7')]
#
# merging 151 + 568
# num_tok MOC 719
# skipping [(9781910797495, 'chp7', 'chp7', 'chp7'), (9781910797495, 'chp7', 'sect48', 'sect48')]
#
# merging 719 + 606
# num_tok MOC 1325
# chunking [(9781910797495, 'chp7', 'chp7', 'chp7'), (9781910797495, 'chp7', 'sect48', 'sect48'), (9781910797495, 'chp7', 'sect49', 'sect49')]
#
# num_tok MOC 127
# skipping [(9781910797495, 'chp7', 'sect50', 'sect50')]
#
# merging 127 + 90
# num_tok MOC 217
# skipping [(9781910797495, 'chp7', 'sect50', 'sect50'), (9781910797495, 'chp7', 'sect51', 'sect51')]
#
# merging 217 + 133
# num_tok MOC 350
# skipping [(9781910797495, 'chp7', 'sect50', 'sect50'), (9781910797495, 'chp7', 'sect51', 'sect51'), (9781910797495, 'chp7', 'sect52', 'sect52')]
#
# merging 350 + 273
# num_tok MOC 623
# skipping [(9781910797495, 'chp7', 'sect50', 'sect50'), (9781910797495, 'chp7', 'sect51', 'sect51'), (9781910797495, 'chp7', 'sect52', 'sect52'), (9781910797495, 'chp7', 'sect53', 'sect53')]
#
# merging 623 + 521
# num_tok MOC 1144
# chunking [(9781910797495, 'chp7', 'sect50', 'sect50'), (9781910797495, 'chp7', 'sect51', 'sect51'), (9781910797495, 'chp7', 'sect52', 'sect52'), (9781910797495, 'chp7', 'sect53', 'sect53'), (9781910797495, 'chp7', 'sect53', 'sect53-1_sub_sect53')]
#
# num_tok MOC 334
# skipping [(9781910797495, 'chp7', 'sect53', 'sect53-2_sub_sect53')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1478
# chunking [(9781910797495, 'chp7', 'sect50', 'sect50'), (9781910797495, 'chp7', 'sect51', 'sect51'), (9781910797495, 'chp7', 'sect52', 'sect52'), (9781910797495, 'chp7', 'sect53', 'sect53'), (9781910797495, 'chp7', 'sect53', 'sect53-1_sub_sect53'), (9781910797495, 'chp7', 'sect53', 'sect53-2_sub_sect53')]
#
# ############################
#
#
# book 9781910797495 chapter chp8
#
# num_tok MOC 7
# skipping [(9781910797495, 'chp8', 'chp8', 'chp8')]
#
# merging 7 + 66
# num_tok MOC 73
# skipping [(9781910797495, 'chp8', 'chp8', 'chp8'), (9781910797495, 'chp8', 'sect56', 'sect56')]
#
# merging 73 + 245
# num_tok MOC 318
# skipping [(9781910797495, 'chp8', 'chp8', 'chp8'), (9781910797495, 'chp8', 'sect56', 'sect56'), (9781910797495, 'chp8', 'sect57', 'sect57')]
#
# merging 318 + 181
# num_tok MOC 499
# skipping [(9781910797495, 'chp8', 'chp8', 'chp8'), (9781910797495, 'chp8', 'sect56', 'sect56'), (9781910797495, 'chp8', 'sect57', 'sect57'), (9781910797495, 'chp8', 'sect58', 'sect58')]
#
# merging 499 + 457
# num_tok MOC 956
# summ [(9781910797495, 'chp8', 'chp8', 'chp8'), (9781910797495, 'chp8', 'sect56', 'sect56'), (9781910797495, 'chp8', 'sect57', 'sect57'), (9781910797495, 'chp8', 'sect58', 'sect58'), (9781910797495, 'chp8', 'sect59', 'sect59')]
#
# num_tok MOC 72
# skipping [(9781910797495, 'chp8', 'sect60', 'sect60')]
#
# merging 72 + 628
# num_tok MOC 700
# skipping [(9781910797495, 'chp8', 'sect60', 'sect60'), (9781910797495, 'chp8', 'sect61', 'sect61')]
#
# merging 700 + 272
# num_tok MOC 972
# summ [(9781910797495, 'chp8', 'sect60', 'sect60'), (9781910797495, 'chp8', 'sect61', 'sect61'), (9781910797495, 'chp8', 'sect61', 'sect61-1_sub_sect61')]
#
#
# ############################
#
#
# book 9781910797495 chapter chp9
#
# num_tok MOC 469
# skipping [(9781910797495, 'chp9', 'chp9', 'chp9')]
#
# merging 469 + 698
# num_tok MOC 1167
# chunking [(9781910797495, 'chp9', 'chp9', 'chp9'), (9781910797495, 'chp9', 'sect64', 'sect64')]
#
# num_tok MOC 257
# skipping [(9781910797495, 'chp9', 'sect65', 'sect65')]
#
# merging 257 + 582
# num_tok MOC 839
# summ [(9781910797495, 'chp9', 'sect65', 'sect65'), (9781910797495, 'chp9', 'sect66', 'sect66')]
#
#
# ############################
#
#
# book 9781910797495 chapter chp10
#
# num_tok MOC 8
# skipping [(9781910797495, 'chp10', 'chp10', 'chp10')]
#
# merging 8 + 932
# num_tok MOC 940
# summ [(9781910797495, 'chp10', 'chp10', 'chp10'), (9781910797495, 'chp10', 'sect69', 'sect69')]
#
# num_tok MOC 162
# skipping [(9781910797495, 'chp10', 'sect69', 'sect69-1_sub_sect69')]
#
# merging 162 + 475
# num_tok MOC 637
# skipping [(9781910797495, 'chp10', 'sect69', 'sect69-1_sub_sect69'), (9781910797495, 'chp10', 'sect69', 'sect69-2_sub_sect69')]
#
# merging 637 + 227
# num_tok MOC 864
# summ [(9781910797495, 'chp10', 'sect69', 'sect69-1_sub_sect69'), (9781910797495, 'chp10', 'sect69', 'sect69-2_sub_sect69'), (9781910797495, 'chp10', 'sect69', 'sect69-3_sub_sect69')]
#
# num_tok MOC 769
# summ [(9781910797495, 'chp10', 'sect69', 'sect69-4_sub_sect69')]
#
# num_tok MOC 524
# skipping [(9781910797495, 'chp10', 'sect70', 'sect70')]
#
# merging 524 + 399
# num_tok MOC 923
# summ [(9781910797495, 'chp10', 'sect70', 'sect70'), (9781910797495, 'chp10', 'sect72', 'sect72')]
#
# num_tok MOC 421
# skipping [(9781910797495, 'chp10', 'sect72', 'sect72-1_sub_sect72')]
#
# merging 421 + 171
# num_tok MOC 592
# skipping [(9781910797495, 'chp10', 'sect72', 'sect72-1_sub_sect72'), (9781910797495, 'chp10', 'sect72', 'sect72-2_sub_sect72')]
#
# merging 592 + 415
# num_tok MOC 1007
# summ [(9781910797495, 'chp10', 'sect72', 'sect72-1_sub_sect72'), (9781910797495, 'chp10', 'sect72', 'sect72-2_sub_sect72'), (9781910797495, 'chp10', 'sect74', 'sect74')]
#
# num_tok MOC 556
# skipping [(9781910797495, 'chp10', 'sect74', 'sect74-1_sub_sect74')]
#
# merging 556 + 371
# num_tok MOC 927
# summ [(9781910797495, 'chp10', 'sect74', 'sect74-1_sub_sect74'), (9781910797495, 'chp10', 'sect74', 'sect74-2_sub_sect74')]
#
# num_tok MOC 705
# skipping [(9781910797495, 'chp10', 'sect76', 'sect76')]
#
# merging 705 + 877
# num_tok MOC 1582
# chunking [(9781910797495, 'chp10', 'sect76', 'sect76'), (9781910797495, 'chp10', 'sect76', 'sect76-1_sub_sect76')]
#
# num_tok MOC 305
# skipping [(9781910797495, 'chp10', 'sect76', 'sect76-2_sub_sect76')]
#
# merging 305 + 393
# num_tok MOC 698
# skipping [(9781910797495, 'chp10', 'sect76', 'sect76-2_sub_sect76'), (9781910797495, 'chp10', 'sect78', 'sect78')]
#
# merging 698 + 605
# num_tok MOC 1303
# chunking [(9781910797495, 'chp10', 'sect76', 'sect76-2_sub_sect76'), (9781910797495, 'chp10', 'sect78', 'sect78'), (9781910797495, 'chp10', 'sect78', 'sect78-1_sub_sect78')]
#
# num_tok MOC 228
# skipping [(9781910797495, 'chp10', 'sect78', 'sect78-2_sub_sect78')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1531
# chunking [(9781910797495, 'chp10', 'sect76', 'sect76-2_sub_sect76'), (9781910797495, 'chp10', 'sect78', 'sect78'), (9781910797495, 'chp10', 'sect78', 'sect78-1_sub_sect78'), (9781910797495, 'chp10', 'sect78', 'sect78-2_sub_sect78')]
#
# ############################
#
#
# book 9781910797495 chapter chp11
#
# num_tok MOC 137
# skipping [(9781910797495, 'chp11', 'chp11', 'chp11')]
#
# merging 137 + 457
# num_tok MOC 594
# skipping [(9781910797495, 'chp11', 'chp11', 'chp11'), (9781910797495, 'chp11', 'sect81', 'sect81')]
#
# merging 594 + 218
# num_tok MOC 812
# summ [(9781910797495, 'chp11', 'chp11', 'chp11'), (9781910797495, 'chp11', 'sect81', 'sect81'), (9781910797495, 'chp11', 'sect82', 'sect82')]
#
# num_tok MOC 290
# skipping [(9781910797495, 'chp11', 'sect83', 'sect83')]
#
# merging 290 + 418
# num_tok MOC 708
# skipping [(9781910797495, 'chp11', 'sect83', 'sect83'), (9781910797495, 'chp11', 'sect84', 'sect84')]
#
# merging 708 + 59
# num_tok MOC 767
# summ [(9781910797495, 'chp11', 'sect83', 'sect83'), (9781910797495, 'chp11', 'sect84', 'sect84'), (9781910797495, 'chp11', 'sect85', 'sect85')]
#
# num_tok MOC 215
# skipping [(9781910797495, 'chp11', 'sect86', 'sect86')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 982
# summ [(9781910797495, 'chp11', 'sect83', 'sect83'), (9781910797495, 'chp11', 'sect84', 'sect84'), (9781910797495, 'chp11', 'sect85', 'sect85'), (9781910797495, 'chp11', 'sect86', 'sect86')]
#
# ############################
#
#
# book 9781910797495 chapter chp12
#
# num_tok MOC 26
# skipping [(9781910797495, 'chp12', 'chp12', 'chp12')]
#
# merging 26 + 274
# num_tok MOC 300
# skipping [(9781910797495, 'chp12', 'chp12', 'chp12'), (9781910797495, 'chp12', 'sect89', 'sect89')]
#
# merging 300 + 510
# num_tok MOC 810
# summ [(9781910797495, 'chp12', 'chp12', 'chp12'), (9781910797495, 'chp12', 'sect89', 'sect89'), (9781910797495, 'chp12', 'sect90', 'sect90')]
#
# num_tok MOC 240
# skipping [(9781910797495, 'chp12', 'sect91', 'sect91')]
#
# merging 240 + 141
# num_tok MOC 381
# skipping [(9781910797495, 'chp12', 'sect91', 'sect91'), (9781910797495, 'chp12', 'sect92', 'sect92')]
#
# merging 381 + 762
# num_tok MOC 1143
# chunking [(9781910797495, 'chp12', 'sect91', 'sect91'), (9781910797495, 'chp12', 'sect92', 'sect92'), (9781910797495, 'chp12', 'sect93', 'sect93')]
#
#
# ############################
#
#
# book 9781910797556 chapter chp1
#
# num_tok MOC 7
# skipping [(9781910797556, 'chp1', 'chp1', 'chp1')]
#
# merging 7 + 47
# num_tok MOC 54
# skipping [(9781910797556, 'chp1', 'chp1', 'chp1'), (9781910797556, 'chp1', 'sect1', 'sect1')]
#
# merging 54 + 487
# num_tok MOC 541
# skipping [(9781910797556, 'chp1', 'chp1', 'chp1'), (9781910797556, 'chp1', 'sect1', 'sect1'), (9781910797556, 'chp1', 'sect2', 'sect2')]
#
# merging 541 + 202
# num_tok MOC 743
# summ [(9781910797556, 'chp1', 'chp1', 'chp1'), (9781910797556, 'chp1', 'sect1', 'sect1'), (9781910797556, 'chp1', 'sect2', 'sect2'), (9781910797556, 'chp1', 'sect3', 'sect3')]
#
# num_tok MOC 162
# skipping [(9781910797556, 'chp1', 'sect4', 'sect4')]
#
# merging 162 + 187
# num_tok MOC 349
# skipping [(9781910797556, 'chp1', 'sect4', 'sect4'), (9781910797556, 'chp1', 'sect5', 'sect5')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1092
# chunking [(9781910797556, 'chp1', 'chp1', 'chp1'), (9781910797556, 'chp1', 'sect1', 'sect1'), (9781910797556, 'chp1', 'sect2', 'sect2'), (9781910797556, 'chp1', 'sect3', 'sect3'), (9781910797556, 'chp1', 'sect4', 'sect4'), (9781910797556, 'chp1', 'sect5', 'sect5')]
#
# ############################
#
#
# book 9781910797556 chapter chp2
#
# num_tok MOC 8
# skipping [(9781910797556, 'chp2', 'chp2', 'chp2')]
#
# merging 8 + 109
# num_tok MOC 117
# skipping [(9781910797556, 'chp2', 'chp2', 'chp2'), (9781910797556, 'chp2', 'sect7', 'sect7')]
#
# merging 117 + 865
# num_tok MOC 982
# summ [(9781910797556, 'chp2', 'chp2', 'chp2'), (9781910797556, 'chp2', 'sect7', 'sect7'), (9781910797556, 'chp2', 'sect8', 'sect8')]
#
# num_tok MOC 774
# summ [(9781910797556, 'chp2', 'sect9', 'sect9')]
#
#
# ############################
#
#
# book 9781910797556 chapter chp3
#
# num_tok MOC 10
# skipping [(9781910797556, 'chp3', 'chp3', 'chp3')]
#
# merging 10 + 366
# num_tok MOC 376
# skipping [(9781910797556, 'chp3', 'chp3', 'chp3'), (9781910797556, 'chp3', 'sect11', 'sect11')]
#
# merging 376 + 461
# num_tok MOC 837
# summ [(9781910797556, 'chp3', 'chp3', 'chp3'), (9781910797556, 'chp3', 'sect11', 'sect11'), (9781910797556, 'chp3', 'sect12', 'sect12')]
#
# num_tok MOC 692
# skipping [(9781910797556, 'chp3', 'sect13', 'sect13')]
#
# merging 692 + 124
# num_tok MOC 816
# summ [(9781910797556, 'chp3', 'sect13', 'sect13'), (9781910797556, 'chp3', 'sect14', 'sect14')]
#
#
# ############################
#
#
# book 9781910797556 chapter chp4
#
# num_tok MOC 125
# skipping [(9781910797556, 'chp4', 'chp4', 'chp4')]
#
# merging 125 + 176
# num_tok MOC 301
# skipping [(9781910797556, 'chp4', 'chp4', 'chp4'), (9781910797556, 'chp4', 'sect16', 'sect16')]
#
# merging 301 + 137
# num_tok MOC 438
# skipping [(9781910797556, 'chp4', 'chp4', 'chp4'), (9781910797556, 'chp4', 'sect16', 'sect16'), (9781910797556, 'chp4', 'sect17', 'sect17')]
#
# merging 438 + 930
# num_tok MOC 1368
# chunking [(9781910797556, 'chp4', 'chp4', 'chp4'), (9781910797556, 'chp4', 'sect16', 'sect16'), (9781910797556, 'chp4', 'sect17', 'sect17'), (9781910797556, 'chp4', 'sect18', 'sect18')]
#
# num_tok MOC 127
# skipping [(9781910797556, 'chp4', 'sect19', 'sect19')]
#
# merging 127 + 56
# num_tok MOC 183
# skipping [(9781910797556, 'chp4', 'sect19', 'sect19'), (9781910797556, 'chp4', 'sect20', 'sect20')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1551
# chunking [(9781910797556, 'chp4', 'chp4', 'chp4'), (9781910797556, 'chp4', 'sect16', 'sect16'), (9781910797556, 'chp4', 'sect17', 'sect17'), (9781910797556, 'chp4', 'sect18', 'sect18'), (9781910797556, 'chp4', 'sect19', 'sect19'), (9781910797556, 'chp4', 'sect20', 'sect20')]
#
# ############################
#
#
# book 9781910797587 chapter chp01
#
# num_tok MOC 171
# skipping [(9781910797587, 'chp01', 'chp01', 'chp01')]
#
# merging 171 + 1051
# num_tok MOC 1222
# chunking [(9781910797587, 'chp01', 'chp01', 'chp01'), (9781910797587, 'chp01', 'sect1', 'sect1')]
#
# num_tok MOC 147
# skipping [(9781910797587, 'chp01', 'sect2', 'sect2')]
#
# merging 147 + 521
# num_tok MOC 668
# skipping [(9781910797587, 'chp01', 'sect2', 'sect2'), (9781910797587, 'chp01', 'sect3', 'sect3')]
#
# merging 668 + 787
# num_tok MOC 1455
# chunking [(9781910797587, 'chp01', 'sect2', 'sect2'), (9781910797587, 'chp01', 'sect3', 'sect3'), (9781910797587, 'chp01', 'sect4', 'sect4')]
#
# num_tok MOC 172
# skipping [(9781910797587, 'chp01', 'sect5', 'sect5')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1627
# chunking [(9781910797587, 'chp01', 'sect2', 'sect2'), (9781910797587, 'chp01', 'sect3', 'sect3'), (9781910797587, 'chp01', 'sect4', 'sect4'), (9781910797587, 'chp01', 'sect5', 'sect5')]
#
# ############################
#
#
# book 9781910797587 chapter chp02
#
# num_tok MOC 156
# skipping [(9781910797587, 'chp02', 'chp02', 'chp02')]
#
# merging 156 + 689
# num_tok MOC 845
# summ [(9781910797587, 'chp02', 'chp02', 'chp02'), (9781910797587, 'chp02', 'sect7', 'sect7')]
#
# num_tok MOC 255
# skipping [(9781910797587, 'chp02', 'sect8', 'sect8')]
#
# merging 255 + 987
# num_tok MOC 1242
# chunking [(9781910797587, 'chp02', 'sect8', 'sect8'), (9781910797587, 'chp02', 'sect9', 'sect9')]
#
# num_tok MOC 184
# skipping [(9781910797587, 'chp02', 'sect10', 'sect10')]
#
# merging 184 + 339
# num_tok MOC 523
# skipping [(9781910797587, 'chp02', 'sect10', 'sect10'), (9781910797587, 'chp02', 'sect11', 'sect11')]
#
# merging 523 + 190
# num_tok MOC 713
# skipping [(9781910797587, 'chp02', 'sect10', 'sect10'), (9781910797587, 'chp02', 'sect11', 'sect11'), (9781910797587, 'chp02', 'sect12', 'sect12')]
#
# merging 713 + 441
# num_tok MOC 1154
# chunking [(9781910797587, 'chp02', 'sect10', 'sect10'), (9781910797587, 'chp02', 'sect11', 'sect11'), (9781910797587, 'chp02', 'sect12', 'sect12'), (9781910797587, 'chp02', 'sect13', 'sect13')]
#
#
# ############################
#
#
# book 9781910797587 chapter chp03
#
# num_tok MOC 192
# skipping [(9781910797587, 'chp03', 'chp03', 'chp03')]
#
# merging 192 + 149
# num_tok MOC 341
# skipping [(9781910797587, 'chp03', 'chp03', 'chp03'), (9781910797587, 'chp03', 'sect15', 'sect15')]
#
# merging 341 + 841
# num_tok MOC 1182
# chunking [(9781910797587, 'chp03', 'chp03', 'chp03'), (9781910797587, 'chp03', 'sect15', 'sect15'), (9781910797587, 'chp03', 'sect16', 'sect16')]
#
# num_tok MOC 482
# skipping [(9781910797587, 'chp03', 'sect17', 'sect17')]
#
# merging 482 + 155
# num_tok MOC 637
# skipping [(9781910797587, 'chp03', 'sect17', 'sect17'), (9781910797587, 'chp03', 'sect18', 'sect18')]
#
# merging 637 + 121
# num_tok MOC 758
# summ [(9781910797587, 'chp03', 'sect17', 'sect17'), (9781910797587, 'chp03', 'sect18', 'sect18'), (9781910797587, 'chp03', 'sect19', 'sect19')]
#
# num_tok MOC 531
# skipping [(9781910797587, 'chp03', 'sect20', 'sect20')]
#
# merging 531 + 180
# num_tok MOC 711
# skipping [(9781910797587, 'chp03', 'sect20', 'sect20'), (9781910797587, 'chp03', 'sect21', 'sect21')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1469
# chunking [(9781910797587, 'chp03', 'sect17', 'sect17'), (9781910797587, 'chp03', 'sect18', 'sect18'), (9781910797587, 'chp03', 'sect19', 'sect19'), (9781910797587, 'chp03', 'sect20', 'sect20'), (9781910797587, 'chp03', 'sect21', 'sect21')]
#
# ############################
#
#
# book 9781910797587 chapter chp04
#
# num_tok MOC 161
# skipping [(9781910797587, 'chp04', 'chp04', 'chp04')]
#
# merging 161 + 2160
# num_tok MOC 2321
# chunking [(9781910797587, 'chp04', 'chp04', 'chp04'), (9781910797587, 'chp04', 'sect23', 'sect23')]
#
# num_tok MOC 746
# summ [(9781910797587, 'chp04', 'sect24', 'sect24')]
#
# num_tok MOC 757
# summ [(9781910797587, 'chp04', 'sect25', 'sect25')]
#
#
# ############################
#
#
# book 9781910797587 chapter chp05
#
# num_tok MOC 149
# skipping [(9781910797587, 'chp05', 'chp05', 'chp05')]
#
# merging 149 + 504
# num_tok MOC 653
# skipping [(9781910797587, 'chp05', 'chp05', 'chp05'), (9781910797587, 'chp05', 'sect27', 'sect27')]
#
# merging 653 + 1017
# num_tok MOC 1670
# chunking [(9781910797587, 'chp05', 'chp05', 'chp05'), (9781910797587, 'chp05', 'sect27', 'sect27'), (9781910797587, 'chp05', 'sect28', 'sect28')]
#
# num_tok MOC 806
# summ [(9781910797587, 'chp05', 'sect29', 'sect29')]
#
# num_tok MOC 1021
# chunking [(9781910797587, 'chp05', 'sect30', 'sect30')]
#
#
# ############################
#
#
# book 9781910797587 chapter chp06
#
# num_tok MOC 6
# skipping [(9781910797587, 'chp06', 'chp06', 'chp06')]
#
# merging 6 + 166
# num_tok MOC 172
# skipping [(9781910797587, 'chp06', 'chp06', 'chp06'), (9781910797587, 'chp06', 'sect32', 'sect32')]
#
# merging 172 + 407
# num_tok MOC 579
# skipping [(9781910797587, 'chp06', 'chp06', 'chp06'), (9781910797587, 'chp06', 'sect32', 'sect32'), (9781910797587, 'chp06', 'sect33', 'sect33')]
#
# merging 579 + 477
# num_tok MOC 1056
# chunking [(9781910797587, 'chp06', 'chp06', 'chp06'), (9781910797587, 'chp06', 'sect32', 'sect32'), (9781910797587, 'chp06', 'sect33', 'sect33'), (9781910797587, 'chp06', 'sect34', 'sect34')]
#
# num_tok MOC 167
# skipping [(9781910797587, 'chp06', 'sect35', 'sect35')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1223
# chunking [(9781910797587, 'chp06', 'chp06', 'chp06'), (9781910797587, 'chp06', 'sect32', 'sect32'), (9781910797587, 'chp06', 'sect33', 'sect33'), (9781910797587, 'chp06', 'sect34', 'sect34'), (9781910797587, 'chp06', 'sect35', 'sect35')]
#
# ############################
#
#
# book 9781910797587 chapter chp07
#
# num_tok MOC 8
# skipping [(9781910797587, 'chp07', 'chp07', 'chp07')]
#
# merging 8 + 182
# num_tok MOC 190
# skipping [(9781910797587, 'chp07', 'chp07', 'chp07'), (9781910797587, 'chp07', 'sect37', 'sect37')]
#
# merging 190 + 171
# num_tok MOC 361
# skipping [(9781910797587, 'chp07', 'chp07', 'chp07'), (9781910797587, 'chp07', 'sect37', 'sect37'), (9781910797587, 'chp07', 'sect38', 'sect38')]
#
# merging 361 + 892
# num_tok MOC 1253
# chunking [(9781910797587, 'chp07', 'chp07', 'chp07'), (9781910797587, 'chp07', 'sect37', 'sect37'), (9781910797587, 'chp07', 'sect38', 'sect38'), (9781910797587, 'chp07', 'sect39', 'sect39')]
#
# num_tok MOC 188
# skipping [(9781910797587, 'chp07', 'sect40', 'sect40')]
#
# merging 188 + 406
# num_tok MOC 594
# skipping [(9781910797587, 'chp07', 'sect40', 'sect40'), (9781910797587, 'chp07', 'sect41', 'sect41')]
#
# merging 594 + 64
# num_tok MOC 658
# skipping [(9781910797587, 'chp07', 'sect40', 'sect40'), (9781910797587, 'chp07', 'sect41', 'sect41'), (9781910797587, 'chp07', 'sect42', 'sect42')]
#
# merging 658 + 88
# num_tok MOC 746
# summ [(9781910797587, 'chp07', 'sect40', 'sect40'), (9781910797587, 'chp07', 'sect41', 'sect41'), (9781910797587, 'chp07', 'sect42', 'sect42'), (9781910797587, 'chp07', 'sect43', 'sect43')]
#
# num_tok MOC 483
# skipping [(9781910797587, 'chp07', 'sect44', 'sect44')]
#
# merging 483 + 135
# num_tok MOC 618
# skipping [(9781910797587, 'chp07', 'sect44', 'sect44'), (9781910797587, 'chp07', 'sect45', 'sect45')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1364
# chunking [(9781910797587, 'chp07', 'sect40', 'sect40'), (9781910797587, 'chp07', 'sect41', 'sect41'), (9781910797587, 'chp07', 'sect42', 'sect42'), (9781910797587, 'chp07', 'sect43', 'sect43'), (9781910797587, 'chp07', 'sect44', 'sect44'), (9781910797587, 'chp07', 'sect45', 'sect45')]
#
# ############################
#
#
# book 9781910797587 chapter chp08
#
# num_tok MOC 160
# skipping [(9781910797587, 'chp08', 'chp08', 'chp08')]
#
# merging 160 + 453
# num_tok MOC 613
# skipping [(9781910797587, 'chp08', 'chp08', 'chp08'), (9781910797587, 'chp08', 'sect47', 'sect47')]
#
# merging 613 + 1637
# num_tok MOC 2250
# chunking [(9781910797587, 'chp08', 'chp08', 'chp08'), (9781910797587, 'chp08', 'sect47', 'sect47'), (9781910797587, 'chp08', 'sect48', 'sect48')]
#
# num_tok MOC 153
# skipping [(9781910797587, 'chp08', 'sect49', 'sect49')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 2403
# chunking [(9781910797587, 'chp08', 'chp08', 'chp08'), (9781910797587, 'chp08', 'sect47', 'sect47'), (9781910797587, 'chp08', 'sect48', 'sect48'), (9781910797587, 'chp08', 'sect49', 'sect49')]
#
# ############################
#
#
# book 9781910797587 chapter chp09
#
# num_tok MOC 8
# skipping [(9781910797587, 'chp09', 'chp09', 'chp09')]
#
# merging 8 + 1192
# num_tok MOC 1200
# chunking [(9781910797587, 'chp09', 'chp09', 'chp09'), (9781910797587, 'chp09', 'sect51', 'sect51')]
#
# num_tok MOC 454
# skipping [(9781910797587, 'chp09', 'sect52', 'sect52')]
#
# merging 454 + 148
# num_tok MOC 602
# skipping [(9781910797587, 'chp09', 'sect52', 'sect52'), (9781910797587, 'chp09', 'sect53', 'sect53')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1802
# chunking [(9781910797587, 'chp09', 'chp09', 'chp09'), (9781910797587, 'chp09', 'sect51', 'sect51'), (9781910797587, 'chp09', 'sect52', 'sect52'), (9781910797587, 'chp09', 'sect53', 'sect53')]
#
# ############################
#
#
# book 9781910797587 chapter chp10
#
# num_tok MOC 111
# skipping [(9781910797587, 'chp10', 'chp10', 'chp10')]
#
# merging 111 + 211
# num_tok MOC 322
# skipping [(9781910797587, 'chp10', 'chp10', 'chp10'), (9781910797587, 'chp10', 'sect55', 'sect55')]
#
# merging 322 + 285
# num_tok MOC 607
# skipping [(9781910797587, 'chp10', 'chp10', 'chp10'), (9781910797587, 'chp10', 'sect55', 'sect55'), (9781910797587, 'chp10', 'sect56', 'sect56')]
#
# merging 607 + 289
# num_tok MOC 896
# summ [(9781910797587, 'chp10', 'chp10', 'chp10'), (9781910797587, 'chp10', 'sect55', 'sect55'), (9781910797587, 'chp10', 'sect56', 'sect56'), (9781910797587, 'chp10', 'sect57', 'sect57')]
#
# num_tok MOC 667
# skipping [(9781910797587, 'chp10', 'sect58', 'sect58')]
#
# merging 667 + 471
# num_tok MOC 1138
# chunking [(9781910797587, 'chp10', 'sect58', 'sect58'), (9781910797587, 'chp10', 'sect59', 'sect59')]
#
# num_tok MOC 246
# skipping [(9781910797587, 'chp10', 'sect60', 'sect60')]
#
# merging 246 + 405
# num_tok MOC 651
# skipping [(9781910797587, 'chp10', 'sect60', 'sect60'), (9781910797587, 'chp10', 'sect61', 'sect61')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1789
# chunking [(9781910797587, 'chp10', 'sect58', 'sect58'), (9781910797587, 'chp10', 'sect59', 'sect59'), (9781910797587, 'chp10', 'sect60', 'sect60'), (9781910797587, 'chp10', 'sect61', 'sect61')]
#
# ############################
#
#
# book 9781910797617 chapter chp1
#
# num_tok MOC 117
# skipping [(9781910797617, 'chp1', 'chp1', 'chp1')]
#
# merging 117 + 410
# num_tok MOC 527
# skipping [(9781910797617, 'chp1', 'chp1', 'chp1'), (9781910797617, 'chp1', 'sect1', 'sect1')]
#
# merging 527 + 223
# num_tok MOC 750
# summ [(9781910797617, 'chp1', 'chp1', 'chp1'), (9781910797617, 'chp1', 'sect1', 'sect1'), (9781910797617, 'chp1', 'sect2', 'sect2')]
#
# num_tok MOC 1293
# chunking [(9781910797617, 'chp1', 'sect3', 'sect3')]
#
# num_tok MOC 952
# summ [(9781910797617, 'chp1', 'sect4', 'sect4')]
#
#
# ############################
#
#
# book 9781910797617 chapter chp2
#
# num_tok MOC 516
# skipping [(9781910797617, 'chp2', 'sect6', 'sect6')]
#
# merging 516 + 513
# num_tok MOC 1029
# chunking [(9781910797617, 'chp2', 'sect6', 'sect6'), (9781910797617, 'chp2', 'sect7', 'sect7')]
#
# num_tok MOC 207
# skipping [(9781910797617, 'chp2', 'sect8', 'sect8')]
#
# merging 207 + 379
# num_tok MOC 586
# skipping [(9781910797617, 'chp2', 'sect8', 'sect8'), (9781910797617, 'chp2', 'sect9', 'sect9')]
#
# merging 586 + 920
# num_tok MOC 1506
# chunking [(9781910797617, 'chp2', 'sect8', 'sect8'), (9781910797617, 'chp2', 'sect9', 'sect9'), (9781910797617, 'chp2', 'sect10', 'sect10')]
#
#
# ############################
#
#
# book 9781910797617 chapter chp3
#
# num_tok MOC 141
# skipping [(9781910797617, 'chp3', 'chp3', 'chp3')]
#
# merging 141 + 84
# num_tok MOC 225
# skipping [(9781910797617, 'chp3', 'chp3', 'chp3'), (9781910797617, 'chp3', 'sect12', 'sect12')]
#
# merging 225 + 754
# num_tok MOC 979
# summ [(9781910797617, 'chp3', 'chp3', 'chp3'), (9781910797617, 'chp3', 'sect12', 'sect12'), (9781910797617, 'chp3', 'sect13', 'sect13')]
#
# num_tok MOC 1346
# chunking [(9781910797617, 'chp3', 'sect14', 'sect14')]
#
# num_tok MOC 1695
# chunking [(9781910797617, 'chp3', 'sect15', 'sect15')]
#
# num_tok MOC 400
# skipping [(9781910797617, 'chp3', 'sect16', 'sect16')]
#
# merging 400 + 173
# num_tok MOC 573
# skipping [(9781910797617, 'chp3', 'sect16', 'sect16'), (9781910797617, 'chp3', 'sect17', 'sect17')]
#
# merging 573 + 469
# num_tok MOC 1042
# chunking [(9781910797617, 'chp3', 'sect16', 'sect16'), (9781910797617, 'chp3', 'sect17', 'sect17'), (9781910797617, 'chp3', 'sect18', 'sect18')]
#
# num_tok MOC 759
# summ [(9781910797617, 'chp3', 'sect19', 'sect19')]
#
# num_tok MOC 816
# summ [(9781910797617, 'chp3', 'sect20', 'sect20')]
#
#
# ############################
#
#
# book 9781910797617 chapter chp4
#
# num_tok MOC 761
# summ [(9781910797617, 'chp4', 'chp4', 'chp4')]
#
# num_tok MOC 707
# skipping [(9781910797617, 'chp4', 'sect23', 'sect23')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1468
# chunking [(9781910797617, 'chp4', 'chp4', 'chp4'), (9781910797617, 'chp4', 'sect23', 'sect23')]
#
# ############################
#
#
# book 9781910797617 chapter chp5
#
# num_tok MOC 165
# skipping [(9781910797617, 'chp5', 'chp5', 'chp5')]
#
# merging 165 + 119
# num_tok MOC 284
# skipping [(9781910797617, 'chp5', 'chp5', 'chp5'), (9781910797617, 'chp5', 'sect25', 'sect25')]
#
# merging 284 + 74
# num_tok MOC 358
# skipping [(9781910797617, 'chp5', 'chp5', 'chp5'), (9781910797617, 'chp5', 'sect25', 'sect25'), (9781910797617, 'chp5', 'sect26', 'sect26')]
#
# merging 358 + 740
# num_tok MOC 1098
# chunking [(9781910797617, 'chp5', 'chp5', 'chp5'), (9781910797617, 'chp5', 'sect25', 'sect25'), (9781910797617, 'chp5', 'sect26', 'sect26'), (9781910797617, 'chp5', 'sect27', 'sect27')]
#
# num_tok MOC 376
# skipping [(9781910797617, 'chp5', 'sect28', 'sect28')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1474
# chunking [(9781910797617, 'chp5', 'chp5', 'chp5'), (9781910797617, 'chp5', 'sect25', 'sect25'), (9781910797617, 'chp5', 'sect26', 'sect26'), (9781910797617, 'chp5', 'sect27', 'sect27'), (9781910797617, 'chp5', 'sect28', 'sect28')]
#
# ############################
#
#
# book 9781910797617 chapter chp6
#
# num_tok MOC 96
# skipping [(9781910797617, 'chp6', 'chp6', 'chp6')]
#
# merging 96 + 1245
# num_tok MOC 1341
# chunking [(9781910797617, 'chp6', 'chp6', 'chp6'), (9781910797617, 'chp6', 'sect30', 'sect30')]
#
# num_tok MOC 521
# skipping [(9781910797617, 'chp6', 'sect31', 'sect31')]
#
# merging 521 + 509
# num_tok MOC 1030
# chunking [(9781910797617, 'chp6', 'sect31', 'sect31'), (9781910797617, 'chp6', 'sect32', 'sect32')]
#
#
# ############################
#
#
# book 9781910797631 chapter chp1
#
# num_tok MOC 571
# skipping [(9781910797631, 'chp1', 'sect1', 'sect1')]
#
# merging 571 + 381
# num_tok MOC 952
# summ [(9781910797631, 'chp1', 'sect1', 'sect1'), (9781910797631, 'chp1', 'sect2', 'sect2')]
#
# num_tok MOC 397
# skipping [(9781910797631, 'chp1', 'sect3', 'sect3')]
#
# merging 397 + 1255
# num_tok MOC 1652
# chunking [(9781910797631, 'chp1', 'sect3', 'sect3'), (9781910797631, 'chp1', 'sect4', 'sect4')]
#
#
# ############################
#
#
# book 9781910797631 chapter chp2
#
# num_tok MOC 6
# skipping [(9781910797631, 'chp2', 'chp2', 'chp2')]
#
# merging 6 + 993
# num_tok MOC 999
# summ [(9781910797631, 'chp2', 'chp2', 'chp2'), (9781910797631, 'chp2', 'sect6', 'sect6')]
#
# num_tok MOC 277
# skipping [(9781910797631, 'chp2', 'sect7', 'sect7')]
#
# merging 277 + 1200
# num_tok MOC 1477
# chunking [(9781910797631, 'chp2', 'sect7', 'sect7'), (9781910797631, 'chp2', 'sect8', 'sect8')]
#
# num_tok MOC 51
# skipping [(9781910797631, 'chp2', 'sect9', 'sect9')]
#
# merging 51 + 78
# num_tok MOC 129
# skipping [(9781910797631, 'chp2', 'sect9', 'sect9'), (9781910797631, 'chp2', 'sect10', 'sect10')]
#
# merging 129 + 85
# num_tok MOC 214
# skipping [(9781910797631, 'chp2', 'sect9', 'sect9'), (9781910797631, 'chp2', 'sect10', 'sect10'), (9781910797631, 'chp2', 'sect11', 'sect11')]
#
# merging 214 + 826
# num_tok MOC 1040
# chunking [(9781910797631, 'chp2', 'sect9', 'sect9'), (9781910797631, 'chp2', 'sect10', 'sect10'), (9781910797631, 'chp2', 'sect11', 'sect11'), (9781910797631, 'chp2', 'sect12', 'sect12')]
#
#
# ############################
#
#
# book 9781910797631 chapter chp3
#
# num_tok MOC 37
# skipping [(9781910797631, 'chp3', 'chp3', 'chp3')]
#
# merging 37 + 224
# num_tok MOC 261
# skipping [(9781910797631, 'chp3', 'chp3', 'chp3'), (9781910797631, 'chp3', 'sect13', 'sect13')]
#
# merging 261 + 2362
# num_tok MOC 2623
# chunking [(9781910797631, 'chp3', 'chp3', 'chp3'), (9781910797631, 'chp3', 'sect13', 'sect13'), (9781910797631, 'chp3', 'sect14', 'sect14')]
#
# num_tok MOC 642
# skipping [(9781910797631, 'chp3', 'sect14', 'sect14-1_sub_sect14')]
#
# merging 642 + 407
# num_tok MOC 1049
# chunking [(9781910797631, 'chp3', 'sect14', 'sect14-1_sub_sect14'), (9781910797631, 'chp3', 'sect15', 'sect15')]
#
# num_tok MOC 761
# summ [(9781910797631, 'chp3', 'sect16', 'sect16')]
#
# num_tok MOC 911
# summ [(9781910797631, 'chp3', 'sect17', 'sect17')]
#
#
# ############################
#
#
# book 9781910797631 chapter chp4
#
# num_tok MOC 7
# skipping [(9781910797631, 'chp4', 'chp4', 'chp4')]
#
# merging 7 + 623
# num_tok MOC 630
# skipping [(9781910797631, 'chp4', 'chp4', 'chp4'), (9781910797631, 'chp4', 'sect19', 'sect19')]
#
# merging 630 + 1176
# num_tok MOC 1806
# chunking [(9781910797631, 'chp4', 'chp4', 'chp4'), (9781910797631, 'chp4', 'sect19', 'sect19'), (9781910797631, 'chp4', 'sect20', 'sect20')]
#
# num_tok MOC 891
# summ [(9781910797631, 'chp4', 'sect21', 'sect21')]
#
# num_tok MOC 156
# skipping [(9781910797631, 'chp4', 'sect22', 'sect22')]
#
# merging 156 + 1586
# num_tok MOC 1742
# chunking [(9781910797631, 'chp4', 'sect22', 'sect22'), (9781910797631, 'chp4', 'sect23', 'sect23')]
#
#
# ############################
#
#
# book 9781910797631 chapter chp5
#
# num_tok MOC 37
# skipping [(9781910797631, 'chp5', 'chp5', 'chp5')]
#
# merging 37 + 108
# num_tok MOC 145
# skipping [(9781910797631, 'chp5', 'chp5', 'chp5'), (9781910797631, 'chp5', 'sect25', 'sect25')]
#
# merging 145 + 200
# num_tok MOC 345
# skipping [(9781910797631, 'chp5', 'chp5', 'chp5'), (9781910797631, 'chp5', 'sect25', 'sect25'), (9781910797631, 'chp5', 'sect26', 'sect26')]
#
# merging 345 + 221
# num_tok MOC 566
# skipping [(9781910797631, 'chp5', 'chp5', 'chp5'), (9781910797631, 'chp5', 'sect25', 'sect25'), (9781910797631, 'chp5', 'sect26', 'sect26'), (9781910797631, 'chp5', 'sect27', 'sect27')]
#
# merging 566 + 299
# num_tok MOC 865
# summ [(9781910797631, 'chp5', 'chp5', 'chp5'), (9781910797631, 'chp5', 'sect25', 'sect25'), (9781910797631, 'chp5', 'sect26', 'sect26'), (9781910797631, 'chp5', 'sect27', 'sect27'), (9781910797631, 'chp5', 'sect28', 'sect28')]
#
# num_tok MOC 811
# summ [(9781910797631, 'chp5', 'sect29', 'sect29')]
#
# num_tok MOC 107
# skipping [(9781910797631, 'chp5', 'sect30', 'sect30')]
#
# merging 107 + 1051
# num_tok MOC 1158
# chunking [(9781910797631, 'chp5', 'sect30', 'sect30'), (9781910797631, 'chp5', 'sect31', 'sect31')]
#
# num_tok MOC 352
# skipping [(9781910797631, 'chp5', 'sect32', 'sect32')]
#
# merging 352 + 255
# num_tok MOC 607
# skipping [(9781910797631, 'chp5', 'sect32', 'sect32'), (9781910797631, 'chp5', 'sect33', 'sect33')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1765
# chunking [(9781910797631, 'chp5', 'sect30', 'sect30'), (9781910797631, 'chp5', 'sect31', 'sect31'), (9781910797631, 'chp5', 'sect32', 'sect32'), (9781910797631, 'chp5', 'sect33', 'sect33')]
#
# ############################
#
#
# book 9781910797631 chapter chp6
#
# num_tok MOC 6
# skipping [(9781910797631, 'chp6', 'chp6', 'chp6')]
#
# merging 6 + 1056
# num_tok MOC 1062
# chunking [(9781910797631, 'chp6', 'chp6', 'chp6'), (9781910797631, 'chp6', 'sect34', 'sect34')]
#
# num_tok MOC 242
# skipping [(9781910797631, 'chp6', 'sect35', 'sect35')]
#
# merging 242 + 546
# num_tok MOC 788
# summ [(9781910797631, 'chp6', 'sect35', 'sect35'), (9781910797631, 'chp6', 'sect36', 'sect36')]
#
# num_tok MOC 589
# skipping [(9781910797631, 'chp6', 'sect37', 'sect37')]
#
# merging 589 + 1764
# num_tok MOC 2353
# chunking [(9781910797631, 'chp6', 'sect37', 'sect37'), (9781910797631, 'chp6', 'sect38', 'sect38')]
#
# num_tok MOC 2694
# chunking [(9781910797631, 'chp6', 'sect39', 'sect39')]
#
# num_tok MOC 1608
# chunking [(9781910797631, 'chp6', 'sect39', 'sect39-1_sub_sect39')]
#
# num_tok MOC 269
# skipping [(9781910797631, 'chp6', 'sect40', 'sect40')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1877
# chunking [(9781910797631, 'chp6', 'sect39', 'sect39-1_sub_sect39'), (9781910797631, 'chp6', 'sect40', 'sect40')]
#
# ############################
#
#
# book 9781910797631 chapter chp7
#
# num_tok MOC 545
# skipping [(9781910797631, 'chp7', 'chp7', 'chp7')]
#
# merging 545 + 176
# num_tok MOC 721
# summ [(9781910797631, 'chp7', 'chp7', 'chp7'), (9781910797631, 'chp7', 'sect42', 'sect42')]
#
# num_tok MOC 170
# skipping [(9781910797631, 'chp7', 'sect43', 'sect43')]
#
# merging 170 + 278
# num_tok MOC 448
# skipping [(9781910797631, 'chp7', 'sect43', 'sect43'), (9781910797631, 'chp7', 'sect44', 'sect44')]
#
# merging 448 + 133
# num_tok MOC 581
# skipping [(9781910797631, 'chp7', 'sect43', 'sect43'), (9781910797631, 'chp7', 'sect44', 'sect44'), (9781910797631, 'chp7', 'sect45', 'sect45')]
#
# merging 581 + 332
# num_tok MOC 913
# summ [(9781910797631, 'chp7', 'sect43', 'sect43'), (9781910797631, 'chp7', 'sect44', 'sect44'), (9781910797631, 'chp7', 'sect45', 'sect45'), (9781910797631, 'chp7', 'sect46', 'sect46')]
#
# num_tok MOC 245
# skipping [(9781910797631, 'chp7', 'sect47', 'sect47')]
#
# merging 245 + 910
# num_tok MOC 1155
# chunking [(9781910797631, 'chp7', 'sect47', 'sect47'), (9781910797631, 'chp7', 'sect48', 'sect48')]
#
#
# ############################
#
#
# book 9781910797631 chapter chp8
#
# num_tok MOC 285
# skipping [(9781910797631, 'chp8', 'chp8', 'chp8')]
#
# merging 285 + 294
# num_tok MOC 579
# skipping [(9781910797631, 'chp8', 'chp8', 'chp8'), (9781910797631, 'chp8', 'sect50', 'sect50')]
#
# merging 579 + 2146
# num_tok MOC 2725
# chunking [(9781910797631, 'chp8', 'chp8', 'chp8'), (9781910797631, 'chp8', 'sect50', 'sect50'), (9781910797631, 'chp8', 'sect51', 'sect51')]
#
# num_tok MOC 257
# skipping [(9781910797631, 'chp8', 'sect52', 'sect52')]
#
# merging 257 + 319
# num_tok MOC 576
# skipping [(9781910797631, 'chp8', 'sect52', 'sect52'), (9781910797631, 'chp8', 'sect53', 'sect53')]
#
# merging 576 + 810
# num_tok MOC 1386
# chunking [(9781910797631, 'chp8', 'sect52', 'sect52'), (9781910797631, 'chp8', 'sect53', 'sect53'), (9781910797631, 'chp8', 'sect54', 'sect54')]
#
# num_tok MOC 323
# skipping [(9781910797631, 'chp8', 'sect55', 'sect55')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1709
# chunking [(9781910797631, 'chp8', 'sect52', 'sect52'), (9781910797631, 'chp8', 'sect53', 'sect53'), (9781910797631, 'chp8', 'sect54', 'sect54'), (9781910797631, 'chp8', 'sect55', 'sect55')]
#
# ############################
#
#
# book 9781910797662 chapter ch01
#
# num_tok MOC 8
# skipping [(9781910797662, 'ch01', 'ch01', 'ch01')]
#
# merging 8 + 481
# num_tok MOC 489
# skipping [(9781910797662, 'ch01', 'ch01', 'ch01'), (9781910797662, 'ch01', 'sect1', 'sect1')]
#
# merging 489 + 1043
# num_tok MOC 1532
# chunking [(9781910797662, 'ch01', 'ch01', 'ch01'), (9781910797662, 'ch01', 'sect1', 'sect1'), (9781910797662, 'ch01', 'sect2', 'sect2')]
#
#
# ############################
#
#
# book 9781910797662 chapter ch02
#
# num_tok MOC 6
# skipping [(9781910797662, 'ch02', 'ch02', 'ch02')]
#
# merging 6 + 1657
# num_tok MOC 1663
# chunking [(9781910797662, 'ch02', 'ch02', 'ch02'), (9781910797662, 'ch02', 'sec14', 'sec14')]
#
# num_tok MOC 286
# skipping [(9781910797662, 'ch02', 'sect4', 'sect4')]
#
# merging 286 + 384
# num_tok MOC 670
# skipping [(9781910797662, 'ch02', 'sect4', 'sect4'), (9781910797662, 'ch02', 'sect5', 'sect5')]
#
# merging 670 + 393
# num_tok MOC 1063
# chunking [(9781910797662, 'ch02', 'sect4', 'sect4'), (9781910797662, 'ch02', 'sect5', 'sect5'), (9781910797662, 'ch02', 'sect6', 'sect6')]
#
# num_tok MOC 530
# skipping [(9781910797662, 'ch02', 'sect7', 'sect7')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1593
# chunking [(9781910797662, 'ch02', 'sect4', 'sect4'), (9781910797662, 'ch02', 'sect5', 'sect5'), (9781910797662, 'ch02', 'sect6', 'sect6'), (9781910797662, 'ch02', 'sect7', 'sect7')]
#
# ############################
#
#
# book 9781910797662 chapter ch03
#
# num_tok MOC 173
# skipping [(9781910797662, 'ch03', 'ch03', 'ch03')]
#
# merging 173 + 165
# num_tok MOC 338
# skipping [(9781910797662, 'ch03', 'ch03', 'ch03'), (9781910797662, 'ch03', 'sect9', 'sect9')]
#
# merging 338 + 144
# num_tok MOC 482
# skipping [(9781910797662, 'ch03', 'ch03', 'ch03'), (9781910797662, 'ch03', 'sect9', 'sect9'), (9781910797662, 'ch03', 'sect10', 'sect10')]
#
# merging 482 + 171
# num_tok MOC 653
# skipping [(9781910797662, 'ch03', 'ch03', 'ch03'), (9781910797662, 'ch03', 'sect9', 'sect9'), (9781910797662, 'ch03', 'sect10', 'sect10'), (9781910797662, 'ch03', 'sect11', 'sect11')]
#
# merging 653 + 63
# num_tok MOC 716
# skipping [(9781910797662, 'ch03', 'ch03', 'ch03'), (9781910797662, 'ch03', 'sect9', 'sect9'), (9781910797662, 'ch03', 'sect10', 'sect10'), (9781910797662, 'ch03', 'sect11', 'sect11'), (9781910797662, 'ch03', 'sect12', 'sect12')]
#
# merging 716 + 274
# num_tok MOC 990
# summ [(9781910797662, 'ch03', 'ch03', 'ch03'), (9781910797662, 'ch03', 'sect9', 'sect9'), (9781910797662, 'ch03', 'sect10', 'sect10'), (9781910797662, 'ch03', 'sect11', 'sect11'), (9781910797662, 'ch03', 'sect12', 'sect12'), (9781910797662, 'ch03', 'sect13', 'sect13')]
#
# num_tok MOC 298
# skipping [(9781910797662, 'ch03', 'sect14', 'sect14')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1288
# chunking [(9781910797662, 'ch03', 'ch03', 'ch03'), (9781910797662, 'ch03', 'sect9', 'sect9'), (9781910797662, 'ch03', 'sect10', 'sect10'), (9781910797662, 'ch03', 'sect11', 'sect11'), (9781910797662, 'ch03', 'sect12', 'sect12'), (9781910797662, 'ch03', 'sect13', 'sect13'), (9781910797662, 'ch03', 'sect14', 'sect14')]
#
# ############################
#
#
# book 9781910797662 chapter ch04
#
# num_tok MOC 67
# skipping [(9781910797662, 'ch04', 'sect16', 'sect16')]
#
# merging 67 + 127
# num_tok MOC 194
# skipping [(9781910797662, 'ch04', 'sect16', 'sect16'), (9781910797662, 'ch04', 'sect17', 'sect17')]
#
# merging 194 + 1878
# num_tok MOC 2072
# chunking [(9781910797662, 'ch04', 'sect16', 'sect16'), (9781910797662, 'ch04', 'sect17', 'sect17'), (9781910797662, 'ch04', 'sect18', 'sect18')]
#
#
# ############################
#
#
# book 9781910797662 chapter ch05
#
# num_tok MOC 12
# skipping [(9781910797662, 'ch05', 'ch05', 'ch05')]
#
# merging 12 + 115
# num_tok MOC 127
# skipping [(9781910797662, 'ch05', 'ch05', 'ch05'), (9781910797662, 'ch05', 'sect20', 'sect20')]
#
# merging 127 + 261
# num_tok MOC 388
# skipping [(9781910797662, 'ch05', 'ch05', 'ch05'), (9781910797662, 'ch05', 'sect20', 'sect20'), (9781910797662, 'ch05', 'sect21', 'sect21')]
#
# merging 388 + 100
# num_tok MOC 488
# skipping [(9781910797662, 'ch05', 'ch05', 'ch05'), (9781910797662, 'ch05', 'sect20', 'sect20'), (9781910797662, 'ch05', 'sect21', 'sect21'), (9781910797662, 'ch05', 'sect22', 'sect22')]
#
# merging 488 + 813
# num_tok MOC 1301
# chunking [(9781910797662, 'ch05', 'ch05', 'ch05'), (9781910797662, 'ch05', 'sect20', 'sect20'), (9781910797662, 'ch05', 'sect21', 'sect21'), (9781910797662, 'ch05', 'sect22', 'sect22'), (9781910797662, 'ch05', 'sect23', 'sect23')]
#
# num_tok MOC 915
# summ [(9781910797662, 'ch05', 'sect24', 'sect24')]
#
# num_tok MOC 440
# skipping [(9781910797662, 'ch05', 'sect25', 'sect25')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1355
# chunking [(9781910797662, 'ch05', 'sect24', 'sect24'), (9781910797662, 'ch05', 'sect25', 'sect25')]
#
# ############################
#
#
# book 9781910797662 chapter ch06
#
# num_tok MOC 9
# skipping [(9781910797662, 'ch06', 'ch06', 'ch06')]
#
# merging 9 + 846
# num_tok MOC 855
# summ [(9781910797662, 'ch06', 'ch06', 'ch06'), (9781910797662, 'ch06', 'sect27', 'sect27')]
#
# num_tok MOC 532
# skipping [(9781910797662, 'ch06', 'sect28', 'sect28')]
#
# merging 532 + 614
# num_tok MOC 1146
# chunking [(9781910797662, 'ch06', 'sect28', 'sect28'), (9781910797662, 'ch06', 'sect29', 'sect29')]
#
#
# ############################
#
#
# book 9781910797662 chapter ch07
#
# num_tok MOC 563
# skipping [(9781910797662, 'ch07', 'ch07', 'ch07')]
#
# merging 563 + 1112
# num_tok MOC 1675
# chunking [(9781910797662, 'ch07', 'ch07', 'ch07'), (9781910797662, 'ch07', 'sect31', 'sect31')]
#
# num_tok MOC 217
# skipping [(9781910797662, 'ch07', 'sect32', 'sect32')]
#
# merging 217 + 25
# num_tok MOC 242
# skipping [(9781910797662, 'ch07', 'sect32', 'sect32'), (9781910797662, 'ch07', 'sect33', 'sect33')]
#
# merging 242 + 266
# num_tok MOC 508
# skipping [(9781910797662, 'ch07', 'sect32', 'sect32'), (9781910797662, 'ch07', 'sect33', 'sect33'), (9781910797662, 'ch07', 'sect34', 'sect34')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 2183
# chunking [(9781910797662, 'ch07', 'ch07', 'ch07'), (9781910797662, 'ch07', 'sect31', 'sect31'), (9781910797662, 'ch07', 'sect32', 'sect32'), (9781910797662, 'ch07', 'sect33', 'sect33'), (9781910797662, 'ch07', 'sect34', 'sect34')]
#
# ############################
#
#
# book 9781910797662 chapter ch08
#
# num_tok MOC 135
# skipping [(9781910797662, 'ch08', 'ch08', 'ch08')]
#
# merging 135 + 614
# num_tok MOC 749
# summ [(9781910797662, 'ch08', 'ch08', 'ch08'), (9781910797662, 'ch08', 'sect36', 'sect36')]
#
# num_tok MOC 399
# skipping [(9781910797662, 'ch08', 'sect37', 'sect37')]
#
# merging 399 + 508
# num_tok MOC 907
# summ [(9781910797662, 'ch08', 'sect37', 'sect37'), (9781910797662, 'ch08', 'sect38', 'sect38')]
#
# num_tok MOC 914
# summ [(9781910797662, 'ch08', 'sect39', 'sect39')]
#
# num_tok MOC 300
# skipping [(9781910797662, 'ch08', 'sect40', 'sect40')]
#
# merging 300 + 265
# num_tok MOC 565
# skipping [(9781910797662, 'ch08', 'sect40', 'sect40'), (9781910797662, 'ch08', 'sect41', 'sect41')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1479
# chunking [(9781910797662, 'ch08', 'sect39', 'sect39'), (9781910797662, 'ch08', 'sect40', 'sect40'), (9781910797662, 'ch08', 'sect41', 'sect41')]
#
# ############################
#
#
# book 9781910797662 chapter ch09
#
# num_tok MOC 79
# skipping [(9781910797662, 'ch09', 'ch09', 'ch09')]
#
# merging 79 + 301
# num_tok MOC 380
# skipping [(9781910797662, 'ch09', 'ch09', 'ch09'), (9781910797662, 'ch09', 'sect43', 'sect43')]
#
# merging 380 + 296
# num_tok MOC 676
# skipping [(9781910797662, 'ch09', 'ch09', 'ch09'), (9781910797662, 'ch09', 'sect43', 'sect43'), (9781910797662, 'ch09', 'sect44', 'sect44')]
#
# merging 676 + 330
# num_tok MOC 1006
# summ [(9781910797662, 'ch09', 'ch09', 'ch09'), (9781910797662, 'ch09', 'sect43', 'sect43'), (9781910797662, 'ch09', 'sect44', 'sect44'), (9781910797662, 'ch09', 'sect45', 'sect45')]
#
# num_tok MOC 330
# skipping [(9781910797662, 'ch09', 'sect46', 'sect46')]
#
# merging 330 + 332
# num_tok MOC 662
# skipping [(9781910797662, 'ch09', 'sect46', 'sect46'), (9781910797662, 'ch09', 'sect47', 'sect47')]
#
# merging 662 + 456
# num_tok MOC 1118
# chunking [(9781910797662, 'ch09', 'sect46', 'sect46'), (9781910797662, 'ch09', 'sect47', 'sect47'), (9781910797662, 'ch09', 'sect48', 'sect48')]
#
# num_tok MOC 286
# skipping [(9781910797662, 'ch09', 'sect49', 'sect49')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1404
# chunking [(9781910797662, 'ch09', 'sect46', 'sect46'), (9781910797662, 'ch09', 'sect47', 'sect47'), (9781910797662, 'ch09', 'sect48', 'sect48'), (9781910797662, 'ch09', 'sect49', 'sect49')]
#
# ############################
#
#
# book 9781910797693 chapter chp1
#
# num_tok MOC 46
# skipping [(9781910797693, 'chp1', 'chp1', 'chp1')]
#
# merging 46 + 209
# num_tok MOC 255
# skipping [(9781910797693, 'chp1', 'chp1', 'chp1'), (9781910797693, 'chp1', 'sect1', 'sect1')]
#
# merging 255 + 116
# num_tok MOC 371
# skipping [(9781910797693, 'chp1', 'chp1', 'chp1'), (9781910797693, 'chp1', 'sect1', 'sect1'), (9781910797693, 'chp1', 'sect2', 'sect2')]
#
# merging 371 + 473
# num_tok MOC 844
# summ [(9781910797693, 'chp1', 'chp1', 'chp1'), (9781910797693, 'chp1', 'sect1', 'sect1'), (9781910797693, 'chp1', 'sect2', 'sect2'), (9781910797693, 'chp1', 'sect3', 'sect3')]
#
# num_tok MOC 460
# skipping [(9781910797693, 'chp1', 'sect4', 'sect4')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1304
# chunking [(9781910797693, 'chp1', 'chp1', 'chp1'), (9781910797693, 'chp1', 'sect1', 'sect1'), (9781910797693, 'chp1', 'sect2', 'sect2'), (9781910797693, 'chp1', 'sect3', 'sect3'), (9781910797693, 'chp1', 'sect4', 'sect4')]
#
# ############################
#
#
# book 9781910797693 chapter chp3
#
# num_tok MOC 578
# skipping [(9781910797693, 'chp3', 'chp3', 'chp3')]
#
# merging 578 + 313
# num_tok MOC 891
# summ [(9781910797693, 'chp3', 'chp3', 'chp3'), (9781910797693, 'chp3', 'sect7', 'sect7')]
#
#
# ############################
#
#
# book 9781910797693 chapter chp4
#
# num_tok MOC 43
# skipping [(9781910797693, 'chp4', 'chp4', 'chp4')]
#
# merging 43 + 291
# num_tok MOC 334
# skipping [(9781910797693, 'chp4', 'chp4', 'chp4'), (9781910797693, 'chp4', 'sect9', 'sect9')]
#
# merging 334 + 765
# num_tok MOC 1099
# ...
#
# merging 638 + 415
# num_tok MOC 1053
# chunking [(9783318066685, 'ch2', 'sec23', 'sec25_sub_sec23'), (9783318066685, 'ch2', 'sec23', 'sec26_sub_sec23'), (9783318066685, 'ch2', 'sec27', 'sec27'), (9783318066685, 'ch2', 'sec28', 'sec28'), (9783318066685, 'ch2', 'sec29', 'sec29')]
#
# num_tok MOC 188
# skipping [(9783318066685, 'ch2', 'sec30', 'sec30')]
#
# merging 188 + 43
# num_tok MOC 231
# skipping [(9783318066685, 'ch2', 'sec30', 'sec30'), (9783318066685, 'ch2', 'sec31', 'sec31')]
#
# merging 231 + 275
# num_tok MOC 506
# skipping [(9783318066685, 'ch2', 'sec30', 'sec30'), (9783318066685, 'ch2', 'sec31', 'sec31'), (9783318066685, 'ch2', 'sec32', 'sec32')]
#
# merging 506 + 104
# num_tok MOC 610
# skipping [(9783318066685, 'ch2', 'sec30', 'sec30'), (9783318066685, 'ch2', 'sec31', 'sec31'), (9783318066685, 'ch2', 'sec32', 'sec32'), (9783318066685, 'ch2', 'sec32', 'sec33_sub_sec32')]
#
# merging 610 + 104
# num_tok MOC 714
# skipping [(9783318066685, 'ch2', 'sec30', 'sec30'), (9783318066685, 'ch2', 'sec31', 'sec31'), (9783318066685, 'ch2', 'sec32', 'sec32'), (9783318066685, 'ch2', 'sec32', 'sec33_sub_sec32'), (9783318066685, 'ch2', 'sec32', 'sec34_sub_sec32')]
#
# merging 714 + 128
# num_tok MOC 842
# summ [(9783318066685, 'ch2', 'sec30', 'sec30'), (9783318066685, 'ch2', 'sec31', 'sec31'), (9783318066685, 'ch2', 'sec32', 'sec32'), (9783318066685, 'ch2', 'sec32', 'sec33_sub_sec32'), (9783318066685, 'ch2', 'sec32', 'sec34_sub_sec32'), (9783318066685, 'ch2', 'sec32', 'sec35_sub_sec32')]
#
# num_tok MOC 107
# skipping [(9783318066685, 'ch2', 'sec32', 'sec36_sub_sec32')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 949
# summ [(9783318066685, 'ch2', 'sec30', 'sec30'), (9783318066685, 'ch2', 'sec31', 'sec31'), (9783318066685, 'ch2', 'sec32', 'sec32'), (9783318066685, 'ch2', 'sec32', 'sec33_sub_sec32'), (9783318066685, 'ch2', 'sec32', 'sec34_sub_sec32'), (9783318066685, 'ch2', 'sec32', 'sec35_sub_sec32'), (9783318066685, 'ch2', 'sec32', 'sec36_sub_sec32')]
#
# ############################
#
#
# book 9783318066685 chapter ch3
#
# num_tok MOC 424
# skipping [(9783318066685, 'ch3', 'ch3', 'ch3')]
#
# merging 424 + 162
# num_tok MOC 586
# skipping [(9783318066685, 'ch3', 'ch3', 'ch3'), (9783318066685, 'ch3', 'sec37', 'sec37')]
#
# merging 586 + 802
# num_tok MOC 1388
# chunking [(9783318066685, 'ch3', 'ch3', 'ch3'), (9783318066685, 'ch3', 'sec37', 'sec37'), (9783318066685, 'ch3', 'sec37', 'sec38_sub_sec37')]
#
# num_tok MOC 7
# skipping [(9783318066685, 'ch3', 'sec39', 'sec39')]
#
# merging 7 + 254
# num_tok MOC 261
# skipping [(9783318066685, 'ch3', 'sec39', 'sec39'), (9783318066685, 'ch3', 'sec39', 'sec40_sub_sec39')]
#
# merging 261 + 320
# num_tok MOC 581
# skipping [(9783318066685, 'ch3', 'sec39', 'sec39'), (9783318066685, 'ch3', 'sec39', 'sec40_sub_sec39'), (9783318066685, 'ch3', 'sec39', 'sec41_sub_sec39')]
#
# merging 581 + 291
# num_tok MOC 872
# summ [(9783318066685, 'ch3', 'sec39', 'sec39'), (9783318066685, 'ch3', 'sec39', 'sec40_sub_sec39'), (9783318066685, 'ch3', 'sec39', 'sec41_sub_sec39'), (9783318066685, 'ch3', 'sec39', 'sec42_sub_sec39')]
#
# num_tok MOC 204
# skipping [(9783318066685, 'ch3', 'sec39', 'sec43_sub_sec39')]
#
# merging 204 + 179
# num_tok MOC 383
# skipping [(9783318066685, 'ch3', 'sec39', 'sec43_sub_sec39'), (9783318066685, 'ch3', 'sec39', 'sec44_sub_sec39')]
#
# merging 383 + 163
# num_tok MOC 546
# skipping [(9783318066685, 'ch3', 'sec39', 'sec43_sub_sec39'), (9783318066685, 'ch3', 'sec39', 'sec44_sub_sec39'), (9783318066685, 'ch3', 'sec39', 'sec45_sub_sec39')]
#
# merging 546 + 211
# num_tok MOC 757
# summ [(9783318066685, 'ch3', 'sec39', 'sec43_sub_sec39'), (9783318066685, 'ch3', 'sec39', 'sec44_sub_sec39'), (9783318066685, 'ch3', 'sec39', 'sec45_sub_sec39'), (9783318066685, 'ch3', 'sec39', 'sec46_sub_sec39')]
#
# num_tok MOC 296
# skipping [(9783318066685, 'ch3', 'sec47', 'sec47')]
#
# merging 296 + 244
# num_tok MOC 540
# skipping [(9783318066685, 'ch3', 'sec47', 'sec47'), (9783318066685, 'ch3', 'sec48', 'sec48')]
#
# merging 540 + 262
# num_tok MOC 802
# summ [(9783318066685, 'ch3', 'sec47', 'sec47'), (9783318066685, 'ch3', 'sec48', 'sec48'), (9783318066685, 'ch3', 'sec49', 'sec49')]
#
#
# ############################
#
#
# book 9783318066685 chapter ch4
#
# num_tok MOC 92
# skipping [(9783318066685, 'ch4', 'ch4', 'ch4')]
#
# merging 92 + 84
# num_tok MOC 176
# skipping [(9783318066685, 'ch4', 'ch4', 'ch4'), (9783318066685, 'ch4', 'sec50', 'sec50')]
#
# merging 176 + 480
# num_tok MOC 656
# skipping [(9783318066685, 'ch4', 'ch4', 'ch4'), (9783318066685, 'ch4', 'sec50', 'sec50'), (9783318066685, 'ch4', 'sec50', 'sec51_sub_sec50')]
#
# merging 656 + 382
# num_tok MOC 1038
# chunking [(9783318066685, 'ch4', 'ch4', 'ch4'), (9783318066685, 'ch4', 'sec50', 'sec50'), (9783318066685, 'ch4', 'sec50', 'sec51_sub_sec50'), (9783318066685, 'ch4', 'sec52', 'sec52')]
#
# num_tok MOC 402
# skipping [(9783318066685, 'ch4', 'sec53', 'sec53')]
#
# merging 402 + 843
# num_tok MOC 1245
# chunking [(9783318066685, 'ch4', 'sec53', 'sec53'), (9783318066685, 'ch4', 'sec54', 'sec54')]
#
# num_tok MOC 1584
# chunking [(9783318066685, 'ch4', 'sec55', 'sec55')]
#
# num_tok MOC 753
# summ [(9783318066685, 'ch4', 'sec56', 'sec56')]
#
# num_tok MOC 53
# skipping [(9783318066685, 'ch4', 'sec56', 'sec57_sub_sec56')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 806
# summ [(9783318066685, 'ch4', 'sec56', 'sec56'), (9783318066685, 'ch4', 'sec56', 'sec57_sub_sec56')]
#
# ############################
#
#
# book 9783318066685 chapter ch5
#
# num_tok MOC 6
# skipping [(9783318066685, 'ch5', 'ch5', 'ch5')]
#
# merging 6 + 401
# num_tok MOC 407
# skipping [(9783318066685, 'ch5', 'ch5', 'ch5'), (9783318066685, 'ch5', 'sec58', 'sec58')]
#
# merging 407 + 124
# num_tok MOC 531
# skipping [(9783318066685, 'ch5', 'ch5', 'ch5'), (9783318066685, 'ch5', 'sec58', 'sec58'), (9783318066685, 'ch5', 'sec58', 'sec59_sub_sec58')]
#
# merging 531 + 265
# num_tok MOC 796
# summ [(9783318066685, 'ch5', 'ch5', 'ch5'), (9783318066685, 'ch5', 'sec58', 'sec58'), (9783318066685, 'ch5', 'sec58', 'sec59_sub_sec58'), (9783318066685, 'ch5', 'sec58', 'sec60_sub_sec58')]
#
# num_tok MOC 424
# skipping [(9783318066685, 'ch5', 'sec58', 'sec61_sub_sec58')]
#
# merging 424 + 895
# num_tok MOC 1319
# chunking [(9783318066685, 'ch5', 'sec58', 'sec61_sub_sec58'), (9783318066685, 'ch5', 'sec62', 'sec62')]
#
#
# ############################
#
#
# book 9783318066685 chapter ch6
#
# num_tok MOC 108
# skipping [(9783318066685, 'ch6', 'ch6', 'ch6')]
#
# merging 108 + 307
# num_tok MOC 415
# skipping [(9783318066685, 'ch6', 'ch6', 'ch6'), (9783318066685, 'ch6', 'sec63', 'sec63')]
#
# merging 415 + 711
# num_tok MOC 1126
# chunking [(9783318066685, 'ch6', 'ch6', 'ch6'), (9783318066685, 'ch6', 'sec63', 'sec63'), (9783318066685, 'ch6', 'sec63', 'sec64_sub_sec63')]
#
# num_tok MOC 84
# skipping [(9783318066685, 'ch6', 'sec65', 'sec65')]
#
# merging 84 + 353
# num_tok MOC 437
# skipping [(9783318066685, 'ch6', 'sec65', 'sec65'), (9783318066685, 'ch6', 'sec65', 'sec66_sub_sec65')]
#
# merging 437 + 670
# num_tok MOC 1107
# chunking [(9783318066685, 'ch6', 'sec65', 'sec65'), (9783318066685, 'ch6', 'sec65', 'sec66_sub_sec65'), (9783318066685, 'ch6', 'sec67', 'sec67')]
#
# num_tok MOC 599
# skipping [(9783318066685, 'ch6', 'sec68', 'sec69_sub_sec68')]
#
# merging 599 + 319
# num_tok MOC 918
# summ [(9783318066685, 'ch6', 'sec68', 'sec69_sub_sec68'), (9783318066685, 'ch6', 'sec68', 'sec70_sub_sec68')]
#
#
# ############################
#
#
# book 9783318067095 chapter ch1
#
# num_tok MOC 76
# skipping [(9783318067095, 'ch1', 'ch1', 'ch1')]
#
# merging 76 + 491
# num_tok MOC 567
# skipping [(9783318067095, 'ch1', 'ch1', 'ch1'), (9783318067095, 'ch1', 'sec2', 'sec2')]
#
# merging 567 + 385
# num_tok MOC 952
# summ [(9783318067095, 'ch1', 'ch1', 'ch1'), (9783318067095, 'ch1', 'sec2', 'sec2'), (9783318067095, 'ch1', 'sec3', 'sec3')]
#
# num_tok MOC 292
# skipping [(9783318067095, 'ch1', 'sec4', 'sec4')]
#
# merging 292 + 879
# num_tok MOC 1171
# chunking [(9783318067095, 'ch1', 'sec4', 'sec4'), (9783318067095, 'ch1', 'sec5', 'sec5')]
#
#
# ############################
#
#
# book 9783318067095 chapter ch2
#
# num_tok MOC 8
# skipping [(9783318067095, 'ch2', 'ch2', 'ch2')]
#
# merging 8 + 390
# num_tok MOC 398
# skipping [(9783318067095, 'ch2', 'ch2', 'ch2'), (9783318067095, 'ch2', 'sec6', 'sec6')]
#
# merging 398 + 494
# num_tok MOC 892
# summ [(9783318067095, 'ch2', 'ch2', 'ch2'), (9783318067095, 'ch2', 'sec6', 'sec6'), (9783318067095, 'ch2', 'sec7', 'sec7')]
#
#
# ############################
#
#
# book 9783318067095 chapter ch3
#
# num_tok MOC 125
# skipping [(9783318067095, 'ch3', 'ch3', 'ch3')]
#
# merging 125 + 495
# num_tok MOC 620
# skipping [(9783318067095, 'ch3', 'ch3', 'ch3'), (9783318067095, 'ch3', 'sec8', 'sec8')]
#
# merging 620 + 356
# num_tok MOC 976
# summ [(9783318067095, 'ch3', 'ch3', 'ch3'), (9783318067095, 'ch3', 'sec8', 'sec8'), (9783318067095, 'ch3', 'sec9', 'sec9')]
#
# num_tok MOC 2203
# chunking [(9783318067095, 'ch3', 'sec10', 'sec10')]
#
#
# ############################
#
#
# book 9783318067095 chapter ch4
#
# num_tok MOC 79
# skipping [(9783318067095, 'ch4', 'ch4', 'ch4')]
#
# merging 79 + 329
# num_tok MOC 408
# skipping [(9783318067095, 'ch4', 'ch4', 'ch4'), (9783318067095, 'ch4', 'sec11', 'sec11')]
#
# merging 408 + 1296
# num_tok MOC 1704
# chunking [(9783318067095, 'ch4', 'ch4', 'ch4'), (9783318067095, 'ch4', 'sec11', 'sec11'), (9783318067095, 'ch4', 'sec12', 'sec12')]
#
#
# ############################
#
#
# book 9783318067095 chapter ch5
#
# num_tok MOC 568
# skipping [(9783318067095, 'ch5', 'ch5', 'ch5')]
#
# merging 568 + 656
# num_tok MOC 1224
# chunking [(9783318067095, 'ch5', 'ch5', 'ch5'), (9783318067095, 'ch5', 'sec13', 'sec13')]
#
# num_tok MOC 665
# skipping [(9783318067095, 'ch5', 'sec14', 'sec14')]
#
# merging 665 + 595
# num_tok MOC 1260
# chunking [(9783318067095, 'ch5', 'sec14', 'sec14'), (9783318067095, 'ch5', 'sec15', 'sec15')]
#
#
# ############################
#
#
# book 9783318067095 chapter ch6
#
# num_tok MOC 743
# summ [(9783318067095, 'ch6', 'ch6', 'ch6')]
#
# num_tok MOC 207
# skipping [(9783318067095, 'ch6', 'sec16', 'sec16')]
#
# merging 207 + 148
# num_tok MOC 355
# skipping [(9783318067095, 'ch6', 'sec16', 'sec16'), (9783318067095, 'ch6', 'sec17', 'sec17')]
#
# merging 355 + 96
# num_tok MOC 451
# skipping [(9783318067095, 'ch6', 'sec16', 'sec16'), (9783318067095, 'ch6', 'sec17', 'sec17'), (9783318067095, 'ch6', 'sec18', 'sec18')]
#
# merging 451 + 127
# num_tok MOC 578
# skipping [(9783318067095, 'ch6', 'sec16', 'sec16'), (9783318067095, 'ch6', 'sec17', 'sec17'), (9783318067095, 'ch6', 'sec18', 'sec18'), (9783318067095, 'ch6', 'sec19', 'sec19')]
#
# merging 578 + 370
# num_tok MOC 948
# summ [(9783318067095, 'ch6', 'sec16', 'sec16'), (9783318067095, 'ch6', 'sec17', 'sec17'), (9783318067095, 'ch6', 'sec18', 'sec18'), (9783318067095, 'ch6', 'sec19', 'sec19'), (9783318067095, 'ch6', 'sec20', 'sec20')]
#
# num_tok MOC 118
# skipping [(9783318067095, 'ch6', 'sec21', 'sec21')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1066
# chunking [(9783318067095, 'ch6', 'sec16', 'sec16'), (9783318067095, 'ch6', 'sec17', 'sec17'), (9783318067095, 'ch6', 'sec18', 'sec18'), (9783318067095, 'ch6', 'sec19', 'sec19'), (9783318067095, 'ch6', 'sec20', 'sec20'), (9783318067095, 'ch6', 'sec21', 'sec21')]
#
# ############################
#
#
# book 9783318067095 chapter ch7
#
# num_tok MOC 192
# skipping [(9783318067095, 'ch7', 'ch7', 'ch7')]
#
# merging 192 + 448
# num_tok MOC 640
# skipping [(9783318067095, 'ch7', 'ch7', 'ch7'), (9783318067095, 'ch7', 'sec22', 'sec22')]
#
# merging 640 + 273
# num_tok MOC 913
# summ [(9783318067095, 'ch7', 'ch7', 'ch7'), (9783318067095, 'ch7', 'sec22', 'sec22'), (9783318067095, 'ch7', 'sec23', 'sec23')]
#
# num_tok MOC 597
# skipping [(9783318067095, 'ch7', 'sec24', 'sec24')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1510
# chunking [(9783318067095, 'ch7', 'ch7', 'ch7'), (9783318067095, 'ch7', 'sec22', 'sec22'), (9783318067095, 'ch7', 'sec23', 'sec23'), (9783318067095, 'ch7', 'sec24', 'sec24')]
#
# ############################
#
#
# book 9783318067095 chapter ch8
#
# num_tok MOC 449
# skipping [(9783318067095, 'ch8', 'ch8', 'ch8')]
#
# merging 449 + 666
# num_tok MOC 1115
# chunking [(9783318067095, 'ch8', 'ch8', 'ch8'), (9783318067095, 'ch8', 'sec25', 'sec25')]
#
# num_tok MOC 261
# skipping [(9783318067095, 'ch8', 'sec26', 'sec26')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1376
# chunking [(9783318067095, 'ch8', 'ch8', 'ch8'), (9783318067095, 'ch8', 'sec25', 'sec25'), (9783318067095, 'ch8', 'sec26', 'sec26')]
#
# ############################
#
#
# book 9783318067095 chapter ch9
#
# num_tok MOC 56
# skipping [(9783318067095, 'ch9', 'ch9', 'ch9')]
#
# merging 56 + 1369
# num_tok MOC 1425
# chunking [(9783318067095, 'ch9', 'ch9', 'ch9'), (9783318067095, 'ch9', 'sec27', 'sec27')]
#
# num_tok MOC 142
# skipping [(9783318067095, 'ch9', 'sec28', 'sec28')]
#
# merging 142 + 266
# num_tok MOC 408
# skipping [(9783318067095, 'ch9', 'sec28', 'sec28'), (9783318067095, 'ch9', 'sec29', 'sec29')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1833
# chunking [(9783318067095, 'ch9', 'ch9', 'ch9'), (9783318067095, 'ch9', 'sec27', 'sec27'), (9783318067095, 'ch9', 'sec28', 'sec28'), (9783318067095, 'ch9', 'sec29', 'sec29')]
#
# ############################
#
#
# book 9783318068207 chapter hh-3
#
# num_tok MOC 1714
# chunking [(9783318068207, 'hh-3', 'sec1', 'sec1')]
#
# num_tok MOC 92
# skipping [(9783318068207, 'hh-3', 'sec2', 'sec2')]
#
# merging 92 + 639
# num_tok MOC 731
# summ [(9783318068207, 'hh-3', 'sec2', 'sec2'), (9783318068207, 'hh-3', 'sec3', 'sec3')]
#
# num_tok MOC 316
# skipping [(9783318068207, 'hh-3', 'sec4', 'sec4')]
#
# merging 316 + 816
# num_tok MOC 1132
# chunking [(9783318068207, 'hh-3', 'sec4', 'sec4'), (9783318068207, 'hh-3', 'sec5', 'sec5')]
#
# num_tok MOC 775
# summ [(9783318068207, 'hh-3', 'sec6', 'sec6')]
#
#
# ############################
#
#
# book 9783318068207 chapter hh-4
#
# num_tok MOC 217
# skipping [(9783318068207, 'hh-4', 'sec7', 'sec7')]
#
# merging 217 + 1460
# num_tok MOC 1677
# chunking [(9783318068207, 'hh-4', 'sec7', 'sec7'), (9783318068207, 'hh-4', 'sec8', 'sec8')]
#
# num_tok MOC 309
# skipping [(9783318068207, 'hh-4', 'sec9', 'sec9')]
#
# merging 309 + 762
# num_tok MOC 1071
# chunking [(9783318068207, 'hh-4', 'sec9', 'sec9'), (9783318068207, 'hh-4', 'sec10', 'sec10')]
#
# num_tok MOC 314
# skipping [(9783318068207, 'hh-4', 'sec11', 'sec11')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1385
# chunking [(9783318068207, 'hh-4', 'sec9', 'sec9'), (9783318068207, 'hh-4', 'sec10', 'sec10'), (9783318068207, 'hh-4', 'sec11', 'sec11')]
#
# ############################
#
#
# book 9783318068207 chapter hh-5
#
# num_tok MOC 514
# skipping [(9783318068207, 'hh-5', 'sec12', 'sec12')]
#
# merging 514 + 848
# num_tok MOC 1362
# chunking [(9783318068207, 'hh-5', 'sec12', 'sec12'), (9783318068207, 'hh-5', 'sec13', 'sec13')]
#
# num_tok MOC 524
# skipping [(9783318068207, 'hh-5', 'sec14', 'sec14')]
#
# merging 524 + 846
# num_tok MOC 1370
# chunking [(9783318068207, 'hh-5', 'sec14', 'sec14'), (9783318068207, 'hh-5', 'sec15', 'sec15')]
#
#
# ############################
#
#
# book 9783318068207 chapter hh-6
#
# num_tok MOC 606
# skipping [(9783318068207, 'hh-6', 'sec17', 'sec17')]
#
# merging 606 + 573
# num_tok MOC 1179
# chunking [(9783318068207, 'hh-6', 'sec17', 'sec17'), (9783318068207, 'hh-6', 'sec18', 'sec18')]
#
# num_tok MOC 1161
# chunking [(9783318068207, 'hh-6', 'sec19', 'sec19')]
#
# num_tok MOC 89
# skipping [(9783318068207, 'hh-6', 'sec20', 'sec20')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1250
# chunking [(9783318068207, 'hh-6', 'sec19', 'sec19'), (9783318068207, 'hh-6', 'sec20', 'sec20')]
#
# ############################
#
#
# book 9783318068207 chapter hh-7
#
# num_tok MOC 1070
# chunking [(9783318068207, 'hh-7', 'sec21', 'sec21')]
#
# num_tok MOC 1655
# chunking [(9783318068207, 'hh-7', 'sec22', 'sec22')]
#
# num_tok MOC 1404
# chunking [(9783318068207, 'hh-7', 'sec23', 'sec23')]
#
# num_tok MOC 1077
# chunking [(9783318068207, 'hh-7', 'sec24', 'sec24')]
#
# num_tok MOC 1197
# chunking [(9783318068207, 'hh-7', 'sec25', 'sec25')]
#
#
# ############################
#
#
# book 9783318068207 chapter hh-8
#
# num_tok MOC 468
# skipping [(9783318068207, 'hh-8', 'sec26', 'sec26')]
#
# merging 468 + 516
# num_tok MOC 984
# summ [(9783318068207, 'hh-8', 'sec26', 'sec26'), (9783318068207, 'hh-8', 'sec27', 'sec27')]
#
# num_tok MOC 392
# skipping [(9783318068207, 'hh-8', 'sec28', 'sec28')]
#
# merging 392 + 483
# num_tok MOC 875
# summ [(9783318068207, 'hh-8', 'sec28', 'sec28'), (9783318068207, 'hh-8', 'sec29', 'sec29')]
#
#
# ############################

# %%
df_moc = df_moc.reset_index(level=[2, 3]).groupby(['book', 'chapter'], sort=False).agg({
    'merge': lambda m: list(m),
    'chunk': lambda c: list(c),
    'text': lambda t: list(t),
    'bullets': lambda b: list(b)[0]
})

# %% [markdown]
# #### Save new dataset

# %%
df_moc.to_csv(OUTPUT_PATH+'df.csv')

# %% [markdown]
# #### Create train, test, validation
#
# Generate files:
# * train.source
# * train.target
# * val.source
# * val.target
# * test.source
# * test.target
#
# Since we do not have a lot of samples, validation and test will be equal for us.

# %%
df_moc.bullets = df_moc.bullets.map(lambda b: ' '.join(b))

# %%
df_moc = df_moc.sample(frac=1, random_state=config.SEED)
df_moc['num_chunks'] = df_moc.text.map(len).cumsum()
tot_chunk = df_moc.num_chunks.iloc[-1]
split1 = np.where(df_moc.num_chunks > int(tot_chunk*0.8))[0][0]+1
split2 = np.where(df_moc.num_chunks > int(tot_chunk*0.9))[0][0]+1
print(split1, split2)
# Out:
# 365 409

# %%
train, val, test =\
    df_moc.iloc[:split1].explode('text'),\
    df_moc.iloc[split1:split2].explode('text'),\
    df_moc.iloc[split2:].explode('text')

train.to_csv(OUTPUT_PATH+'train.csv')
val.to_csv(OUTPUT_PATH+'val.csv')
test.to_csv(OUTPUT_PATH+'test.csv')

# %%
with open(OUTPUT_PATH+'train.source', 'w') as tr_s,\
    open(OUTPUT_PATH+'train.target', 'w') as tr_t,\
    open(OUTPUT_PATH+'train.index', 'w') as tr_i:
    for idx, row in train[['text', 'bullets']].iterrows():
        tr_i.write(str(idx) + '\n')
        tr_s.write(row.text + '\n')
        tr_t.write(row.bullets + '\n')

# %%
with open(OUTPUT_PATH+'val.source', 'w') as va_s,\
    open(OUTPUT_PATH+'val.target', 'w') as va_t,\
    open(OUTPUT_PATH+'val.index', 'w') as va_i:
    for idx, row in val[['text', 'bullets']].iterrows():
        va_i.write(str(idx) + '\n')
        va_s.write(row.text + '\n')
        va_t.write(row.bullets + '\n')

# %%
with open(OUTPUT_PATH+'test.source', 'w') as te_s,\
    open(OUTPUT_PATH+'test.target', 'w') as te_t,\
    open(OUTPUT_PATH+'test.index', 'w') as te_i:
    for idx, row in test[['text', 'bullets']].iterrows():
        te_i.write(str(idx) + '\n')
        te_s.write(row.text + '\n')
        te_t.write(row.bullets + '\n')

# %% [markdown]
# ### **Study new dataset**

# %%
np.mean(df_moc.text_num_tokens.tolist())
# Out:
# 743.2905027932961

# %%
num_chunked, num_not_chunked = 0, 0
for idx in set(df_moc.index.tolist()):
    merge = eval(idx[2])
    chunk = idx[3]
    if chunk:
        num_chunked += len(merge)
    else:
        num_not_chunked += len(merge)

assert num_chunked + num_not_chunked == len(df)

print('percentage of chunked sections: %.2f %%'%(num_chunked/len(df)*100))
# Out:
# percentage of chunked sections: 75.24 %
