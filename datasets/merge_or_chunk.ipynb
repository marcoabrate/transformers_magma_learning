# %% [markdown]
# ### **Config**

# %%
import os
import sys

sys.path.insert(0, '/home/marco/epfl/magma/')
import config

# %%
# General configurations

MODEL = 'pegasus'

RE_SPLITTER = '\.(?!\d)|\n'     # do we split sentences of paragraphs?
                                # use '\.|\n' or '\n', respectively

# Output path
OUTPUT_PATH = config.MAGMA_DIR+'datasets/merge_or_chunk/'+MODEL+'/'
if not os.path.exists(OUTPUT_PATH):
    os.makedirs(OUTPUT_PATH)

# %% [markdown]
# ### **Init**

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import re
import pandas as pd
import gensim

if 'pegasus' in MODEL:
    from transformers import PegasusTokenizer
    tokenizer =\
        PegasusTokenizer.from_pretrained('google/pegasus-large')
elif 'bart' in MODEL:
    from transformers import BartTokenizer
    tokenizer =\
        BartTokenizer.from_pretrained('facebook/bart-large-cnn')
elif 't5' in MODEL:
    from transformers import T5Tokenizer
    tokenizer=\
        T5Tokenizer.from_pretrained('t5-large')

# %% [markdown]
# ### **Karger Books Base Dataset**

# %%
base_dataset = config.MAGMA_DIR+'datasets/karger_books_base/df.csv'
df = pd.read_csv(base_dataset)
df = df.set_index(['book', 'chapter', 'section', 'subsection'])
df.bullets = df.bullets.map(eval, na_action='ignore')

# %% [markdown]
# ### **Preprocessing**

# %% [markdown]
# #### Preprocessing
#
# * Split based on RE_SPLITTER
# * Explode the dataset
# * Remove unwanted chars at beginning or end of sentence
# * Remove multiple spaces
# * Remove long words (> config.TOKEN_MAX_LEN chars)
# * Remove short sentences / paragraphs (< config.PARA_MIN_LEN tokens)

# %%
# Split in sentences / paragraphs based on RE_SPLITTER
df.text =\
    df.text.map(lambda x: [p.strip() for p in re.split(RE_SPLITTER, x) if p!=''],
                na_action='ignore')
    
# explode to get one row for each paragraph /sentence
df = df.explode('text')
df = df.rename(columns={'text': 'para'})
df = df.dropna()

# Remove unwanted chars at beginning or end of sentence
df.para = df.para.map(lambda p: p.lstrip('.,;:-)] \n'))
df.para = df.para.map(lambda p: p.rstrip('.,;:-([ \n'))

# Remove multiple spaces
df.para = df.para.map(lambda p:
    re.sub('\s+', ' ', p).strip())

# Remove long words (> config.TOKEN_MAX_LEN chars)
def para2words(para):
    return gensim.utils.simple_preprocess(
        para, deacc=True, max_len=config.TOKEN_MAX_LEN)
df['para_proc'] = df.para.map(para2words)

# Remove short sentences / paragraphs (< config.PARA_MIN_LEN tokens)
df.loc[df.para_proc.map(len) <\
    config.PARA_MIN_LEN, 'para_proc'] = np.nan

df = df.dropna()

# %% [markdown]
# ### **Merge or Chunk Sections**

# %%
df = df.groupby(level=[0,1,2,3], sort=False).agg(
    {'para': lambda t: ''.join([p+'. ' for p in t]),
     'bullets': lambda b: list(b)[0]})
df = df.rename(columns={'para': 'text'})

# %%
df['text_enc'] = df.text.map(tokenizer.tokenize)
df['text_num_tokens'] = df.text_enc.map(len)

# %% [markdown]
# #### Chunk function

# %%
def chunk_text(text, num_tok):
    text_sent =\
        [sent.strip()+'.' for sent in re.split(RE_SPLITTER, text) if len(sent) > 1]

    # calculate number of tokens per sentence
    num_tok_sent = [len(tokenizer.tokenize(sent)) for sent in text_sent]
    
    # calculate chunk dimension to fit into model
    n = int(np.ceil(num_tok / config.MODEL_MAX_LEN))
    len_chunk = int(num_tok / n)
    # get a more uniform splitting to avoid splits
    # which are too short at the end
    if len_chunk+50 > config.MODEL_MAX_LEN:
        len_chunk = int(num_tok / (n+1))
    
    len_curr = 0
    text_curr = []
    text_chunk = []
    for te, len_sent in zip(text_sent, num_tok_sent):

        if len_curr + len_sent < len_chunk:
            text_curr.append(te)
            len_curr += len_sent

        elif len_curr + len_sent >= config.MODEL_MAX_LEN:
            text_chunk.append(text_curr)

            text_curr = [te]
            len_curr = len_sent

        else: # >= len_chunk && < MODEL_MAX_LEN
            text_curr.append(te)
            text_chunk.append(text_curr)
            
            text_curr = []
            len_curr = 0

    if len_curr > 0:
        text_chunk.append(text_curr)

    return text_chunk

# %% [markdown]
# #### Merge or Chunk

# %%
def chunk_or_merge(df_merge, num_row, num_tok, bid, cpt, i, index):
    print('num_tok MOC', num_tok)

    # if the text fits perfectly, we just add it to df_merge
    if num_tok >= CHUNK_MIN_LEN and num_tok < config.MODEL_MAX_LEN:
        id_merged = index[i-num_row:i]
        print('summ', id_merged)

        data_merged = []
        for c in df.columns:
            if c == 'bullets':
                data_merged.append(df.loc[id_merged, c].iloc[0])
            else:
                data_merged.append(df.loc[id_merged, c].sum())

        new_index = pd.MultiIndex.from_arrays(
            [[bid], [cpt], [str(id_merged)], [False]])
        df_merge_add = pd.DataFrame(
            data = [data_merged],
            index = new_index,
            columns = df.columns)
        df_merge = df_merge.append(df_merge_add)
        return False, df_merge

    # if the text is too long, we chunk it
    elif num_tok >= config.MODEL_MAX_LEN:
        id_merged = index[i-num_row:i]
        print('chunking', id_merged)

        new_index = pd.MultiIndex.from_arrays(
            [[bid], [cpt], [str(id_merged)], [True]])

        text_merged = df.loc[id_merged, 'text'].sum()
        text_chunked = chunk_text(text_merged, num_tok)
        for tc in text_chunked:
            t = ' '.join(tc)
            df_merge_add = pd.DataFrame(
                data = [[t,
                        df.iloc[i-1].bullets,
                        tokenizer.tokenize(t),
                        len(tokenizer.tokenize(t))]],
                index = new_index,
                columns = df.columns)
            df_merge = df_merge.append(df_merge_add)
        return False, df_merge

    # if the text is too short, we merge it
    elif num_tok < CHUNK_MIN_LEN:
        print('skipping', index[i-num_row:i])
        return True, df_merge

# %% [markdown]
# #### Create the new dataset

# %%
# define new dataset for the chapters
indices = pd.MultiIndex.from_arrays(
    [[], [], [], []],
    names = ['book', 'chapter', 'merge', 'chunk'])
df_moc = pd.DataFrame(index = indices, columns = df.columns.tolist())

# minimum length of a chunk
CHUNK_MIN_LEN = np.ceil(config.BULLETS_MED_LEN / config.MAX_RATIO)
print('Chunk minimum length:', CHUNK_MIN_LEN)
print()

index = df.index.tolist()

i_cpt = 0
for bid in sorted(list(set(df.index.get_level_values(0)))):
    cpts = config.get_cpts(df, bid)
    for cpt in cpts:
        print('book', bid, 'chapter', cpt)
        print()

        merge = False
        num_row, num_row_past = 0, 0
        num_tok, num_tok_past = 0, 0
        max_i = i_cpt + len(df.loc[bid, cpt])

        # for each section in chapter
        for i in range(i_cpt, max_i):
            # if previous section is too short, 
            # we merge it with the one below
            if merge: 
                num_row += 1
                print('merging', num_tok, '+', df.iloc[i].text_num_tokens)
                num_tok += df.iloc[i].text_num_tokens
            else:
                num_row_past = num_row
                num_row = 1
                num_tok_past = num_tok
                num_tok = df.iloc[i].text_num_tokens
            '''
                after merging or considering a new section, we call this function
                to study the length. Then we either add the row to the dataset, chunk it 
                or do nothing if it is still too short
            '''
            merge, df_moc =\
                chunk_or_merge(df_moc, num_row, num_tok, bid, cpt, i+1, index)

            print()
            
            '''
                if the last chunk of the chapter is too small, we merge it
                with the above and repeat one last time the process
            '''
            if merge and (i+1 == max_i):
                print('EXCEPTION, last chunk too small.')
                if num_row_past == 0:
                    _, df_moc =\
                        chunk_or_merge(df_moc, num_row, config.MODEL_MAX_LEN-1, bid, cpt, i+1, index)
                else:
                    num_row += num_row_past
                    num_tok += num_tok_past
                    # drop last row added and re-calculate for new, bigger chunk
                    df_moc = df_moc.drop(df_moc.index[-1])
                    _, df_moc =\
                        chunk_or_merge(df_moc, num_row, num_tok, bid, cpt, i+1, index)
                 
        i_cpt += len(df.loc[bid, cpt])
        print('\n############################')
        print()
        print()

for idx, r in df_moc.groupby(level=[0,1,2,3]).text.apply(list).iteritems():
    idx_merged = eval(idx[2])
    old_txt = ''.join(df.loc[idx_merged].text.tolist()).strip()
    new_txt = ' '.join(r).strip()
    assert old_txt == new_txt
# Out:
# Chunk minimum length: 720.0
#
# book 9781905832729 chapter ch_2
#
# num_tok MOC 11
# skipping [(9781905832729, 'ch_2', 'ch_2', 'ch_2')]
#
# merging 11 + 239
# num_tok MOC 250
# skipping [(9781905832729, 'ch_2', 'ch_2', 'ch_2'), (9781905832729, 'ch_2', '1.i', '1.i')]
#
# merging 250 + 692
# num_tok MOC 942
# summ [(9781905832729, 'ch_2', 'ch_2', 'ch_2'), (9781905832729, 'ch_2', '1.i', '1.i'), (9781905832729, 'ch_2', '1.ii', '1.ii')]
#
#
# ############################
#
#
# book 9781905832729 chapter ch_3
#
# num_tok MOC 93
# skipping [(9781905832729, 'ch_3', '2.i', '2.i')]
#
# merging 93 + 268
# num_tok MOC 361
# skipping [(9781905832729, 'ch_3', '2.i', '2.i'), (9781905832729, 'ch_3', '2.ii', '2.ii')]
#
# merging 361 + 488
# num_tok MOC 849
# summ [(9781905832729, 'ch_3', '2.i', '2.i'), (9781905832729, 'ch_3', '2.ii', '2.ii'), (9781905832729, 'ch_3', '2.iii', '2.iii')]
#
# num_tok MOC 424
# skipping [(9781905832729, 'ch_3', '2.iv', '2.iv')]
#
# merging 424 + 867
# num_tok MOC 1291
# chunking [(9781905832729, 'ch_3', '2.iv', '2.iv'), (9781905832729, 'ch_3', '2.v', '2.v')]
#
# num_tok MOC 1041
# chunking [(9781905832729, 'ch_3', '2.vi', '2.vi')]
#
# num_tok MOC 213
# skipping [(9781905832729, 'ch_3', '2.vii', '2.vii')]
#
# merging 213 + 2476
# num_tok MOC 2689
# chunking [(9781905832729, 'ch_3', '2.vii', '2.vii'), (9781905832729, 'ch_3', '2.viii', '2.viii')]
# /home/marco/miniconda3/envs/magma/lib/python3.6/site-packages/ipykernel_launcher.py:24: PerformanceWarning: indexing past lexsort depth may impact performance.
# /home/marco/miniconda3/envs/magma/lib/python3.6/site-packages/ipykernel_launcher.py:66: PerformanceWarning: indexing past lexsort depth may impact performance.
# ############################
#
#
# book 9781905832729 chapter ch_4
#
# num_tok MOC 8
# skipping [(9781905832729, 'ch_4', 'ch_4', 'ch_4')]
#
# merging 8 + 240
# num_tok MOC 248
# skipping [(9781905832729, 'ch_4', 'ch_4', 'ch_4'), (9781905832729, 'ch_4', '3.i', '3.i')]
#
# merging 248 + 339
# num_tok MOC 587
# skipping [(9781905832729, 'ch_4', 'ch_4', 'ch_4'), (9781905832729, 'ch_4', '3.i', '3.i'), (9781905832729, 'ch_4', '3.ii', '3.ii')]
#
# merging 587 + 287
# num_tok MOC 874
# summ [(9781905832729, 'ch_4', 'ch_4', 'ch_4'), (9781905832729, 'ch_4', '3.i', '3.i'), (9781905832729, 'ch_4', '3.ii', '3.ii'), (9781905832729, 'ch_4', '3.iii', '3.iii')]
#
# num_tok MOC 62
# skipping [(9781905832729, 'ch_4', '3.iv', '3.iv')]
#
# merging 62 + 164
# num_tok MOC 226
# skipping [(9781905832729, 'ch_4', '3.iv', '3.iv'), (9781905832729, 'ch_4', '3.v', '3.v')]
#
# merging 226 + 2193
# num_tok MOC 2419
# chunking [(9781905832729, 'ch_4', '3.iv', '3.iv'), (9781905832729, 'ch_4', '3.v', '3.v'), (9781905832729, 'ch_4', '3.vi', '3.vi')]
#
# num_tok MOC 615
# skipping [(9781905832729, 'ch_4', '3.vii', '3.vii')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 3034
# chunking [(9781905832729, 'ch_4', '3.iv', '3.iv'), (9781905832729, 'ch_4', '3.v', '3.v'), (9781905832729, 'ch_4', '3.vi', '3.vi'), (9781905832729, 'ch_4', '3.vii', '3.vii')]
#
# ############################
#
#
# book 9781905832729 chapter ch_5
#
# num_tok MOC 243
# skipping [(9781905832729, 'ch_5', 'ch_5', 'ch_5')]
#
# merging 243 + 150
# num_tok MOC 393
# skipping [(9781905832729, 'ch_5', 'ch_5', 'ch_5'), (9781905832729, 'ch_5', '4.i', '4.i')]
#
# merging 393 + 350
# num_tok MOC 743
# summ [(9781905832729, 'ch_5', 'ch_5', 'ch_5'), (9781905832729, 'ch_5', '4.i', '4.i'), (9781905832729, 'ch_5', '4.ii', '4.ii')]
#
# num_tok MOC 2625
# chunking [(9781905832729, 'ch_5', '4.iii', '4.iii')]
#
#
# ############################
#
#
# book 9781905832729 chapter ch_6
#
# num_tok MOC 99
# skipping [(9781905832729, 'ch_6', 'ch_6', 'ch_6')]
#
# merging 99 + 785
# num_tok MOC 884
# summ [(9781905832729, 'ch_6', 'ch_6', 'ch_6'), (9781905832729, 'ch_6', '5.i', '5.i')]
#
# num_tok MOC 25
# skipping [(9781905832729, 'ch_6', '5.ii', '5.ii')]
#
# merging 25 + 533
# num_tok MOC 558
# skipping [(9781905832729, 'ch_6', '5.ii', '5.ii'), (9781905832729, 'ch_6', '5.iii', '5.iii')]
#
# merging 558 + 828
# num_tok MOC 1386
# chunking [(9781905832729, 'ch_6', '5.ii', '5.ii'), (9781905832729, 'ch_6', '5.iii', '5.iii'), (9781905832729, 'ch_6', '5.iv', '5.iv')]
#
#
# ############################
#
#
# book 9781905832729 chapter ch_7
#
# num_tok MOC 112
# skipping [(9781905832729, 'ch_7', 'ch_7', 'ch_7')]
#
# merging 112 + 125
# num_tok MOC 237
# skipping [(9781905832729, 'ch_7', 'ch_7', 'ch_7'), (9781905832729, 'ch_7', '6.i', '6.i')]
#
# merging 237 + 214
# num_tok MOC 451
# skipping [(9781905832729, 'ch_7', 'ch_7', 'ch_7'), (9781905832729, 'ch_7', '6.i', '6.i'), (9781905832729, 'ch_7', '6.ii', '6.ii')]
#
# merging 451 + 898
# num_tok MOC 1349
# chunking [(9781905832729, 'ch_7', 'ch_7', 'ch_7'), (9781905832729, 'ch_7', '6.i', '6.i'), (9781905832729, 'ch_7', '6.ii', '6.ii'), (9781905832729, 'ch_7', '6.iii', '6.iii')]
#
# num_tok MOC 253
# skipping [(9781905832729, 'ch_7', '6.iv', '6.iv')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1602
# chunking [(9781905832729, 'ch_7', 'ch_7', 'ch_7'), (9781905832729, 'ch_7', '6.i', '6.i'), (9781905832729, 'ch_7', '6.ii', '6.ii'), (9781905832729, 'ch_7', '6.iii', '6.iii'), (9781905832729, 'ch_7', '6.iv', '6.iv')]
#
# ############################
#
#
# book 9781905832729 chapter ch_8
#
# num_tok MOC 10
# skipping [(9781905832729, 'ch_8', 'ch_8', 'ch_8')]
#
# merging 10 + 179
# num_tok MOC 189
# skipping [(9781905832729, 'ch_8', 'ch_8', 'ch_8'), (9781905832729, 'ch_8', '7.i', '7.i')]
#
# merging 189 + 1840
# num_tok MOC 2029
# chunking [(9781905832729, 'ch_8', 'ch_8', 'ch_8'), (9781905832729, 'ch_8', '7.i', '7.i'), (9781905832729, 'ch_8', '7.ii', '7.ii')]
#
# num_tok MOC 2045
# chunking [(9781905832729, 'ch_8', '7.iii', '7.iii')]
#
#
# ############################
#
#
# book 9781905832729 chapter ch_9
#
# num_tok MOC 6
# skipping [(9781905832729, 'ch_9', 'ch_9', 'ch_9')]
#
# merging 6 + 941
# num_tok MOC 947
# summ [(9781905832729, 'ch_9', 'ch_9', 'ch_9'), (9781905832729, 'ch_9', '8.i', '8.i')]
#
# num_tok MOC 728
# summ [(9781905832729, 'ch_9', '8.ii', '8.ii')]
#
#
# ############################
#
#
# book 9781905832729 chapter ch_10
#
# num_tok MOC 112
# skipping [(9781905832729, 'ch_10', 'ch_10', 'ch_10')]
#
# merging 112 + 498
# num_tok MOC 610
# skipping [(9781905832729, 'ch_10', 'ch_10', 'ch_10'), (9781905832729, 'ch_10', '9.i', '9.i')]
#
# merging 610 + 196
# num_tok MOC 806
# summ [(9781905832729, 'ch_10', 'ch_10', 'ch_10'), (9781905832729, 'ch_10', '9.i', '9.i'), (9781905832729, 'ch_10', '9.ii', '9.ii')]
#
# num_tok MOC 1315
# chunking [(9781905832729, 'ch_10', '9.iii', '9.iii')]
#
#
# ############################
#
#
# book 9781905832729 chapter ch_11
#
# num_tok MOC 4
# skipping [(9781905832729, 'ch_11', 'ch_11', 'ch_11')]
#
# merging 4 + 1410
# num_tok MOC 1414
# chunking [(9781905832729, 'ch_11', 'ch_11', 'ch_11'), (9781905832729, 'ch_11', '10.i', '10.i')]
#
# num_tok MOC 1246
# chunking [(9781905832729, 'ch_11', '10.ii', '10.ii')]
#
# num_tok MOC 1154
# chunking [(9781905832729, 'ch_11', '10.iii', '10.iii')]
#
#
# ############################
#
#
# book 9781908541024 chapter ch_2
#
# num_tok MOC 6
# skipping [(9781908541024, 'ch_2', 'ch_2', 'ch_2')]
#
# merging 6 + 264
# num_tok MOC 270
# skipping [(9781908541024, 'ch_2', 'ch_2', 'ch_2'), (9781908541024, 'ch_2', '1.i', '1.i')]
#
# merging 270 + 495
# num_tok MOC 765
# summ [(9781908541024, 'ch_2', 'ch_2', 'ch_2'), (9781908541024, 'ch_2', '1.i', '1.i'), (9781908541024, 'ch_2', '1.ii', '1.ii')]
#
#
# ############################
#
#
# book 9781908541024 chapter ch_3
#
# num_tok MOC 848
# summ [(9781908541024, 'ch_3', '2.i', '2.i')]
#
# num_tok MOC 550
# skipping [(9781908541024, 'ch_3', '2.ii', '2.ii')]
#
# merging 550 + 236
# num_tok MOC 786
# summ [(9781908541024, 'ch_3', '2.ii', '2.ii'), (9781908541024, 'ch_3', '2.iii', '2.iii')]
#
#
# ############################
#
#
# book 9781908541024 chapter ch_4
#
# num_tok MOC 2260
# chunking [(9781908541024, 'ch_4', '3.i', '3.i')]
#
# num_tok MOC 2526
# chunking [(9781908541024, 'ch_4', '3.ii', '3.ii')]
#
# num_tok MOC 2574
# chunking [(9781908541024, 'ch_4', '3.iii', '3.iii')]
#
#
# ############################
#
#
# book 9781908541024 chapter ch_5
#
# num_tok MOC 366
# skipping [(9781908541024, 'ch_5', 'ch_5', 'ch_5')]
#
# merging 366 + 360
# num_tok MOC 726
# summ [(9781908541024, 'ch_5', 'ch_5', 'ch_5'), (9781908541024, 'ch_5', '4.i', '4.i')]
#
# num_tok MOC 455
# skipping [(9781908541024, 'ch_5', '4.ii', '4.ii')]
#
# merging 455 + 418
# num_tok MOC 873
# summ [(9781908541024, 'ch_5', '4.ii', '4.ii'), (9781908541024, 'ch_5', '4.iii', '4.iii')]
#
#
# ############################
#
#
# book 9781908541024 chapter ch_6
#
# num_tok MOC 357
# skipping [(9781908541024, 'ch_6', 'ch_6', 'ch_6')]
#
# merging 357 + 1288
# num_tok MOC 1645
# chunking [(9781908541024, 'ch_6', 'ch_6', 'ch_6'), (9781908541024, 'ch_6', '5.i', '5.i')]
#
# num_tok MOC 362
# skipping [(9781908541024, 'ch_6', '5.ii', '5.ii')]
#
# merging 362 + 550
# num_tok MOC 912
# summ [(9781908541024, 'ch_6', '5.ii', '5.ii'), (9781908541024, 'ch_6', '5.iii', '5.iii')]
#
# num_tok MOC 951
# summ [(9781908541024, 'ch_6', '5.iv', '5.iv')]
#
# num_tok MOC 447
# skipping [(9781908541024, 'ch_6', '5.v', '5.v')]
#
# merging 447 + 274
# num_tok MOC 721
# summ [(9781908541024, 'ch_6', '5.v', '5.v'), (9781908541024, 'ch_6', '5.vi', '5.vi')]
#
#
# ############################
#
#
# book 9781908541024 chapter ch_7
#
# num_tok MOC 631
# skipping [(9781908541024, 'ch_7', 'ch_7', 'ch_7')]
#
# merging 631 + 548
# num_tok MOC 1179
# chunking [(9781908541024, 'ch_7', 'ch_7', 'ch_7'), (9781908541024, 'ch_7', '6.i', '6.i')]
#
# num_tok MOC 252
# skipping [(9781908541024, 'ch_7', '6.ii', '6.ii')]
#
# merging 252 + 290
# num_tok MOC 542
# skipping [(9781908541024, 'ch_7', '6.ii', '6.ii'), (9781908541024, 'ch_7', '6.iii', '6.iii')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1721
# chunking [(9781908541024, 'ch_7', 'ch_7', 'ch_7'), (9781908541024, 'ch_7', '6.i', '6.i'), (9781908541024, 'ch_7', '6.ii', '6.ii'), (9781908541024, 'ch_7', '6.iii', '6.iii')]
#
# ############################
#
#
# book 9781908541024 chapter ch_8
#
# num_tok MOC 120
# skipping [(9781908541024, 'ch_8', 'ch_8', 'ch_8')]
#
# merging 120 + 631
# num_tok MOC 751
# summ [(9781908541024, 'ch_8', 'ch_8', 'ch_8'), (9781908541024, 'ch_8', '7.i', '7.i')]
#
# num_tok MOC 379
# skipping [(9781908541024, 'ch_8', '7.ii', '7.ii')]
#
# merging 379 + 351
# num_tok MOC 730
# summ [(9781908541024, 'ch_8', '7.ii', '7.ii'), (9781908541024, 'ch_8', '7.iii', '7.iii')]
#
# num_tok MOC 302
# skipping [(9781908541024, 'ch_8', '7.iv', '7.iv')]
#
# merging 302 + 301
# num_tok MOC 603
# skipping [(9781908541024, 'ch_8', '7.iv', '7.iv'), (9781908541024, 'ch_8', '7.v', '7.v')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1333
# chunking [(9781908541024, 'ch_8', '7.ii', '7.ii'), (9781908541024, 'ch_8', '7.iii', '7.iii'), (9781908541024, 'ch_8', '7.iv', '7.iv'), (9781908541024, 'ch_8', '7.v', '7.v')]
#
# ############################
#
#
# book 9781908541024 chapter ch_9
#
# num_tok MOC 135
# skipping [(9781908541024, 'ch_9', 'ch_9', 'ch_9')]
#
# merging 135 + 2214
# num_tok MOC 2349
# chunking [(9781908541024, 'ch_9', 'ch_9', 'ch_9'), (9781908541024, 'ch_9', '8.1', '8.1')]
#
# num_tok MOC 267
# skipping [(9781908541024, 'ch_9', '8.ii', '8.ii')]
#
# merging 267 + 73
# num_tok MOC 340
# skipping [(9781908541024, 'ch_9', '8.ii', '8.ii'), (9781908541024, 'ch_9', '8.iii', '8.iii')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 2689
# chunking [(9781908541024, 'ch_9', 'ch_9', 'ch_9'), (9781908541024, 'ch_9', '8.1', '8.1'), (9781908541024, 'ch_9', '8.ii', '8.ii'), (9781908541024, 'ch_9', '8.iii', '8.iii')]
# ############################
#
#
# book 9781908541024 chapter ch_10
#
# num_tok MOC 194
# skipping [(9781908541024, 'ch_10', 'ch_10', 'ch_10')]
#
# merging 194 + 93
# num_tok MOC 287
# skipping [(9781908541024, 'ch_10', 'ch_10', 'ch_10'), (9781908541024, 'ch_10', '9.i', '9.i')]
#
# merging 287 + 201
# num_tok MOC 488
# skipping [(9781908541024, 'ch_10', 'ch_10', 'ch_10'), (9781908541024, 'ch_10', '9.i', '9.i'), (9781908541024, 'ch_10', '9.ii', '9.ii')]
#
# merging 488 + 493
# num_tok MOC 981
# summ [(9781908541024, 'ch_10', 'ch_10', 'ch_10'), (9781908541024, 'ch_10', '9.i', '9.i'), (9781908541024, 'ch_10', '9.ii', '9.ii'), (9781908541024, 'ch_10', '9.iii', '9.iii')]
#
# num_tok MOC 3048
# chunking [(9781908541024, 'ch_10', '9.iv', '9.iv')]
#
# num_tok MOC 322
# skipping [(9781908541024, 'ch_10', '9.v', '9.v')]
#
# merging 322 + 190
# num_tok MOC 512
# skipping [(9781908541024, 'ch_10', '9.v', '9.v'), (9781908541024, 'ch_10', '9.vi', '9.vi')]
#
# merging 512 + 178
# num_tok MOC 690
# skipping [(9781908541024, 'ch_10', '9.v', '9.v'), (9781908541024, 'ch_10', '9.vi', '9.vi'), (9781908541024, 'ch_10', '9.vii', '9.vii')]
#
# merging 690 + 329
# num_tok MOC 1019
# chunking [(9781908541024, 'ch_10', '9.v', '9.v'), (9781908541024, 'ch_10', '9.vi', '9.vi'), (9781908541024, 'ch_10', '9.vii', '9.vii'), (9781908541024, 'ch_10', '9.viii', '9.viii')]
#
#
# ############################
#
#
# book 9781908541024 chapter ch_11
#
# num_tok MOC 165
# skipping [(9781908541024, 'ch_11', 'ch_11', 'ch_11')]
#
# merging 165 + 127
# num_tok MOC 292
# skipping [(9781908541024, 'ch_11', 'ch_11', 'ch_11'), (9781908541024, 'ch_11', '10.i', '10.i')]
#
# merging 292 + 675
# num_tok MOC 967
# summ [(9781908541024, 'ch_11', 'ch_11', 'ch_11'), (9781908541024, 'ch_11', '10.i', '10.i'), (9781908541024, 'ch_11', '10.ii', '10.ii')]
#
# num_tok MOC 96
# skipping [(9781908541024, 'ch_11', '10.iii', '10.iii')]
#
# merging 96 + 669
# num_tok MOC 765
# summ [(9781908541024, 'ch_11', '10.iii', '10.iii'), (9781908541024, 'ch_11', '10.iv', '10.iv')]
#
# num_tok MOC 300
# skipping [(9781908541024, 'ch_11', '10.v', '10.v')]
#
# merging 300 + 343
# num_tok MOC 643
# skipping [(9781908541024, 'ch_11', '10.v', '10.v'), (9781908541024, 'ch_11', '10.vi', '10.vi')]
#
# merging 643 + 711
# num_tok MOC 1354
# chunking [(9781908541024, 'ch_11', '10.v', '10.v'), (9781908541024, 'ch_11', '10.vi', '10.vi'), (9781908541024, 'ch_11', '10.vii', '10.vii')]
#
# num_tok MOC 179
# skipping [(9781908541024, 'ch_11', '10.viii', '10.viii')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1533
# chunking [(9781908541024, 'ch_11', '10.v', '10.v'), (9781908541024, 'ch_11', '10.vi', '10.vi'), (9781908541024, 'ch_11', '10.vii', '10.vii'), (9781908541024, 'ch_11', '10.viii', '10.viii')]
#
# ############################
#
#
# book 9781908541024 chapter ch_12
#
# num_tok MOC 11
# skipping [(9781908541024, 'ch_12', 'ch_12', 'ch_12')]
#
# merging 11 + 2087
# num_tok MOC 2098
# chunking [(9781908541024, 'ch_12', 'ch_12', 'ch_12'), (9781908541024, 'ch_12', '11.i', '11.i')]
#
# num_tok MOC 1014
# summ [(9781908541024, 'ch_12', '11.ii', '11.ii')]
#
#
# ############################
#
#
# book 9781908541024 chapter ch_13
#
# num_tok MOC 330
# skipping [(9781908541024, 'ch_13', 'ch_13', 'ch_13')]
#
# merging 330 + 246
# num_tok MOC 576
# skipping [(9781908541024, 'ch_13', 'ch_13', 'ch_13'), (9781908541024, 'ch_13', '12.i', '12.i')]
#
# merging 576 + 387
# num_tok MOC 963
# summ [(9781908541024, 'ch_13', 'ch_13', 'ch_13'), (9781908541024, 'ch_13', '12.i', '12.i'), (9781908541024, 'ch_13', '12.ii', '12.ii')]
#
# num_tok MOC 453
# skipping [(9781908541024, 'ch_13', '12.iii', '12.iii')]
#
# merging 453 + 144
# num_tok MOC 597
# skipping [(9781908541024, 'ch_13', '12.iii', '12.iii'), (9781908541024, 'ch_13', '12.iv', '12.iv')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1560
# chunking [(9781908541024, 'ch_13', 'ch_13', 'ch_13'), (9781908541024, 'ch_13', '12.i', '12.i'), (9781908541024, 'ch_13', '12.ii', '12.ii'), (9781908541024, 'ch_13', '12.iii', '12.iii'), (9781908541024, 'ch_13', '12.iv', '12.iv')]
#
# ############################
#
#
# book 9781908541062 chapter ch_2
#
# num_tok MOC 4
# skipping [(9781908541062, 'ch_2', 'ch_2', 'ch_2')]
#
# merging 4 + 253
# num_tok MOC 257
# skipping [(9781908541062, 'ch_2', 'ch_2', 'ch_2'), (9781908541062, 'ch_2', '1.i', '1.i')]
#
# merging 257 + 163
# num_tok MOC 420
# skipping [(9781908541062, 'ch_2', 'ch_2', 'ch_2'), (9781908541062, 'ch_2', '1.i', '1.i'), (9781908541062, 'ch_2', '1.ii', '1.ii')]
#
# merging 420 + 893
# num_tok MOC 1313
# chunking [(9781908541062, 'ch_2', 'ch_2', 'ch_2'), (9781908541062, 'ch_2', '1.i', '1.i'), (9781908541062, 'ch_2', '1.ii', '1.ii'), (9781908541062, 'ch_2', '1.iii', '1.iii')]
#
# num_tok MOC 551
# skipping [(9781908541062, 'ch_2', '1.iv', '1.iv')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1864
# chunking [(9781908541062, 'ch_2', 'ch_2', 'ch_2'), (9781908541062, 'ch_2', '1.i', '1.i'), (9781908541062, 'ch_2', '1.ii', '1.ii'), (9781908541062, 'ch_2', '1.iii', '1.iii'), (9781908541062, 'ch_2', '1.iv', '1.iv')]
#
# ############################
#
#
# book 9781908541062 chapter ch_3
#
# num_tok MOC 71
# skipping [(9781908541062, 'ch_3', 'ch_3', 'ch_3')]
#
# merging 71 + 1194
# num_tok MOC 1265
# chunking [(9781908541062, 'ch_3', 'ch_3', 'ch_3'), (9781908541062, 'ch_3', '2.i', '2.i')]
#
# num_tok MOC 300
# skipping [(9781908541062, 'ch_3', '2.ii', '2.ii')]
#
# merging 300 + 148
# num_tok MOC 448
# skipping [(9781908541062, 'ch_3', '2.ii', '2.ii'), (9781908541062, 'ch_3', '2.iii', '2.iii')]
#
# merging 448 + 320
# num_tok MOC 768
# summ [(9781908541062, 'ch_3', '2.ii', '2.ii'), (9781908541062, 'ch_3', '2.iii', '2.iii'), (9781908541062, 'ch_3', '2.iv', '2.iv')]
#
# num_tok MOC 190
# skipping [(9781908541062, 'ch_3', '2.v', '2.v')]
#
# merging 190 + 236
# num_tok MOC 426
# skipping [(9781908541062, 'ch_3', '2.v', '2.v'), (9781908541062, 'ch_3', '2.vi', '2.vi')]
#
# merging 426 + 342
# num_tok MOC 768
# summ [(9781908541062, 'ch_3', '2.v', '2.v'), (9781908541062, 'ch_3', '2.vi', '2.vi'), (9781908541062, 'ch_3', '2.vii', '2.vii')]
#
# num_tok MOC 117
# skipping [(9781908541062, 'ch_3', '2.viii', '2.viii')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 885
# summ [(9781908541062, 'ch_3', '2.v', '2.v'), (9781908541062, 'ch_3', '2.vi', '2.vi'), (9781908541062, 'ch_3', '2.vii', '2.vii'), (9781908541062, 'ch_3', '2.viii', '2.viii')]
#
# ############################
#
#
# book 9781908541062 chapter ch_4
#
# num_tok MOC 62
# skipping [(9781908541062, 'ch_4', 'ch_4', 'ch_4')]
#
# merging 62 + 341
# num_tok MOC 403
# skipping [(9781908541062, 'ch_4', 'ch_4', 'ch_4'), (9781908541062, 'ch_4', '3.i', '3.i')]
#
# merging 403 + 447
# num_tok MOC 850
# summ [(9781908541062, 'ch_4', 'ch_4', 'ch_4'), (9781908541062, 'ch_4', '3.i', '3.i'), (9781908541062, 'ch_4', '3.ii', '3.ii')]
#
# num_tok MOC 655
# skipping [(9781908541062, 'ch_4', '3.iii', '3.iii')]
#
# merging 655 + 459
# num_tok MOC 1114
# chunking [(9781908541062, 'ch_4', '3.iii', '3.iii'), (9781908541062, 'ch_4', '3.iv', '3.iv')]
#
# num_tok MOC 110
# skipping [(9781908541062, 'ch_4', '3.v', '3.v')]
#
# merging 110 + 347
# num_tok MOC 457
# skipping [(9781908541062, 'ch_4', '3.v', '3.v'), (9781908541062, 'ch_4', '3.vi', '3.vi')]
#
# merging 457 + 658
# num_tok MOC 1115
# chunking [(9781908541062, 'ch_4', '3.v', '3.v'), (9781908541062, 'ch_4', '3.vi', '3.vi'), (9781908541062, 'ch_4', '3.vii', '3.vii')]
#
# num_tok MOC 410
# skipping [(9781908541062, 'ch_4', '3.viii', '3.viii')]
#
# merging 410 + 242
# num_tok MOC 652
# skipping [(9781908541062, 'ch_4', '3.viii', '3.viii'), (9781908541062, 'ch_4', '3.ix', '3.ix')]
#
# merging 652 + 229
# num_tok MOC 881
# summ [(9781908541062, 'ch_4', '3.viii', '3.viii'), (9781908541062, 'ch_4', '3.ix', '3.ix'), (9781908541062, 'ch_4', '3.x', '3.x')]
#
# num_tok MOC 846
# summ [(9781908541062, 'ch_4', '3.xi', '3.xi')]
#
#
# ############################
#
#
# book 9781908541062 chapter ch_5
#
# num_tok MOC 177
# skipping [(9781908541062, 'ch_5', 'ch_5', 'ch_5')]
#
# merging 177 + 313
# num_tok MOC 490
# skipping [(9781908541062, 'ch_5', 'ch_5', 'ch_5'), (9781908541062, 'ch_5', '4.i', '4.i')]
#
# merging 490 + 675
# num_tok MOC 1165
# chunking [(9781908541062, 'ch_5', 'ch_5', 'ch_5'), (9781908541062, 'ch_5', '4.i', '4.i'), (9781908541062, 'ch_5', '4.ii', '4.ii')]
#
# num_tok MOC 577
# skipping [(9781908541062, 'ch_5', '4.iii', '4.iii')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1742
# chunking [(9781908541062, 'ch_5', 'ch_5', 'ch_5'), (9781908541062, 'ch_5', '4.i', '4.i'), (9781908541062, 'ch_5', '4.ii', '4.ii'), (9781908541062, 'ch_5', '4.iii', '4.iii')]
#
# ############################
#
#
# book 9781908541062 chapter ch_6
#
# num_tok MOC 142
# skipping [(9781908541062, 'ch_6', 'ch_6', 'ch_6')]
#
# merging 142 + 844
# num_tok MOC 986
# summ [(9781908541062, 'ch_6', 'ch_6', 'ch_6'), (9781908541062, 'ch_6', '5.i', '5.i')]
#
# num_tok MOC 1027
# chunking [(9781908541062, 'ch_6', '5.ii', '5.ii')]
#
# num_tok MOC 2209
# chunking [(9781908541062, 'ch_6', '5.iii', '5.iii')]
# ############################
#
#
# book 9781908541062 chapter ch_7
#
# num_tok MOC 51
# skipping [(9781908541062, 'ch_7', 'ch_7', 'ch_7')]
#
# merging 51 + 854
# num_tok MOC 905
# summ [(9781908541062, 'ch_7', 'ch_7', 'ch_7'), (9781908541062, 'ch_7', '6.i', '6.i')]
#
# num_tok MOC 882
# summ [(9781908541062, 'ch_7', '6.ii', '6.ii')]
#
# num_tok MOC 226
# skipping [(9781908541062, 'ch_7', '6.iii', '6.iii')]
#
# merging 226 + 263
# num_tok MOC 489
# skipping [(9781908541062, 'ch_7', '6.iii', '6.iii'), (9781908541062, 'ch_7', '6.iv', '6.iv')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1371
# chunking [(9781908541062, 'ch_7', '6.ii', '6.ii'), (9781908541062, 'ch_7', '6.iii', '6.iii'), (9781908541062, 'ch_7', '6.iv', '6.iv')]
#
# ############################
#
#
# book 9781908541062 chapter ch_8
#
# num_tok MOC 157
# skipping [(9781908541062, 'ch_8', 'ch_8', 'ch_8')]
#
# merging 157 + 502
# num_tok MOC 659
# skipping [(9781908541062, 'ch_8', 'ch_8', 'ch_8'), (9781908541062, 'ch_8', '7.i', '7.i')]
#
# merging 659 + 2082
# num_tok MOC 2741
# chunking [(9781908541062, 'ch_8', 'ch_8', 'ch_8'), (9781908541062, 'ch_8', '7.i', '7.i'), (9781908541062, 'ch_8', '7.ii', '7.ii')]
#
# num_tok MOC 293
# skipping [(9781908541062, 'ch_8', '7.iii', '7.iii')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 3034
# chunking [(9781908541062, 'ch_8', 'ch_8', 'ch_8'), (9781908541062, 'ch_8', '7.i', '7.i'), (9781908541062, 'ch_8', '7.ii', '7.ii'), (9781908541062, 'ch_8', '7.iii', '7.iii')]
#
# ############################
#
#
# book 9781908541062 chapter ch_9
#
# num_tok MOC 481
# skipping [(9781908541062, 'ch_9', 'ch_9', 'ch_9')]
#
# merging 481 + 161
# num_tok MOC 642
# skipping [(9781908541062, 'ch_9', 'ch_9', 'ch_9'), (9781908541062, 'ch_9', '8.i', '8.i')]
#
# merging 642 + 234
# num_tok MOC 876
# summ [(9781908541062, 'ch_9', 'ch_9', 'ch_9'), (9781908541062, 'ch_9', '8.i', '8.i'), (9781908541062, 'ch_9', '8.ii', '8.ii')]
#
# num_tok MOC 462
# skipping [(9781908541062, 'ch_9', '8.iii', '8.iii')]
#
# merging 462 + 624
# num_tok MOC 1086
# chunking [(9781908541062, 'ch_9', '8.iii', '8.iii'), (9781908541062, 'ch_9', '8.iv', '8.iv')]
#
# num_tok MOC 2244
# chunking [(9781908541062, 'ch_9', '8.v', '8.v')]
#
# num_tok MOC 401
# skipping [(9781908541062, 'ch_9', '8.vi', '8.vi')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 2645
# chunking [(9781908541062, 'ch_9', '8.v', '8.v'), (9781908541062, 'ch_9', '8.vi', '8.vi')]
#
# ############################
#
#
# book 9781908541062 chapter ch_10
#
# num_tok MOC 204
# skipping [(9781908541062, 'ch_10', 'ch_10', 'ch_10')]
#
# merging 204 + 1398
# num_tok MOC 1602
# chunking [(9781908541062, 'ch_10', 'ch_10', 'ch_10'), (9781908541062, 'ch_10', '9.i', '9.i')]
#
# num_tok MOC 211
# skipping [(9781908541062, 'ch_10', '9.ii', '9.ii')]
#
# merging 211 + 610
# num_tok MOC 821
# summ [(9781908541062, 'ch_10', '9.ii', '9.ii'), (9781908541062, 'ch_10', '9.iii', '9.iii')]
#
# num_tok MOC 373
# skipping [(9781908541062, 'ch_10', '9.iv', '9.iv')]
#
# merging 373 + 389
# num_tok MOC 762
# summ [(9781908541062, 'ch_10', '9.iv', '9.iv'), (9781908541062, 'ch_10', '9.v', '9.v')]
#
# num_tok MOC 353
# skipping [(9781908541062, 'ch_10', '9.vi', '9.vi')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1115
# chunking [(9781908541062, 'ch_10', '9.iv', '9.iv'), (9781908541062, 'ch_10', '9.v', '9.v'), (9781908541062, 'ch_10', '9.vi', '9.vi')]
#
# ############################
#
#
# book 9781908541062 chapter ch_11
#
# num_tok MOC 33
# skipping [(9781908541062, 'ch_11', 'ch_11', 'ch_11')]
#
# merging 33 + 191
# num_tok MOC 224
# skipping [(9781908541062, 'ch_11', 'ch_11', 'ch_11'), (9781908541062, 'ch_11', '10.i', '10.i')]
#
# merging 224 + 248
# num_tok MOC 472
# skipping [(9781908541062, 'ch_11', 'ch_11', 'ch_11'), (9781908541062, 'ch_11', '10.i', '10.i'), (9781908541062, 'ch_11', '10.ii', '10.ii')]
#
# merging 472 + 454
# num_tok MOC 926
# summ [(9781908541062, 'ch_11', 'ch_11', 'ch_11'), (9781908541062, 'ch_11', '10.i', '10.i'), (9781908541062, 'ch_11', '10.ii', '10.ii'), (9781908541062, 'ch_11', '10.iii', '10.iii')]
#
# num_tok MOC 151
# skipping [(9781908541062, 'ch_11', '10.iv', '10.iv')]
#
# merging 151 + 206
# num_tok MOC 357
# skipping [(9781908541062, 'ch_11', '10.iv', '10.iv'), (9781908541062, 'ch_11', '10.v', '10.v')]
#
# merging 357 + 160
# num_tok MOC 517
# skipping [(9781908541062, 'ch_11', '10.iv', '10.iv'), (9781908541062, 'ch_11', '10.v', '10.v'), (9781908541062, 'ch_11', '10.vi', '10.vi')]
#
# merging 517 + 253
# num_tok MOC 770
# summ [(9781908541062, 'ch_11', '10.iv', '10.iv'), (9781908541062, 'ch_11', '10.v', '10.v'), (9781908541062, 'ch_11', '10.vi', '10.vi'), (9781908541062, 'ch_11', '10.vii', '10.vii')]
#
# num_tok MOC 204
# skipping [(9781908541062, 'ch_11', '10.viii', '10.viii')]
#
# merging 204 + 116
# num_tok MOC 320
# skipping [(9781908541062, 'ch_11', '10.viii', '10.viii'), (9781908541062, 'ch_11', '10.ix', '10.ix')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1090
# chunking [(9781908541062, 'ch_11', '10.iv', '10.iv'), (9781908541062, 'ch_11', '10.v', '10.v'), (9781908541062, 'ch_11', '10.vi', '10.vi'), (9781908541062, 'ch_11', '10.vii', '10.vii'), (9781908541062, 'ch_11', '10.viii', '10.viii'), (9781908541062, 'ch_11', '10.ix', '10.ix')]
#
# ############################
#
#
# book 9781908541086 chapter ch_3
#
# num_tok MOC 353
# skipping [(9781908541086, 'ch_3', '1.i', '1.i')]
#
# merging 353 + 262
# num_tok MOC 615
# skipping [(9781908541086, 'ch_3', '1.i', '1.i'), (9781908541086, 'ch_3', '1.ii', '1.ii')]
#
# merging 615 + 332
# num_tok MOC 947
# summ [(9781908541086, 'ch_3', '1.i', '1.i'), (9781908541086, 'ch_3', '1.ii', '1.ii'), (9781908541086, 'ch_3', '1.iii', '1.iii')]
#
#
# ############################
#
#
# book 9781908541086 chapter ch_4
#
# num_tok MOC 39
# skipping [(9781908541086, 'ch_4', 'ch_4', 'ch_4')]
#
# merging 39 + 839
# num_tok MOC 878
# summ [(9781908541086, 'ch_4', 'ch_4', 'ch_4'), (9781908541086, 'ch_4', '2.i', '2.i')]
#
# num_tok MOC 413
# skipping [(9781908541086, 'ch_4', '2.ii', '2.ii')]
#
# merging 413 + 198
# num_tok MOC 611
# skipping [(9781908541086, 'ch_4', '2.ii', '2.ii'), (9781908541086, 'ch_4', '2.iii', '2.iii')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1489
# chunking [(9781908541086, 'ch_4', 'ch_4', 'ch_4'), (9781908541086, 'ch_4', '2.i', '2.i'), (9781908541086, 'ch_4', '2.ii', '2.ii'), (9781908541086, 'ch_4', '2.iii', '2.iii')]
#
# ############################
#
#
# book 9781908541086 chapter ch_5
#
# num_tok MOC 48
# skipping [(9781908541086, 'ch_5', 'ch_5', 'ch_5')]
#
# merging 48 + 1094
# num_tok MOC 1142
# chunking [(9781908541086, 'ch_5', 'ch_5', 'ch_5'), (9781908541086, 'ch_5', '3.i', '3.i')]
#
# num_tok MOC 1013
# summ [(9781908541086, 'ch_5', '3.ii', '3.ii')]
#
# num_tok MOC 982
# summ [(9781908541086, 'ch_5', '3.iii', '3.iii')]
#
# num_tok MOC 1346
# chunking [(9781908541086, 'ch_5', '3.iv', '3.iv')]
#
#
# ############################
#
#
# book 9781908541086 chapter ch_6
#
# num_tok MOC 259
# skipping [(9781908541086, 'ch_6', 'ch_6', 'ch_6')]
#
# merging 259 + 553
# num_tok MOC 812
# summ [(9781908541086, 'ch_6', 'ch_6', 'ch_6'), (9781908541086, 'ch_6', '4.i', '4.i')]
#
# num_tok MOC 177
# skipping [(9781908541086, 'ch_6', '4.ii', '4.ii')]
#
# merging 177 + 1364
# num_tok MOC 1541
# chunking [(9781908541086, 'ch_6', '4.ii', '4.ii'), (9781908541086, 'ch_6', '4.iii', '4.iii')]
#
# num_tok MOC 479
# skipping [(9781908541086, 'ch_6', '4.iv', '4.iv')]
#
# merging 479 + 425
# num_tok MOC 904
# summ [(9781908541086, 'ch_6', '4.iv', '4.iv'), (9781908541086, 'ch_6', '4.v', '4.v')]
#
# num_tok MOC 261
# skipping [(9781908541086, 'ch_6', '4.vi', '4.vi')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1165
# chunking [(9781908541086, 'ch_6', '4.iv', '4.iv'), (9781908541086, 'ch_6', '4.v', '4.v'), (9781908541086, 'ch_6', '4.vi', '4.vi')]
#
# ############################
#
#
# book 9781908541086 chapter ch_7
#
# num_tok MOC 4
# skipping [(9781908541086, 'ch_7', 'ch_7', 'ch_7')]
#
# merging 4 + 426
# num_tok MOC 430
# skipping [(9781908541086, 'ch_7', 'ch_7', 'ch_7'), (9781908541086, 'ch_7', '5.i', '5.i')]
#
# merging 430 + 327
# num_tok MOC 757
# summ [(9781908541086, 'ch_7', 'ch_7', 'ch_7'), (9781908541086, 'ch_7', '5.i', '5.i'), (9781908541086, 'ch_7', '5.ii', '5.ii')]
#
# num_tok MOC 1134
# chunking [(9781908541086, 'ch_7', '5.iii', '5.iii')]
#
# num_tok MOC 196
# skipping [(9781908541086, 'ch_7', '5.iv', '5.iv')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1330
# chunking [(9781908541086, 'ch_7', '5.iii', '5.iii'), (9781908541086, 'ch_7', '5.iv', '5.iv')]
#
# ############################
#
#
# book 9781908541086 chapter ch_8
#
# num_tok MOC 43
# skipping [(9781908541086, 'ch_8', 'ch_8', 'ch_8')]
#
# merging 43 + 256
# num_tok MOC 299
# skipping [(9781908541086, 'ch_8', 'ch_8', 'ch_8'), (9781908541086, 'ch_8', '6.i', '6.i')]
#
# merging 299 + 265
# num_tok MOC 564
# skipping [(9781908541086, 'ch_8', 'ch_8', 'ch_8'), (9781908541086, 'ch_8', '6.i', '6.i'), (9781908541086, 'ch_8', '6.ii', '6.ii')]
#
# merging 564 + 1471
# num_tok MOC 2035
# chunking [(9781908541086, 'ch_8', 'ch_8', 'ch_8'), (9781908541086, 'ch_8', '6.i', '6.i'), (9781908541086, 'ch_8', '6.ii', '6.ii'), (9781908541086, 'ch_8', '6.iii', '6.iii')]
#
# num_tok MOC 1617
# chunking [(9781908541086, 'ch_8', '6.iv', '6.iv')]
#
# num_tok MOC 429
# skipping [(9781908541086, 'ch_8', '6.v', '6.v')]
#
# merging 429 + 181
# num_tok MOC 610
# skipping [(9781908541086, 'ch_8', '6.v', '6.v'), (9781908541086, 'ch_8', '6.vi', '6.vi')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 2227
# chunking [(9781908541086, 'ch_8', '6.iv', '6.iv'), (9781908541086, 'ch_8', '6.v', '6.v'), (9781908541086, 'ch_8', '6.vi', '6.vi')]
# ############################
#
#
# book 9781908541086 chapter ch_9
#
# num_tok MOC 99
# skipping [(9781908541086, 'ch_9', 'ch_9', 'ch_9')]
#
# merging 99 + 213
# num_tok MOC 312
# skipping [(9781908541086, 'ch_9', 'ch_9', 'ch_9'), (9781908541086, 'ch_9', '7.i', '7.i')]
#
# merging 312 + 1106
# num_tok MOC 1418
# chunking [(9781908541086, 'ch_9', 'ch_9', 'ch_9'), (9781908541086, 'ch_9', '7.i', '7.i'), (9781908541086, 'ch_9', '7.ii', '7.ii')]
#
# num_tok MOC 1372
# chunking [(9781908541086, 'ch_9', '7.iii', '7.iii')]
#
# num_tok MOC 287
# skipping [(9781908541086, 'ch_9', '7.iv', '7.iv')]
#
# merging 287 + 109
# num_tok MOC 396
# skipping [(9781908541086, 'ch_9', '7.iv', '7.iv'), (9781908541086, 'ch_9', '7.v', '7.v')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1768
# chunking [(9781908541086, 'ch_9', '7.iii', '7.iii'), (9781908541086, 'ch_9', '7.iv', '7.iv'), (9781908541086, 'ch_9', '7.v', '7.v')]
#
# ############################
#
#
# book 9781908541086 chapter ch_10
#
# num_tok MOC 7
# skipping [(9781908541086, 'ch_10', 'ch_10', 'ch_10')]
#
# merging 7 + 1062
# num_tok MOC 1069
# chunking [(9781908541086, 'ch_10', 'ch_10', 'ch_10'), (9781908541086, 'ch_10', '8.i', '8.i')]
#
# num_tok MOC 518
# skipping [(9781908541086, 'ch_10', '8.ii', '8.ii')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1587
# chunking [(9781908541086, 'ch_10', 'ch_10', 'ch_10'), (9781908541086, 'ch_10', '8.i', '8.i'), (9781908541086, 'ch_10', '8.ii', '8.ii')]
#
# ############################
#
#
# book 9781908541086 chapter ch_11
#
# num_tok MOC 4
# skipping [(9781908541086, 'ch_11', 'ch_11', 'ch_11')]
#
# merging 4 + 876
# num_tok MOC 880
# summ [(9781908541086, 'ch_11', 'ch_11', 'ch_11'), (9781908541086, 'ch_11', '9.i', '9.i')]
#
# num_tok MOC 336
# skipping [(9781908541086, 'ch_11', '9.ii', '9.ii')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1216
# chunking [(9781908541086, 'ch_11', 'ch_11', 'ch_11'), (9781908541086, 'ch_11', '9.i', '9.i'), (9781908541086, 'ch_11', '9.ii', '9.ii')]
#
# ############################
#
#
# book 9781908541178 chapter ch_4
#
# num_tok MOC 103
# skipping [(9781908541178, 'ch_4', 'ch_4', 'ch_4')]
#
# merging 103 + 1233
# num_tok MOC 1336
# chunking [(9781908541178, 'ch_4', 'ch_4', 'ch_4'), (9781908541178, 'ch_4', '1.i', '1.i')]
#
# num_tok MOC 211
# skipping [(9781908541178, 'ch_4', '1.ii', '1.ii')]
#
# merging 211 + 419
# num_tok MOC 630
# skipping [(9781908541178, 'ch_4', '1.ii', '1.ii'), (9781908541178, 'ch_4', '1.iii', '1.iii')]
#
# merging 630 + 287
# num_tok MOC 917
# summ [(9781908541178, 'ch_4', '1.ii', '1.ii'), (9781908541178, 'ch_4', '1.iii', '1.iii'), (9781908541178, 'ch_4', '1.iv', '1.iv')]
#
# num_tok MOC 173
# skipping [(9781908541178, 'ch_4', '1.v', '1.v')]
#
# merging 173 + 522
# num_tok MOC 695
# skipping [(9781908541178, 'ch_4', '1.v', '1.v'), (9781908541178, 'ch_4', '1.vi', '1.vi')]
#
# merging 695 + 357
# num_tok MOC 1052
# chunking [(9781908541178, 'ch_4', '1.v', '1.v'), (9781908541178, 'ch_4', '1.vi', '1.vi'), (9781908541178, 'ch_4', '1.viii', '1.viii')]
#
# num_tok MOC 325
# skipping [(9781908541178, 'ch_4', '1.ix', '1.ix')]
#
# merging 325 + 574
# num_tok MOC 899
# summ [(9781908541178, 'ch_4', '1.ix', '1.ix'), (9781908541178, 'ch_4', '1.x', '1.x')]
#
# num_tok MOC 423
# skipping [(9781908541178, 'ch_4', '1.xi', '1.xi')]
#
# merging 423 + 855
# num_tok MOC 1278
# chunking [(9781908541178, 'ch_4', '1.xi', '1.xi'), (9781908541178, 'ch_4', '1.xii', '1.xii')]
#
#
# ############################
#
#
# book 9781908541178 chapter ch_5
#
# num_tok MOC 196
# skipping [(9781908541178, 'ch_5', 'ch_5', 'ch_5')]
#
# merging 196 + 2300
# num_tok MOC 2496
# chunking [(9781908541178, 'ch_5', 'ch_5', 'ch_5'), (9781908541178, 'ch_5', '2.i', '2.i')]
#
# num_tok MOC 702
# skipping [(9781908541178, 'ch_5', '2.ii', '2.ii')]
#
# merging 702 + 179
# num_tok MOC 881
# summ [(9781908541178, 'ch_5', '2.ii', '2.ii'), (9781908541178, 'ch_5', '2.iii', '2.iii')]
#
#
# ############################
#
#
# book 9781908541178 chapter ch_6
#
# num_tok MOC 7
# skipping [(9781908541178, 'ch_6', 'ch_6', 'ch_6')]
#
# merging 7 + 671
# num_tok MOC 678
# skipping [(9781908541178, 'ch_6', 'ch_6', 'ch_6'), (9781908541178, 'ch_6', '3.i', '3.i')]
#
# merging 678 + 312
# num_tok MOC 990
# summ [(9781908541178, 'ch_6', 'ch_6', 'ch_6'), (9781908541178, 'ch_6', '3.i', '3.i'), (9781908541178, 'ch_6', '3.ii', '3.ii')]
#
# num_tok MOC 6106
# chunking [(9781908541178, 'ch_6', '3.iii', '3.iii')]
#
# num_tok MOC 930
# summ [(9781908541178, 'ch_6', '3.iv', '3.iv')]
#
# num_tok MOC 756
# summ [(9781908541178, 'ch_6', '3.v', '3.v')]
#
# num_tok MOC 259
# skipping [(9781908541178, 'ch_6', '3.vi', '3.vi')]
#
# merging 259 + 541
# num_tok MOC 800
# summ [(9781908541178, 'ch_6', '3.vi', '3.vi'), (9781908541178, 'ch_6', '3.vii', '3.vii')]
#
#
# ############################
#
#
# book 9781908541178 chapter ch_7
#
# num_tok MOC 236
# skipping [(9781908541178, 'ch_7', 'ch_7', 'ch_7')]
#
# merging 236 + 691
# num_tok MOC 927
# summ [(9781908541178, 'ch_7', 'ch_7', 'ch_7'), (9781908541178, 'ch_7', '4.i', '4.i')]
#
# num_tok MOC 1677
# chunking [(9781908541178, 'ch_7', '4.ii', '4.ii')]
#
# num_tok MOC 3305
# chunking [(9781908541178, 'ch_7', '4.iii', '4.iii')]
#
# num_tok MOC 1632
# chunking [(9781908541178, 'ch_7', '4.iv', '4.iv')]
#
# num_tok MOC 1393
# chunking [(9781908541178, 'ch_7', '4.v', '4.v')]
#
#
# ############################
#
#
# book 9781908541178 chapter ch_8
#
# num_tok MOC 6
# skipping [(9781908541178, 'ch_8', 'ch_8', 'ch_8')]
#
# merging 6 + 1608
# num_tok MOC 1614
# chunking [(9781908541178, 'ch_8', 'ch_8', 'ch_8'), (9781908541178, 'ch_8', '5.i', '5.i')]
#
# num_tok MOC 2017
# chunking [(9781908541178, 'ch_8', '5.ii', '5.ii')]
#
#
# ############################
#
#
# book 9781908541277 chapter ch_4
#
# num_tok MOC 10
# skipping [(9781908541277, 'ch_4', 'ch_4', 'ch_4')]
#
# merging 10 + 194
# num_tok MOC 204
# skipping [(9781908541277, 'ch_4', 'ch_4', 'ch_4'), (9781908541277, 'ch_4', 'sec0', 'sec0')]
#
# merging 204 + 303
# num_tok MOC 507
# skipping [(9781908541277, 'ch_4', 'ch_4', 'ch_4'), (9781908541277, 'ch_4', 'sec0', 'sec0'), (9781908541277, 'ch_4', 'sec1', 'sec1')]
#
# merging 507 + 242
# num_tok MOC 749
# summ [(9781908541277, 'ch_4', 'ch_4', 'ch_4'), (9781908541277, 'ch_4', 'sec0', 'sec0'), (9781908541277, 'ch_4', 'sec1', 'sec1'), (9781908541277, 'ch_4', 'sec2', 'sec2')]
#
#
# ############################
#
#
# book 9781908541277 chapter ch_5
#
# num_tok MOC 8
# skipping [(9781908541277, 'ch_5', 'ch_5', 'ch_5')]
#
# merging 8 + 1076
# num_tok MOC 1084
# chunking [(9781908541277, 'ch_5', 'ch_5', 'ch_5'), (9781908541277, 'ch_5', 'sec0', 'sec0')]
#
# num_tok MOC 2590
# chunking [(9781908541277, 'ch_5', 'sec1', 'sec1')]
#
# num_tok MOC 517
# skipping [(9781908541277, 'ch_5', 'sec2', 'sec2')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 3107
# chunking [(9781908541277, 'ch_5', 'sec1', 'sec1'), (9781908541277, 'ch_5', 'sec2', 'sec2')]
#
# ############################
#
#
# book 9781908541277 chapter ch_6
#
# num_tok MOC 160
# skipping [(9781908541277, 'ch_6', 'ch_6', 'ch_6')]
#
# merging 160 + 470
# num_tok MOC 630
# skipping [(9781908541277, 'ch_6', 'ch_6', 'ch_6'), (9781908541277, 'ch_6', 'sec0', 'sec0')]
#
# merging 630 + 245
# num_tok MOC 875
# summ [(9781908541277, 'ch_6', 'ch_6', 'ch_6'), (9781908541277, 'ch_6', 'sec0', 'sec0'), (9781908541277, 'ch_6', 'sec1', 'sec1')]
#
# num_tok MOC 1090
# chunking [(9781908541277, 'ch_6', 'sec2', 'sec2')]
#
#
# ############################
#
#
# book 9781908541277 chapter ch_7
#
# num_tok MOC 5
# skipping [(9781908541277, 'ch_7', 'ch_7', 'ch_7')]
#
# merging 5 + 856
# num_tok MOC 861
# summ [(9781908541277, 'ch_7', 'ch_7', 'ch_7'), (9781908541277, 'ch_7', 'sec0', 'sec0')]
#
# num_tok MOC 3525
# chunking [(9781908541277, 'ch_7', 'sec1', 'sec1')]
#
# num_tok MOC 375
# skipping [(9781908541277, 'ch_7', 'sec2', 'sec2')]
#
# merging 375 + 591
# num_tok MOC 966
# summ [(9781908541277, 'ch_7', 'sec2', 'sec2'), (9781908541277, 'ch_7', 'sec3', 'sec3')]
#
# num_tok MOC 438
# skipping [(9781908541277, 'ch_7', 'sec4', 'sec4')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1404
# chunking [(9781908541277, 'ch_7', 'sec2', 'sec2'), (9781908541277, 'ch_7', 'sec3', 'sec3'), (9781908541277, 'ch_7', 'sec4', 'sec4')]
#
# ############################
#
#
# book 9781908541277 chapter ch_8
#
# num_tok MOC 7
# skipping [(9781908541277, 'ch_8', 'ch_8', 'ch_8')]
#
# merging 7 + 4793
# num_tok MOC 4800
# chunking [(9781908541277, 'ch_8', 'ch_8', 'ch_8'), (9781908541277, 'ch_8', 'sec0', 'sec0')]
#
# num_tok MOC 9591
# chunking [(9781908541277, 'ch_8', 'sec1', 'sec1')]
#
# num_tok MOC 425
# skipping [(9781908541277, 'ch_8', 'sec2', 'sec2')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 10016
# chunking [(9781908541277, 'ch_8', 'sec1', 'sec1'), (9781908541277, 'ch_8', 'sec2', 'sec2')]
# ############################
#
#
# book 9781908541277 chapter ch_9
#
# num_tok MOC 7
# skipping [(9781908541277, 'ch_9', 'ch_9', 'ch_9')]
#
# merging 7 + 1050
# num_tok MOC 1057
# chunking [(9781908541277, 'ch_9', 'ch_9', 'ch_9'), (9781908541277, 'ch_9', 'sec0', 'sec0')]
#
# num_tok MOC 743
# summ [(9781908541277, 'ch_9', 'sec1', 'sec1')]
#
# num_tok MOC 295
# skipping [(9781908541277, 'ch_9', 'sec2', 'sec2')]
#
# merging 295 + 575
# num_tok MOC 870
# summ [(9781908541277, 'ch_9', 'sec2', 'sec2'), (9781908541277, 'ch_9', 'sec3', 'sec3')]
#
# num_tok MOC 332
# skipping [(9781908541277, 'ch_9', 'sec4', 'sec4')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1202
# chunking [(9781908541277, 'ch_9', 'sec2', 'sec2'), (9781908541277, 'ch_9', 'sec3', 'sec3'), (9781908541277, 'ch_9', 'sec4', 'sec4')]
#
# ############################
#
#
# book 9781908541277 chapter ch_10
#
# num_tok MOC 351
# skipping [(9781908541277, 'ch_10', 'ch_10', 'ch_10')]
#
# merging 351 + 128
# num_tok MOC 479
# skipping [(9781908541277, 'ch_10', 'ch_10', 'ch_10'), (9781908541277, 'ch_10', 'sec0', 'sec0')]
#
# merging 479 + 354
# num_tok MOC 833
# summ [(9781908541277, 'ch_10', 'ch_10', 'ch_10'), (9781908541277, 'ch_10', 'sec0', 'sec0'), (9781908541277, 'ch_10', 'sec1', 'sec1')]
#
# num_tok MOC 502
# skipping [(9781908541277, 'ch_10', 'sec2', 'sec2')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1335
# chunking [(9781908541277, 'ch_10', 'ch_10', 'ch_10'), (9781908541277, 'ch_10', 'sec0', 'sec0'), (9781908541277, 'ch_10', 'sec1', 'sec1'), (9781908541277, 'ch_10', 'sec2', 'sec2')]
#
# ############################
#
#
# book 9781908541277 chapter ch_11
#
# num_tok MOC 3
# skipping [(9781908541277, 'ch_11', 'ch_11', 'ch_11')]
#
# merging 3 + 1809
# num_tok MOC 1812
# chunking [(9781908541277, 'ch_11', 'ch_11', 'ch_11'), (9781908541277, 'ch_11', 'sec0', 'sec0')]
#
# num_tok MOC 548
# skipping [(9781908541277, 'ch_11', 'sec1', 'sec1')]
#
# merging 548 + 294
# num_tok MOC 842
# summ [(9781908541277, 'ch_11', 'sec1', 'sec1'), (9781908541277, 'ch_11', 'sec2', 'sec2')]
#
# num_tok MOC 389
# skipping [(9781908541277, 'ch_11', 'sec3', 'sec3')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1231
# chunking [(9781908541277, 'ch_11', 'sec1', 'sec1'), (9781908541277, 'ch_11', 'sec2', 'sec2'), (9781908541277, 'ch_11', 'sec3', 'sec3')]
#
# ############################
#
#
# book 9781908541277 chapter ch_12
#
# num_tok MOC 4
# skipping [(9781908541277, 'ch_12', 'ch_12', 'ch_12')]
#
# merging 4 + 1675
# num_tok MOC 1679
# chunking [(9781908541277, 'ch_12', 'ch_12', 'ch_12'), (9781908541277, 'ch_12', 'sec0', 'sec0')]
#
# num_tok MOC 794
# summ [(9781908541277, 'ch_12', 'sec1', 'sec1')]
#
#
# ############################
#
#
# book 9781908541406 chapter ch_3
#
# num_tok MOC 352
# skipping [(9781908541406, 'ch_3', 'ch_3', 'ch_3')]
#
# merging 352 + 275
# num_tok MOC 627
# skipping [(9781908541406, 'ch_3', 'ch_3', 'ch_3'), (9781908541406, 'ch_3', 'sec0', 'sec0')]
#
# merging 627 + 623
# num_tok MOC 1250
# chunking [(9781908541406, 'ch_3', 'ch_3', 'ch_3'), (9781908541406, 'ch_3', 'sec0', 'sec0'), (9781908541406, 'ch_3', 'sec1', 'sec1')]
#
# num_tok MOC 844
# summ [(9781908541406, 'ch_3', 'sec2', 'sec2')]
#
# num_tok MOC 435
# skipping [(9781908541406, 'ch_3', 'sec3', 'sec3')]
#
# merging 435 + 239
# num_tok MOC 674
# skipping [(9781908541406, 'ch_3', 'sec3', 'sec3'), (9781908541406, 'ch_3', 'sec4', 'sec4')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1518
# chunking [(9781908541406, 'ch_3', 'sec2', 'sec2'), (9781908541406, 'ch_3', 'sec3', 'sec3'), (9781908541406, 'ch_3', 'sec4', 'sec4')]
#
# ############################
#
#
# book 9781908541406 chapter ch_4
#
# num_tok MOC 205
# skipping [(9781908541406, 'ch_4', 'ch_4', 'ch_4')]
#
# merging 205 + 1116
# num_tok MOC 1321
# chunking [(9781908541406, 'ch_4', 'ch_4', 'ch_4'), (9781908541406, 'ch_4', 'sec0', 'sec0')]
#
# num_tok MOC 505
# skipping [(9781908541406, 'ch_4', 'sec1', 'sec1')]
#
# merging 505 + 865
# num_tok MOC 1370
# chunking [(9781908541406, 'ch_4', 'sec1', 'sec1'), (9781908541406, 'ch_4', 'sec2', 'sec2')]
#
#
# ############################
#
#
# book 9781908541406 chapter ch_5
#
# num_tok MOC 7
# skipping [(9781908541406, 'ch_5', 'ch_5', 'ch_5')]
#
# merging 7 + 1407
# num_tok MOC 1414
# chunking [(9781908541406, 'ch_5', 'ch_5', 'ch_5'), (9781908541406, 'ch_5', 'sec0', 'sec0')]
#
# num_tok MOC 231
# skipping [(9781908541406, 'ch_5', 'sec1', 'sec1')]
#
# merging 231 + 452
# num_tok MOC 683
# skipping [(9781908541406, 'ch_5', 'sec1', 'sec1'), (9781908541406, 'ch_5', 'sec2', 'sec2')]
#
# merging 683 + 471
# num_tok MOC 1154
# chunking [(9781908541406, 'ch_5', 'sec1', 'sec1'), (9781908541406, 'ch_5', 'sec2', 'sec2'), (9781908541406, 'ch_5', 'sec3', 'sec3')]
#
# num_tok MOC 689
# skipping [(9781908541406, 'ch_5', 'sec4', 'sec4')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1843
# chunking [(9781908541406, 'ch_5', 'sec1', 'sec1'), (9781908541406, 'ch_5', 'sec2', 'sec2'), (9781908541406, 'ch_5', 'sec3', 'sec3'), (9781908541406, 'ch_5', 'sec4', 'sec4')]
#
# ############################
#
#
# book 9781908541406 chapter ch_6
#
# num_tok MOC 4
# skipping [(9781908541406, 'ch_6', 'ch_6', 'ch_6')]
#
# merging 4 + 1646
# num_tok MOC 1650
# chunking [(9781908541406, 'ch_6', 'ch_6', 'ch_6'), (9781908541406, 'ch_6', 'sec0', 'sec0')]
#
# num_tok MOC 4833
# chunking [(9781908541406, 'ch_6', 'sec1', 'sec1')]
#
#
# ############################
#
#
# book 9781908541406 chapter ch_7
#
# num_tok MOC 321
# skipping [(9781908541406, 'ch_7', 'ch_7', 'ch_7')]
#
# merging 321 + 892
# num_tok MOC 1213
# chunking [(9781908541406, 'ch_7', 'ch_7', 'ch_7'), (9781908541406, 'ch_7', 'sec0', 'sec0')]
#
# num_tok MOC 146
# skipping [(9781908541406, 'ch_7', 'sec1', 'sec1')]
#
# merging 146 + 497
# num_tok MOC 643
# skipping [(9781908541406, 'ch_7', 'sec1', 'sec1'), (9781908541406, 'ch_7', 'sec2', 'sec2')]
#
# merging 643 + 117
# num_tok MOC 760
# summ [(9781908541406, 'ch_7', 'sec1', 'sec1'), (9781908541406, 'ch_7', 'sec2', 'sec2'), (9781908541406, 'ch_7', 'sec3', 'sec3')]
#
#
# ############################
#
#
# book 9781908541406 chapter ch_8
#
# num_tok MOC 220
# skipping [(9781908541406, 'ch_8', 'ch_8', 'ch_8')]
#
# merging 220 + 381
# num_tok MOC 601
# skipping [(9781908541406, 'ch_8', 'ch_8', 'ch_8'), (9781908541406, 'ch_8', 'sec0', 'sec0')]
#
# merging 601 + 352
# num_tok MOC 953
# summ [(9781908541406, 'ch_8', 'ch_8', 'ch_8'), (9781908541406, 'ch_8', 'sec0', 'sec0'), (9781908541406, 'ch_8', 'sec1', 'sec1')]
#
# num_tok MOC 913
# summ [(9781908541406, 'ch_8', 'sec2', 'sec2')]
#
# num_tok MOC 247
# skipping [(9781908541406, 'ch_8', 'sec3', 'sec3')]
#
# merging 247 + 265
# num_tok MOC 512
# skipping [(9781908541406, 'ch_8', 'sec3', 'sec3'), (9781908541406, 'ch_8', 'sec4', 'sec4')]
#
# merging 512 + 352
# num_tok MOC 864
# summ [(9781908541406, 'ch_8', 'sec3', 'sec3'), (9781908541406, 'ch_8', 'sec4', 'sec4'), (9781908541406, 'ch_8', 'sec5', 'sec5')]
#
# num_tok MOC 518
# skipping [(9781908541406, 'ch_8', 'sec6', 'sec6')]
#
# merging 518 + 223
# num_tok MOC 741
# summ [(9781908541406, 'ch_8', 'sec6', 'sec6'), (9781908541406, 'ch_8', 'sec7', 'sec7')]
#
# num_tok MOC 244
# skipping [(9781908541406, 'ch_8', 'sec8', 'sec8')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 985
# summ [(9781908541406, 'ch_8', 'sec6', 'sec6'), (9781908541406, 'ch_8', 'sec7', 'sec7'), (9781908541406, 'ch_8', 'sec8', 'sec8')]
#
# ############################
#
#
# book 9781908541406 chapter ch_9
#
# num_tok MOC 421
# skipping [(9781908541406, 'ch_9', 'ch_9', 'ch_9')]
#
# merging 421 + 169
# num_tok MOC 590
# skipping [(9781908541406, 'ch_9', 'ch_9', 'ch_9'), (9781908541406, 'ch_9', 'sec0', 'sec0')]
#
# merging 590 + 880
# num_tok MOC 1470
# chunking [(9781908541406, 'ch_9', 'ch_9', 'ch_9'), (9781908541406, 'ch_9', 'sec0', 'sec0'), (9781908541406, 'ch_9', 'sec1', 'sec1')]
#
# num_tok MOC 185
# skipping [(9781908541406, 'ch_9', 'sec2', 'sec2')]
#
# merging 185 + 765
# num_tok MOC 950
# summ [(9781908541406, 'ch_9', 'sec2', 'sec2'), (9781908541406, 'ch_9', 'sec3', 'sec3')]
#
#
# ############################
#
#
# book 9781908541406 chapter ch_10
#
# num_tok MOC 451
# skipping [(9781908541406, 'ch_10', 'ch_10', 'ch_10')]
#
# merging 451 + 336
# num_tok MOC 787
# summ [(9781908541406, 'ch_10', 'ch_10', 'ch_10'), (9781908541406, 'ch_10', 'sec0', 'sec0')]
#
# num_tok MOC 149
# skipping [(9781908541406, 'ch_10', 'sec1', 'sec1')]
#
# merging 149 + 152
# num_tok MOC 301
# skipping [(9781908541406, 'ch_10', 'sec1', 'sec1'), (9781908541406, 'ch_10', 'sec2', 'sec2')]
#
# merging 301 + 219
# num_tok MOC 520
# skipping [(9781908541406, 'ch_10', 'sec1', 'sec1'), (9781908541406, 'ch_10', 'sec2', 'sec2'), (9781908541406, 'ch_10', 'sec3', 'sec3')]
#
# merging 520 + 648
# num_tok MOC 1168
# chunking [(9781908541406, 'ch_10', 'sec1', 'sec1'), (9781908541406, 'ch_10', 'sec2', 'sec2'), (9781908541406, 'ch_10', 'sec3', 'sec3'), (9781908541406, 'ch_10', 'sec4', 'sec4')]
#
# num_tok MOC 342
# skipping [(9781908541406, 'ch_10', 'sec5', 'sec5')]
#
# merging 342 + 901
# num_tok MOC 1243
# chunking [(9781908541406, 'ch_10', 'sec5', 'sec5'), (9781908541406, 'ch_10', 'sec6', 'sec6')]
#
# num_tok MOC 137
# skipping [(9781908541406, 'ch_10', 'sec7', 'sec7')]
#
# merging 137 + 467
# num_tok MOC 604
# skipping [(9781908541406, 'ch_10', 'sec7', 'sec7'), (9781908541406, 'ch_10', 'sec8', 'sec8')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1847
# chunking [(9781908541406, 'ch_10', 'sec5', 'sec5'), (9781908541406, 'ch_10', 'sec6', 'sec6'), (9781908541406, 'ch_10', 'sec7', 'sec7'), (9781908541406, 'ch_10', 'sec8', 'sec8')]
# ############################
#
#
# book 9781908541406 chapter ch_11
#
# num_tok MOC 6
# skipping [(9781908541406, 'ch_11', 'ch_11', 'ch_11')]
#
# merging 6 + 2683
# num_tok MOC 2689
# chunking [(9781908541406, 'ch_11', 'ch_11', 'ch_11'), (9781908541406, 'ch_11', 'sec0', 'sec0')]
#
# num_tok MOC 1287
# chunking [(9781908541406, 'ch_11', 'sec1', 'sec1')]
#
#
# ############################
#
#
# book 9781908541406 chapter ch_12
#
# num_tok MOC 294
# skipping [(9781908541406, 'ch_12', 'ch_12', 'ch_12')]
#
# merging 294 + 184
# num_tok MOC 478
# skipping [(9781908541406, 'ch_12', 'ch_12', 'ch_12'), (9781908541406, 'ch_12', 'sec0', 'sec0')]
#
# merging 478 + 574
# num_tok MOC 1052
# chunking [(9781908541406, 'ch_12', 'ch_12', 'ch_12'), (9781908541406, 'ch_12', 'sec0', 'sec0'), (9781908541406, 'ch_12', 'sec1', 'sec1')]
#
# num_tok MOC 334
# skipping [(9781908541406, 'ch_12', 'sec2', 'sec2')]
#
# merging 334 + 323
# num_tok MOC 657
# skipping [(9781908541406, 'ch_12', 'sec2', 'sec2'), (9781908541406, 'ch_12', 'sec3', 'sec3')]
#
# merging 657 + 624
# num_tok MOC 1281
# chunking [(9781908541406, 'ch_12', 'sec2', 'sec2'), (9781908541406, 'ch_12', 'sec3', 'sec3'), (9781908541406, 'ch_12', 'sec4', 'sec4')]
#
# num_tok MOC 648
# skipping [(9781908541406, 'ch_12', 'sec5', 'sec5')]
#
# merging 648 + 144
# num_tok MOC 792
# summ [(9781908541406, 'ch_12', 'sec5', 'sec5'), (9781908541406, 'ch_12', 'sec6', 'sec6')]
#
#
# ############################
#
#
# book 9781908541406 chapter ch_13
#
# num_tok MOC 5
# skipping [(9781908541406, 'ch_13', 'ch_13', 'ch_13')]
#
# merging 5 + 1548
# num_tok MOC 1553
# ...
#
# merging 577 + 474
# num_tok MOC 1051
# chunking [(9783318066685, 'ch2', 'sec23', 'sec26_sub_sec23'), (9783318066685, 'ch2', 'sec27', 'sec27'), (9783318066685, 'ch2', 'sec28', 'sec28'), (9783318066685, 'ch2', 'sec29', 'sec29')]
#
# num_tok MOC 211
# skipping [(9783318066685, 'ch2', 'sec30', 'sec30')]
#
# merging 211 + 40
# num_tok MOC 251
# skipping [(9783318066685, 'ch2', 'sec30', 'sec30'), (9783318066685, 'ch2', 'sec31', 'sec31')]
#
# merging 251 + 307
# num_tok MOC 558
# skipping [(9783318066685, 'ch2', 'sec30', 'sec30'), (9783318066685, 'ch2', 'sec31', 'sec31'), (9783318066685, 'ch2', 'sec32', 'sec32')]
#
# merging 558 + 120
# num_tok MOC 678
# skipping [(9783318066685, 'ch2', 'sec30', 'sec30'), (9783318066685, 'ch2', 'sec31', 'sec31'), (9783318066685, 'ch2', 'sec32', 'sec32'), (9783318066685, 'ch2', 'sec32', 'sec33_sub_sec32')]
#
# merging 678 + 108
# num_tok MOC 786
# summ [(9783318066685, 'ch2', 'sec30', 'sec30'), (9783318066685, 'ch2', 'sec31', 'sec31'), (9783318066685, 'ch2', 'sec32', 'sec32'), (9783318066685, 'ch2', 'sec32', 'sec33_sub_sec32'), (9783318066685, 'ch2', 'sec32', 'sec34_sub_sec32')]
#
# num_tok MOC 138
# skipping [(9783318066685, 'ch2', 'sec32', 'sec35_sub_sec32')]
#
# merging 138 + 119
# num_tok MOC 257
# skipping [(9783318066685, 'ch2', 'sec32', 'sec35_sub_sec32'), (9783318066685, 'ch2', 'sec32', 'sec36_sub_sec32')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1043
# chunking [(9783318066685, 'ch2', 'sec30', 'sec30'), (9783318066685, 'ch2', 'sec31', 'sec31'), (9783318066685, 'ch2', 'sec32', 'sec32'), (9783318066685, 'ch2', 'sec32', 'sec33_sub_sec32'), (9783318066685, 'ch2', 'sec32', 'sec34_sub_sec32'), (9783318066685, 'ch2', 'sec32', 'sec35_sub_sec32'), (9783318066685, 'ch2', 'sec32', 'sec36_sub_sec32')]
#
# ############################
#
#
# book 9783318066685 chapter ch3
#
# num_tok MOC 458
# skipping [(9783318066685, 'ch3', 'ch3', 'ch3')]
#
# merging 458 + 185
# num_tok MOC 643
# skipping [(9783318066685, 'ch3', 'ch3', 'ch3'), (9783318066685, 'ch3', 'sec37', 'sec37')]
#
# merging 643 + 928
# num_tok MOC 1571
# chunking [(9783318066685, 'ch3', 'ch3', 'ch3'), (9783318066685, 'ch3', 'sec37', 'sec37'), (9783318066685, 'ch3', 'sec37', 'sec38_sub_sec37')]
#
# num_tok MOC 5
# skipping [(9783318066685, 'ch3', 'sec39', 'sec39')]
#
# merging 5 + 288
# num_tok MOC 293
# skipping [(9783318066685, 'ch3', 'sec39', 'sec39'), (9783318066685, 'ch3', 'sec39', 'sec40_sub_sec39')]
#
# merging 293 + 363
# num_tok MOC 656
# skipping [(9783318066685, 'ch3', 'sec39', 'sec39'), (9783318066685, 'ch3', 'sec39', 'sec40_sub_sec39'), (9783318066685, 'ch3', 'sec39', 'sec41_sub_sec39')]
#
# merging 656 + 321
# num_tok MOC 977
# summ [(9783318066685, 'ch3', 'sec39', 'sec39'), (9783318066685, 'ch3', 'sec39', 'sec40_sub_sec39'), (9783318066685, 'ch3', 'sec39', 'sec41_sub_sec39'), (9783318066685, 'ch3', 'sec39', 'sec42_sub_sec39')]
# num_tok MOC 229
# skipping [(9783318066685, 'ch3', 'sec39', 'sec43_sub_sec39')]
#
# merging 229 + 208
# num_tok MOC 437
# skipping [(9783318066685, 'ch3', 'sec39', 'sec43_sub_sec39'), (9783318066685, 'ch3', 'sec39', 'sec44_sub_sec39')]
#
# merging 437 + 183
# num_tok MOC 620
# skipping [(9783318066685, 'ch3', 'sec39', 'sec43_sub_sec39'), (9783318066685, 'ch3', 'sec39', 'sec44_sub_sec39'), (9783318066685, 'ch3', 'sec39', 'sec45_sub_sec39')]
#
# merging 620 + 234
# num_tok MOC 854
# summ [(9783318066685, 'ch3', 'sec39', 'sec43_sub_sec39'), (9783318066685, 'ch3', 'sec39', 'sec44_sub_sec39'), (9783318066685, 'ch3', 'sec39', 'sec45_sub_sec39'), (9783318066685, 'ch3', 'sec39', 'sec46_sub_sec39')]
#
# num_tok MOC 328
# skipping [(9783318066685, 'ch3', 'sec47', 'sec47')]
#
# merging 328 + 270
# num_tok MOC 598
# skipping [(9783318066685, 'ch3', 'sec47', 'sec47'), (9783318066685, 'ch3', 'sec48', 'sec48')]
#
# merging 598 + 284
# num_tok MOC 882
# summ [(9783318066685, 'ch3', 'sec47', 'sec47'), (9783318066685, 'ch3', 'sec48', 'sec48'), (9783318066685, 'ch3', 'sec49', 'sec49')]
#
#
# ############################
#
#
# book 9783318066685 chapter ch4
#
# num_tok MOC 98
# skipping [(9783318066685, 'ch4', 'ch4', 'ch4')]
#
# merging 98 + 90
# num_tok MOC 188
# skipping [(9783318066685, 'ch4', 'ch4', 'ch4'), (9783318066685, 'ch4', 'sec50', 'sec50')]
#
# merging 188 + 522
# num_tok MOC 710
# skipping [(9783318066685, 'ch4', 'ch4', 'ch4'), (9783318066685, 'ch4', 'sec50', 'sec50'), (9783318066685, 'ch4', 'sec50', 'sec51_sub_sec50')]
#
# merging 710 + 426
# num_tok MOC 1136
# chunking [(9783318066685, 'ch4', 'ch4', 'ch4'), (9783318066685, 'ch4', 'sec50', 'sec50'), (9783318066685, 'ch4', 'sec50', 'sec51_sub_sec50'), (9783318066685, 'ch4', 'sec52', 'sec52')]
#
# num_tok MOC 447
# skipping [(9783318066685, 'ch4', 'sec53', 'sec53')]
#
# merging 447 + 971
# num_tok MOC 1418
# chunking [(9783318066685, 'ch4', 'sec53', 'sec53'), (9783318066685, 'ch4', 'sec54', 'sec54')]
#
# num_tok MOC 1809
# chunking [(9783318066685, 'ch4', 'sec55', 'sec55')]
#
# num_tok MOC 856
# summ [(9783318066685, 'ch4', 'sec56', 'sec56')]
#
# num_tok MOC 57
# skipping [(9783318066685, 'ch4', 'sec56', 'sec57_sub_sec56')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 913
# summ [(9783318066685, 'ch4', 'sec56', 'sec56'), (9783318066685, 'ch4', 'sec56', 'sec57_sub_sec56')]
#
# ############################
#
#
# book 9783318066685 chapter ch5
#
# num_tok MOC 5
# skipping [(9783318066685, 'ch5', 'ch5', 'ch5')]
#
# merging 5 + 452
# num_tok MOC 457
# skipping [(9783318066685, 'ch5', 'ch5', 'ch5'), (9783318066685, 'ch5', 'sec58', 'sec58')]
#
# merging 457 + 142
# num_tok MOC 599
# skipping [(9783318066685, 'ch5', 'ch5', 'ch5'), (9783318066685, 'ch5', 'sec58', 'sec58'), (9783318066685, 'ch5', 'sec58', 'sec59_sub_sec58')]
#
# merging 599 + 301
# num_tok MOC 900
# summ [(9783318066685, 'ch5', 'ch5', 'ch5'), (9783318066685, 'ch5', 'sec58', 'sec58'), (9783318066685, 'ch5', 'sec58', 'sec59_sub_sec58'), (9783318066685, 'ch5', 'sec58', 'sec60_sub_sec58')]
#
# num_tok MOC 486
# skipping [(9783318066685, 'ch5', 'sec58', 'sec61_sub_sec58')]
#
# merging 486 + 1003
# num_tok MOC 1489
# chunking [(9783318066685, 'ch5', 'sec58', 'sec61_sub_sec58'), (9783318066685, 'ch5', 'sec62', 'sec62')]
#
#
# ############################
#
#
# book 9783318066685 chapter ch6
#
# num_tok MOC 113
# skipping [(9783318066685, 'ch6', 'ch6', 'ch6')]
#
# merging 113 + 321
# num_tok MOC 434
# skipping [(9783318066685, 'ch6', 'ch6', 'ch6'), (9783318066685, 'ch6', 'sec63', 'sec63')]
#
# merging 434 + 814
# num_tok MOC 1248
# chunking [(9783318066685, 'ch6', 'ch6', 'ch6'), (9783318066685, 'ch6', 'sec63', 'sec63'), (9783318066685, 'ch6', 'sec63', 'sec64_sub_sec63')]
#
# num_tok MOC 95
# skipping [(9783318066685, 'ch6', 'sec65', 'sec65')]
#
# merging 95 + 402
# num_tok MOC 497
# skipping [(9783318066685, 'ch6', 'sec65', 'sec65'), (9783318066685, 'ch6', 'sec65', 'sec66_sub_sec65')]
#
# merging 497 + 731
# num_tok MOC 1228
# chunking [(9783318066685, 'ch6', 'sec65', 'sec65'), (9783318066685, 'ch6', 'sec65', 'sec66_sub_sec65'), (9783318066685, 'ch6', 'sec67', 'sec67')]
#
# num_tok MOC 683
# skipping [(9783318066685, 'ch6', 'sec68', 'sec69_sub_sec68')]
#
# merging 683 + 355
# num_tok MOC 1038
# chunking [(9783318066685, 'ch6', 'sec68', 'sec69_sub_sec68'), (9783318066685, 'ch6', 'sec68', 'sec70_sub_sec68')]
#
#
# ############################
#
#
# book 9783318067095 chapter ch1
#
# num_tok MOC 75
# skipping [(9783318067095, 'ch1', 'ch1', 'ch1')]
#
# merging 75 + 537
# num_tok MOC 612
# skipping [(9783318067095, 'ch1', 'ch1', 'ch1'), (9783318067095, 'ch1', 'sec2', 'sec2')]
#
# merging 612 + 407
# num_tok MOC 1019
# chunking [(9783318067095, 'ch1', 'ch1', 'ch1'), (9783318067095, 'ch1', 'sec2', 'sec2'), (9783318067095, 'ch1', 'sec3', 'sec3')]
#
# num_tok MOC 318
# skipping [(9783318067095, 'ch1', 'sec4', 'sec4')]
#
# merging 318 + 953
# num_tok MOC 1271
# chunking [(9783318067095, 'ch1', 'sec4', 'sec4'), (9783318067095, 'ch1', 'sec5', 'sec5')]
#
#
# ############################
#
#
# book 9783318067095 chapter ch2
#
# num_tok MOC 7
# skipping [(9783318067095, 'ch2', 'ch2', 'ch2')]
#
# merging 7 + 416
# num_tok MOC 423
# skipping [(9783318067095, 'ch2', 'ch2', 'ch2'), (9783318067095, 'ch2', 'sec6', 'sec6')]
#
# merging 423 + 532
# num_tok MOC 955
# summ [(9783318067095, 'ch2', 'ch2', 'ch2'), (9783318067095, 'ch2', 'sec6', 'sec6'), (9783318067095, 'ch2', 'sec7', 'sec7')]
#
#
# ############################
#
#
# book 9783318067095 chapter ch3
#
# num_tok MOC 131
# skipping [(9783318067095, 'ch3', 'ch3', 'ch3')]
#
# merging 131 + 532
# num_tok MOC 663
# skipping [(9783318067095, 'ch3', 'ch3', 'ch3'), (9783318067095, 'ch3', 'sec8', 'sec8')]
#
# merging 663 + 388
# num_tok MOC 1051
# chunking [(9783318067095, 'ch3', 'ch3', 'ch3'), (9783318067095, 'ch3', 'sec8', 'sec8'), (9783318067095, 'ch3', 'sec9', 'sec9')]
#
# num_tok MOC 2461
# chunking [(9783318067095, 'ch3', 'sec10', 'sec10')]
#
#
# ############################
#
#
# book 9783318067095 chapter ch4
#
# num_tok MOC 82
# skipping [(9783318067095, 'ch4', 'ch4', 'ch4')]
#
# merging 82 + 369
# num_tok MOC 451
# skipping [(9783318067095, 'ch4', 'ch4', 'ch4'), (9783318067095, 'ch4', 'sec11', 'sec11')]
#
# merging 451 + 1403
# num_tok MOC 1854
# chunking [(9783318067095, 'ch4', 'ch4', 'ch4'), (9783318067095, 'ch4', 'sec11', 'sec11'), (9783318067095, 'ch4', 'sec12', 'sec12')]
#
#
# ############################
#
#
# book 9783318067095 chapter ch5
#
# num_tok MOC 611
# skipping [(9783318067095, 'ch5', 'ch5', 'ch5')]
#
# merging 611 + 711
# num_tok MOC 1322
# chunking [(9783318067095, 'ch5', 'ch5', 'ch5'), (9783318067095, 'ch5', 'sec13', 'sec13')]
#
# num_tok MOC 723
# summ [(9783318067095, 'ch5', 'sec14', 'sec14')]
#
# num_tok MOC 632
# skipping [(9783318067095, 'ch5', 'sec15', 'sec15')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1355
# chunking [(9783318067095, 'ch5', 'sec14', 'sec14'), (9783318067095, 'ch5', 'sec15', 'sec15')]
#
# ############################
#
#
# book 9783318067095 chapter ch6
#
# num_tok MOC 808
# summ [(9783318067095, 'ch6', 'ch6', 'ch6')]
#
# num_tok MOC 232
# skipping [(9783318067095, 'ch6', 'sec16', 'sec16')]
#
# merging 232 + 159
# num_tok MOC 391
# skipping [(9783318067095, 'ch6', 'sec16', 'sec16'), (9783318067095, 'ch6', 'sec17', 'sec17')]
#
# merging 391 + 100
# num_tok MOC 491
# skipping [(9783318067095, 'ch6', 'sec16', 'sec16'), (9783318067095, 'ch6', 'sec17', 'sec17'), (9783318067095, 'ch6', 'sec18', 'sec18')]
#
# merging 491 + 133
# num_tok MOC 624
# skipping [(9783318067095, 'ch6', 'sec16', 'sec16'), (9783318067095, 'ch6', 'sec17', 'sec17'), (9783318067095, 'ch6', 'sec18', 'sec18'), (9783318067095, 'ch6', 'sec19', 'sec19')]
#
# merging 624 + 429
# num_tok MOC 1053
# chunking [(9783318067095, 'ch6', 'sec16', 'sec16'), (9783318067095, 'ch6', 'sec17', 'sec17'), (9783318067095, 'ch6', 'sec18', 'sec18'), (9783318067095, 'ch6', 'sec19', 'sec19'), (9783318067095, 'ch6', 'sec20', 'sec20')]
#
# num_tok MOC 121
# skipping [(9783318067095, 'ch6', 'sec21', 'sec21')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1174
# chunking [(9783318067095, 'ch6', 'sec16', 'sec16'), (9783318067095, 'ch6', 'sec17', 'sec17'), (9783318067095, 'ch6', 'sec18', 'sec18'), (9783318067095, 'ch6', 'sec19', 'sec19'), (9783318067095, 'ch6', 'sec20', 'sec20'), (9783318067095, 'ch6', 'sec21', 'sec21')]
#
# ############################
#
#
# book 9783318067095 chapter ch7
#
# num_tok MOC 201
# skipping [(9783318067095, 'ch7', 'ch7', 'ch7')]
#
# merging 201 + 505
# num_tok MOC 706
# skipping [(9783318067095, 'ch7', 'ch7', 'ch7'), (9783318067095, 'ch7', 'sec22', 'sec22')]
#
# merging 706 + 304
# num_tok MOC 1010
# summ [(9783318067095, 'ch7', 'ch7', 'ch7'), (9783318067095, 'ch7', 'sec22', 'sec22'), (9783318067095, 'ch7', 'sec23', 'sec23')]
#
# num_tok MOC 654
# skipping [(9783318067095, 'ch7', 'sec24', 'sec24')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1664
# chunking [(9783318067095, 'ch7', 'ch7', 'ch7'), (9783318067095, 'ch7', 'sec22', 'sec22'), (9783318067095, 'ch7', 'sec23', 'sec23'), (9783318067095, 'ch7', 'sec24', 'sec24')]
# ############################
#
#
# book 9783318067095 chapter ch8
#
# num_tok MOC 485
# skipping [(9783318067095, 'ch8', 'ch8', 'ch8')]
#
# merging 485 + 745
# num_tok MOC 1230
# chunking [(9783318067095, 'ch8', 'ch8', 'ch8'), (9783318067095, 'ch8', 'sec25', 'sec25')]
#
# num_tok MOC 281
# skipping [(9783318067095, 'ch8', 'sec26', 'sec26')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1511
# chunking [(9783318067095, 'ch8', 'ch8', 'ch8'), (9783318067095, 'ch8', 'sec25', 'sec25'), (9783318067095, 'ch8', 'sec26', 'sec26')]
#
# ############################
#
#
# book 9783318067095 chapter ch9
#
# num_tok MOC 56
# skipping [(9783318067095, 'ch9', 'ch9', 'ch9')]
#
# merging 56 + 1468
# num_tok MOC 1524
# chunking [(9783318067095, 'ch9', 'ch9', 'ch9'), (9783318067095, 'ch9', 'sec27', 'sec27')]
#
# num_tok MOC 152
# skipping [(9783318067095, 'ch9', 'sec28', 'sec28')]
#
# merging 152 + 291
# num_tok MOC 443
# skipping [(9783318067095, 'ch9', 'sec28', 'sec28'), (9783318067095, 'ch9', 'sec29', 'sec29')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1967
# chunking [(9783318067095, 'ch9', 'ch9', 'ch9'), (9783318067095, 'ch9', 'sec27', 'sec27'), (9783318067095, 'ch9', 'sec28', 'sec28'), (9783318067095, 'ch9', 'sec29', 'sec29')]
#
# ############################
#
#
# book 9783318068207 chapter hh-3
#
# num_tok MOC 1989
# chunking [(9783318068207, 'hh-3', 'sec1', 'sec1')]
#
# num_tok MOC 109
# skipping [(9783318068207, 'hh-3', 'sec2', 'sec2')]
#
# merging 109 + 729
# num_tok MOC 838
# summ [(9783318068207, 'hh-3', 'sec2', 'sec2'), (9783318068207, 'hh-3', 'sec3', 'sec3')]
#
# num_tok MOC 364
# skipping [(9783318068207, 'hh-3', 'sec4', 'sec4')]
#
# merging 364 + 970
# num_tok MOC 1334
# chunking [(9783318068207, 'hh-3', 'sec4', 'sec4'), (9783318068207, 'hh-3', 'sec5', 'sec5')]
#
# num_tok MOC 882
# summ [(9783318068207, 'hh-3', 'sec6', 'sec6')]
#
#
# ############################
#
#
# book 9783318068207 chapter hh-4
#
# num_tok MOC 238
# skipping [(9783318068207, 'hh-4', 'sec7', 'sec7')]
#
# merging 238 + 1713
# num_tok MOC 1951
# chunking [(9783318068207, 'hh-4', 'sec7', 'sec7'), (9783318068207, 'hh-4', 'sec8', 'sec8')]
#
# num_tok MOC 339
# skipping [(9783318068207, 'hh-4', 'sec9', 'sec9')]
#
# merging 339 + 854
# num_tok MOC 1193
# chunking [(9783318068207, 'hh-4', 'sec9', 'sec9'), (9783318068207, 'hh-4', 'sec10', 'sec10')]
#
# num_tok MOC 346
# skipping [(9783318068207, 'hh-4', 'sec11', 'sec11')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1539
# chunking [(9783318068207, 'hh-4', 'sec9', 'sec9'), (9783318068207, 'hh-4', 'sec10', 'sec10'), (9783318068207, 'hh-4', 'sec11', 'sec11')]
#
# ############################
#
#
# book 9783318068207 chapter hh-5
#
# num_tok MOC 569
# skipping [(9783318068207, 'hh-5', 'sec12', 'sec12')]
#
# merging 569 + 950
# num_tok MOC 1519
# chunking [(9783318068207, 'hh-5', 'sec12', 'sec12'), (9783318068207, 'hh-5', 'sec13', 'sec13')]
#
# num_tok MOC 580
# skipping [(9783318068207, 'hh-5', 'sec14', 'sec14')]
#
# merging 580 + 977
# num_tok MOC 1557
# chunking [(9783318068207, 'hh-5', 'sec14', 'sec14'), (9783318068207, 'hh-5', 'sec15', 'sec15')]
#
#
# ############################
#
#
# book 9783318068207 chapter hh-6
#
# num_tok MOC 664
# skipping [(9783318068207, 'hh-6', 'sec17', 'sec17')]
#
# merging 664 + 675
# num_tok MOC 1339
# chunking [(9783318068207, 'hh-6', 'sec17', 'sec17'), (9783318068207, 'hh-6', 'sec18', 'sec18')]
#
# num_tok MOC 1295
# chunking [(9783318068207, 'hh-6', 'sec19', 'sec19')]
#
# num_tok MOC 95
# skipping [(9783318068207, 'hh-6', 'sec20', 'sec20')]
#
# EXCEPTION, last chunk too small.
# num_tok MOC 1390
# chunking [(9783318068207, 'hh-6', 'sec19', 'sec19'), (9783318068207, 'hh-6', 'sec20', 'sec20')]
#
# ############################
#
#
# book 9783318068207 chapter hh-7
#
# num_tok MOC 1214
# chunking [(9783318068207, 'hh-7', 'sec21', 'sec21')]
#
# num_tok MOC 1853
# chunking [(9783318068207, 'hh-7', 'sec22', 'sec22')]
#
# num_tok MOC 1593
# chunking [(9783318068207, 'hh-7', 'sec23', 'sec23')]
#
# num_tok MOC 1262
# chunking [(9783318068207, 'hh-7', 'sec24', 'sec24')]
#
# num_tok MOC 1363
# chunking [(9783318068207, 'hh-7', 'sec25', 'sec25')]
#
#
# ############################
#
#
# book 9783318068207 chapter hh-8
#
# num_tok MOC 534
# skipping [(9783318068207, 'hh-8', 'sec26', 'sec26')]
#
# merging 534 + 574
# num_tok MOC 1108
# chunking [(9783318068207, 'hh-8', 'sec26', 'sec26'), (9783318068207, 'hh-8', 'sec27', 'sec27')]
#
# num_tok MOC 431
# skipping [(9783318068207, 'hh-8', 'sec28', 'sec28')]
#
# merging 431 + 534
# num_tok MOC 965
# summ [(9783318068207, 'hh-8', 'sec28', 'sec28'), (9783318068207, 'hh-8', 'sec29', 'sec29')]
#
#
# ############################

# %%
df_moc = df_moc.reset_index(level=[2, 3]).groupby(['book', 'chapter'], sort=False).agg({
    'merge': lambda m: list(m),
    'chunk': lambda c: list(c),
    'text': lambda t: list(t),
    'bullets': lambda b: list(b)[0]
})

# %% [markdown]
# #### Save new dataset

# %%
df_moc.to_csv(OUTPUT_PATH+'df.csv')

# %% [markdown]
# #### Create train, test, validation
#
# Generate files:
# * train.source
# * train.target
# * val.source
# * val.target
# * test.source
# * test.target
#
# Since we do not have a lot of samples, validation and test will be equal for us.

# %%
df_moc.bullets = df_moc.bullets.map(lambda b: ' '.join(b))

# %%
df_moc = df_moc.sample(frac=1, random_state=config.SEED)
df_moc['num_chunks'] = df_moc.text.map(len).cumsum()
tot_chunk = df_moc.num_chunks.iloc[-1]
split1 = np.where(df_moc.num_chunks > int(tot_chunk*0.8))[0][0]+1
split2 = np.where(df_moc.num_chunks > int(tot_chunk*0.9))[0][0]+1
print(split1, split2)
# Out:
# 365 409

# %%
train, val, test =\
    df_moc.iloc[:split1].explode('text'),\
    df_moc.iloc[split1:split2].explode('text'),\
    df_moc.iloc[split2:].explode('text')

train.to_csv(OUTPUT_PATH+'train.csv')
val.to_csv(OUTPUT_PATH+'val.csv')
test.to_csv(OUTPUT_PATH+'test.csv')

# %%
with open(OUTPUT_PATH+'train.source', 'w') as tr_s,\
    open(OUTPUT_PATH+'train.target', 'w') as tr_t,\
    open(OUTPUT_PATH+'train.index', 'w') as tr_i:
    for idx, row in train[['text', 'bullets']].iterrows():
        tr_i.write(str(idx) + '\n')
        tr_s.write(row.text + '\n')
        tr_t.write(row.bullets + '\n')

# %%
with open(OUTPUT_PATH+'val.source', 'w') as va_s,\
    open(OUTPUT_PATH+'val.target', 'w') as va_t,\
    open(OUTPUT_PATH+'val.index', 'w') as va_i:
    for idx, row in val[['text', 'bullets']].iterrows():
        va_i.write(str(idx) + '\n')
        va_s.write(row.text + '\n')
        va_t.write(row.bullets + '\n')

# %%
with open(OUTPUT_PATH+'test.source', 'w') as te_s,\
    open(OUTPUT_PATH+'test.target', 'w') as te_t,\
    open(OUTPUT_PATH+'test.index', 'w') as te_i:
    for idx, row in test[['text', 'bullets']].iterrows():
        te_i.write(str(idx) + '\n')
        te_s.write(row.text + '\n')
        te_t.write(row.bullets + '\n')
