# %% [markdown]
# #### AWS

# %%
magma_dir = '/home/ubuntu/magma/'
bucket_dir = '/home/ubuntu/s3/'
transformers_dir = '/home/ubuntu/transformers/'
cache_dir = bucket_dir+'.cache/'

# %% [markdown]
# ### **Config**

# %%
import os
import sys

sys.path.insert(0, '/home/marco/epfl/magma/')
import config

from torch import cuda
device = 'cuda' if cuda.is_available() else 'cpu'

# %%
MODEL = 'bart'
MODELS = {}

# %%
# Dataset path
data_dir = config.MAGMA_DIR + 'datasets/karger_books_para_wordembed/'+MODEL+'/'

# %% [markdown]
# #### AWS

# %%
data_dir = bucket_dir + 'datasets/karger_books_para_wordembed/'+MODEL+'/'

# %% [markdown]
# ### **Init**

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import re
import pandas as pd
from tqdm import tqdm
from textwrap import fill
tqdm.pandas()

# %% [markdown]
# ### **Function Definition**

# %% [markdown]
# ##### Import Model and Tok

# %%
def import_model_tok(model_name_or_path, verbose=False):
    global MODELS

    if model_name_or_path in MODELS.keys():
        if verbose : print('[+] model already present in cache\n')
        return MODELS[model_name_or_path]
    if verbose : print('[*] importing the model\n')
    
    from transformers import BartForConditionalGeneration, BartTokenizer
    model = BartForConditionalGeneration.from_pretrained(model_name_or_path)
    tokenizer = BartTokenizer.from_pretrained(model_name_or_path)

    if verbose : print(model.config)
    MODELS[model_name_or_path] = model, tokenizer
    if verbose : print('[+] the model is now present in cache\n')
    return MODELS[model_name_or_path]

# %% [markdown]
# ##### Print Examples

# %%
def print_examples(model_name_list, df, n_examples=10):
    
    df_examples = df.sample(n_examples, axis='index', random_state=config.SEED)
    
    for idx, row in df_examples.iterrows():
        print(idx)
        print(fill(row.text, 100))
        print()
        print('Reference:')
        print(fill(row.bullets, 100))
        print()
        for model_name in model_name_list:
            model, tokenizer = import_model_tok(model_name)
            model = model.to(device)
            
            summ_enc_list = model.generate(
                tokenizer.encode(row.text, return_tensors='pt').to(device),
                min_length = config.ONE_BULLET_MIN_LEN,
                max_length = config.ONE_BULLET_MAX_LEN,
                length_penalty = config.LENGTH_PENALTY,
                num_beams = config.NUM_BEAMS,
                no_repeat_ngram_size = config.NO_REPEAT_NGRAM_SIZE,
                num_return_sequences = config.NUM_BEAMS,
                early_stopping = True)
            
            for summ_enc in summ_enc_list:
                summ_num_tok = len(tokenizer.convert_ids_to_tokens(summ_enc, skip_special_tokens=True))
                summ = tokenizer.decode(summ_enc, skip_special_tokens=True)

                rouge, sent_trans, w2v = evaluate_prediction(summ, row.bullets)
                
                print('%s (%d tok):'%(model_name, summ_num_tok))
                print('R1\tp: %.2f \tr: %.2f \tf: %.2f\nR2\tp: %.2f \tr: %.2f \tf: %.2f\nRL\tp: %.2f \tr: %.2f \tf: %.2f'%(
                rouge['rouge1_precision'], rouge['rouge1_recall'], rouge['rouge1_fmeasure'],
                rouge['rouge2_precision'], rouge['rouge2_recall'], rouge['rouge2_fmeasure'],
                rouge['rougeL_precision'], rouge['rougeL_recall'], rouge['rougeL_fmeasure']))
                print('ST\t%.2f\t\tW2V\t%.2f'%(sent_trans, w2v))
                print()
                print(fill(summ, 100))
                print()
            print()
            
        print(''.join(['#']*100))
        print()

# %% [markdown]
# ## **Sentence-Transformers**

# %%
data_dir_st = data_dir + 'st/base/'

# %%
df_train = pd.read_csv(data_dir_st + 'train.csv').set_index(['book', 'chapter'])
df_val = pd.read_csv(data_dir_st + 'val.csv').set_index(['book', 'chapter'])
df_test = pd.read_csv(data_dir_st + 'test.csv').set_index(['book', 'chapter'])

# %% [markdown]
# ### **Print and Summarization**

# %% [markdown]
# #### Print Train Examples

# %%
print_examples([
    'sshleifer/distilbart-cnn-12-6',
    magma_dir+'fine-tuning/ft_bart_para_wordembed/checkpoint-196'],
    df_train)
# Out:
# (9781912776696, 'hh-5')
# Kaplan-Meier curves provide a way of plotting the distribution of a time-to-event endpoint. In
# Figure 2.1 the dashed line shows that at 24 months' follow-up the estimated survival probability is
# 54%. Kaplan-Meier survival curves are often used to compare the data between two groups of subjects.
# Figure 2.2 shows Kaplan-Meier curves for OS in a randomized study of patients with human epidermal
# growth factor receptor 2 (HER2)-positive metastatic breast cancer treated either with or without
# trastuzumab. The Kaplan-Meier curve steps down at time points at which deaths occur, while censored
# observations are denoted by notches on the curve. In this study, the follow-up period ranged from 3
# months to 74 months.
#
# Reference:
# Kaplan-Meier curves plot the probability of being event free over time. The curves from different
# treatment groups can be plotted against each other to show the differences in outcome.
#
# sshleifer/distilbart-cnn-12-6 (63 tok):
# R1	p: 18.75 	r: 30.00 	f: 23.08
# R2	p: 4.26 	r: 6.90 	f: 5.26
# RL	p: 14.58 	r: 23.33 	f: 17.95
# ST	61.43		W2V	47.30
#
#  Kaplan-Meier survival curves are often used to compare the data between two groups of subjects.
# Figure 2.2 shows Kaplan-Meier curves for OS in a randomized study of patients with human epidermal
# growth factor receptor 2-positive metastatic breast cancer treated either with or without
# trastuzumab.
#
# sshleifer/distilbart-cnn-12-6 (43 tok):
# R1	p: 30.56 	r: 36.67 	f: 33.33
# R2	p: 2.86 	r: 3.45 	f: 3.12
# RL	p: 19.44 	r: 23.33 	f: 21.21
# ST	65.57		W2V	58.81
#
#  Kaplan-Meier survival curves are often used to compare the data between two groups of subjects. In
# Figure 2.1 the dashed line shows that at 24 months' follow-up the estimated survival probability is
# 54%.
#
# sshleifer/distilbart-cnn-12-6 (44 tok):
# R1	p: 30.56 	r: 36.67 	f: 33.33
# R2	p: 2.86 	r: 3.45 	f: 3.12
# RL	p: 19.44 	r: 23.33 	f: 21.21
# ST	65.57		W2V	58.81
#
#  Kaplan-Meier survival curves are often used to compare the data between two groups of subjects. In
# Figure 2.1 the dashed line shows that at 24 months' follow-up the estimated survival probability is
# 54%.
#
# sshleifer/distilbart-cnn-12-6 (39 tok):
# R1	p: 28.12 	r: 30.00 	f: 29.03
# R2	p: 3.23 	r: 3.45 	f: 3.33
# RL	p: 18.75 	r: 20.00 	f: 19.35
# ST	64.83		W2V	54.01
#
#  Kaplan-Meier survival curves are often used to compare the data between two groups of subjects.
# Figure 2.1 shows that at 24 months' follow-up the estimated survival probability is 54%.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (18 tok):
# R1	p: 75.00 	r: 30.00 	f: 42.86
# R2	p: 36.36 	r: 13.79 	f: 20.00
# RL	p: 66.67 	r: 26.67 	f: 38.10
# ST	76.05		W2V	55.23
#
# Kaplan-Meier curves plot the distribution of a time-to-event endpoint.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (32 tok):
# R1	p: 44.00 	r: 36.67 	f: 40.00
# R2	p: 16.67 	r: 13.79 	f: 15.09
# RL	p: 36.00 	r: 30.00 	f: 32.73
# ST	78.20		W2V	59.73
#
# Kaplan-Meier curves plot the distribution of a time-to-event endpoint. They are often used to
# compare the data between two groups of subjects.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (14 tok):
# R1	p: 80.00 	r: 26.67 	f: 40.00
# R2	p: 55.56 	r: 17.24 	f: 26.32
# RL	p: 80.00 	r: 26.67 	f: 40.00
# ST	77.15		W2V	62.16
#
# Kaplan-Meier curves plot the distribution of events over time.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (14 tok):
# R1	p: 80.00 	r: 26.67 	f: 40.00
# R2	p: 55.56 	r: 17.24 	f: 26.32
# RL	p: 80.00 	r: 26.67 	f: 40.00
# ST	77.15		W2V	62.16
#
# Kaplan-Meier curves plot the distribution of events over time.
#
#
# ####################################################################################################
#
# (9781908541062, 'ch_9')
# The traditional 'pyramid' approach to the treatment of RA was to begin with symptomatic treatment of
# inflammation using NSAIDs in addition to rest and corticosteroid injections. If the disease did not
# significantly improve with these simple treatments, then more potent DMARDs were added. It is now
# clear, however, that effective therapy early in the course of RA results in a long-term reduction in
# joint damage compared to delayed therapy, the so-called window of opportunity. This has led to the
# general principle that inflammation should be controlled as completely and as soon as possible by
# the early and aggressive introduction of DMARDs. The currently approved non-biological drugs for
# treating RA are listed in Table 8.1. Most of these require monitoring for the prompt detection of
# potential adverse effects, although the precise monitoring recommendations vary from center to
# center. The British Society for Rheumatology, the European League Against Rheumatism and the
# American College of Rheumatology have each developed guidelines for the use and monitoring of RA
# therapies.
#
# Reference:
# Treatment-to-target strategies, including combination DMARD therapy, rapidly suppress inflammation
# and minimize long-term damage and disability.
#
# sshleifer/distilbart-cnn-12-6 (78 tok):
# R1	p: 12.70 	r: 44.44 	f: 19.75
# R2	p: 1.61 	r: 5.88 	f: 2.53
# RL	p: 11.11 	r: 38.89 	f: 17.28
# ST	62.64		W2V	38.29
#
#  Traditional 'pyramid' approach to the treatment of RA was to begin with symptomatic treatment of
# inflammation using NSAIDs in addition to rest and corticosteroid injections. If the disease did not
# significantly improve with these simple treatments, then more potent DMARDs were added. Effective
# therapy early in the course of RA results in a long-term reduction in joint damage compared to
# delayed therapy.
#
# sshleifer/distilbart-cnn-12-6 (74 tok):
# R1	p: 13.56 	r: 44.44 	f: 20.78
# R2	p: 1.72 	r: 5.88 	f: 2.67
# RL	p: 11.86 	r: 38.89 	f: 18.18
# ST	61.26		W2V	34.73
#
#  Traditional 'pyramid' approach to the treatment of RA was to begin with symptomatic treatment of
# inflammation using NSAIDs in addition to rest and corticosteroid injections. If the disease did not
# significantly improve with these simple treatments, then more potent DMARDs were added. Effective
# therapy early in the course of RA results in a long-term reduction in joint damage.
#
# sshleifer/distilbart-cnn-12-6 (55 tok):
# R1	p: 9.52 	r: 22.22 	f: 13.33
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 9.52 	r: 22.22 	f: 13.33
# ST	52.93		W2V	26.37
#
#  Traditional 'pyramid' approach to the treatment of RA was to begin with symptomatic treatment of
# inflammation using NSAIDs in addition to rest and corticosteroid injections. If the disease did not
# significantly improve with these simple treatments, then more potent DMARDs were added.
#
# sshleifer/distilbart-cnn-12-6 (56 tok):
# R1	p: 9.30 	r: 22.22 	f: 13.11
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 9.30 	r: 22.22 	f: 13.11
# ST	53.08		W2V	25.82
#
#  The traditional 'pyramid' approach to the treatment of RA was to begin with symptomatic treatment
# of inflammation using NSAIDs in addition to rest and corticosteroid injections. If the disease did
# not significantly improve with these simple treatments, then more potent DMARDs were added.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (24 tok):
# R1	p: 14.29 	r: 16.67 	f: 15.38
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 9.52 	r: 11.11 	f: 10.26
# ST	54.40		W2V	26.07
#
# Early and aggressive introduction of DMARDs has led to the development of guidelines for the use and
# monitoring of RA therapies.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (35 tok):
# R1	p: 9.68 	r: 16.67 	f: 12.24
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 6.45 	r: 11.11 	f: 8.16
# ST	51.01		W2V	23.98
#
# Early and aggressive introduction of DMARDs has led to the development of guidelines for the use and
# monitoring of RA therapies, although the precise monitoring recommendations vary from center to
# center.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (33 tok):
# R1	p: 10.34 	r: 16.67 	f: 12.77
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 6.90 	r: 11.11 	f: 8.51
# ST	51.80		W2V	26.00
#
# Early and aggressive introduction of DMARDs has led to the development of guidelines for the use and
# monitoring of RA therapies, although monitoring recommendations vary from center to center.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (19 tok):
# R1	p: 13.33 	r: 11.11 	f: 12.12
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 6.67 	r: 5.56 	f: 6.06
# ST	56.62		W2V	21.45
#
# Early and aggressive introduction of DMARDs is the mainstay of the treatment of RA treatment.
#
#
# ####################################################################################################
#
# (9781910797495, 'chp8')
# Postincisional pain. Postincisional syndrome is defined as pain at or close to the site of a
# surgical incision that persists beyond the usual healing period. As with other neuropathic pain
# syndromes, patients exhibit allodynia and sometimes also edema in the vicinity of the surgical
# wound, which is typical of temporary peripheral sensitization. Postamputation persistent pain.
# Postamputation persistent pain is a special case of PPSP because large nerves are deliberately cut
# in all patients. It is interesting, then, that only 30-50% develop PPSP, whereas 100% have nerve
# injury (see Table 8.1). This emphasizes the multifactorial basis of PPSP. A surprising omission in
# studies of amputation pain is information about how the nerves amputated are managed (id est clean
# cut or ligature tied). Use of a ligature tie in animal studies is known to generate neuropathic
# pain.
#
# Reference:
# Persistent postsurgical pain (PPSP) is defined as pain at or close to the site of surgical incision
# that persists beyond the expected healing period.
# sshleifer/distilbart-cnn-12-6 (40 tok):
# R1	p: 17.86 	r: 20.83 	f: 19.23
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 14.29 	r: 16.67 	f: 15.38
# ST	68.58		W2V	29.40
#
#  Postamputation persistent pain is a special case of PPSP because large nerves are deliberately cut
# in all patients. Only 30-50% develop PPSP, whereas 100% have nerve injury.
#
# sshleifer/distilbart-cnn-12-6 (37 tok):
# R1	p: 20.00 	r: 20.83 	f: 20.41
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 16.00 	r: 16.67 	f: 16.33
# ST	65.58		W2V	30.29
#
#  Postamputation persistent pain is a special case of PPSP because large nerves are deliberately cut.
# Only 30-50% develop PPSP, whereas 100% have nerve injury.
#
# sshleifer/distilbart-cnn-12-6 (39 tok):
# R1	p: 18.52 	r: 20.83 	f: 19.61
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 14.81 	r: 16.67 	f: 15.69
# ST	68.35		W2V	29.66
#
#  Postamputation persistent pain is a special case of PPSP because large nerves are deliberately cut
# in all patients. 30-50% develop PPSP, whereas 100% have nerve injury.
#
# sshleifer/distilbart-cnn-12-6 (42 tok):
# R1	p: 16.67 	r: 20.83 	f: 18.52
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 13.33 	r: 16.67 	f: 14.81
# ST	68.55		W2V	30.77
#
#  Postamputation persistent pain is a special case of PPSP because large nerves are deliberately cut
# in all patients. Only 30-50% of patients develop PPSP, whereas 100% have nerve injury.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (27 tok):
# R1	p: 86.36 	r: 79.17 	f: 82.61
# R2	p: 80.95 	r: 73.91 	f: 77.27
# RL	p: 86.36 	r: 79.17 	f: 82.61
# ST	81.43		W2V	83.25
#
# Postincisional syndrome is defined as pain at or close to the site of surgical incision that
# persists beyond the usual healing period.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (27 tok):
# R1	p: 86.36 	r: 79.17 	f: 82.61
# R2	p: 80.95 	r: 73.91 	f: 77.27
# RL	p: 86.36 	r: 79.17 	f: 82.61
# ST	81.43		W2V	83.25
#
# Postincisional syndrome is defined as pain at or close to the site of surgical incision that
# persists beyond the usual healing period.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (27 tok):
# R1	p: 90.91 	r: 83.33 	f: 86.96
# R2	p: 90.48 	r: 82.61 	f: 86.36
# RL	p: 90.91 	r: 83.33 	f: 86.96
# ST	82.11		W2V	86.41
#
# Postincisional syndrome is defined as pain at or close to the site of surgical incision that
# persists beyond the expected healing period.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (21 tok):
# R1	p: 28.57 	r: 16.67 	f: 21.05
# R2	p: 7.69 	r: 4.35 	f: 5.56
# RL	p: 28.57 	r: 16.67 	f: 21.05
# ST	68.74		W2V	23.44
#
# Patients with PPSP exhibit allodynia and sometimes edema in the vicinity of surgical wound.
#
#
# ####################################################################################################
#
# (9781908541666, 'ch_12')
# Treatment. Immediate treatment of any identifiable cause of the DKA should be undertaken without
# delay. Until recently, standard management of DKA focused on reducing blood glucose levels with
# insulin and intravenous fluids. There is still universal agreement that the initial cornerstone of
# treatment is fluid replacement and insulin administration. The intravascular volume should be
# expanded to correct a typical deficit of 100 mL/kg of water with intravenous isotonic saline, which
# will also improve renal perfusion. Infusion rates of 1 L per hour for the first hour, 1 L for the
# next 2 hours and 1 L over the next 4 hours are usually adequate except in those patients with
# profound hypovolemia and hypotension, who may need twice this amount (Table 11.3). If the initial
# systolic blood pressure is below 90 mmHg, 500 mL of normal saline should be given over 15 minutes.
# In the presence of significant hypernatremia, isotonic saline can be replaced with 0.45% saline. The
# aim is to replace total body deficits of water and electrolytes, with half the estimated deficit
# being replaced in 12-24 hours (see Table 11.3). Once the blood glucose has fallen to about 14 mmol/L
# (252 mg/dL), saline should be replaced with 5% dextrose (or an infusion of 10% glucose given at 125
# mL/hour started alongside the infusion of normal saline to correct circulatory volume) to allow
# continued insulin administration to suppress ketogenesis while avoiding hypoglycemia.
#
# Reference:
# Treatment of DKA is by fluid and electrolyte replacement, intravenous insulin and treatment of the
# underlying cause, when known.
#
# sshleifer/distilbart-cnn-12-6 (64 tok):
# R1	p: 22.64 	r: 63.16 	f: 33.33
# R2	p: 3.85 	r: 11.11 	f: 5.71
# RL	p: 13.21 	r: 36.84 	f: 19.44
# ST	61.19		W2V	61.33
#
#  Until recently, management of DKA focused on reducing blood glucose levels with insulin and
# intravenous fluids. There is still universal agreement that the initial cornerstone of treatment is
# fluid replacement and insulin administration. Intravascular volume should be expanded to correct a
# typical deficit of 100 mL/kg of water with intravenous isotonic saline.
#
# sshleifer/distilbart-cnn-12-6 (65 tok):
# R1	p: 22.22 	r: 63.16 	f: 32.88
# R2	p: 3.77 	r: 11.11 	f: 5.63
# RL	p: 12.96 	r: 36.84 	f: 19.18
# ST	61.63		W2V	62.54
#
#  Until recently, management of DKA focused on reducing blood glucose levels with insulin and
# intravenous fluids. There is still universal agreement that the initial cornerstone of treatment is
# fluid replacement and insulin administration. The intravascular volume should be expanded to correct
# a typical deficit of 100 mL/kg of water with intravenous isotonic saline.
#
# sshleifer/distilbart-cnn-12-6 (72 tok):
# R1	p: 20.34 	r: 63.16 	f: 30.77
# R2	p: 3.45 	r: 11.11 	f: 5.26
# RL	p: 11.86 	r: 36.84 	f: 17.95
# ST	58.94		W2V	61.14
#
#  Until recently, management of DKA focused on reducing blood glucose levels with insulin and
# intravenous fluids. There is still universal agreement that the initial cornerstone of treatment is
# fluid replacement and insulin administration. Intravascular volume should be expanded to correct a
# typical deficit of 100 mL/kg of water with intravenous isotonic saline, which will also improve
# renal perfusion.
#
# sshleifer/distilbart-cnn-12-6 (62 tok):
# R1	p: 23.08 	r: 63.16 	f: 33.80
# R2	p: 3.92 	r: 11.11 	f: 5.80
# RL	p: 13.46 	r: 36.84 	f: 19.72
# ST	60.49		W2V	60.48
#
#  Until recently, management of DKA focused on reducing blood glucose levels with insulin and
# intravenous fluids. There is still universal agreement that the initial cornerstone of treatment is
# fluid replacement and insulin administration. Intravascular volume should be expanded to correct a
# typical deficit of 100 mL/kg of water with isotonic saline.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (22 tok):
# R1	p: 58.82 	r: 52.63 	f: 55.56
# R2	p: 37.50 	r: 33.33 	f: 35.29
# RL	p: 58.82 	r: 52.63 	f: 55.56
# ST	80.57		W2V	64.82
#
# Treatment of DKA is by fluid and insulin, with immediate fluid and insulin administration as the
# mainstay.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (19 tok):
# R1	p: 60.00 	r: 47.37 	f: 52.94
# R2	p: 42.86 	r: 33.33 	f: 37.50
# RL	p: 60.00 	r: 47.37 	f: 52.94
# ST	81.17		W2V	60.36
#
# Treatment of DKA is by fluid and insulin, with immediate immediate fluid and insulin administration.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (22 tok):
# R1	p: 58.82 	r: 52.63 	f: 55.56
# R2	p: 37.50 	r: 33.33 	f: 35.29
# RL	p: 58.82 	r: 52.63 	f: 55.56
# ST	79.95		W2V	67.35
#
# Treatment of DKA is by fluid and insulin, with immediate fluid and insulin administration as the
# principalstay.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (17 tok):
# R1	p: 76.92 	r: 52.63 	f: 62.50
# R2	p: 33.33 	r: 22.22 	f: 26.67
# RL	p: 61.54 	r: 42.11 	f: 50.00
# ST	79.93		W2V	72.60
#
# Treatment of DKA is based on fluid and intravenous fluid replacement and insulin.
#
#
# ####################################################################################################
#
# (9781910797495, 'chp1')
# Because it is an experience, pain itself cannot be measured directly. Pain, like consciousness
# itself, is constructed by complex brain processes that are strongly affected by a person's
# attitudes, beliefs, personality and interpretation of the significance of nociceptive stimuli.
# Central to the understanding of clinical pain is the concept that pain may be present without an
# obvious peripheral source or cause. Mechanisms of neuropathic pain. Definition. Neuropathic pain is
# initiated or caused by a primary lesion of the PNS or CNS. Patients often complain not only of
# spontaneous pain, but also of pain from stimuli that are not normally painful (allodynia). For
# example, a light touch may be described as painful.
#
# Reference:
# Neuropathic pain is produced by a lesion of the peripheral or central nervous system (CNS).
# sshleifer/distilbart-cnn-12-6 (44 tok):
# R1	p: 28.57 	r: 66.67 	f: 40.00
# R2	p: 14.71 	r: 35.71 	f: 20.83
# RL	p: 28.57 	r: 66.67 	f: 40.00
# ST	74.74		W2V	54.85
#
#  Neuropathic pain is initiated or caused by a primary lesion of the PNS or CNS. Patients often
# complain not only of spontaneous pain, but also of pain from stimuli that are not normally painful
# (allodynia)
#
# sshleifer/distilbart-cnn-12-6 (48 tok):
# R1	p: 26.32 	r: 66.67 	f: 37.74
# R2	p: 13.51 	r: 35.71 	f: 19.61
# RL	p: 26.32 	r: 66.67 	f: 37.74
# ST	75.09		W2V	55.65
#
#  Neuropathic pain is initiated or caused by a primary lesion of the PNS or CNS. Pain is constructed
# by complex brain processes that are strongly affected by a person's attitudes, beliefs, personality
# and interpretation of nociceptive stimuli.
#
# sshleifer/distilbart-cnn-12-6 (51 tok):
# R1	p: 24.39 	r: 66.67 	f: 35.71
# R2	p: 12.50 	r: 35.71 	f: 18.52
# RL	p: 24.39 	r: 66.67 	f: 35.71
# ST	74.61		W2V	57.66
#
#  Neuropathic pain is initiated or caused by a primary lesion of the PNS or CNS. Pain is constructed
# by complex brain processes that are strongly affected by a person's attitudes, beliefs, personality
# and interpretation of the significance of nociceptive stimuli.
#
# sshleifer/distilbart-cnn-12-6 (42 tok):
# R1	p: 30.30 	r: 66.67 	f: 41.67
# R2	p: 15.62 	r: 35.71 	f: 21.74
# RL	p: 30.30 	r: 66.67 	f: 41.67
# ST	75.34		W2V	55.91
#
#  Neuropathic pain is initiated or caused by a primary lesion of the PNS or CNS. Patients often
# complain not only of spontaneous pain, but also of pain from stimuli not normally painful
# (allodynia)
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (22 tok):
# R1	p: 81.25 	r: 86.67 	f: 83.87
# R2	p: 53.33 	r: 57.14 	f: 55.17
# RL	p: 75.00 	r: 80.00 	f: 77.42
# ST	95.15		W2V	73.05
#
# Neuropathic pain is initiated or caused by a primary lesion of the central nervous system (CNS).
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (19 tok):
# R1	p: 80.00 	r: 80.00 	f: 80.00
# R2	p: 50.00 	r: 50.00 	f: 50.00
# RL	p: 73.33 	r: 73.33 	f: 73.33
# ST	88.59		W2V	68.77
#
# Neuropathic pain is initiated or caused by a primary lesion of the central nervous system.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (22 tok):
# R1	p: 81.25 	r: 86.67 	f: 83.87
# R2	p: 53.33 	r: 57.14 	f: 55.17
# RL	p: 75.00 	r: 80.00 	f: 77.42
# ST	96.36		W2V	78.06
#
# Neuropathic pain is initiated or caused by a primary lesion of the peripheral nervous system (CNS).
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (19 tok):
# R1	p: 80.00 	r: 80.00 	f: 80.00
# R2	p: 50.00 	r: 50.00 	f: 50.00
# RL	p: 73.33 	r: 73.33 	f: 73.33
# ST	88.59		W2V	68.77
#
# Neuropathic pain is initiated or caused by a primary lesion of the central nervous system.
#
#
# ####################################################################################################
#
# (9781910797662, 'ch03')
# Delay in diagnosis. Although it is difficult to prove that delay in diagnosis affects prognosis,
# screening for asymptomatic microscopic hematuria is associated with a shift towards more favorable
# tumor characteristics of lower stage and grade at diagnosis, and better survival. Delays may occur
# for a variety of reasons.
#
# Reference:
# Delay in treatment adversely affects prognosis.
#
# sshleifer/distilbart-cnn-12-6 (39 tok):
# R1	p: 0.00 	r: 0.00 	f: 0.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 0.00 	r: 0.00 	f: 0.00
# ST	44.26		W2V	9.84
#
#  Screening for asymptomatic microscopic hematuria is associated with a shift towards more favorable
# tumor characteristics of lower stage and grade at diagnosis. Delays may occur for a variety of
# reasons.
#
# sshleifer/distilbart-cnn-12-6 (33 tok):
# R1	p: 0.00 	r: 0.00 	f: 0.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 0.00 	r: 0.00 	f: 0.00
# ST	40.39		W2V	7.97
#
#  Screening for asymptomatic microscopic hematuria is associated with a shift towards more favorable
# tumor characteristics of lower stage and grade at diagnosis, and better survival.
#
# sshleifer/distilbart-cnn-12-6 (41 tok):
# R1	p: 3.12 	r: 16.67 	f: 5.26
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 3.12 	r: 16.67 	f: 5.26
# ST	47.18		W2V	16.93
#
#  Screening for asymptomatic microscopic hematuria is associated with a shift towards more favorable
# tumor characteristics of lower stage and grade at diagnosis. Delays in diagnosis may occur for a
# variety of reasons.
#
# sshleifer/distilbart-cnn-12-6 (32 tok):
# R1	p: 0.00 	r: 0.00 	f: 0.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 0.00 	r: 0.00 	f: 0.00
# ST	37.07		W2V	2.57
#
#  Screening for asymptomatic microscopic hematuria is associated with a shift towards more favorable
# tumor characteristics. Delays may occur for a variety of reasons.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (17 tok):
# R1	p: 13.33 	r: 33.33 	f: 19.05
# R2	p: 7.14 	r: 20.00 	f: 10.53
# RL	p: 13.33 	r: 33.33 	f: 19.05
# ST	58.00		W2V	19.32
#
# Delay in diagnosis is associated with a shift towards more favorable tumor characteristics and
# survival.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (19 tok):
# R1	p: 12.50 	r: 33.33 	f: 18.18
# R2	p: 6.67 	r: 20.00 	f: 10.00
# RL	p: 12.50 	r: 33.33 	f: 18.18
# ST	56.39		W2V	23.02
#
# Delay in diagnosis is associated with a shift towards more favorable tumor characteristics, and
# better survival.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (16 tok):
# R1	p: 14.29 	r: 33.33 	f: 20.00
# R2	p: 7.69 	r: 20.00 	f: 11.11
# RL	p: 14.29 	r: 33.33 	f: 20.00
# ST	59.70		W2V	24.99
#
# Delay in diagnosis is associated with a shift towards favorable tumor characteristics and survival.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (12 tok):
# R1	p: 22.22 	r: 33.33 	f: 26.67
# R2	p: 12.50 	r: 20.00 	f: 15.38
# RL	p: 22.22 	r: 33.33 	f: 26.67
# ST	63.42		W2V	27.76
#
# Delay in diagnosis is not always a prognostic factor.
#
#
# ####################################################################################################
#
# (9781910797310, 'chp2')
# Well-differentiated tumors with adenocarcinoma morphology (acinar, papillary, lepidic,
# micropapillary) or squamous cell carcinoma (unequivocal keratinization and well-formed classical
# bridges) on routine light microscopy can be diagnosed as adenocarcinoma or squamous cell carcinoma,
# respectively, without immunohistochemistry. Poorly differentiated tumors should undergo limited
# immuno-histochemistry. A single adenocarcinoma marker (exempli gratia thyroid transcription factor 1
# [TTF1] or Napsin-A) or squamous cell carcinoma marker (exempli gratia p40, cytokeratin 5/6 or p63)
# can be used to classify most tumors. Carcinomas lacking clear differentiation by morphology and
# immunohistochemistry are classified as 'NSCLC, not otherwise specified (NOS)'. NOS carcinomas that
# stain with adenocarcinoma markers are classified as 'NSCLC, favor adenocarcinoma'; tumors that stain
# with squamous markers are classified as 'NSCLC, favor squamous cell carcinoma'. In this way, a
# diagnosis of NSCLC-NOS can be avoided in up to 90% of cases.
#
# Reference:
# Classification of NSCLC further into specific pathological subtypes (exempli gratia adenocarcinoma
# versus squamous cell carcinoma) will determine eligibility for certain types of molecular testing
# and aid therapeutic decisions based on the specific histological and genetic characteristics of the
# tumor.
#
# sshleifer/distilbart-cnn-12-6 (69 tok):
# R1	p: 18.18 	r: 15.38 	f: 16.67
# R2	p: 6.25 	r: 5.26 	f: 5.71
# RL	p: 18.18 	r: 15.38 	f: 16.67
# ST	58.22		W2V	7.13
#
#  Well-differentiated tumors with adenocarcinoma morphology (acinar, papillary, lepidic,
# micropapillary) or squamous cell carcinoma (unequivocal keratinization and well-formed classical
# bridges) on routine light microscopy. Poorly differentiated tumors should undergo limited immuno-
# histochemistry.
#
# sshleifer/distilbart-cnn-12-6 (72 tok):
# R1	p: 16.67 	r: 15.38 	f: 16.00
# R2	p: 5.71 	r: 5.26 	f: 5.48
# RL	p: 16.67 	r: 15.38 	f: 16.00
# ST	60.18		W2V	6.18
#
#  Well-differentiated tumors with adenocarcinoma morphology (acinar, papillary, lepidic,
# micropapillary) or squamous cell carcinoma (unequivocal keratinization and well-formed classical
# bridges) on routine light microscopy can be diagnosed. Poorly differentiated tumors should undergo
# limited immuno-histochemistry.
#
# sshleifer/distilbart-cnn-12-6 (69 tok):
# R1	p: 18.18 	r: 15.38 	f: 16.67
# R2	p: 6.25 	r: 5.26 	f: 5.71
# RL	p: 18.18 	r: 15.38 	f: 16.67
# ST	58.22		W2V	7.13
#
#  Well-differentiated tumors with adenocarcinoma morphology (acinar, papillary, lepidic,
# micropapillary) or squamous cell carcinoma (unequivocal keratinization and well-formed classical
# bridges) on routine light microscopy. Poorly differentiated tumors should undergo limited immuno-
# histochemistry.
#
# sshleifer/distilbart-cnn-12-6 (72 tok):
# R1	p: 20.59 	r: 17.95 	f: 19.18
# R2	p: 6.06 	r: 5.26 	f: 5.63
# RL	p: 17.65 	r: 15.38 	f: 16.44
# ST	60.76		W2V	17.60
#
#  Well-differentiated tumors with adenocarcinoma morphology (acinar, papillary, lepidic,
# micropapillary) or squamous cell carcinoma (unequivocal keratinization and well-formed classical
# bridges) on routine light microscopy can be diagnosed as 'NSCLC, not otherwise specified (NOS)'
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (40 tok):
# R1	p: 27.78 	r: 12.82 	f: 17.54
# R2	p: 5.88 	r: 2.63 	f: 3.64
# RL	p: 27.78 	r: 12.82 	f: 17.54
# ST	55.34		W2V	27.00
#
# NSCLC-NOS can be classified as 'NSCLC, not otherwise specified (NOS) or 'adenocarcinoma' based on
# morphology and immunohistochemistry.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (40 tok):
# R1	p: 27.78 	r: 12.82 	f: 17.54
# R2	p: 5.88 	r: 2.63 	f: 3.64
# RL	p: 27.78 	r: 12.82 	f: 17.54
# ST	55.34		W2V	27.00
#
# NSCLC-NOS can be classified as 'NSCLC, not otherwise specified (NOS) or 'adenocarcinoma' based on
# morphology and immunohistochemistry.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (29 tok):
# R1	p: 15.38 	r: 5.13 	f: 7.69
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 15.38 	r: 5.13 	f: 7.69
# ST	49.15		W2V	16.50
#
# NSCLC-NOS can be classified as NSCLC, not otherwise specified (NOS) or adenocarcinoma.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (43 tok):
# R1	p: 26.32 	r: 12.82 	f: 17.24
# R2	p: 5.56 	r: 2.63 	f: 3.57
# RL	p: 26.32 	r: 12.82 	f: 17.24
# ST	54.66		W2V	24.07
#
# NSCLC-NOS can be classified as 'NSCLC, not otherwise specified (NOS) or 'adenocarcinoma' based on
# morphology, immunohistochemistry and histochemistry.
#
#
# ####################################################################################################
#
# (9781910797587, 'chp03')
# Estimates of incidence and prevalence also vary according to the definition of OA used; for example,
# symptomatic versus radiographic criteria. Even when radiographic definitions are used, different
# radiographic features may be emphasized (exempli gratia osteophytes vs joint-space narrowing). It is
# interesting to note that the correlation between pain and radiographic OA features is not as strong
# as expected, for reasons discussed in Chapter 4 (see page 50).
#
# Reference:
# Although radiographic OA is common, it is not always symptomatic.
#
# sshleifer/distilbart-cnn-12-6 (24 tok):
# R1	p: 20.00 	r: 40.00 	f: 26.67
# R2	p: 10.53 	r: 22.22 	f: 14.29
# RL	p: 20.00 	r: 40.00 	f: 26.67
# ST	61.30		W2V	25.05
#
#  The correlation between pain and radiographic OA features is not as strong as expected, for reasons
# discussed in Chapter 4.
#
# sshleifer/distilbart-cnn-12-6 (28 tok):
# R1	p: 17.39 	r: 40.00 	f: 24.24
# R2	p: 9.09 	r: 22.22 	f: 12.90
# RL	p: 17.39 	r: 40.00 	f: 24.24
# ST	56.64		W2V	24.82
#
#  The correlation between pain and radiographic OA features is not as strong as expected, for reasons
# discussed in Chapter 4 (see page 50)
#
# sshleifer/distilbart-cnn-12-6 (17 tok):
# R1	p: 28.57 	r: 40.00 	f: 33.33
# R2	p: 15.38 	r: 22.22 	f: 18.18
# RL	p: 28.57 	r: 40.00 	f: 33.33
# ST	65.05		W2V	32.99
#
#  The correlation between pain and radiographic OA features is not as strong as expected.
#
# sshleifer/distilbart-cnn-12-6 (15 tok):
# R1	p: 7.69 	r: 10.00 	f: 8.70
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 7.69 	r: 10.00 	f: 8.70
# ST	55.77		W2V	0.15
#
#  Estimates of incidence and prevalence vary according to the definition of OA used.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (11 tok):
# R1	p: 100.00 	r: 60.00 	f: 75.00
# R2	p: 100.00 	r: 55.56 	f: 71.43
# RL	p: 100.00 	r: 60.00 	f: 75.00
# ST	85.71		W2V	77.46
#
# Radiographic OA is not always symptomatic.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (14 tok):
# R1	p: 75.00 	r: 60.00 	f: 66.67
# R2	p: 71.43 	r: 55.56 	f: 62.50
# RL	p: 75.00 	r: 60.00 	f: 66.67
# ST	87.44		W2V	69.61
#
# Radiographic OA is not always symptomatic or radiographic.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (14 tok):
# R1	p: 75.00 	r: 60.00 	f: 66.67
# R2	p: 71.43 	r: 55.56 	f: 62.50
# RL	p: 75.00 	r: 60.00 	f: 66.67
# ST	87.44		W2V	69.61
#
# Radiographic OA is not always symptomatic or radiographic.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (11 tok):
# R1	p: 100.00 	r: 60.00 	f: 75.00
# R2	p: 100.00 	r: 55.56 	f: 71.43
# RL	p: 100.00 	r: 60.00 	f: 75.00
# ST	85.71		W2V	77.46
#
# Radiographic OA is not always symptomatic.
#
#
# ####################################################################################################
#
# (9781908541963, 'chapter10')
# Hepatocellular carcinoma. Epidemiology and pathogenesis. Hepatocellular carcinoma (hepatoma, HCC) is
# a malignancy of hepatocytes. HCC is a common cause of mortality in the developing world. Although
# currently less common in the developed world, the incidence is expected to rise as patients with
# cirrhosis due to chronic hepatitis C age. Marked geographic variation in incidence is largely due to
# variation in the risk factors that predispose an individual to the tumor (Table 10.1). Most cases of
# HCC occur in liver that is already cirrhotic. Thus, patients with advanced viral hepatitis,
# hemochromatosis or alcoholic liver disease are at risk. Hepatitis B presents a unique risk, as there
# is evidence that a tumor may develop in the absence of cirrhosis - presumably via direct integration
# of viral DNA into the host genome.
#
# Reference:
# Hepatocellular carcinoma often has few specific symptoms or signs.
#
# sshleifer/distilbart-cnn-12-6 (60 tok):
# R1	p: 2.27 	r: 11.11 	f: 3.77
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 2.27 	r: 11.11 	f: 3.77
# ST	47.93		W2V	7.02
#
#  Most cases of HCC occur in liver that is already cirrhotic. Patients with advanced viral hepatitis,
# hemochromatosis or alcoholic liver disease are at risk. Hepatitis B presents a unique risk, as there
# is evidence that a tumor may develop in the absence of cirrhosis.
#
# sshleifer/distilbart-cnn-12-6 (57 tok):
# R1	p: 9.09 	r: 33.33 	f: 14.29
# R2	p: 3.12 	r: 12.50 	f: 5.00
# RL	p: 9.09 	r: 33.33 	f: 14.29
# ST	62.47		W2V	10.44
#
#  Hepatocellular carcinoma (hepatoma, HCC) is a malignancy of hepatocytes. Most cases of HCC occur in
# liver that is already cirrhotic. Patients with advanced viral hepatitis, hemochromatosis or
# alcoholic liver disease are at risk.
#
# sshleifer/distilbart-cnn-12-6 (47 tok):
# R1	p: 2.86 	r: 11.11 	f: 4.55
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 2.86 	r: 11.11 	f: 4.55
# ST	40.54		W2V	10.96
#
#  HCC is a common cause of mortality in the developing world. Most cases of HCC occur in liver that
# is already cirrhotic. Patients with advanced viral hepatitis, hemochromatosis or alcoholic liver
# disease are at risk.
#
# sshleifer/distilbart-cnn-12-6 (51 tok):
# R1	p: 6.45 	r: 22.22 	f: 10.00
# R2	p: 3.33 	r: 12.50 	f: 5.26
# RL	p: 6.45 	r: 22.22 	f: 10.00
# ST	61.14		W2V	14.15
#
#  Hepatocellular carcinoma (hepatoma, HCC) is a malignancy of hepatocytes. HCC is a common cause of
# mortality in the developing world. Most cases of HCC occur in liver that is already cirrhotic.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (18 tok):
# R1	p: 16.67 	r: 22.22 	f: 19.05
# R2	p: 9.09 	r: 12.50 	f: 10.53
# RL	p: 16.67 	r: 22.22 	f: 19.05
# ST	66.68		W2V	26.00
#
# Hepatocellular carcinoma is a common cause of mortality in the developing world.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (18 tok):
# R1	p: 16.67 	r: 22.22 	f: 19.05
# R2	p: 9.09 	r: 12.50 	f: 10.53
# RL	p: 16.67 	r: 22.22 	f: 19.05
# ST	66.68		W2V	26.00
#
# Hepatocellular carcinoma is a common cause of mortality in the developing world.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (25 tok):
# R1	p: 15.38 	r: 22.22 	f: 18.18
# R2	p: 8.33 	r: 12.50 	f: 10.00
# RL	p: 15.38 	r: 22.22 	f: 18.18
# ST	68.96		W2V	29.02
#
# Hepatocellular carcinoma (hepatoma, HCC) is a common cause of mortality in developing countries.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (17 tok):
# R1	p: 18.18 	r: 22.22 	f: 20.00
# R2	p: 10.00 	r: 12.50 	f: 11.11
# RL	p: 18.18 	r: 22.22 	f: 20.00
# ST	66.02		W2V	28.62
#
# Hepatocellular carcinoma is a common cause of mortality in developing countries.
#
#
# ####################################################################################################
#
# (9781910797273, 'chp6')
# Promoting repair has been an unexplored sphere of MS therapy. Recently, in animal models of
# demyelination, LINGO antagonists have been shown to promote oligodendrocyte differentiation and
# myelination in vitro. Initiated in 2013, the first multinational Phase II trial of anti-LINGO-1
# antibodies in patients with acute optic neuritis has shown an effect on promoting nerve repair
# following optic neuritis. Ultimately, therapies that successfully promote remyelination and repair
# may be applicable across the spectrum of MS subtypes, including progressive forms of the disease.
# Tyrosine kinase inhibitors. Mastinib has completed a positive Phase IIb study in patients with
# primary and secondary progressive MS, the results of which are reported to include improvement in
# the Multiple Sclerosis Functional Composite (see pages 54 -). A Phase III trial in this population
# is now in progress, and it may prove to be an oral treatment option for this more rare type of MS.
# Mastinib targets mast cells and inhibits several biochemical processes. It is used in the treatment
# of canine diseases and is also being evaluated in stroke, amyotrophic lateral sclerosis and
# Alzheimer's disease.
#
# Reference:
# Anti-LINGO antibody is the first remyelination-promoting therapy to reach Phase II clinical trials
# in optic neuritis. Treatments that overcome molecular obstacles to remyelination may complement
# immune-directed therapies for MS in the future.
# sshleifer/distilbart-cnn-12-6 (60 tok):
# R1	p: 20.45 	r: 25.71 	f: 22.78
# R2	p: 2.33 	r: 2.94 	f: 2.60
# RL	p: 15.91 	r: 20.00 	f: 17.72
# ST	60.92		W2V	45.55
#
#  LINGO antagonists have been shown to promote oligodendrocyte differentiation and myelination in
# vitro. Mastinib has completed a positive Phase IIb study in patients with primary and secondary
# progressive MS, the results of which are reported to include improvement in the Multiple Sclerosis
# Functional Composite.
#
# sshleifer/distilbart-cnn-12-6 (65 tok):
# R1	p: 18.37 	r: 25.71 	f: 21.43
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 10.20 	r: 14.29 	f: 11.90
# ST	59.86		W2V	33.06
#
#  LINGO antagonists promote oligodendrocyte differentiation and myelination in vitro. Mastinib has
# completed a positive Phase IIb study in patients with primary and secondary progressive MS. A Phase
# III trial in this population is now in progress, and it may prove to be an oral treatment option for
# this population.
#
# sshleifer/distilbart-cnn-12-6 (43 tok):
# R1	p: 20.69 	r: 17.14 	f: 18.75
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 17.24 	r: 14.29 	f: 15.62
# ST	62.06		W2V	18.06
#
#  LINGO antagonists have been shown to promote oligodendrocyte differentiation and myelination in
# vitro. Mastinib has completed a positive Phase IIb study in patients with primary and secondary
# progressive MS.
#
# sshleifer/distilbart-cnn-12-6 (39 tok):
# R1	p: 20.00 	r: 14.29 	f: 16.67
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 16.00 	r: 11.43 	f: 13.33
# ST	63.02		W2V	15.33
#
#  LINGO antagonists promote oligodendrocyte differentiation and myelination in vitro. Mastinib has
# completed a positive Phase IIb study in patients with primary and secondary progressive MS.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (30 tok):
# R1	p: 31.82 	r: 20.00 	f: 24.56
# R2	p: 4.76 	r: 2.94 	f: 3.64
# RL	p: 27.27 	r: 17.14 	f: 21.05
# ST	57.74		W2V	25.39
#
# Treatments that successfully promote remyelination and repair may be applicable across the spectrum
# of MS subtypes, including progressive forms of the disease.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (28 tok):
# R1	p: 33.33 	r: 20.00 	f: 25.00
# R2	p: 5.00 	r: 2.94 	f: 3.70
# RL	p: 28.57 	r: 17.14 	f: 21.43
# ST	57.18		W2V	23.59
#
# Treatments that successfully promote remyelination and repair may be applicable across the spectrum
# of MS, including progressive forms of the disease.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (27 tok):
# R1	p: 35.00 	r: 20.00 	f: 25.45
# R2	p: 5.26 	r: 2.94 	f: 3.77
# RL	p: 30.00 	r: 17.14 	f: 21.82
# ST	55.45		W2V	26.98
#
# Treatments that promote remyelination and repair may be applicable across the spectrum of MS,
# including progressive forms of the disease.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (23 tok):
# R1	p: 37.50 	r: 17.14 	f: 23.53
# R2	p: 6.67 	r: 2.94 	f: 4.08
# RL	p: 31.25 	r: 14.29 	f: 19.61
# ST	51.83		W2V	17.64
#
# Treatments that successfully promote remyelination and repair may be applicable across the spectrum
# of MS subtypes.
#
#
# ####################################################################################################

# %% [markdown]
# #### Print Val Examples

# %%
print_examples([
    'sshleifer/distilbart-cnn-12-6',
    magma_dir+'fine-tuning/ft_bart_para_wordembed/checkpoint-196'],
    df_val)
# Out:
# (9781908541178, 'ch_6')
# Many anatomic factors can play a primary or a secondary role in the development and progression of
# low back pain syndromes. The most common causes of low back pain are mechanical in origin.
# Mechanical disorders of the lumbar spine are related to injury, overuse or deformity of a spinal
# structure. The most important traumatic factors in low back pain relate to soft tissue structures.
# Precise identification of the injured tissue, and the role of that injury in the consequent pain and
# dysfunction, can be frustratingly difficult. Problems occur in muscles, intervertebral discs, facet
# joints, ligaments or spinal nerves. Aging causes modification of these structures over time, and
# different parts of the spine tend to be at greater risk for change or injury during different
# decades of life. Early in life, muscle injuries are more frequent, while joint problems occur in the
# sixth decade of life (Table 3.1).
#
# Reference:
# Mechanical disorders - muscle strain, spondylolisthesis, herniated intervertebral disc,
# osteoarthritis, spinal stenosis - are the most common causes of low back pain.
#
# sshleifer/distilbart-cnn-12-6 (43 tok):
# R1	p: 24.14 	r: 35.00 	f: 28.57
# R2	p: 3.57 	r: 5.26 	f: 4.26
# RL	p: 13.79 	r: 20.00 	f: 16.33
# ST	69.73		W2V	49.38
#
#  Mechanical disorders of the lumbar spine are related to injury, overuse or deformity of a spinal
# structure. Problems occur in muscles, intervertebral discs, facet joints, ligaments or spinal
# nerves.
#
# sshleifer/distilbart-cnn-12-6 (51 tok):
# R1	p: 27.91 	r: 60.00 	f: 38.10
# R2	p: 19.05 	r: 42.11 	f: 26.23
# RL	p: 18.60 	r: 40.00 	f: 25.40
# ST	74.08		W2V	72.93
#
#  The most common causes of low back pain are mechanical in origin. Mechanical disorders of the
# lumbar spine are related to injury, overuse or deformity of a spinal structure. The most important
# traumatic factors in low back pain relate to soft tissue structures.
#
# sshleifer/distilbart-cnn-12-6 (52 tok):
# R1	p: 21.62 	r: 40.00 	f: 28.07
# R2	p: 2.78 	r: 5.26 	f: 3.64
# RL	p: 16.22 	r: 30.00 	f: 21.05
# ST	63.61		W2V	53.73
#
#  Mechanical disorders of the lumbar spine are related to injury, overuse or deformity of a spinal
# structure. Problems occur in muscles, intervertebral discs, facet joints, ligaments or spinal
# nerves. Aging causes modification of these structures over time.
#
# sshleifer/distilbart-cnn-12-6 (36 tok):
# R1	p: 41.38 	r: 60.00 	f: 48.98
# R2	p: 28.57 	r: 42.11 	f: 34.04
# RL	p: 27.59 	r: 40.00 	f: 32.65
# ST	78.22		W2V	75.56
#
#  The most common causes of low back pain are mechanical in origin. Mechanical disorders of the
# lumbar spine are related to injury, overuse or deformity of a spinal structure.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (36 tok):
# R1	p: 41.38 	r: 60.00 	f: 48.98
# R2	p: 28.57 	r: 42.11 	f: 34.04
# RL	p: 27.59 	r: 40.00 	f: 32.65
# ST	78.26		W2V	75.56
#
# The most common causes of low back pain are mechanical in origin. Mechanical disorders of the lumbar
# spine are related to injury, overuse or deformity of a spinal structure.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (55 tok):
# R1	p: 25.53 	r: 60.00 	f: 35.82
# R2	p: 17.39 	r: 42.11 	f: 24.62
# RL	p: 17.02 	r: 40.00 	f: 23.88
# ST	71.18		W2V	65.04
#
# The most common causes of low back pain are mechanical in origin. Mechanical disorders of the lumbar
# spine are related to injury, overuse or deformity of a spinal structure. Different parts of the
# spine are at greater risk for change or injury during different decades of life.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (36 tok):
# R1	p: 41.38 	r: 60.00 	f: 48.98
# R2	p: 28.57 	r: 42.11 	f: 34.04
# RL	p: 27.59 	r: 40.00 	f: 32.65
# ST	78.26		W2V	75.56
#
# The most common causes of low back pain are mechanical in origin. Mechanical disorders of the lumbar
# spine are related to injury, overuse or deformity of a spinal structure.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (36 tok):
# R1	p: 41.38 	r: 60.00 	f: 48.98
# R2	p: 28.57 	r: 42.11 	f: 34.04
# RL	p: 27.59 	r: 40.00 	f: 32.65
# ST	80.06		W2V	75.56
#
# The most common causes of low back pain are mechanical in origin; mechanical disorders of the lumbar
# spine are related to injury, overuse or deformity of a spinal structure.
#
#
# ####################################################################################################
#
# (9781912776726, 'ch4')
# Patients with glioblastoma have specific information needs. While the amount of information that
# patients want varies from person to person, and in some cases understanding may be impaired by
# cognitive deficits, patients and their carers need frank but compassionate information on diagnosis,
# prognosis, treatment options, recurrence and end-of-life care. News of a poor prognosis can be
# difficult to process initially. Patients need time to ask questions and receive honest answers. A
# combination of written and verbal information over several consultations and ongoing access to a
# well-resourced specialist nurse and psychologist or counselor are all important in this respect.
# Standard of care for newly diagnosed glioblastoma. The current standard of care for newly diagnosed
# glioblastoma is maximum surgical resection followed by radiotherapy and concomitant temozolomide and
# adjuvant temozolomide.
#
# Reference:
# Radiotherapy and temozolomide is suitable for fit elderly patients with glioblastoma.
#
# sshleifer/distilbart-cnn-12-6 (38 tok):
# R1	p: 7.14 	r: 18.18 	f: 10.26
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 3.57 	r: 9.09 	f: 5.13
# ST	33.78		W2V	19.73
#
#  Patients need frank but compassionate information on diagnosis, prognosis, treatment options,
# recurrence and end-of-life care. News of a poor prognosis can be difficult to process initially.
#
# sshleifer/distilbart-cnn-12-6 (29 tok):
# R1	p: 33.33 	r: 54.55 	f: 41.38
# R2	p: 11.76 	r: 20.00 	f: 14.81
# RL	p: 16.67 	r: 27.27 	f: 20.69
# ST	65.75		W2V	48.27
#
#  The current standard of care for newly diagnosed glioblastoma is maximum surgical resection
# followed by radiotherapy and temozolomide.
#
# sshleifer/distilbart-cnn-12-6 (23 tok):
# R1	p: 25.00 	r: 36.36 	f: 29.63
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 12.50 	r: 18.18 	f: 14.81
# ST	61.51		W2V	37.96
#
#  The current standard of care for newly diagnosed glioblastoma is maximum surgical resection
# followed by radiotherapy.
#
# sshleifer/distilbart-cnn-12-6 (19 tok):
# R1	p: 23.08 	r: 27.27 	f: 25.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 15.38 	r: 18.18 	f: 16.67
# ST	57.69		W2V	31.83
#
#  The current standard of care for newly diagnosed glioblastoma is maximum surgical resection.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (26 tok):
# R1	p: 11.76 	r: 18.18 	f: 14.29
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 5.88 	r: 9.09 	f: 7.14
# ST	39.99		W2V	17.62
#
# Patients need frank but compassionate information on diagnosis, prognosis, treatment options,
# recurrence and end-of-life care.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (32 tok):
# R1	p: 21.05 	r: 36.36 	f: 26.67
# R2	p: 11.11 	r: 20.00 	f: 14.29
# RL	p: 15.79 	r: 27.27 	f: 20.00
# ST	56.29		W2V	34.00
#
# Patients with glioblastoma need frank but compassionate information on diagnosis, prognosis,
# treatment options, recurrence and end-of-life care.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (13 tok):
# R1	p: 42.86 	r: 27.27 	f: 33.33
# R2	p: 33.33 	r: 20.00 	f: 25.00
# RL	p: 42.86 	r: 27.27 	f: 33.33
# ST	54.37		W2V	39.95
#
# Patients with glioblastoma have specific information needs.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (13 tok):
# R1	p: 42.86 	r: 27.27 	f: 33.33
# R2	p: 33.33 	r: 20.00 	f: 25.00
# RL	p: 42.86 	r: 27.27 	f: 33.33
# ST	54.37		W2V	39.95
#
# Patients with glioblastoma have specific information needs.
#
#
# ####################################################################################################
#
# (9783318066241, 'ch6')
# Fluid type. Both an open-label and a triple-blind RCT have demonstrated that fluid resuscitation
# using lactated Ringer's solution (a balanced salt solution) is associated with a decreased
# inflammatory response when compared with fluid resuscitation with normal saline (with a high
# chloride content). According to in vitro experiments, it seems that this anti-inflammatory effect
# depends on lactate. However, both studies included a small number of patients, and the influence of
# lactated Ringer's solution on important outcomes such as OF or mortality is unknown. In studies
# addressing other clinical scenarios, balanced fluids such as lactated Ringer's solution seem to be
# associated with a decreased need for blood products and a lower incidence of renal replacement
# therapy, hyperkalemia and postoperative infections when compared with normal saline. For the time
# being, it seems that lactated Ringer's solution is a good choice for fluid resuscitation in AP.
#
# Reference:
# Lactated Ringer's solution is associated with a decreased inflammatory response in AP when compared
# with normal saline.
# sshleifer/distilbart-cnn-12-6 (66 tok):
# R1	p: 32.69 	r: 94.44 	f: 48.57
# R2	p: 27.45 	r: 82.35 	f: 41.18
# RL	p: 30.77 	r: 88.89 	f: 45.71
# ST	71.46		W2V	63.27
#
#  An open-label and a triple-blind RCT have demonstrated that fluid resuscitation using lactated
# Ringer's solution (a balanced salt solution) is associated with a decreased inflammatory response
# when compared with fluid resuscitation with normal saline. According to in vitro experiments, it
# seems that this anti-inflammatory effect depends on lactate.
#
# sshleifer/distilbart-cnn-12-6 (57 tok):
# R1	p: 27.27 	r: 66.67 	f: 38.71
# R2	p: 23.26 	r: 58.82 	f: 33.33
# RL	p: 27.27 	r: 66.67 	f: 38.71
# ST	66.63		W2V	45.11
#
#  An open-label and a triple-blind RCT have demonstrated that fluid resuscitation using lactated
# Ringer's solution (a balanced salt solution) is associated with a decreased inflammatory response.
# According to in vitro experiments, it seems that this anti-inflammatory effect depends on lactate.
#
# sshleifer/distilbart-cnn-12-6 (69 tok):
# R1	p: 31.48 	r: 94.44 	f: 47.22
# R2	p: 26.42 	r: 82.35 	f: 40.00
# RL	p: 29.63 	r: 88.89 	f: 44.44
# ST	72.84		W2V	69.01
#
#  An open-label and a triple-blind RCT have demonstrated that fluid resuscitation using lactated
# Ringer's solution (a balanced salt solution) is associated with a decreased inflammatory response
# when compared with fluid resuscitation with normal saline (with a high chloride content) According
# to in vitro experiments, this anti-inflammatory effect depends on lactate.
#
# sshleifer/distilbart-cnn-12-6 (63 tok):
# R1	p: 34.69 	r: 94.44 	f: 50.75
# R2	p: 29.17 	r: 82.35 	f: 43.08
# RL	p: 32.65 	r: 88.89 	f: 47.76
# ST	71.43		W2V	64.89
#
#  An open-label and a triple-blind RCT have demonstrated that fluid resuscitation using lactated
# Ringer's solution (a balanced salt solution) is associated with a decreased inflammatory response
# when compared with fluid resuscitation with normal saline. According to in vitro experiments, this
# anti-inflammatory effect depends on lactate.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (45 tok):
# R1	p: 36.11 	r: 72.22 	f: 48.15
# R2	p: 28.57 	r: 58.82 	f: 38.46
# RL	p: 36.11 	r: 72.22 	f: 48.15
# ST	63.07		W2V	49.33
#
# Balanced fluids such as lactated Ringer's solution seem to be associated with a decreased need for
# blood products and a lower incidence of renal replacement therapy, hyperkalemia and postoperative
# infections when compared with normal saline.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (45 tok):
# R1	p: 37.14 	r: 72.22 	f: 49.06
# R2	p: 29.41 	r: 58.82 	f: 39.22
# RL	p: 37.14 	r: 72.22 	f: 49.06
# ST	62.64		W2V	50.02
#
# Balanced fluids such as lactated Ringer's solution seem to be associated with a decreased need for
# blood products, a lower incidence of renal replacement therapy, hyperkalemia and postoperative
# infections when compared with normal saline.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (40 tok):
# R1	p: 25.81 	r: 44.44 	f: 32.65
# R2	p: 20.00 	r: 35.29 	f: 25.53
# RL	p: 25.81 	r: 44.44 	f: 32.65
# ST	58.03		W2V	31.96
#
# Balanced fluids such as lactated Ringer's solution seem to be associated with a decreased need for
# blood products and a lower incidence of renal replacement therapy, hyperkalemia and postoperative
# infections.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (40 tok):
# R1	p: 25.81 	r: 44.44 	f: 32.65
# R2	p: 20.00 	r: 35.29 	f: 25.53
# RL	p: 25.81 	r: 44.44 	f: 32.65
# ST	58.03		W2V	31.96
#
# Balanced fluids such as lactated Ringer's solution seem to be associated with a decreased need for
# blood products and a lower incidence of renal replacement therapy, hyperkalemia and postoperative
# infections.
#
#
# ####################################################################################################
#
# (9781910797662, 'ch07')
# Management of advanced and metastatic disease. A core principle in the management of solid tumors is
# to consider control of both the primary and metastatic disease. Several clinical scenarios occur in
# bladder cancer. Cancers that are clearly confined to the bladder can potentially be cured if the
# primary tumor can be removed or ablated, through surgery, radiation therapy or multimodality
# approaches, and there is no metastatic disease; 5-year survival rates are about 70%. Management of
# these cancers is discussed in chapter on 'Management of non-muscle-invasive disease'.
#
# Reference:
# Management of both local and distant metastatic disease should be considered.
#
# sshleifer/distilbart-cnn-12-6 (43 tok):
# R1	p: 17.14 	r: 54.55 	f: 26.09
# R2	p: 8.82 	r: 30.00 	f: 13.64
# RL	p: 17.14 	r: 54.55 	f: 26.09
# ST	62.06		W2V	51.56
#
#  A core principle in the management of solid tumors is to consider control of both the primary and
# metastatic disease. Management of these cancers is discussed in chapter on 'Management of non-
# muscle-invasive disease'
#
# sshleifer/distilbart-cnn-12-6 (46 tok):
# R1	p: 17.07 	r: 63.64 	f: 26.92
# R2	p: 7.50 	r: 30.00 	f: 12.00
# RL	p: 17.07 	r: 63.64 	f: 26.92
# ST	63.19		W2V	43.87
#
#  A core principle in the management of solid tumors is to consider control of both the primary and
# metastatic disease. Cancers that are clearly confined to the bladder can potentially be cured if the
# primary tumor can be removed or ablated.
#
# sshleifer/distilbart-cnn-12-6 (52 tok):
# R1	p: 15.22 	r: 63.64 	f: 24.56
# R2	p: 6.67 	r: 30.00 	f: 10.91
# RL	p: 15.22 	r: 63.64 	f: 24.56
# ST	61.14		W2V	42.84
#
#  A core principle in the management of solid tumors is to consider control of both the primary and
# metastatic disease. Cancers that are clearly confined to the bladder can potentially be cured if the
# primary tumor can be removed or ablated, through surgery or radiation therapy.
#
# sshleifer/distilbart-cnn-12-6 (43 tok):
# R1	p: 2.86 	r: 9.09 	f: 4.35
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 2.86 	r: 9.09 	f: 4.35
# ST	45.92		W2V	14.57
#
#  Several clinical scenarios occur in bladder cancer. Cancers that are clearly confined to the
# bladder can potentially be cured if the primary tumor can be removed or ablated, through surgery,
# radiation therapy or multimodality approaches.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (21 tok):
# R1	p: 31.58 	r: 54.55 	f: 40.00
# R2	p: 16.67 	r: 30.00 	f: 21.43
# RL	p: 31.58 	r: 54.55 	f: 40.00
# ST	63.09		W2V	46.18
#
# The management of both the primary and metastatic disease is a key component of the treatment of
# bladder cancer.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (21 tok):
# R1	p: 31.58 	r: 54.55 	f: 40.00
# R2	p: 16.67 	r: 30.00 	f: 21.43
# RL	p: 31.58 	r: 54.55 	f: 40.00
# ST	63.09		W2V	46.18
#
# The management of both the primary and metastatic disease is a key component of the treatment of
# bladder cancer.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (22 tok):
# R1	p: 25.00 	r: 45.45 	f: 32.26
# R2	p: 10.53 	r: 20.00 	f: 13.79
# RL	p: 25.00 	r: 45.45 	f: 32.26
# ST	53.10		W2V	44.95
#
# The management of both the primary and metastatic tumor control is a key component of the treatment
# of bladder cancer.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (25 tok):
# R1	p: 26.09 	r: 54.55 	f: 35.29
# R2	p: 13.64 	r: 30.00 	f: 18.75
# RL	p: 26.09 	r: 54.55 	f: 35.29
# ST	60.98		W2V	52.10
#
# The management of both the primary and metastatic disease is a key principle in the management of
# both the tumor and tumor control.
#
#
# ####################################################################################################
#
# (9781910797723, 'chp3')
# What types of tumor are potentially susceptible to immuno-oncology?. Clearly, the potential
# sensitivity of a given cancer to immuno-oncology therapies will depend on the ability of the tumor
# to trigger an immune response (immunogenicity). Cancer is characterized by an accumulation of
# genetic mutations, many of which result in the expression of cancer-specific antigens that can bind
# to major histocompatibility complex (MHC) class I molecules on the cancer cell surface. These
# antigen-MHC complexes can be recognized by cytotoxic CD8+ lymphocytes, that, if activated, could
# potentially mount an immune response against the tumor. As a result, tumors with high somatic
# mutation rates may be more susceptible to immuno-oncology therapies than those with lower mutation
# rates. Somatic mutation rates differ markedly, both between tumor types and within an individual
# tumor type: the rate may vary more than 1000-fold between tumors with the highest and lowest rates
# (Figure 3.2). The highest rates are seen in cancers of the skin, lung, bladder and stomach, while
# the lowest are seen in hematologic and pediatric cancers. It is noteworthy that the highest rates
# occur in tumors that are induced by carcinogens such as tobacco smoke or ultraviolet light.
#
# Reference:
# The potential sensitivity of a given cancer to immunotherapy depends on the immunogenicity of the
# tumor, which is related to the somatic mutation rate within tumor cells.- The highest mutation rates
# are seen in cancers of the skin, lung, bladder and stomach, rendering these tumor types more
# sensitive to immunotherapy.
# sshleifer/distilbart-cnn-12-6 (77 tok):
# R1	p: 46.67 	r: 56.00 	f: 50.91
# R2	p: 22.03 	r: 26.53 	f: 24.07
# RL	p: 33.33 	r: 40.00 	f: 36.36
# ST	86.24		W2V	74.10
#
#  The potential sensitivity of a given cancer to immuno-oncology therapies will depend on the ability
# of the tumor to trigger an immune response (immunogenicity) Cancer is characterized by an
# accumulation of genetic mutations, many of which result in the expression of cancer-specific
# antigens. Somatic mutation rates differ markedly, both between tumor types and within an individual
# tumor type.
#
# sshleifer/distilbart-cnn-12-6 (59 tok):
# R1	p: 44.44 	r: 40.00 	f: 42.11
# R2	p: 22.73 	r: 20.41 	f: 21.51
# RL	p: 35.56 	r: 32.00 	f: 33.68
# ST	78.46		W2V	68.54
#
#  The potential sensitivity of a given cancer to immuno-oncology therapies will depend on the ability
# of the tumor to trigger an immune response (immunogenicity) Cancer is characterized by an
# accumulation of genetic mutations, many of which result in the expression of cancer-specific
# antigens.
#
# sshleifer/distilbart-cnn-12-6 (66 tok):
# R1	p: 40.38 	r: 42.00 	f: 41.18
# R2	p: 19.61 	r: 20.41 	f: 20.00
# RL	p: 32.69 	r: 34.00 	f: 33.33
# ST	78.57		W2V	70.10
#
#  The potential sensitivity of a given cancer to immuno-oncology therapies will depend on the ability
# of the tumor to trigger an immune response (immunogenicity) Cancer is characterized by an
# accumulation of genetic mutations, many of which result in the expression of cancer-specific
# antigens that can bind to cancer cell surface.
#
# sshleifer/distilbart-cnn-12-6 (51 tok):
# R1	p: 74.36 	r: 58.00 	f: 65.17
# R2	p: 57.89 	r: 44.90 	f: 50.57
# RL	p: 71.79 	r: 56.00 	f: 62.92
# ST	84.67		W2V	81.60
#
#  The potential sensitivity of a given cancer to immuno-oncology therapies will depend on the ability
# of the tumor to trigger an immune response (immunogenicity) The highest rates are seen in cancers of
# the skin, lung, bladder and stomach.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (33 tok):
# R1	p: 58.33 	r: 28.00 	f: 37.84
# R2	p: 34.78 	r: 16.33 	f: 22.22
# RL	p: 54.17 	r: 26.00 	f: 35.14
# ST	72.98		W2V	70.57
#
# The sensitivity of a given cancer to immuno-oncology therapies will depend on the ability of the
# tumor to trigger an immune response (immunogenicity).
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (33 tok):
# R1	p: 58.33 	r: 28.00 	f: 37.84
# R2	p: 26.09 	r: 12.24 	f: 16.67
# RL	p: 50.00 	r: 24.00 	f: 32.43
# ST	73.34		W2V	70.69
#
# The sensitivity of a given tumor to immuno-oncology therapies will depend on the ability of the
# tumor to trigger an immune response (immunogenicity).
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (32 tok):
# R1	p: 65.22 	r: 30.00 	f: 41.10
# R2	p: 31.82 	r: 14.29 	f: 19.72
# RL	p: 56.52 	r: 26.00 	f: 35.62
# ST	73.35		W2V	74.29
#
# The sensitivity of a given tumor to immuno-oncology therapies depends on the ability of the tumor to
# trigger an immune response (immunogenicity).
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (33 tok):
# R1	p: 58.33 	r: 28.00 	f: 37.84
# R2	p: 26.09 	r: 12.24 	f: 16.67
# RL	p: 50.00 	r: 24.00 	f: 32.43
# ST	73.34		W2V	70.69
#
# The sensitivity of a given tumor to immuno-oncology therapies will depend on the ability of the
# tumor to trigger an immune response (immunogenicity).
#
#
# ####################################################################################################
#
# (9781910797471, 'ch02')
# Advances in the management of heart failure (HF) over the past 20 years have been informed by a
# better understanding of its pathophysiology. There are few situations in cardiology where treatment
# has been as closely linked to an appreciation of the underlying science. Vicious cycle of heart
# failure. HF is a disease of inappropriate adaptation to injury. The body has a limited range of
# compensatory responses to circulatory impairment, mainly vasoconstriction and sodium and water
# retention (see below). In general, however, these adjustments to hypovolemia are poorly suited to
# pump failure, and increases in the preload and afterload of the failing heart lead to worsening HF
# (Figure 2.1).
#
# Reference:
# Remodeling is a cardiac response that is initially appropriate and becomes inappropriate as the
# heart enlarges excessively and hypertrophies.
#
# sshleifer/distilbart-cnn-12-6 (40 tok):
# R1	p: 15.62 	r: 26.32 	f: 19.61
# R2	p: 3.23 	r: 5.56 	f: 4.08
# RL	p: 12.50 	r: 21.05 	f: 15.69
# ST	51.25		W2V	-1.14
#
#  Heart failure is a disease of inappropriate adaptation to injury. The body has a limited range of
# compensatory responses to circulatory impairment. These adjustments to hypovolemia are poorly suited
# to pump failure.
#
# sshleifer/distilbart-cnn-12-6 (39 tok):
# R1	p: 15.62 	r: 26.32 	f: 19.61
# R2	p: 3.23 	r: 5.56 	f: 4.08
# RL	p: 9.38 	r: 15.79 	f: 11.76
# ST	36.12		W2V	21.65
#
#  Advances in the management of heart failure (HF) over the past 20 years have been informed by a
# better understanding of its pathophysiology. HF is a disease of inappropriate adaptation to injury.
#
# sshleifer/distilbart-cnn-12-6 (29 tok):
# R1	p: 13.04 	r: 15.79 	f: 14.29
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 8.70 	r: 10.53 	f: 9.52
# ST	27.17		W2V	15.11
#
#  Advances in the management of heart failure (HF) over the past 20 years have been informed by a
# better understanding of its pathophysiology.
#
# sshleifer/distilbart-cnn-12-6 (34 tok):
# R1	p: 18.52 	r: 26.32 	f: 21.74
# R2	p: 3.85 	r: 5.56 	f: 4.55
# RL	p: 11.11 	r: 15.79 	f: 13.04
# ST	39.09		W2V	17.20
#
#  Advances in the management of heart failure (HF) have been informed by a better understanding of
# its pathophysiology. HF is a disease of inappropriate adaptation to injury.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (11 tok):
# R1	p: 40.00 	r: 21.05 	f: 27.59
# R2	p: 11.11 	r: 5.56 	f: 7.41
# RL	p: 30.00 	r: 15.79 	f: 20.69
# ST	45.23		W2V	27.41
#
# Heart failure is a disease of inappropriate adaptation to injury.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (11 tok):
# R1	p: 40.00 	r: 21.05 	f: 27.59
# R2	p: 11.11 	r: 5.56 	f: 7.41
# RL	p: 30.00 	r: 15.79 	f: 20.69
# ST	45.23		W2V	27.41
#
# Heart failure is a disease of inappropriate adaptation to injury.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (14 tok):
# R1	p: 36.36 	r: 21.05 	f: 26.67
# R2	p: 10.00 	r: 5.56 	f: 7.14
# RL	p: 27.27 	r: 15.79 	f: 20.00
# ST	42.46		W2V	27.22
#
# Heart failure (HF) is a disease of inappropriate adaptation to injury.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (11 tok):
# R1	p: 40.00 	r: 21.05 	f: 27.59
# R2	p: 11.11 	r: 5.56 	f: 7.41
# RL	p: 30.00 	r: 15.79 	f: 20.69
# ST	45.23		W2V	27.41
#
# Heart failure is a disease of inappropriate adaptation to injury.
#
#
# ####################################################################################################
#
# (9781910797815, 'chp9')
# There are no specific diagnostic criteria for MPN-BP. The principal criterion is the same as for de
# novo acute myeloid leukemia (AML): more than 20% blasts in bone marrow or peripheral blood.
# Persistence is also important if only peripheral blood blasts are considered. Importantly,
# acceleration or progression of myelofibrosis is usually apparent before the development of overt
# leukemia. Signs of this include.
#
# Reference:
# Signs of accelerating myelofibrosis may precede the development of overt leukemia.
#
# sshleifer/distilbart-cnn-12-6 (44 tok):
# R1	p: 6.06 	r: 18.18 	f: 9.09
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 6.06 	r: 18.18 	f: 9.09
# ST	36.23		W2V	27.69
#
#  There are no specific diagnostic criteria for MPN-BP. The principal criterion is the same as for de
# novo acute myeloid leukemia (AML): more than 20% blasts in bone marrow or peripheral blood.
#
# sshleifer/distilbart-cnn-12-6 (45 tok):
# R1	p: 5.88 	r: 18.18 	f: 8.89
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 5.88 	r: 18.18 	f: 8.89
# ST	35.59		W2V	17.69
#
#  There are no specific diagnostic criteria for MPN-BP. Principal criterion is the same as for de
# novo acute myeloid leukemia (AML) More than 20% blasts in bone marrow or peripheral blood are
# considered.
#
# sshleifer/distilbart-cnn-12-6 (32 tok):
# R1	p: 8.70 	r: 18.18 	f: 11.76
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 8.70 	r: 18.18 	f: 11.76
# ST	36.51		W2V	24.15
#
#  There are no specific diagnostic criteria for MPN-BP. The principal criterion is the same as for de
# novo acute myeloid leukemia (AML)
#
# sshleifer/distilbart-cnn-12-6 (29 tok):
# R1	p: 9.09 	r: 18.18 	f: 12.12
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 9.09 	r: 18.18 	f: 12.12
# ST	34.81		W2V	21.81
#
#  There are no specific diagnostic criteria for MPN-BP. The principal criterion is the same as for de
# novo acute myeloid leukemia.
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (14 tok):
# R1	p: 18.18 	r: 18.18 	f: 18.18
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 18.18 	r: 18.18 	f: 18.18
# ST	13.66		W2V	22.45
#
# There is no diagnostic criteria for the diagnosis of MPN-BP.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (11 tok):
# R1	p: 0.00 	r: 0.00 	f: 0.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 0.00 	r: 0.00 	f: 0.00
# ST	7.84		W2V	-3.50
#
# There is no diagnostic criteria for MPN-BP.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (12 tok):
# R1	p: 0.00 	r: 0.00 	f: 0.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 0.00 	r: 0.00 	f: 0.00
# ST	7.89		W2V	-1.24
#
# There are no specific diagnostic criteria for MPN-BP.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (11 tok):
# R1	p: 0.00 	r: 0.00 	f: 0.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 0.00 	r: 0.00 	f: 0.00
# ST	8.00		W2V	-2.31
#
# There are no diagnostic criteria for MPN-BP.
#
#
# ####################################################################################################
#
# (9783318068207, 'hh-7')
# NGS testing for predictive biomarkers. EGFR activation of the RAS/RAF/MEK/ERK pathway (see Chapter
# 1) plays an important role in oncogenesis in CRC. Up to 50% of CRCs show activating mutations of
# KRAS. Anti-EGFR antibodies, such as cetuximab and panitumumab, can be beneficial in patients with
# metastatic CRC provided that there is no downstream mutation activating the RAS/RAF/MEK/ERK pathway.
# Initially, patients with codon 12/13 KRAS mutations did not benefit in clinical trials, and
# subsequently mutations in other codons of KRAS and in NRAS were also shown to confer resistance to
# antibody-based therapies., Thus, guidelines require an 'extended' RAS analysis be performed. At
# present, the minimum testing required to determine whether anti-EGFR therapy may be of benefit is
# this extended RAS testing of KRAS and NRAS. codons 12 and 13 of exon 2. codons 59 and 61 of exon 3.
# codons 117 and 146 of exon 4. Wild-type phenotype for KRAS and NRAS is thus an indication for anti-
# EGFR therapy.
#
# Reference:
# The minimum testing required to determine whether anti-EGFR therapy may be of benefit in CRC is
# extended RAS testing of KRAS and NRAS: codons 12 and 13 of exon 2; codons 59 and 61 of exon 3; and
# codons 117 and 146 of exon 4.
#
# sshleifer/distilbart-cnn-12-6 (42 tok):
# R1	p: 37.04 	r: 21.74 	f: 27.40
# R2	p: 7.69 	r: 4.44 	f: 5.63
# RL	p: 22.22 	r: 13.04 	f: 16.44
# ST	55.68		W2V	35.87
#
#  EGFR activation of the RAS/RAF/MEK/ERK pathway plays an important role in oncogenesis in CRC. Up to
# 50% of CRCs show activating mutations of KRAS.
#
# sshleifer/distilbart-cnn-12-6 (72 tok):
# R1	p: 30.23 	r: 28.26 	f: 29.21
# R2	p: 7.14 	r: 6.67 	f: 6.90
# RL	p: 16.28 	r: 15.22 	f: 15.73
# ST	56.74		W2V	42.61
#
#  EGFR activation of the RAS/RAF/MEK/ERK pathway plays an important role in oncogenesis in CRC. Up to
# 50% of CRCs show activating mutations of KRAS. Anti-EGFR antibodies, such as cetuximab and
# panitumumab, can be beneficial in patients with metastatic CRC.
#
# sshleifer/distilbart-cnn-12-6 (70 tok):
# R1	p: 30.23 	r: 28.26 	f: 29.21
# R2	p: 7.14 	r: 6.67 	f: 6.90
# RL	p: 16.28 	r: 15.22 	f: 15.73
# ST	56.69		W2V	42.61
#
#  EGFR activation of the RAS/RAF/MEK/ERK pathway plays an important role in oncogenesis in CRC. Up to
# 50% of CRCs show activating mutations of KRAS. Anti-EGFR antibodies such as cetuximab and
# panitumumab can be beneficial in patients with metastatic CRC.
#
# sshleifer/distilbart-cnn-12-6 (67 tok):
# R1	p: 30.43 	r: 30.43 	f: 30.43
# R2	p: 6.67 	r: 6.67 	f: 6.67
# RL	p: 19.57 	r: 19.57 	f: 19.57
# ST	61.39		W2V	49.52
#
#  EGFR activation of the RAS/RAF/MEK/ERK pathway plays an important role in oncogenesis in CRC. Up to
# 50% of CRCs show activating mutations of KRAS. Mutations in other codons of KRAS and in NRAS were
# also shown to confer resistance to antibody-based therapies.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (43 tok):
# R1	p: 75.76 	r: 54.35 	f: 63.29
# R2	p: 62.50 	r: 44.44 	f: 51.95
# RL	p: 66.67 	r: 47.83 	f: 55.70
# ST	75.13		W2V	79.98
#
# Up to 50% of CRCs show activating mutations of KRAS, and the minimum testing required to determine
# whether anti-EGFR therapy may be of benefit is extended RAS testing of KRAS and NRAS.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (50 tok):
# R1	p: 65.71 	r: 50.00 	f: 56.79
# R2	p: 55.88 	r: 42.22 	f: 48.10
# RL	p: 57.14 	r: 43.48 	f: 49.38
# ST	73.74		W2V	72.15
#
# Up to 50% of CRCs show activating mutations of KRAS, and the minimum testing required to determine
# whether anti-EGFR therapy may be of benefit is extended RAS testing of KRAS/RAF/MEK/ERK pathway.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (44 tok):
# R1	p: 73.53 	r: 54.35 	f: 62.50
# R2	p: 57.58 	r: 42.22 	f: 48.72
# RL	p: 64.71 	r: 47.83 	f: 55.00
# ST	74.12		W2V	80.64
#
# Up to 50% of CRCs show activating mutations of KRAS, and the minimum testing required to determine
# whether anti-EGFR therapy may be of benefit is this extended RAS testing of KRAS and NRAS.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (42 tok):
# R1	p: 71.88 	r: 50.00 	f: 58.97
# R2	p: 54.84 	r: 37.78 	f: 44.74
# RL	p: 62.50 	r: 43.48 	f: 51.28
# ST	75.28		W2V	76.06
#
# Up to 50% of CRCs show activating mutations of KRAS, and the minimum testing required to determine
# whether anti-EGFR therapy is of benefit is extended RAS testing of KRAS and NRAS.
#
#
# ####################################################################################################
#
# (9781910797815, 'chp4')
# Management of low-risk patients. Treatment to reduce cardiovascular risk factors, and promotion of a
# generally healthy lifestyle, may be sufficient intervention for very-low-risk patients. Smoking
# cessation should be actively promoted because cigarette smoking has been shown to be an independent
# risk factor for thrombosis in patients with ET. Low-dose aspirin has been shown to reduce both
# microvascular symptoms (exempli gratia erythromelalgia) and transient neurological and visual
# disturbances such as hemiparesis, scintillating scotomas, amaurosis fugax (transcient monocular
# blindness) and seizures. There is also evidence that antiplatelet therapy reduces the risk of venous
# thrombosis in patients with JAK2 V617F mutations and cardiovascular risk factors (arterial
# thrombosis). Higher doses of aspirin (up to 500 mg daily) may be required in patients with acute
# erythromelalgia.
#
# Reference:
# All patients should receive interventions to reduce cardiovascular risk factors, particularly
# smoking cessation advice.
#
# sshleifer/distilbart-cnn-12-6 (57 tok):
# R1	p: 15.38 	r: 42.86 	f: 22.64
# R2	p: 5.26 	r: 15.38 	f: 7.84
# RL	p: 10.26 	r: 28.57 	f: 15.09
# ST	55.72		W2V	30.96
#
#  Low-dose aspirin has been shown to reduce microvascular symptoms (exempli gratia erythromelalgia)
# and transient neurological and visual disturbances. Smoking cessation should be actively promoted
# because cigarette smoking has been shown to be an independent risk factor for thrombosis.
#
# sshleifer/distilbart-cnn-12-6 (48 tok):
# R1	p: 16.22 	r: 42.86 	f: 23.53
# R2	p: 2.78 	r: 7.69 	f: 4.08
# RL	p: 8.11 	r: 21.43 	f: 11.76
# ST	64.12		W2V	17.62
#
#  Smoking cessation should be actively promoted because cigarette smoking has been shown to be an
# independent risk factor for thrombosis in patients with ET. There is also evidence that antiplatelet
# therapy reduces the risk of venous thrombosis.
#
# sshleifer/distilbart-cnn-12-6 (28 tok):
# R1	p: 25.00 	r: 42.86 	f: 31.58
# R2	p: 4.35 	r: 7.69 	f: 5.56
# RL	p: 12.50 	r: 21.43 	f: 15.79
# ST	63.06		W2V	31.22
#
#  Smoking cessation should be actively promoted because cigarette smoking has been shown to be an
# independent risk factor for thrombosis in patients with ET.
#
# sshleifer/distilbart-cnn-12-6 (44 tok):
# R1	p: 15.15 	r: 35.71 	f: 21.28
# R2	p: 3.12 	r: 7.69 	f: 4.44
# RL	p: 6.06 	r: 14.29 	f: 8.51
# ST	64.67		W2V	11.89
#
#  Smoking cessation should be actively promoted because cigarette smoking is an independent risk
# factor for thrombosis in patients with ET. There is also evidence that antiplatelet therapy reduces
# the risk of venous thrombosis.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (26 tok):
# R1	p: 27.27 	r: 42.86 	f: 33.33
# R2	p: 19.05 	r: 30.77 	f: 23.53
# RL	p: 22.73 	r: 35.71 	f: 27.78
# ST	72.80		W2V	33.80
#
# Treatment to reduce cardiovascular risk factors and promotion of a generally healthy lifestyle may
# be sufficient intervention for very-low-risk patients.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (26 tok):
# R1	p: 27.27 	r: 42.86 	f: 33.33
# R2	p: 19.05 	r: 30.77 	f: 23.53
# RL	p: 22.73 	r: 35.71 	f: 27.78
# ST	71.81		W2V	35.96
#
# Treatment to reduce cardiovascular risk factors and promotion of a generally healthy lifestyle is a
# sufficient intervention for very-low-risk patients.
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (25 tok):
# R1	p: 28.57 	r: 42.86 	f: 34.29
# R2	p: 20.00 	r: 30.77 	f: 24.24
# RL	p: 23.81 	r: 35.71 	f: 28.57
# ST	71.71		W2V	35.96
#
# Treatment to reduce cardiovascular risk factors and promotion of a generally healthy lifestyle is
# sufficient intervention for very-low-risk patients.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (26 tok):
# R1	p: 27.27 	r: 42.86 	f: 33.33
# R2	p: 19.05 	r: 30.77 	f: 23.53
# RL	p: 22.73 	r: 35.71 	f: 27.78
# ST	71.81		W2V	35.96
#
# Treatment to reduce cardiovascular risk factors and promotion of a generally healthy lifestyle is a
# sufficient intervention for very-low-risk patients.
#
#
# ####################################################################################################
#
# (9781908541277, 'ch_11')
# There are no clear data indicating differences in safety among PHT, CBZ, PB and PRM. Current
# evidence suggests that the risk of major congenital malformations is two to four times higher with
# the use of VPA than with other AEDs such as CBZ and LTG. Absolute rates have ranged from 6% to 11%,
# although the risk may be minimized by keeping daily doses at or below 1000 mg. High-dose exposure to
# VPA in utero may impair later cognitive function. The teratogenic risk associated with LTG
# monotherapy is low and is similar to that associated with CBZ, although preliminary data suggest the
# possibility of greater risk of major malformations at higher dosage. There are still insufficient
# data regarding the safety of other modern AEDs.
#
# Reference:
# The risk of major malformations in babies exposed in utero seems to be greater with sodium valproate
# (VPA) than with other AEDs.
#
# sshleifer/distilbart-cnn-12-6 (54 tok):
# R1	p: 28.57 	r: 54.55 	f: 37.50
# R2	p: 17.07 	r: 33.33 	f: 22.58
# RL	p: 28.57 	r: 54.55 	f: 37.50
# ST	70.14		W2V	52.04
#
#  Current evidence suggests that the risk of major congenital malformations is two to four times
# higher with the use of VPA than with other AEDs such as CBZ and LTG. There are still insufficient
# data regarding the safety of other modern AEDs.
#
# sshleifer/distilbart-cnn-12-6 (51 tok):
# R1	p: 36.84 	r: 63.64 	f: 46.67
# R2	p: 21.62 	r: 38.10 	f: 27.59
# RL	p: 31.58 	r: 54.55 	f: 40.00
# ST	74.95		W2V	56.61
#
#  The risk of major congenital malformations is two to four times higher with the use of VPA than
# with other AEDs such as CBZ and LTG. High-dose exposure to VPA in utero may impair later cognitive
# function.
#
# sshleifer/distilbart-cnn-12-6 (39 tok):
# R1	p: 40.00 	r: 54.55 	f: 46.15
# R2	p: 24.14 	r: 33.33 	f: 28.00
# RL	p: 40.00 	r: 54.55 	f: 46.15
# ST	73.42		W2V	51.07
#
#  Current evidence suggests that the risk of major congenital malformations is two to four times
# higher with the use of VPA than with other AEDs such as CBZ and LTG.
#
# sshleifer/distilbart-cnn-12-6 (53 tok):
# R1	p: 30.77 	r: 54.55 	f: 39.34
# R2	p: 18.42 	r: 33.33 	f: 23.73
# RL	p: 30.77 	r: 54.55 	f: 39.34
# ST	66.30		W2V	46.57
#
#  Current evidence suggests that the risk of major congenital malformations is two to four times
# higher with the use of VPA than with other AEDs such as CBZ and LTG. The teratogenic risk associated
# with LTG monotherapy is low.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (21 tok):
# R1	p: 6.67 	r: 4.55 	f: 5.41
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 6.67 	r: 4.55 	f: 5.41
# ST	36.46		W2V	24.33
#
# There are no clear data indicating differences in safety among PHT, CBZ, PB and PRM.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (21 tok):
# R1	p: 6.67 	r: 4.55 	f: 5.41
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 6.67 	r: 4.55 	f: 5.41
# ST	36.62		W2V	21.30
#
# There is no clear data indicating differences in safety among PHT, CBZ, PB and PRM.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (21 tok):
# R1	p: 6.67 	r: 4.55 	f: 5.41
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 6.67 	r: 4.55 	f: 5.41
# ST	36.46		W2V	24.33
#
# There are no clear data indicating differences in safety among PHT, CBZ, PB and PRM.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (21 tok):
# R1	p: 6.67 	r: 4.55 	f: 5.41
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 6.67 	r: 4.55 	f: 5.41
# ST	36.46		W2V	24.33
#
# There are no clear data indicating differences in safety among PHT, CBZ, PB and PRM.
#
#
# ####################################################################################################

# %% [markdown]
# #### Print Test Examples

# %%
print_examples([
    'sshleifer/distilbart-cnn-12-6',
    magma_dir+'fine-tuning/ft_bart_para_wordembed/checkpoint-196'],
    df_test)
# Out:
# (9781908541277, 'ch_8')
# Indications. OXC has a similar spectrum of efficacy to CBZ against partial and tonic-clonic
# seizures. It tends to be better tolerated than CBZ with fewer neurotoxic side effects. Dosage. The
# recommended starting dose for OXC in adults is 150-600 mg daily in two doses. The dose can be
# titrated upwards as clinically indicated to 3000-4000 mg daily. A starting dose of 5 mg/kg daily in
# children over 3 years of age can be prescribed, increasing gradually to a maintenance dose of about
# 30 mg/kg daily. Patients already on CBZ may be switched immediately to OXC using a dosage ratio of
# 1.5 OXC to 1 CBZ. Particular care in immediate switching needs to be taken when the daily CBZ dose
# exceeds 1200 mg. Plasma concentrations of the clinically active metabolite of OXC increase linearly
# with dose. No studies, however, have attempted to relate elevated plasma levels to efficacy or
# toxicity.
#
# Reference:
# This wider choice of AEDs permits pharmacological treatment to be better matched to the individual
# patient's circumstances.
#
# sshleifer/distilbart-cnn-12-6 (38 tok):
# R1	p: 17.86 	r: 27.78 	f: 21.74
# R2	p: 7.41 	r: 11.76 	f: 9.09
# RL	p: 14.29 	r: 22.22 	f: 17.39
# ST	42.06		W2V	31.24
#
#  OXC has a similar spectrum of efficacy to CBZ against partial and tonic-clonic seizures. It tends
# to be better tolerated than CBZ with fewer neurotoxic side effects.
#
# sshleifer/distilbart-cnn-12-6 (40 tok):
# R1	p: 17.86 	r: 27.78 	f: 21.74
# R2	p: 7.41 	r: 11.76 	f: 9.09
# RL	p: 14.29 	r: 22.22 	f: 17.39
# ST	41.99		W2V	30.48
#
#  OXC has a similar spectrum of efficacy to CBZ against partial and tonic-clonic seizures. OXC tends
# to be better tolerated than CBZ with fewer neurotoxic side effects.
#
# sshleifer/distilbart-cnn-12-6 (55 tok):
# R1	p: 14.63 	r: 33.33 	f: 20.34
# R2	p: 5.00 	r: 11.76 	f: 7.02
# RL	p: 12.20 	r: 27.78 	f: 16.95
# ST	42.64		W2V	40.85
#
#  OXC has a similar spectrum of efficacy to CBZ against partial and tonic-clonic seizures. It tends
# to be better tolerated than CBZ with fewer neurotoxic side effects. The recommended starting dose
# for OXC in adults is 150-600 mg daily.
#
# sshleifer/distilbart-cnn-12-6 (42 tok):
# R1	p: 9.68 	r: 16.67 	f: 12.24
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 9.68 	r: 16.67 	f: 12.24
# ST	37.47		W2V	28.37
#
#  OXC has a similar spectrum of efficacy to CBZ against partial and tonic-clonic seizures. The
# recommended starting dose for OXC in adults is 150-600 mg daily in two doses.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (29 tok):
# R1	p: 22.73 	r: 27.78 	f: 25.00
# R2	p: 9.52 	r: 11.76 	f: 10.53
# RL	p: 18.18 	r: 22.22 	f: 20.00
# ST	42.99		W2V	36.21
#
# OXC has a similar spectrum of efficacy to CBZ; it tends to be better tolerated than CBZ with fewer
# neurotoxic side effects.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (29 tok):
# R1	p: 22.73 	r: 27.78 	f: 25.00
# R2	p: 9.52 	r: 11.76 	f: 10.53
# RL	p: 18.18 	r: 22.22 	f: 20.00
# ST	42.99		W2V	36.21
#
# OXC has a similar spectrum of efficacy to CBZ; it tends to be better tolerated than CBZ with fewer
# neurotoxic side effects.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (31 tok):
# R1	p: 20.83 	r: 27.78 	f: 23.81
# R2	p: 4.35 	r: 5.88 	f: 5.00
# RL	p: 16.67 	r: 22.22 	f: 19.05
# ST	42.67		W2V	37.64
#
# OXC has a similar spectrum of efficacy to CBZ; it tends to be a better tolerated drug than CBZ with
# fewer neurotoxic side effects.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (43 tok):
# R1	p: 14.29 	r: 27.78 	f: 18.87
# R2	p: 5.88 	r: 11.76 	f: 7.84
# RL	p: 14.29 	r: 27.78 	f: 18.87
# ST	38.75		W2V	38.13
#
# OXC has a similar spectrum of efficacy to CBZ; it tends to be better tolerated than CBZ with fewer
# neurotoxic side effects. No studies have attempted to relate elevated plasma levels to efficacy or
# toxicity.
#
#
# ####################################################################################################
#
# (9781910797426, 'ch03')
# Symptoms and signs include pain or tenderness and guarding in the right upper quadrant, nausea and
# vomiting, fever, fast pulse (tachycardia) and a positive Murphy's sign (transient cessation of
# breathing due to pain during inspiration while the right upper quadrant is palpated, but not the
# left upper quadrant). Complications include empyema, perforation of the gallbladder, liver abscess
# and emphysematous cholecystitis. An inflamed and distended gallbladder may obstruct the main bile
# duct by pressure from a gallstone causing obstructive jaundice (Mirizzi's syndrome). Laboratory
# tests. Leukocytosis and mild elevation in serum bilirubin and transaminases may be present.
# Transabdominal ultrasonography is the most useful test for acute cholecystitis as it establishes the
# presence of gallstones (Figure 3.5). A thickened gallbladder wall (> 4 mm) and pericholecystic fluid
# are highly suggestive of acute cholecystitis (Figure 3.6). Sonographic Murphy's sign (tenderness
# over the gallbladder from the ultrasound transducer during imaging) is also diagnostic. Radionuclide
# scanning is a useful test if ultrasound is non-diagnostic or inconclusive but there is clinical
# suspicion of acute cholecystitis. A Tc-HIDA (hepatobiliary iminodiacetic acid) scan uses a
# technetium-labeled analog of iminodiacetic acid. Non-visualization of the gallbladder with
# visualization of the tracer in the CBD and the small intestine is consistent with cystic duct
# obstruction. This test is about 95% accurate for the diagnosis of acute cholecystitis. Computed
# tomography is useful for identifying local complications of acute cholecystitis (Figure 3.7).
# Medical treatment of acute cholecystitis involves.
#
# Reference:
# Transabdominal ultrasound is the imaging test of choice, with an accuracy of over 95%, for the
# diagnosis of gallstones in either acute or chronic cholecystitis. A Tc-HIDA (hepatobiliary
# iminodiacetic acid) scan is 95% accurate for the diagnosis of acute cholecystitis.
#
# sshleifer/distilbart-cnn-12-6 (60 tok):
# R1	p: 19.35 	r: 14.63 	f: 16.67
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 12.90 	r: 9.76 	f: 11.11
# ST	41.21		W2V	22.40
#
#  Complications include empyema, perforation of the gallbladder, liver abscess and emphysematous
# cholecystitis. An inflamed and distended gallbladder may obstruct the main bile duct by pressure
# from a gallstone causing obstructive jaundice.
#
# sshleifer/distilbart-cnn-12-6 (72 tok):
# R1	p: 15.38 	r: 14.63 	f: 15.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 10.26 	r: 9.76 	f: 10.00
# ST	44.41		W2V	18.22
#
#  Complications include empyema, perforation of the gallbladder, liver abscess and emphysematous
# cholecystitis. An inflamed and distended gallbladder may obstruct the main bile duct by pressure
# from a gallstone causing obstructive jaundice (Mirizzi's syndrome) Laboratory tests may be present.
#
# sshleifer/distilbart-cnn-12-6 (75 tok):
# R1	p: 16.67 	r: 17.07 	f: 16.87
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 11.90 	r: 12.20 	f: 12.05
# ST	49.41		W2V	25.54
#
#  Complications include empyema, perforation of the gallbladder, liver abscess and emphysematous
# cholecystitis. An inflamed and distended gallbladder may obstruct the main bile duct by pressure
# from a gallstone causing obstructive jaundice (Mirizzi's syndrome) Laboratory tests are useful for
# identifying local complications.
#
# sshleifer/distilbart-cnn-12-6 (76 tok):
# R1	p: 16.28 	r: 17.07 	f: 16.67
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 11.63 	r: 12.20 	f: 11.90
# ST	47.23		W2V	23.85
#
#  Complications include empyema, perforation of the gallbladder, liver abscess and emphysematous
# cholecystitis. An inflamed and distended gallbladder may obstruct the main bile duct by pressure
# from a gallstone causing obstructive jaundice (Mirizzi's syndrome) Laboratory tests may be useful
# for identifying local complications.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (108 tok):
# R1	p: 36.92 	r: 58.54 	f: 45.28
# R2	p: 12.50 	r: 20.00 	f: 15.38
# RL	p: 24.62 	r: 39.02 	f: 30.19
# ST	75.17		W2V	66.09
#
# Transabdominal ultrasonography is the most useful test for acute cholecystitis as it establishes the
# presence of gallstones. A thickened gallbladder wall (> 4 mm) and pericholecystic fluid are highly
# suggestive of acute choleicystitis. A Tc-HIDA scan is a technetium-labeled analog of iminodiacetic
# acid. Non-visualization of the gallbladder with visualization of the tracer in the CBD and the small
# intestine suggests cystic duct obstruction.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (108 tok):
# R1	p: 36.92 	r: 58.54 	f: 45.28
# R2	p: 12.50 	r: 20.00 	f: 15.38
# RL	p: 24.62 	r: 39.02 	f: 30.19
# ST	75.70		W2V	66.45
#
# Transabdominal ultrasonography is the most useful test for acute cholecystitis as it establishes the
# presence of gallstones. A thickened gallbladder wall (> 4 mm) and pericholecystic fluid are highly
# suggestive of acute choleicystitis. A Tc-HIDA scan is a technetium-labeled analog of iminodiacetic
# acid. Non-visualization of the gallbladder with visualization of the tracer in the CBD and the small
# intestine indicates cystic duct obstruction.
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (80 tok):
# R1	p: 45.45 	r: 48.78 	f: 47.06
# R2	p: 18.60 	r: 20.00 	f: 19.28
# RL	p: 34.09 	r: 36.59 	f: 35.29
# ST	78.32		W2V	67.85
#
# Transabdominal ultrasonography is the most useful test for acute cholecystitis as it establishes the
# presence of gallstones. A thickened gallbladder wall (> 4 mm) and pericholecystic fluid are highly
# suggestive of acute choleicystitis. A Tc-HIDA scan is a technetium-labeled analog of iminodiacetic
# acid.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (57 tok):
# R1	p: 40.62 	r: 31.71 	f: 35.62
# R2	p: 12.90 	r: 10.00 	f: 11.27
# RL	p: 34.38 	r: 26.83 	f: 30.14
# ST	71.41		W2V	50.35
#
# Transabdominal ultrasonography is the most useful test for acute cholecystitis as it establishes the
# presence of gallstones. A thickened gallbladder wall (> 4 mm) and pericholecystic fluid are highly
# suggestive of acute choleicystitis.
#
#
# ####################################################################################################
#
# (9781910797907, 'chp2')
# As discussed in Chapter 1, mutations in the PKLR gene on chromosome 1 are responsible for PK
# deficiency. More than 300 different mutations have been reported; most are very rare, occurring only
# once. Currently, about 25% of patients diagnosed with PK deficiency appear to have a previously
# unrecorded mutation. Although many of the mutations associated with PK deficiency are rare, a few
# are recorded more frequently (Table 2.1). The variability in how PK deficiency manifests is thought
# to reflect the heterogeneity of these causative mutations, as well as the fact that most individuals
# with PK deficiency will be compound heterozygotes (id est they will have a different mutation in
# each copy of the PKLR gene).
#
# Reference:
# About one quarter of patients diagnosed with PK deficiency will have a previously unrecorded
# mutation in the PKLR gene.
#
# sshleifer/distilbart-cnn-12-6 (36 tok):
# R1	p: 48.39 	r: 78.95 	f: 60.00
# R2	p: 40.00 	r: 66.67 	f: 50.00
# RL	p: 35.48 	r: 57.89 	f: 44.00
# ST	84.42		W2V	62.41
#
#  More than 300 different mutations in the PKLR gene on chromosome 1 are responsible for PK
# deficiency. 25% of patients diagnosed with PK deficiency appear to have a previously unrecorded
# mutation.
#
# sshleifer/distilbart-cnn-12-6 (35 tok):
# R1	p: 43.33 	r: 68.42 	f: 53.06
# R2	p: 31.03 	r: 50.00 	f: 38.30
# RL	p: 30.00 	r: 47.37 	f: 36.73
# ST	83.47		W2V	56.88
#
#  More than 300 different mutations in the PKLR gene on chromosome 1 are responsible for PK
# deficiency. 25% of patients diagnosed with PK deficiency appear to have previously unrecorded
# mutations.
#
# sshleifer/distilbart-cnn-12-6 (35 tok):
# R1	p: 46.67 	r: 73.68 	f: 57.14
# R2	p: 34.48 	r: 55.56 	f: 42.55
# RL	p: 33.33 	r: 52.63 	f: 40.82
# ST	83.82		W2V	62.41
#
#  More than 300 different mutations in the PKLR gene on chromosome 1 are responsible for PK
# deficiency. 25% of patients diagnosed with PK deficiency appear to have previously unrecorded
# mutation.
#
# sshleifer/distilbart-cnn-12-6 (36 tok):
# R1	p: 40.00 	r: 63.16 	f: 48.98
# R2	p: 31.03 	r: 50.00 	f: 38.30
# RL	p: 40.00 	r: 63.16 	f: 48.98
# ST	71.84		W2V	42.62
#
#  About 25% of patients diagnosed with PK deficiency appear to have a previously unrecorded mutation.
# More than 300 different mutations have been reported; most are very rare, occurring only once.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (16 tok):
# R1	p: 46.15 	r: 31.58 	f: 37.50
# R2	p: 33.33 	r: 22.22 	f: 26.67
# RL	p: 30.77 	r: 21.05 	f: 25.00
# ST	67.80		W2V	43.61
#
# Mutations in the PKLR gene on chromosome 1 are responsible for PK deficiency.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (18 tok):
# R1	p: 46.67 	r: 36.84 	f: 41.18
# R2	p: 21.43 	r: 16.67 	f: 18.75
# RL	p: 26.67 	r: 21.05 	f: 23.53
# ST	70.60		W2V	41.57
#
# Mutation of the PKLR gene on chromosome 1 is the main cause of PK deficiency.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (19 tok):
# R1	p: 43.75 	r: 36.84 	f: 40.00
# R2	p: 26.67 	r: 22.22 	f: 24.24
# RL	p: 25.00 	r: 21.05 	f: 22.86
# ST	68.96		W2V	45.67
#
# Mutations in the PKLR gene on chromosome 1 are responsible for the development of PK deficiency.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (16 tok):
# R1	p: 46.15 	r: 31.58 	f: 37.50
# R2	p: 33.33 	r: 22.22 	f: 26.67
# RL	p: 30.77 	r: 21.05 	f: 25.00
# ST	67.80		W2V	43.61
#
# Mutations in the PKLR gene on chromosome 1 are responsible for PK deficiency.
#
#
# ####################################################################################################
#
# (9781910797105, 'ch05')
# The risk is further increased if minor psychotic symptoms pre-exist and if cannabis use starts early
# in adolescence. Research suggests that this effect of cannabis may be mediated by a particular gene.
# Those with a specific version of the catechol- O -methyltransferase (COMT) gene, carried by about a
# quarter of the general population, appear to be especially prone to psychosis after cannabis use.
# Delta-9-THC, the active component of cannabis, disrupts learning and recall in schizophrenia.
# Psychosocial risk factors. There is emerging evidence for the role of non-biological risk factors in
# schizophrenia, such as the effects of urban upbringing and of ethnicity, as noted in Chapter 3.
#
# Reference:
# Psychosocial risk factors are being re-established as important risk factors.
#
# sshleifer/distilbart-cnn-12-6 (58 tok):
# R1	p: 0.00 	r: 0.00 	f: 0.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 0.00 	r: 0.00 	f: 0.00
# ST	16.59		W2V	14.99
#
#  Research suggests that this effect of cannabis may be mediated by a particular gene. Those with a
# specific version of the catechol- O -methyltransferase (COMT) gene, carried by about a quarter of
# the general population, appear to be especially prone to psychosis after cannabis use.
#
# sshleifer/distilbart-cnn-12-6 (53 tok):
# R1	p: 0.00 	r: 0.00 	f: 0.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 0.00 	r: 0.00 	f: 0.00
# ST	16.95		W2V	6.64
#
#  Those with a specific version of the catechol- O -methyltransferase (COMT) gene appear to be
# especially prone to psychosis after cannabis use. Delta-9-THC, the active component of cannabis,
# disrupts learning and recall in schizophrenia.
#
# sshleifer/distilbart-cnn-12-6 (47 tok):
# R1	p: 0.00 	r: 0.00 	f: 0.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 0.00 	r: 0.00 	f: 0.00
# ST	17.40		W2V	2.42
#
#  Research suggests that this effect of cannabis may be mediated by a particular gene. Those with a
# specific version of the catechol- O -methyltransferase (COMT) gene appear to be especially prone to
# psychosis after cannabis use.
#
# sshleifer/distilbart-cnn-12-6 (61 tok):
# R1	p: 0.00 	r: 0.00 	f: 0.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 0.00 	r: 0.00 	f: 0.00
# ST	18.08		W2V	3.79
#
#  Research suggests that this effect of cannabis may be mediated by a particular gene. Those with a
# specific version of the catechol- O -methyltransferase (COMT) gene appear to be especially prone to
# psychosis after cannabis use. Delta-9-THC disrupts learning and recall in schizophrenia.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (27 tok):
# R1	p: 13.04 	r: 27.27 	f: 17.65
# R2	p: 4.55 	r: 10.00 	f: 6.25
# RL	p: 13.04 	r: 27.27 	f: 17.65
# ST	51.02		W2V	38.22
#
# There is evidence for the role of non-biological risk factors in schizophrenia, such as the effects
# of urban upbringing and of ethnicity.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (27 tok):
# R1	p: 13.04 	r: 27.27 	f: 17.65
# R2	p: 4.55 	r: 10.00 	f: 6.25
# RL	p: 13.04 	r: 27.27 	f: 17.65
# ST	51.02		W2V	38.22
#
# There is evidence for the role of non-biological risk factors in schizophrenia, such as the effects
# of urban upbringing and of ethnicity.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (32 tok):
# R1	p: 11.11 	r: 27.27 	f: 15.79
# R2	p: 3.85 	r: 10.00 	f: 5.56
# RL	p: 11.11 	r: 27.27 	f: 15.79
# ST	49.45		W2V	35.80
#
# There is evidence for the role of non-biological risk factors in schizophrenia, such as the effects
# of urban upbringing and of ethnicity, such as urban upbringing.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (32 tok):
# R1	p: 11.11 	r: 27.27 	f: 15.79
# R2	p: 3.85 	r: 10.00 	f: 5.56
# RL	p: 11.11 	r: 27.27 	f: 15.79
# ST	49.45		W2V	35.80
#
# There is evidence for the role of non-biological risk factors in schizophrenia, such as the effects
# of urban upbringing and of ethnicity, such as urban upbringing.
#
#
# ####################################################################################################
#
# (9781908541680, 'ch_4')
# Overweight/obesity as a whole predisposes to, or is associated with, numerous cardiac complications
# such as coronary heart disease (CHD), atrial fibrillation, heart failure and sudden cardiac death as
# a result of abnormalities in blood glucose, lipids, blood pressure, coagulation and inflammation.
# Independent of any of the other known cardiometabolic risk factors, obesity is associated with
# hypertension, tachycardia, left ventricular hypertrophy, increased collagen deposition, reduced
# cardiac contractility and increased end-diastolic pressure. The major circulatory complications are
# increased total and pulmonary blood volume, high cardiac output and elevated left ventricular end-
# diastolic pressure.
#
# Reference:
# Obesity significantly affects cardiometabolic status and risk.
# sshleifer/distilbart-cnn-12-6 (48 tok):
# R1	p: 6.45 	r: 28.57 	f: 10.53
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 6.45 	r: 28.57 	f: 10.53
# ST	52.55		W2V	15.24
#
#  Obesity is associated with hypertension, tachycardia, left ventricular hypertrophy, increased
# collagen deposition, reduced cardiac contractility and increased end-diastolic pressure. The major
# circulatory complications are increased total and pulmonary blood volume.
#
# sshleifer/distilbart-cnn-12-6 (35 tok):
# R1	p: 10.00 	r: 28.57 	f: 14.81
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 10.00 	r: 28.57 	f: 14.81
# ST	55.92		W2V	4.68
#
#  Obesity is associated with hypertension, tachycardia, left ventricular hypertrophy, increased
# collagen deposition, reduced cardiac contractility and increased end-diastolic pressure.
#
# sshleifer/distilbart-cnn-12-6 (39 tok):
# R1	p: 8.00 	r: 28.57 	f: 12.50
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 8.00 	r: 28.57 	f: 12.50
# ST	54.88		W2V	12.87
#
#  Obesity is associated with hypertension, tachycardia, left ventricular hypertrophy and increased
# end-diastolic pressure. The major circulatory complications are increased total and pulmonary blood
# volume.
#
# sshleifer/distilbart-cnn-12-6 (31 tok):
# R1	p: 9.52 	r: 28.57 	f: 14.29
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 9.52 	r: 28.57 	f: 14.29
# ST	50.96		W2V	13.81
#
#  Obesity predisposes to cardiac complications such as coronary heart disease (CHD), atrial
# fibrillation, heart failure, heart failure and sudden cardiac death.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (36 tok):
# R1	p: 8.33 	r: 28.57 	f: 12.90
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 8.33 	r: 28.57 	f: 12.90
# ST	53.13		W2V	5.46
#
# Overweight/obesity predisposes to, or is associated with, numerous cardiac complications such as
# coronary heart disease, atrial fibrillation, heart failure and sudden cardiac death.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (37 tok):
# R1	p: 8.00 	r: 28.57 	f: 12.50
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 8.00 	r: 28.57 	f: 12.50
# ST	49.23		W2V	3.08
#
# Overweight/obesity predisposes to or is associated with, numerous cardiac complications such as
# coronary heart disease (CHD), atrial fibrillation, heart failure and sudden cardiac death
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (18 tok):
# R1	p: 9.09 	r: 14.29 	f: 11.11
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 9.09 	r: 14.29 	f: 11.11
# ST	56.75		W2V	-7.38
#
# Overweight/obesity predisposes to, or is associated with, numerous cardiac complications.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (18 tok):
# R1	p: 9.09 	r: 14.29 	f: 11.11
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 9.09 	r: 14.29 	f: 11.11
# ST	56.75		W2V	-7.38
#
# Overweight/obesity predisposes to, or is associated with, numerous cardiac complications.
#
#
# ####################################################################################################
#
# (9781908541024, 'ch_12')
# The vast majority of primary brain tumors occur sporadically, but a small number appear to be
# familial. The etiology of sporadic brain tumors is unknown, but environmental factors are suspected.
# Most patients with a family history of primary brain tumors have a hereditary disease that is known
# to be associated with such tumors, such as tuberous sclerosis, neurofibromatosis, familial polyposis
# or Li-Fraumeni syndrome. However, some patients do not have any underlying or obvious hereditary
# disorder that would predispose them to primary brain tumors, but nevertheless give a striking
# history of these tumors in first-degree relatives. Usually, the tumors are found to be high-grade
# gliomas.
#
# Reference:
# There are several syndromes associated with an inherited predisposition to a variety of brain
# tumors. However, the vast majority of brain tumors are not inherited.
#
# sshleifer/distilbart-cnn-12-6 (37 tok):
# R1	p: 40.00 	r: 48.00 	f: 43.64
# R2	p: 17.24 	r: 20.83 	f: 18.87
# RL	p: 26.67 	r: 32.00 	f: 29.09
# ST	68.75		W2V	53.20
#
#  The vast majority of primary brain tumors occur sporadically, but a small number appear to be
# familial. The etiology of sporadic brain tumors is unknown, but environmental factors are suspected.
#
# sshleifer/distilbart-cnn-12-6 (40 tok):
# R1	p: 33.33 	r: 48.00 	f: 39.34
# R2	p: 8.57 	r: 12.50 	f: 10.17
# RL	p: 19.44 	r: 28.00 	f: 22.95
# ST	70.12		W2V	52.21
#
#  The etiology of sporadic brain tumors is unknown, but environmental factors are suspected. Most
# patients with a family history of primary brain tumors have a hereditary disease that is known to be
# associated with such tumors.
#
# sshleifer/distilbart-cnn-12-6 (28 tok):
# R1	p: 45.45 	r: 40.00 	f: 42.55
# R2	p: 23.81 	r: 20.83 	f: 22.22
# RL	p: 36.36 	r: 32.00 	f: 34.04
# ST	68.84		W2V	57.49
#
#  The vast majority of primary brain tumors occur sporadically. The etiology of sporadic brain tumors
# is unknown, but environmental factors are suspected.
#
# sshleifer/distilbart-cnn-12-6 (36 tok):
# R1	p: 41.38 	r: 48.00 	f: 44.44
# R2	p: 17.86 	r: 20.83 	f: 19.23
# RL	p: 27.59 	r: 32.00 	f: 29.63
# ST	67.97		W2V	56.97
#
#  The vast majority of primary brain tumors occur sporadically, but a small number appear to be
# familial. The etiology of sporadic brain tumors is unknown. Environmental factors are suspected.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (21 tok):
# R1	p: 47.06 	r: 32.00 	f: 38.10
# R2	p: 25.00 	r: 16.67 	f: 20.00
# RL	p: 35.29 	r: 24.00 	f: 28.57
# ST	68.69		W2V	45.18
#
# The vast majority of primary brain tumors occur sporadically, but a small number appear to be
# familial.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (21 tok):
# R1	p: 47.06 	r: 32.00 	f: 38.10
# R2	p: 25.00 	r: 16.67 	f: 20.00
# RL	p: 35.29 	r: 24.00 	f: 28.57
# ST	68.69		W2V	45.18
#
# The vast majority of primary brain tumors occur sporadically, but a small number appear to be
# familial.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (21 tok):
# R1	p: 47.06 	r: 32.00 	f: 38.10
# R2	p: 25.00 	r: 16.67 	f: 20.00
# RL	p: 35.29 	r: 24.00 	f: 28.57
# ST	68.69		W2V	45.18
#
# The vast majority of primary brain tumors occur sporadically, but a small number appear to be
# familial.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (21 tok):
# R1	p: 47.06 	r: 32.00 	f: 38.10
# R2	p: 25.00 	r: 16.67 	f: 20.00
# RL	p: 35.29 	r: 24.00 	f: 28.57
# ST	68.69		W2V	45.18
#
# The vast majority of primary brain tumors occur sporadically, but a small number appear to be
# familial.
#
#
# ####################################################################################################
#
# (9781910797211, 'ch04')
# Dopamine agonist versus levodopa. In younger patients, the issues of neuroprotection and dyskinesias
# should be considered. The results of four controlled dopamine-agonist monotherapy trials have been
# published and suggest that initiation of treatment with an agonist is beneficial in the early stages
# of Parkinson's disease. However, the results of the PD Med study, a multicenter real-life pragmatic
# study, reporting on quality of life-related outcomes in both young and old patients with Parkinson's
# disease, is likely to generate considerable controversy regarding the use of dopamine agonists and
# the choice of initial therapy. In total, 1620 patients with early Parkinson's disease were recruited
# and given one of three initial treatment regimens. levodopa formulation (528 patients). levodopa-
# sparing strategy - dopamine agonist (632 patients). levodopa-sparing strategy - MAOB inhibitor
# (selegiline; 460 patients). The study started in 2000 with a median follow-up of 3 years and maximum
# of 7 years. During this time the dopamine agonists varied, including ergot agonists that are no
# longer in widespread use. The randomization to levodopa or alternative regimens was at the
# discretion of the clinician and a large part of the study was conducted in centers for the care of
# the elderly. The findings suggest relatively small but persistent benefits of starting therapy with
# levodopa rather than the listed alternatives. Interestingly, initial treatment with a MAOB inhibitor
# appeared to be at least as effective as treatment with a dopamine agonist.
#
# Reference:
# Trial data indicate that treatment of Parkinson's disease could be initiated with levodopa, oral
# dopamine agonists or a monoamine oxidase B (MAOB) inhibitor. The PD MED study seems to suggest that
# initial therapy with levodopa offers a small but persistent benefit compared with the alternatives,
# and initial MAOB inhibitor treatment is at least as effective as a dopamine agonist.
# sshleifer/distilbart-cnn-12-6 (72 tok):
# R1	p: 51.72 	r: 50.00 	f: 50.85
# R2	p: 19.30 	r: 18.64 	f: 18.97
# RL	p: 31.03 	r: 30.00 	f: 30.51
# ST	71.90		W2V	49.29
#
#  PD Med study is a multicenter real-life pragmatic study, reporting on quality of life-related
# outcomes in both young and old patients with Parkinson's disease. In younger patients, the issues of
# neuroprotection and dyskinesias should be considered. Initial treatment with a MAOB inhibitor
# appeared to be at least as effective as treatment with a dopamine agonist.
#
# sshleifer/distilbart-cnn-12-6 (72 tok):
# R1	p: 51.72 	r: 50.00 	f: 50.85
# R2	p: 19.30 	r: 18.64 	f: 18.97
# RL	p: 29.31 	r: 28.33 	f: 28.81
# ST	72.29		W2V	49.29
#
#  PD Med study is a multicenter real-life pragmatic study, reporting on quality of life-related
# outcomes in both young and old patients with Parkinson's disease. Initial treatment with a MAOB
# inhibitor appeared to be at least as effective as treatment with a dopamine agonist. In younger
# patients, the issues of neuroprotection and dyskinesias should be considered.
#
# sshleifer/distilbart-cnn-12-6 (54 tok):
# R1	p: 63.04 	r: 48.33 	f: 54.72
# R2	p: 24.44 	r: 18.64 	f: 21.15
# RL	p: 36.96 	r: 28.33 	f: 32.08
# ST	72.66		W2V	52.74
#
#  PD Med study is a multicenter real-life pragmatic study, reporting on quality of life-related
# outcomes in both young and old patients with Parkinson's disease. Initial treatment with a MAOB
# inhibitor appeared to be at least as effective as treatment with a dopamine agonist.
#
# sshleifer/distilbart-cnn-12-6 (50 tok):
# R1	p: 33.33 	r: 21.67 	f: 26.26
# R2	p: 10.53 	r: 6.78 	f: 8.25
# RL	p: 17.95 	r: 11.67 	f: 14.14
# ST	50.51		W2V	27.65
#
#  PD Med study is a multicenter real-life pragmatic study, reporting on quality of life-related
# outcomes in both young and old patients with Parkinson's disease. In younger patients, the issues of
# neuroprotection and dyskinesias should be considered.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (39 tok):
# R1	p: 43.33 	r: 21.67 	f: 28.89
# R2	p: 13.79 	r: 6.78 	f: 9.09
# RL	p: 33.33 	r: 16.67 	f: 22.22
# ST	68.88		W2V	46.92
#
# In younger patients, the issues of neuroprotection and dyskinesias should be considered. The
# findings suggest relatively small but persistent benefits of starting therapy with levodopa rather
# than the listed alternatives.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (36 tok):
# R1	p: 53.57 	r: 25.00 	f: 34.09
# R2	p: 18.52 	r: 8.47 	f: 11.63
# RL	p: 25.00 	r: 11.67 	f: 15.91
# ST	61.47		W2V	44.03
#
# In younger patients, the issues of neuroprotection and dyskinesias should be considered. Initial
# treatment with a dopamine agonist is beneficial in the early stages of Parkinson's disease.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (18 tok):
# R1	p: 33.33 	r: 6.67 	f: 11.11
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 16.67 	r: 3.33 	f: 5.56
# ST	35.40		W2V	12.19
#
# In younger patients, the issues of neuroprotection and dyskinesias should be considered.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (27 tok):
# R1	p: 40.00 	r: 13.33 	f: 20.00
# R2	p: 10.53 	r: 3.39 	f: 5.13
# RL	p: 20.00 	r: 6.67 	f: 10.00
# ST	42.01		W2V	24.19
#
# In younger patients, the issues of neuroprotection and dyskinesias should be considered,
# particularly in those with early Parkinson's disease.
#
#
# ####################################################################################################
#
# (9781908541963, 'chapter5')
# A rapid deterioration may indicate the development of a complicating cholangiocarcinoma. The risk of
# this malignant transformation is about 6-15% over the course of the disease. Screening for malignant
# transformation is not effective in detecting early disease, and progression to cholangiocarcinoma is
# generally regarded as a contraindication to liver transplantation. Treatment. UDCA, 10-15 mg/kg/day,
# is recommended. This ameliorates pruritus, improves the liver biochemistry and histology and may
# alter the natural history of the disease. Immunosuppressive and antifibrotic therapies have not
# proved effective. Liver transplantation is used widely for advanced disease. The indications for
# transplantation are less precise than they are in PBC, but persistent jaundice of more than 3
# months' duration, in addition to evidence of liver failure or severe portal hypertension, are
# reasonable indications to proceed to liver transplantation. The results of liver transplantation are
# excellent in the absence of cholangiocarcinoma. PSC recurs in 8-15% of cases and is occasionally a
# cause of significant graft dysfunction.
#
# Reference:
# Primary sclerosing cholangitis is strongly associated with ulcerative colitis and is unpredictable;
# late disease can be managed effectively with liver transplantation unless complicated by
# cholangiocarcinoma.
#
# sshleifer/distilbart-cnn-12-6 (39 tok):
# R1	p: 22.73 	r: 20.00 	f: 21.28
# R2	p: 4.76 	r: 4.17 	f: 4.44
# RL	p: 13.64 	r: 12.00 	f: 12.77
# ST	45.28		W2V	14.00
#
#  UDCA, 10-15 mg/kg/day, ameliorates pruritus, improves the liver biochemistry and histology. Liver
# transplantation is used widely for advanced disease.
#
# sshleifer/distilbart-cnn-12-6 (38 tok):
# R1	p: 23.81 	r: 20.00 	f: 21.74
# R2	p: 5.00 	r: 4.17 	f: 4.55
# RL	p: 14.29 	r: 12.00 	f: 13.04
# ST	45.56		W2V	16.20
#
#  UDCA, 10-15 mg/kg/day, ameliorates pruritus, improves liver biochemistry and histology. Liver
# transplantation is used widely for advanced disease.
#
# sshleifer/distilbart-cnn-12-6 (38 tok):
# R1	p: 22.73 	r: 20.00 	f: 21.28
# R2	p: 4.76 	r: 4.17 	f: 4.44
# RL	p: 13.64 	r: 12.00 	f: 12.77
# ST	45.65		W2V	15.63
#
#  UDCA, 10-15 mg/kg/day, ameliorates pruritus and improves liver biochemistry and histology. Liver
# transplantation is used widely for advanced disease.
#
# sshleifer/distilbart-cnn-12-6 (35 tok):
# R1	p: 12.50 	r: 12.00 	f: 12.24
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 8.33 	r: 8.00 	f: 8.16
# ST	34.24		W2V	5.33
#
#  The risk of this malignant transformation is about 6-15% over the course of the disease. UDCA,
# 10-15 mg/kg/day, is recommended.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (39 tok):
# R1	p: 21.74 	r: 20.00 	f: 20.83
# R2	p: 4.55 	r: 4.17 	f: 4.35
# RL	p: 17.39 	r: 16.00 	f: 16.67
# ST	62.14		W2V	17.60
#
# Liver transplantation is an option for advanced PBC, but the risk of developing cholangiocarcinoma
# is a contraindication for the use of liver transplantation.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (38 tok):
# R1	p: 22.73 	r: 20.00 	f: 21.28
# R2	p: 4.76 	r: 4.17 	f: 4.44
# RL	p: 13.64 	r: 12.00 	f: 12.77
# ST	61.98		W2V	16.30
#
# Liver transplantation is an option for advanced PBC, but the risk of developing cholangiocarcinoma
# is a contraindication for the use of transplantation.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (29 tok):
# R1	p: 27.78 	r: 20.00 	f: 23.26
# R2	p: 5.88 	r: 4.17 	f: 4.88
# RL	p: 16.67 	r: 12.00 	f: 13.95
# ST	60.77		W2V	24.39
#
# Liver transplantation is an option for patients with advanced PBC who have a high risk of developing
# cholangiocarcinoma.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (34 tok):
# R1	p: 27.27 	r: 24.00 	f: 25.53
# R2	p: 4.76 	r: 4.17 	f: 4.44
# RL	p: 13.64 	r: 12.00 	f: 12.77
# ST	65.01		W2V	16.44
#
# Liver transplantation is an option for advanced PBC, but the risk of developing cholangiocarcinoma
# over the course of the disease is low.
#
#
# ####################################################################################################
#
# (9781910797426, 'ch03')
# Etiology and pathogenesis. Chronic gallbladder inflammation is attributed as an etiologic factor in
# gallbladder cancer along with molecular alterations in p53 and K-ras. Inflammation may occur as a
# result of gallstones, gallbladder polyps, chronic Salmonella infection, congenital biliary cysts,
# abnormal pancreaticobiliary duct junction, carcinogen exposure and certain drugs. There are
# molecular differences between gallbladder cancers associated with gallstones and those with an
# abnormal pancreaticobiliary junction. Epidemiology and risk factors. Gallbladder carcinoma is the
# fifth most common gastrointestinal (GI) cancer in the USA and is the most common GI cancer in Native
# Americans. Incidence and mortality are very high in certain Latin American countries, especially
# Chile. Risk factors for gallbladder cancer are outlined in Table 3.3. The majority of gallbladder
# cancers are adenocarcinomas.
#
# Reference:
# Gallbladder cancer is the most common gastrointestinal cancer in Native Americans in the USA and
# also has a very high incidence in certain Latin American countries, particularly Chile.
# sshleifer/distilbart-cnn-12-6 (81 tok):
# R1	p: 41.18 	r: 75.00 	f: 53.16
# R2	p: 22.00 	r: 40.74 	f: 28.57
# RL	p: 37.25 	r: 67.86 	f: 48.10
# ST	78.04		W2V	68.87
#
#  Gallbladder carcinoma is the fifth most common gastrointestinal (GI) cancer in the USA. Incidence
# and mortality are very high in certain Latin American countries, especially Chile. Inflammation may
# occur as a result of gallstones, gallbladder polyps, chronic Salmonella infection, congenital
# biliary cysts, abnormal pancreaticobiliary duct junction, carcinogen exposure and certain drugs.
#
# sshleifer/distilbart-cnn-12-6 (81 tok):
# R1	p: 41.18 	r: 75.00 	f: 53.16
# R2	p: 22.00 	r: 40.74 	f: 28.57
# RL	p: 37.25 	r: 67.86 	f: 48.10
# ST	77.84		W2V	68.84
#
#  Gallbladder carcinoma is the fifth most common gastrointestinal (GI) cancer in the USA.
# Inflammation may occur as a result of gallstones, gallbladder polyps, chronic Salmonella infection,
# congenital biliary cysts, abnormal pancreaticobiliary duct junction, carcinogen exposure and certain
# drugs. Incidence and mortality are very high in certain Latin American countries, especially Chile.
#
# sshleifer/distilbart-cnn-12-6 (75 tok):
# R1	p: 35.42 	r: 60.71 	f: 44.74
# R2	p: 21.28 	r: 37.04 	f: 27.03
# RL	p: 27.08 	r: 46.43 	f: 34.21
# ST	72.72		W2V	68.11
#
#  Gallbladder carcinoma is the fifth most common gastrointestinal (GI) cancer in the USA and is the
# most common GI cancer in Native Americans. Inflammation may occur as a result of gallstones,
# gallbladder polyps, chronic Salmonella infection, congenital biliary cysts, abnormal
# pancreaticobiliary duct junction, carcinogen exposure and certain drugs.
#
# sshleifer/distilbart-cnn-12-6 (77 tok):
# R1	p: 42.86 	r: 75.00 	f: 54.55
# R2	p: 22.92 	r: 40.74 	f: 29.33
# RL	p: 38.78 	r: 67.86 	f: 49.35
# ST	79.81		W2V	72.83
#
#  Gallbladder carcinoma is the fifth most common gastrointestinal (GI) cancer in the USA. Incidence
# and mortality are very high in certain Latin American countries, especially Chile. Inflammation may
# occur as a result of gallstones, gallbladder polyps, chronic Salmonella infection, congenital
# biliary cysts, abnormal pancreaticobiliary duct junction and certain drugs.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (29 tok):
# R1	p: 65.22 	r: 53.57 	f: 58.82
# R2	p: 45.45 	r: 37.04 	f: 40.82
# RL	p: 52.17 	r: 42.86 	f: 47.06
# ST	78.45		W2V	76.86
#
# Gallbladder carcinoma is the fifth most common gastrointestinal (GI) cancer in the USA and is the
# most common GI cancer in Native Americans.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (44 tok):
# R1	p: 68.57 	r: 85.71 	f: 76.19
# R2	p: 44.12 	r: 55.56 	f: 49.18
# RL	p: 54.29 	r: 67.86 	f: 60.32
# ST	89.49		W2V	86.77
#
# Gallbladder carcinoma is the fifth most common gastrointestinal (GI) cancer in the USA and the most
# common GI cancer in Native Americans. Incidence and mortality are very high in certain Latin
# American countries, especially Chile.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (28 tok):
# R1	p: 68.18 	r: 53.57 	f: 60.00
# R2	p: 47.62 	r: 37.04 	f: 41.67
# RL	p: 54.55 	r: 42.86 	f: 48.00
# ST	78.65		W2V	77.05
#
# Gallbladder carcinoma is the fifth most common gastrointestinal (GI) cancer in the USA and the most
# common GI cancer in Native Americans.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (44 tok):
# R1	p: 50.00 	r: 53.57 	f: 51.72
# R2	p: 34.48 	r: 37.04 	f: 35.71
# RL	p: 40.00 	r: 42.86 	f: 41.38
# ST	78.36		W2V	75.31
#
# Gallbladder carcinoma is the fifth most common gastrointestinal (GI) cancer in the USA and is the
# most common GI cancer in Native Americans. The majority of gallbladder cancers are adenocarcinomas.
#
#
# ####################################################################################################
#
# (9781910797495, 'chp12')
# Acute headache. The immediate, important first step in assessing a new headache is determining
# whether the headache is a serious, potentially life-threatening medical event requiring emergency
# evaluation and management. All the possibilities highlighted in Table 12.1 must be entertained and
# discarded before considering the headache to be caused by a chronic headache condition. Brain
# imaging, including neurovascular studies, may be needed as well as cerebrospinal fluid (CSF)
# pressure measurement and analysis and further evaluation by a neurologist.
#
# Reference:
# In patients without history of chronic headaches, determine whether an acute new headache is a
# serious, potentially life-threatening condition.
#
# sshleifer/distilbart-cnn-12-6 (56 tok):
# R1	p: 11.63 	r: 25.00 	f: 15.87
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 9.30 	r: 20.00 	f: 12.70
# ST	40.06		W2V	4.48
#
#  All the possibilities highlighted in Table 12.1 must be entertained and discarded before
# considering the headache to be caused by a chronic headache condition. Brain imaging, including
# neurovascular studies, may be needed as well as cerebrospinal fluid (CSF) pressure measurement and
# analysis.
#
# sshleifer/distilbart-cnn-12-6 (52 tok):
# R1	p: 11.90 	r: 25.00 	f: 16.13
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 9.52 	r: 20.00 	f: 12.90
# ST	42.54		W2V	8.36
#
#  All the possibilities highlighted in Table 12.1 must be entertained and discarded before
# considering the headache to be caused by a chronic headache condition. Brain imaging, including
# neurovascular studies, may be needed as well as cerebrospinal fluid pressure measurement and
# analysis.
#
# sshleifer/distilbart-cnn-12-6 (55 tok):
# R1	p: 11.90 	r: 25.00 	f: 16.13
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 9.52 	r: 20.00 	f: 12.90
# ST	39.61		W2V	5.11
#
#  All possibilities highlighted in Table 12.1 must be entertained and discarded before considering
# the headache to be caused by a chronic headache condition. Brain imaging, including neurovascular
# studies, may be needed as well as cerebrospinal fluid (CSF) pressure measurement and analysis.
#
# sshleifer/distilbart-cnn-12-6 (40 tok):
# R1	p: 15.15 	r: 25.00 	f: 18.87
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 12.12 	r: 20.00 	f: 15.09
# ST	45.81		W2V	16.12
#
#  All the possibilities highlighted in Table 12.1 must be entertained and discarded before
# considering the headache to be caused by a chronic headache condition. Brain imaging, including
# neurovascular studies, may be needed.
#
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (29 tok):
# R1	p: 38.46 	r: 50.00 	f: 43.48
# R2	p: 28.00 	r: 36.84 	f: 31.82
# RL	p: 34.62 	r: 45.00 	f: 39.13
# ST	78.94		W2V	51.83
#
# The first step in assessing a new headache is determining whether the headache is a serious,
# potentially life-threatening medical event requiring emergency evaluation and management.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (29 tok):
# R1	p: 38.46 	r: 50.00 	f: 43.48
# R2	p: 28.00 	r: 36.84 	f: 31.82
# RL	p: 34.62 	r: 45.00 	f: 39.13
# ST	78.94		W2V	51.83
#
# The first step in assessing a new headache is determining whether the headache is a serious,
# potentially life-threatening medical event requiring emergency evaluation and management.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (30 tok):
# R1	p: 40.74 	r: 55.00 	f: 46.81
# R2	p: 30.77 	r: 42.11 	f: 35.56
# RL	p: 37.04 	r: 50.00 	f: 42.55
# ST	80.09		W2V	54.26
#
# The first step in assessing a new headache is to determine whether the headache is a serious,
# potentially life-threatening medical event requiring emergency evaluation and management.
#
# /home/marco/epfl/magma/fine-tuning/ft_bart_para_wordembed/checkpoint-196 (28 tok):
# R1	p: 36.00 	r: 45.00 	f: 40.00
# R2	p: 20.83 	r: 26.32 	f: 23.26
# RL	p: 32.00 	r: 40.00 	f: 35.56
# ST	78.38		W2V	47.53
#
# The first step in assessing a new headache is determining whether the headache is a serious, life-
# threatening medical event requiring emergency evaluation and management.
#
#
# ####################################################################################################
