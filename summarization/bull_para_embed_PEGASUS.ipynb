# %% [markdown]
# #### AWS

# %%
magma_dir = '/home/ubuntu/magma/'
bucket_dir = '/home/ubuntu/s3/'
transformers_dir = '/home/ubuntu/transformers/'
cache_dir = bucket_dir+'.cache/'

# %% [markdown]
# ### **Config**

# %%
import os
import sys

sys.path.insert(0, '/home/marco/epfl/magma/')
import config

from torch import cuda
device = 'cuda' if cuda.is_available() else 'cpu'

# %%
MODEL = 'pegasus'
MODELS = {}

# %%
# Dataset path
data_dir = config.MAGMA_DIR + 'datasets/karger_books_para_wordembed/'+MODEL+'/'

# %% [markdown]
# #### AWS

# %%
data_dir = bucket_dir + 'datasets/karger_books_para_wordembed/'+MODEL+'/'

# %% [markdown]
# ### **Init**

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import re
import pandas as pd
from tqdm import tqdm
from textwrap import fill
tqdm.pandas()

# %% [markdown]
# ### **Function Definition**

# %% [markdown]
# ##### Import Model and Tok

# %%
def import_model_tok(model_name_or_path, verbose=False):
    global MODELS

    if model_name_or_path in MODELS.keys():
        if verbose : print('[+] model already present in cache\n')
        return MODELS[model_name_or_path]
    if verbose : print('[*] importing the model\n')
    
    from transformers import PegasusForConditionalGeneration, PegasusTokenizer
    model = PegasusForConditionalGeneration.from_pretrained(model_name_or_path, cache_dir=cache_dir)
    tokenizer = PegasusTokenizer.from_pretrained(model_name_or_path, cache_dir=cache_dir)

    if verbose : print(model.config)
    MODELS[model_name_or_path] = model, tokenizer
    if verbose : print('[+] the model is now present in cache\n')
    return MODELS[model_name_or_path]

# %% [markdown]
# ##### Print Examples

# %%
def print_examples(model_name_list, df, n_examples=10):
    
    df_examples = df.sample(n_examples, axis='index', random_state=config.SEED)
    
    for idx, row in df_examples.iterrows():
        print(idx)
        print(fill(row.text, 100))
        print()
        print('Reference:')
        print(fill(row.bullets, 100))
        print()
        for model_name in model_name_list:
            model, tokenizer = import_model_tok(model_name)
            model = model.to(device)
            
            summ_enc_list = model.generate(
                tokenizer.encode(row.text, return_tensors='pt').to(device),
                min_length = config.ONE_BULLET_MIN_LEN,
                max_length = config.ONE_BULLET_MAX_LEN,
                length_penalty = config.LENGTH_PENALTY,
                num_beams = config.NUM_BEAMS,
                no_repeat_ngram_size = config.NO_REPEAT_NGRAM_SIZE,
                num_return_sequences = config.NUM_BEAMS,
                early_stopping = True)
            
            for summ_enc in summ_enc_list:
                summ_num_tok = len(tokenizer.convert_ids_to_tokens(summ_enc, skip_special_tokens=True))
                summ = tokenizer.decode(summ_enc, skip_special_tokens=True)

                rouge, sent_trans, w2v = evaluate_prediction(summ, row.bullets)
                
                print('%s (%d tok):'%(model_name, summ_num_tok))
                print('R1\tp: %.2f \tr: %.2f \tf: %.2f\nR2\tp: %.2f \tr: %.2f \tf: %.2f\nRL\tp: %.2f \tr: %.2f \tf: %.2f'%(
                rouge['rouge1_precision'], rouge['rouge1_recall'], rouge['rouge1_fmeasure'],
                rouge['rouge2_precision'], rouge['rouge2_recall'], rouge['rouge2_fmeasure'],
                rouge['rougeL_precision'], rouge['rougeL_recall'], rouge['rougeL_fmeasure']))
                print('ST\t%.2f\t\tW2V\t%.2f'%(sent_trans, w2v))
                print()
                print(fill(summ, 100))
                print()
            print()
            
        print(''.join(['#']*100))
        print()

# %% [markdown]
# ## **Sentence-Transformers**

# %%
data_dir_st = data_dir + 'st/base/'

# %%
df_train = pd.read_csv(data_dir_st + 'train.csv').set_index(['book', 'chapter'])
df_val = pd.read_csv(data_dir_st + 'val.csv').set_index(['book', 'chapter'])
df_test = pd.read_csv(data_dir_st + 'test.csv').set_index(['book', 'chapter'])

# %% [markdown]
# ### **Print and Summarization**

# %%
from transformers import AutoConfig
model_config = AutoConfig.from_pretrained(model_name_or_path)
model_config.min_length = config.ONE_BULLET_MIN_LEN
model_config.max_length = config.ONE_BULLET_MAX_LEN

model_config_dir = bucket_dir+'fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/'
model_config.save_pretrained(model_config_dir)

# %% [markdown]
# #### Print Train Examples

# %%
print_examples([
    'google/pegasus-large',
    bucket_dir+'fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/'],
    df_train)
# Out:
# (9781912776696, 'hh-5')
# Kaplan-Meier curves provide a way of plotting the distribution of a time-to-event endpoint. In
# Figure 2.1 the dashed line shows that at 24 months' follow-up the estimated survival probability is
# 54%. Kaplan-Meier survival curves are often used to compare the data between two groups of subjects.
# Figure 2.2 shows Kaplan-Meier curves for OS in a randomized study of patients with human epidermal
# growth factor receptor 2 (HER2)-positive metastatic breast cancer treated either with or without
# trastuzumab. The Kaplan-Meier curve steps down at time points at which deaths occur, while censored
# observations are denoted by notches on the curve. In this study, the follow-up period ranged from 3
# months to 74 months.
#
# Reference:
# Kaplan-Meier curves plot the probability of being event free over time. The curves from different
# treatment groups can be plotted against each other to show the differences in outcome.
#
# google/pegasus-large (41 tok):
# R1	p: 15.15 	r: 16.67 	f: 15.87
# R2	p: 6.25 	r: 6.90 	f: 6.56
# RL	p: 12.12 	r: 13.33 	f: 12.70
# ST	47.94		W2V	18.98
#
# Figure 2.2 shows Kaplan-Meier curves for OS in a randomized study of patients with human epidermal
# growth factor receptor 2 (HER2)-positive metastatic breast cancer treated either with or without
# trastuzumab.
#
# google/pegasus-large (41 tok):
# R1	p: 15.15 	r: 16.67 	f: 15.87
# R2	p: 6.25 	r: 6.90 	f: 6.56
# RL	p: 12.12 	r: 13.33 	f: 12.70
# ST	48.01		W2V	15.67
#
# Figures 2.2 shows Kaplan-Meier curves for OS in a randomized study of patients with human epidermal
# growth factor receptor 2 (HER2)-positive metastatic breast cancer treated either with or without
# trastuzumab.
#
# google/pegasus-large (27 tok):
# R1	p: 21.74 	r: 16.67 	f: 18.87
# R2	p: 4.55 	r: 3.45 	f: 3.92
# RL	p: 17.39 	r: 13.33 	f: 15.09
# ST	64.37		W2V	22.29
#
# The Kaplan-Meier curve steps down at time points at which deaths occur, while censored observations
# are denoted by notches on the curve.
#
# google/pegasus-large (22 tok):
# R1	p: 20.00 	r: 13.33 	f: 16.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 10.00 	r: 6.67 	f: 8.00
# ST	41.41		W2V	39.98
#
# In Figure 2.1 the dashed line shows that at 24 months' follow-up the estimated survival probability
# is 54%.
#
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (21 tok):
# R1	p: 50.00 	r: 26.67 	f: 34.78
# R2	p: 13.33 	r: 6.90 	f: 9.09
# RL	p: 43.75 	r: 23.33 	f: 30.43
# ST	75.96		W2V	43.56
#
# Kaplan-Meier curves provide a way of plotting the distribution of a time-to-event endpoint.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (20 tok):
# R1	p: 53.33 	r: 26.67 	f: 35.56
# R2	p: 14.29 	r: 6.90 	f: 9.30
# RL	p: 46.67 	r: 23.33 	f: 31.11
# ST	77.14		W2V	40.77
#
# Kaplan-Meier curves provide a way of plotting the distribution of time-to-event endpoints.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (17 tok):
# R1	p: 42.86 	r: 20.00 	f: 27.27
# R2	p: 15.38 	r: 6.90 	f: 9.52
# RL	p: 42.86 	r: 20.00 	f: 27.27
# ST	76.33		W2V	42.05
#
# Kaplan-Meier curves provide a way of plotting the distribution of an event endpoint.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (16 tok):
# R1	p: 38.46 	r: 16.67 	f: 23.26
# R2	p: 16.67 	r: 6.90 	f: 9.76
# RL	p: 38.46 	r: 16.67 	f: 23.26
# ST	70.99		W2V	37.76
#
# Kaplan-Meier curves provide a way of plotting the distribution of an endpoint.
#
#
# ####################################################################################################
#
# (9781908541062, 'ch_9')
# The traditional 'pyramid' approach to the treatment of RA was to begin with symptomatic treatment of
# inflammation using NSAIDs in addition to rest and corticosteroid injections. If the disease did not
# significantly improve with these simple treatments, then more potent DMARDs were added. It is now
# clear, however, that effective therapy early in the course of RA results in a long-term reduction in
# joint damage compared to delayed therapy, the so-called window of opportunity. This has led to the
# general principle that inflammation should be controlled as completely and as soon as possible by
# the early and aggressive introduction of DMARDs. The currently approved non-biological drugs for
# treating RA are listed in Table 8.1. Most of these require monitoring for the prompt detection of
# potential adverse effects, although the precise monitoring recommendations vary from center to
# center. The British Society for Rheumatology, the European League Against Rheumatism and the
# American College of Rheumatology have each developed guidelines for the use and monitoring of RA
# therapies.
#
# Reference:
# Treatment-to-target strategies, including combination DMARD therapy, rapidly suppress inflammation
# and minimize long-term damage and disability.
#
# google/pegasus-large (30 tok):
# R1	p: 14.81 	r: 22.22 	f: 17.78
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 14.81 	r: 22.22 	f: 17.78
# ST	54.02		W2V	34.64
#
# This has led to the general principle that inflammation should be controlled as completely and as
# soon as possible by the early and aggressive introduction of DMARDs.
#
# google/pegasus-large (62 tok):
# R1	p: 7.27 	r: 22.22 	f: 10.96
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 7.27 	r: 22.22 	f: 10.96
# ST	51.35		W2V	31.25
#
# This has led to the general principle that inflammation should be controlled as completely and as
# soon as possible by the early and aggressive introduction of DMARDs. The British Society for
# Rheumatology, the European League Against Rheumatism and the American College of Rheumatology have
# each developed guidelines for the use and monitoring of RA therapies.
#
# google/pegasus-large (39 tok):
# R1	p: 15.15 	r: 27.78 	f: 19.61
# R2	p: 3.12 	r: 5.88 	f: 4.08
# RL	p: 12.12 	r: 22.22 	f: 15.69
# ST	57.93		W2V	12.03
#
# It is now clear, however, that effective therapy early in the course of RA results in a long-term
# reduction in joint damage compared to delayed therapy, the so-called window of opportunity.
#
# google/pegasus-large (32 tok):
# R1	p: 7.14 	r: 11.11 	f: 8.70
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 7.14 	r: 11.11 	f: 8.70
# ST	33.32		W2V	15.04
#
# The British Society for Rheumatology, the European League Against Rheumatism and the American
# College of Rheumatology have each developed guidelines for the use and monitoring of RA therapies.
#
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (16 tok):
# R1	p: 0.00 	r: 0.00 	f: 0.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 0.00 	r: 0.00 	f: 0.00
# ST	44.47		W2V	10.60
#
# DMARDs should be used as early as possible in the course of RA.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (17 tok):
# R1	p: 0.00 	r: 0.00 	f: 0.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 0.00 	r: 0.00 	f: 0.00
# ST	49.95		W2V	2.83
#
# DMARDs should be used as early as possible in the course of the disease.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (12 tok):
# R1	p: 11.11 	r: 5.56 	f: 7.41
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 11.11 	r: 5.56 	f: 7.41
# ST	47.94		W2V	2.50
#
# DMARDs are the mainstay of the treatment of RA.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (11 tok):
# R1	p: 12.50 	r: 5.56 	f: 7.69
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 12.50 	r: 5.56 	f: 7.69
# ST	51.45		W2V	1.23
#
# DMARDs are the mainstay of treatment for RA.
#
#
# ####################################################################################################
#
# (9781910797495, 'chp8')
# Postincisional pain. Postincisional syndrome is defined as pain at or close to the site of a
# surgical incision that persists beyond the usual healing period. As with other neuropathic pain
# syndromes, patients exhibit allodynia and sometimes also edema in the vicinity of the surgical
# wound, which is typical of temporary peripheral sensitization. Postamputation persistent pain.
# Postamputation persistent pain is a special case of PPSP because large nerves are deliberately cut
# in all patients. It is interesting, then, that only 30-50% develop PPSP, whereas 100% have nerve
# injury (see Table 8.1). This emphasizes the multifactorial basis of PPSP. A surprising omission in
# studies of amputation pain is information about how the nerves amputated are managed (id est clean
# cut or ligature tied). Use of a ligature tie in animal studies is known to generate neuropathic
# pain.
#
# Reference:
# Persistent postsurgical pain (PPSP) is defined as pain at or close to the site of surgical incision
# that persists beyond the expected healing period.
# google/pegasus-large (22 tok):
# R1	p: 27.78 	r: 20.83 	f: 23.81
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 22.22 	r: 16.67 	f: 19.05
# ST	69.64		W2V	22.20
#
# Postamputation persistent pain is a special case of PPSP because large nerves are deliberately cut
# in all patients.
#
# google/pegasus-large (48 tok):
# R1	p: 19.05 	r: 33.33 	f: 24.24
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 11.90 	r: 20.83 	f: 15.15
# ST	64.00		W2V	34.45
#
# Postamputation persistent pain is a special case of PPSP because large nerves are deliberately cut
# in all patients. A surprising omission in studies of amputation pain is information about how the
# nerves amputated are managed (id est clean cut or ligature tied).
#
# google/pegasus-large (26 tok):
# R1	p: 20.83 	r: 20.83 	f: 20.83
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 12.50 	r: 12.50 	f: 12.50
# ST	40.35		W2V	33.53
#
# A surprising omission in studies of amputation pain is information about how the nerves amputated
# are managed (id est clean cut or ligature tied).
#
# google/pegasus-large (48 tok):
# R1	p: 19.05 	r: 33.33 	f: 24.24
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 11.90 	r: 20.83 	f: 15.15
# ST	63.32		W2V	34.28
#
# Postamputation persistent pain is a special case of PPSP because large nerves are deliberately cut
# in all patients. A surprising omission in studies of amputation pain is information about how the
# amputated nerves are managed (id est clean cut or ligature tied).
#
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (31 tok):
# R1	p: 88.00 	r: 91.67 	f: 89.80
# R2	p: 75.00 	r: 78.26 	f: 76.60
# RL	p: 88.00 	r: 91.67 	f: 89.80
# ST	94.93		W2V	93.15
#
# Postamputation persistent pain (PPSP) is defined as pain at or close to the site of a surgical
# incision that persists beyond the usual healing period.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (31 tok):
# R1	p: 83.33 	r: 83.33 	f: 83.33
# R2	p: 73.91 	r: 73.91 	f: 73.91
# RL	p: 83.33 	r: 83.33 	f: 83.33
# ST	91.32		W2V	83.31
#
# Postincisional syndrome (PPSP) is defined as pain at or close to the site of a surgical incision
# that persists beyond the usual healing period.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (30 tok):
# R1	p: 91.67 	r: 91.67 	f: 91.67
# R2	p: 82.61 	r: 82.61 	f: 82.61
# RL	p: 91.67 	r: 91.67 	f: 91.67
# ST	94.89		W2V	93.15
#
# Postamputation persistent pain (PPSP) is defined as pain at or close to the site of surgical
# incision that persists beyond the usual healing period.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (27 tok):
# R1	p: 82.61 	r: 79.17 	f: 80.85
# R2	p: 72.73 	r: 69.57 	f: 71.11
# RL	p: 82.61 	r: 79.17 	f: 80.85
# ST	81.61		W2V	80.12
#
# Postincisional syndrome is defined as pain at or close to the site of a surgical incision that
# persists beyond the usual healing period.
#
#
# ####################################################################################################
#
# (9781908541666, 'ch_12')
# Treatment. Immediate treatment of any identifiable cause of the DKA should be undertaken without
# delay. Until recently, standard management of DKA focused on reducing blood glucose levels with
# insulin and intravenous fluids. There is still universal agreement that the initial cornerstone of
# treatment is fluid replacement and insulin administration. The intravascular volume should be
# expanded to correct a typical deficit of 100 mL/kg of water with intravenous isotonic saline, which
# will also improve renal perfusion. Infusion rates of 1 L per hour for the first hour, 1 L for the
# next 2 hours and 1 L over the next 4 hours are usually adequate except in those patients with
# profound hypovolemia and hypotension, who may need twice this amount (Table 11.3). If the initial
# systolic blood pressure is below 90 mmHg, 500 mL of normal saline should be given over 15 minutes.
# In the presence of significant hypernatremia, isotonic saline can be replaced with 0.45% saline. The
# aim is to replace total body deficits of water and electrolytes, with half the estimated deficit
# being replaced in 12-24 hours (see Table 11.3). Once the blood glucose has fallen to about 14 mmol/L
# (252 mg/dL), saline should be replaced with 5% dextrose (or an infusion of 10% glucose given at 125
# mL/hour started alongside the infusion of normal saline to correct circulatory volume) to allow
# continued insulin administration to suppress ketogenesis while avoiding hypoglycemia.
#
# Reference:
# Treatment of DKA is by fluid and electrolyte replacement, intravenous insulin and treatment of the
# underlying cause, when known.
#
# google/pegasus-large (65 tok):
# R1	p: 7.41 	r: 21.05 	f: 10.96
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 3.70 	r: 10.53 	f: 5.48
# ST	41.89		W2V	21.41
#
# Once the blood glucose has fallen to about 14 mmol/L (252 mg/dL), saline should be replaced with 5%
# dextrose (or an infusion of 10% glucose given at 125 mL/hour started alongside the infusion of
# normal saline to correct circulatory volume) to allow continued insulin administration to suppress
# ketogenesis while avoiding hypoglycemia.
#
# google/pegasus-large (94 tok):
# R1	p: 7.41 	r: 31.58 	f: 12.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 4.94 	r: 21.05 	f: 8.00
# ST	44.64		W2V	31.80
#
# The aim is to replace total body deficits of water and electrolytes, with half the estimated deficit
# being replaced in 12-24 hours (see Table 11.3). Once the blood glucose has fallen to about 14 mmol/L
# (252 mg/dL), saline should be replaced with 5% dextrose (or an infusion of 10% glucose given at 125
# mL/hour started alongside the infusion of normal saline to correct circulatory volume) to allow
# continued insulin administration to suppress ketogenesis while avoiding hypoglycemia.
#
# google/pegasus-large (96 tok):
# R1	p: 6.17 	r: 26.32 	f: 10.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 4.94 	r: 21.05 	f: 8.00
# ST	36.63		W2V	24.83
#
# The intravascular volume should be expanded to correct a typical deficit of 100 mL/kg of water with
# intravenous isotonic saline, which will also improve renal perfusion. Once the blood glucose has
# fallen to about 14 mmol/L (252 mg/dL), saline should be replaced with 5% dextrose (or an infusion of
# 10% glucose given at 125 mL/hour started alongside the infusion of normal saline to correct
# circulatory volume) to allow continued insulin administration to suppress ketosis while avoiding
# hypoglycemia.
#
# google/pegasus-large (66 tok):
# R1	p: 7.41 	r: 21.05 	f: 10.96
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 3.70 	r: 10.53 	f: 5.48
# ST	39.20		W2V	21.41
#
# Once the blood glucose has fallen to about 14 mmol/L (252 mg/dL), saline should be replaced with 5%
# dextrose (or an infusion of 10% glucose given at 125 mL/hour started alongside the infusion of
# normal saline to correct circulatory volume) to allow continued insulin administration to suppress
# ketogenesis while avoiding hypoglycemia..
#
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (15 tok):
# R1	p: 38.46 	r: 26.32 	f: 31.25
# R2	p: 16.67 	r: 11.11 	f: 13.33
# RL	p: 23.08 	r: 15.79 	f: 18.75
# ST	64.47		W2V	31.56
#
# Immediate treatment of any identifiable cause of DKA should be undertaken without delay.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (26 tok):
# R1	p: 52.17 	r: 63.16 	f: 57.14
# R2	p: 9.09 	r: 11.11 	f: 10.00
# RL	p: 30.43 	r: 36.84 	f: 33.33
# ST	77.27		W2V	63.63
#
# Immediate treatment of any identifiable cause of DKA should be undertaken without delay. The
# cornerstone of treatment is fluid replacement and insulin administration.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (16 tok):
# R1	p: 42.86 	r: 31.58 	f: 36.36
# R2	p: 15.38 	r: 11.11 	f: 12.90
# RL	p: 28.57 	r: 21.05 	f: 24.24
# ST	63.50		W2V	41.06
#
# Immediate treatment of any identifiable cause of the DKA should be undertaken without delay.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (27 tok):
# R1	p: 50.00 	r: 63.16 	f: 55.81
# R2	p: 8.70 	r: 11.11 	f: 9.76
# RL	p: 29.17 	r: 36.84 	f: 32.56
# ST	77.79		W2V	67.22
#
# Immediate treatment of any identifiable cause of the DKA should be undertaken without delay. The
# cornerstone of treatment is fluid replacement and insulin administration.
#
#
# ####################################################################################################
#
# (9781910797495, 'chp1')
# Because it is an experience, pain itself cannot be measured directly. Pain, like consciousness
# itself, is constructed by complex brain processes that are strongly affected by a person's
# attitudes, beliefs, personality and interpretation of the significance of nociceptive stimuli.
# Central to the understanding of clinical pain is the concept that pain may be present without an
# obvious peripheral source or cause. Mechanisms of neuropathic pain. Definition. Neuropathic pain is
# initiated or caused by a primary lesion of the PNS or CNS. Patients often complain not only of
# spontaneous pain, but also of pain from stimuli that are not normally painful (allodynia). For
# example, a light touch may be described as painful.
#
# Reference:
# Neuropathic pain is produced by a lesion of the peripheral or central nervous system (CNS).
# google/pegasus-large (25 tok):
# R1	p: 10.00 	r: 13.33 	f: 11.43
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 10.00 	r: 13.33 	f: 11.43
# ST	48.54		W2V	26.39
#
# Patients often complain not only of spontaneous pain, but also of pain from stimuli that are not
# normally painful (allodynia).
#
# google/pegasus-large (23 tok):
# R1	p: 31.82 	r: 46.67 	f: 37.84
# R2	p: 4.76 	r: 7.14 	f: 5.71
# RL	p: 22.73 	r: 33.33 	f: 27.03
# ST	53.86		W2V	56.82
#
# Central to the understanding of clinical pain is the concept that pain may be present without an
# obvious peripheral source or cause.
#
# google/pegasus-large (37 tok):
# R1	p: 10.00 	r: 20.00 	f: 13.33
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 6.67 	r: 13.33 	f: 8.89
# ST	49.00		W2V	23.41
#
# Patients often complain not only of spontaneous pain, but also of pain from stimuli that are not
# normally painful (allodynia). For example, a light touch may be described as painful.
#
# google/pegasus-large (25 tok):
# R1	p: 10.00 	r: 13.33 	f: 11.43
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 10.00 	r: 13.33 	f: 11.43
# ST	45.93		W2V	27.00
#
# Patient often complain not only of spontaneous pain, but also of pain from stimuli that are not
# normally painful (allodynia).
#
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (19 tok):
# R1	p: 66.67 	r: 66.67 	f: 66.67
# R2	p: 35.71 	r: 35.71 	f: 35.71
# RL	p: 66.67 	r: 66.67 	f: 66.67
# ST	87.09		W2V	65.80
#
# Neuropathic pain is initiated or caused by a primary lesion of the PNS or CNS.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (20 tok):
# R1	p: 76.47 	r: 86.67 	f: 81.25
# R2	p: 62.50 	r: 71.43 	f: 66.67
# RL	p: 76.47 	r: 86.67 	f: 81.25
# ST	90.12		W2V	79.58
#
# Neuropathic pain is initiated or caused by a primary lesion of the peripheral or central nervous
# system.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (12 tok):
# R1	p: 27.27 	r: 20.00 	f: 23.08
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 27.27 	r: 20.00 	f: 23.08
# ST	43.83		W2V	31.69
#
# Pain may be present without an obvious peripheral source or cause.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (11 tok):
# R1	p: 20.00 	r: 13.33 	f: 16.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 20.00 	r: 13.33 	f: 16.00
# ST	36.69		W2V	22.63
#
# Pain may be present without an obvious source or cause.
#
#
# ####################################################################################################
#
# (9781910797662, 'ch03')
# Delay in diagnosis. Although it is difficult to prove that delay in diagnosis affects prognosis,
# screening for asymptomatic microscopic hematuria is associated with a shift towards more favorable
# tumor characteristics of lower stage and grade at diagnosis, and better survival. Delays may occur
# for a variety of reasons.
#
# Reference:
# Delay in treatment adversely affects prognosis.
#
# google/pegasus-large (42 tok):
# R1	p: 10.81 	r: 66.67 	f: 18.60
# R2	p: 5.56 	r: 40.00 	f: 9.76
# RL	p: 10.81 	r: 66.67 	f: 18.60
# ST	55.21		W2V	20.82
#
# Although it is difficult to prove that delay in diagnosis affects prognosis, screening for
# asymptomatic microscopic hematuria is associated with a shift towards more favorable tumor
# characteristics of lower stage and grade at diagnosis, and better survival.
#
# google/pegasus-large (42 tok):
# R1	p: 10.81 	r: 66.67 	f: 18.60
# R2	p: 5.56 	r: 40.00 	f: 9.76
# RL	p: 10.81 	r: 66.67 	f: 18.60
# ST	54.88		W2V	21.52
#
# Despite it is difficult to prove that delay in diagnosis affects prognosis, screening for
# asymptomatic microscopic hematuria is associated with a shift towards more favorable tumor
# characteristics of lower stage and grade at diagnosis, and better survival.
#
# google/pegasus-large (42 tok):
# R1	p: 10.81 	r: 66.67 	f: 18.60
# R2	p: 5.56 	r: 40.00 	f: 9.76
# RL	p: 10.81 	r: 66.67 	f: 18.60
# ST	55.61		W2V	22.88
#
# Although it is difficult to prove that delay in diagnosis affects prognosis, screening for
# asymptomatic micro hematuria is associated with a shift towards more favorable tumor characteristics
# of lower stage and grade at diagnosis, and better survival.
#
# google/pegasus-large (10 tok):
# R1	p: 0.00 	r: 0.00 	f: 0.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 0.00 	r: 0.00 	f: 0.00
# ST	37.18		W2V	10.32
#
# Delays may occur for a variety of reasons.
#
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (12 tok):
# R1	p: 18.18 	r: 33.33 	f: 23.53
# R2	p: 10.00 	r: 20.00 	f: 13.33
# RL	p: 18.18 	r: 33.33 	f: 23.53
# ST	53.95		W2V	33.61
#
# Delay in diagnosis may be due to a variety of reasons.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (9 tok):
# R1	p: 37.50 	r: 50.00 	f: 42.86
# R2	p: 14.29 	r: 20.00 	f: 16.67
# RL	p: 37.50 	r: 50.00 	f: 42.86
# ST	64.99		W2V	48.38
#
# Delay in diagnosis is associated with better prognosis.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (9 tok):
# R1	p: 25.00 	r: 33.33 	f: 28.57
# R2	p: 14.29 	r: 20.00 	f: 16.67
# RL	p: 25.00 	r: 33.33 	f: 28.57
# ST	61.00		W2V	24.75
#
# Delay in diagnosis is associated with better survival.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (12 tok):
# R1	p: 18.18 	r: 33.33 	f: 23.53
# R2	p: 10.00 	r: 20.00 	f: 13.33
# RL	p: 18.18 	r: 33.33 	f: 23.53
# ST	55.29		W2V	32.03
#
# Delay in diagnosis may be due to a variety of factors.
#
#
# ####################################################################################################
#
# (9781910797310, 'chp2')
# Well-differentiated tumors with adenocarcinoma morphology (acinar, papillary, lepidic,
# micropapillary) or squamous cell carcinoma (unequivocal keratinization and well-formed classical
# bridges) on routine light microscopy can be diagnosed as adenocarcinoma or squamous cell carcinoma,
# respectively, without immunohistochemistry. Poorly differentiated tumors should undergo limited
# immuno-histochemistry. A single adenocarcinoma marker (exempli gratia thyroid transcription factor 1
# [TTF1] or Napsin-A) or squamous cell carcinoma marker (exempli gratia p40, cytokeratin 5/6 or p63)
# can be used to classify most tumors. Carcinomas lacking clear differentiation by morphology and
# immunohistochemistry are classified as 'NSCLC, not otherwise specified (NOS)'. NOS carcinomas that
# stain with adenocarcinoma markers are classified as 'NSCLC, favor adenocarcinoma'; tumors that stain
# with squamous markers are classified as 'NSCLC, favor squamous cell carcinoma'. In this way, a
# diagnosis of NSCLC-NOS can be avoided in up to 90% of cases.
#
# Reference:
# Classification of NSCLC further into specific pathological subtypes (exempli gratia adenocarcinoma
# versus squamous cell carcinoma) will determine eligibility for certain types of molecular testing
# and aid therapeutic decisions based on the specific histological and genetic characteristics of the
# tumor.
#
# google/pegasus-large (60 tok):
# R1	p: 16.22 	r: 15.38 	f: 15.79
# R2	p: 5.56 	r: 5.26 	f: 5.41
# RL	p: 16.22 	r: 15.38 	f: 15.79
# ST	55.23		W2V	41.07
#
# Well-differentiated tumors with adenocarcinoma morphology (acinar, papillary, lepidic,
# micropapillary) or squamous cell carcinoma (unequivocal keratinization and well-formed classical
# bridges) on routine light microscopy can be diagnosed as adenocarcinoma or squamous cell carcinoma,
# respectively, without immunohistochemistry.
#
# google/pegasus-large (59 tok):
# R1	p: 16.67 	r: 15.38 	f: 16.00
# R2	p: 5.71 	r: 5.26 	f: 5.48
# RL	p: 16.67 	r: 15.38 	f: 16.00
# ST	55.35		W2V	39.51
#
# Well-differentiated tumors with adenocarcinoma morphology (acinar, papillary, lepidic,
# micropapillary) or squamous cell carcinoma (unequivocalization and well-formed classical bridges) on
# routine light microscopy can be diagnosed as adenocarcinoma or squamous cell carcinoma,
# respectively, without immunohistochemistry.
#
# google/pegasus-large (98 tok):
# R1	p: 10.94 	r: 17.95 	f: 13.59
# R2	p: 3.17 	r: 5.26 	f: 3.96
# RL	p: 9.38 	r: 15.38 	f: 11.65
# ST	61.54		W2V	30.61
#
# Well-differentiated tumors with adenocarcinoma morphology (acinar, papillary, lepidic,
# micropapillary) or squamous cell carcinoma (unequivocal keratinization and well-formed classical
# bridges) on routine light microscopy can be diagnosed as adenocarcinoma or squamous cell carcinoma,
# respectively, without immunohistochemistry. NOS carcinomas that stain with adenocarcinoma markers
# are classified as 'NSCLC, favor adenocarcinoma'; tumors that stain with squamous markers are
# classified as ‘NSCLC, favor squamous cell carcinoma'.
#
# google/pegasus-large (98 tok):
# R1	p: 10.94 	r: 17.95 	f: 13.59
# R2	p: 3.17 	r: 5.26 	f: 3.96
# RL	p: 9.38 	r: 15.38 	f: 11.65
# ST	61.64		W2V	34.66
#
# Well-differentiated tumors with adenocarcinoma morphology (acinar, papillary, lepidic,
# micropapillary) or squamous cell carcinoma (unequivocal keratinization and well-formed classical
# bridges) on routine light microscopy can be diagnosed as adenocarcinoma or squamous cell carcinoma,
# respectively, without immunohistochemistry. NOS carcinomas that stain with adenocarcinoma markers
# are classified as 'NSCLC, favor adenocarcinoma'; tumors that stain with squamous markers are
# classified in 'NSCLC, favour squamous cell carcinoma'.
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (34 tok):
# R1	p: 13.64 	r: 7.69 	f: 9.84
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 9.09 	r: 5.13 	f: 6.56
# ST	55.56		W2V	12.76
#
# Non-small-cell lung cancer (NSCLC) that lacks clear differentiation by morphology and
# immunohistochemistry is classified as 'NSCLC, not otherwise specified' (NOS).
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (32 tok):
# R1	p: 14.29 	r: 7.69 	f: 10.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 9.52 	r: 5.13 	f: 6.67
# ST	53.94		W2V	14.49
#
# Non-small-cell lung cancer (NSCLC) that lacks clear differentiation by morphology and
# immunohistochemistry is classified as 'NSCLC, not otherwise specified'.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (33 tok):
# R1	p: 13.64 	r: 7.69 	f: 9.84
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 9.09 	r: 5.13 	f: 6.56
# ST	55.81		W2V	12.76
#
# Non-small-cell lung cancer (NSCLC) that lacks clear differentiation by morphology and
# immunohistochemistry is classified as 'NSCLC, not otherwise specified (NOS).
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (34 tok):
# R1	p: 13.64 	r: 7.69 	f: 9.84
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 9.09 	r: 5.13 	f: 6.56
# ST	54.17		W2V	12.76
#
# Non-small-cell lung cancer (NSCLC) that lacks clear differentiation by morphology and
# immunohistochemistry is classified as 'NSCLC, not otherwise specified (NOS).'
#
#
# ####################################################################################################
#
# (9781910797587, 'chp03')
# Estimates of incidence and prevalence also vary according to the definition of OA used; for example,
# symptomatic versus radiographic criteria. Even when radiographic definitions are used, different
# radiographic features may be emphasized (exempli gratia osteophytes vs joint-space narrowing). It is
# interesting to note that the correlation between pain and radiographic OA features is not as strong
# as expected, for reasons discussed in Chapter 4 (see page 50).
#
# Reference:
# Although radiographic OA is common, it is not always symptomatic.
#
# google/pegasus-large (26 tok):
# R1	p: 5.56 	r: 10.00 	f: 7.14
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 5.56 	r: 10.00 	f: 7.14
# ST	44.10		W2V	12.53
#
# Even when radiographic definitions are used, different radiographic features may be emphasized
# (exempli gratiaphytes vs joint-space narrowing).
#
# google/pegasus-large (32 tok):
# R1	p: 20.69 	r: 60.00 	f: 30.77
# R2	p: 10.71 	r: 33.33 	f: 16.22
# RL	p: 13.79 	r: 40.00 	f: 20.51
# ST	54.90		W2V	49.93
#
# It is interesting to note that the correlation between pain and radiographic OA features is not as
# strong as expected, for reasons discussed in Chapter 4 (see page 50).
#
# google/pegasus-large (27 tok):
# R1	p: 5.26 	r: 10.00 	f: 6.90
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 5.26 	r: 10.00 	f: 6.90
# ST	47.75		W2V	8.61
#
# Even when radiographic definitions are used, different radiographic features may be emphasized
# (exempli gratiaphytes vs joint osteo-space narrowing).
#
# google/pegasus-large (27 tok):
# R1	p: 5.26 	r: 10.00 	f: 6.90
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 5.26 	r: 10.00 	f: 6.90
# ST	48.00		W2V	8.57
#
# Even when radiographic definitions are used, different radiographic features may be emphasized
# (exempli gratiaphytes vs joint-space narrowing osteo).
#
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (21 tok):
# R1	p: 15.79 	r: 30.00 	f: 20.69
# R2	p: 5.56 	r: 11.11 	f: 7.41
# RL	p: 15.79 	r: 30.00 	f: 20.69
# ST	47.91		W2V	46.40
#
# The correlation between pain and radiographic features is not as strong as expected, for reasons
# discussed in Chapter 4.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (15 tok):
# R1	p: 28.57 	r: 40.00 	f: 33.33
# R2	p: 15.38 	r: 22.22 	f: 18.18
# RL	p: 28.57 	r: 40.00 	f: 33.33
# ST	64.99		W2V	48.05
#
# The correlation between pain and radiographic OA features is not as strong as expected.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (16 tok):
# R1	p: 26.67 	r: 40.00 	f: 32.00
# R2	p: 14.29 	r: 22.22 	f: 17.39
# RL	p: 26.67 	r: 40.00 	f: 32.00
# ST	66.98		W2V	47.35
#
# The correlation between pain and radiographic features of OA is not as strong as expected.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (14 tok):
# R1	p: 23.08 	r: 30.00 	f: 26.09
# R2	p: 8.33 	r: 11.11 	f: 9.52
# RL	p: 23.08 	r: 30.00 	f: 26.09
# ST	50.70		W2V	45.87
#
# The correlation between pain and radiographic features is not as strong as expected.
#
#
# ####################################################################################################
#
# (9781908541963, 'chapter10')
# Hepatocellular carcinoma. Epidemiology and pathogenesis. Hepatocellular carcinoma (hepatoma, HCC) is
# a malignancy of hepatocytes. HCC is a common cause of mortality in the developing world. Although
# currently less common in the developed world, the incidence is expected to rise as patients with
# cirrhosis due to chronic hepatitis C age. Marked geographic variation in incidence is largely due to
# variation in the risk factors that predispose an individual to the tumor (Table 10.1). Most cases of
# HCC occur in liver that is already cirrhotic. Thus, patients with advanced viral hepatitis,
# hemochromatosis or alcoholic liver disease are at risk. Hepatitis B presents a unique risk, as there
# is evidence that a tumor may develop in the absence of cirrhosis - presumably via direct integration
# of viral DNA into the host genome.
#
# Reference:
# Hepatocellular carcinoma often has few specific symptoms or signs.
#
# google/pegasus-large (26 tok):
# R1	p: 0.00 	r: 0.00 	f: 0.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 0.00 	r: 0.00 	f: 0.00
# ST	31.88		W2V	-4.73
#
# Although currently less common in the developed world, the incidence is expected to rise as patients
# with cirrhosis due to chronic hepatitis C age.
#
# google/pegasus-large (34 tok):
# R1	p: 0.00 	r: 0.00 	f: 0.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 0.00 	r: 0.00 	f: 0.00
# ST	46.67		W2V	8.82
#
# Hepatitis B presents a unique risk, as there is evidence that a tumor may develop in the absence of
# cirrhosis - presumably via direct integration of viral DNA into the host genome.
#
# google/pegasus-large (46 tok):
# R1	p: 2.63 	r: 11.11 	f: 4.26
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 2.63 	r: 11.11 	f: 4.26
# ST	37.38		W2V	-0.23
#
# Although currently less common in the developed world, the incidence is expected to rise as patients
# with cirrhosis due to chronic hepatitis C age. Thus, patients with advanced viral hepatitis,
# hemochromatosis or alcoholic liver disease are at risk.
#
# google/pegasus-large (27 tok):
# R1	p: 0.00 	r: 0.00 	f: 0.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 0.00 	r: 0.00 	f: 0.00
# ST	33.63		W2V	-2.86
#
# However, currently less common in the developed world, the incidence is expected to rise as patients
# with cirrhosis due to chronic hepatitis C age.
#
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (18 tok):
# R1	p: 15.38 	r: 22.22 	f: 18.18
# R2	p: 8.33 	r: 12.50 	f: 10.00
# RL	p: 15.38 	r: 22.22 	f: 18.18
# ST	65.88		W2V	29.37
#
# Hepatocellular carcinoma (HCC) is a common cause of mortality in the developing world.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (15 tok):
# R1	p: 16.67 	r: 22.22 	f: 19.05
# R2	p: 9.09 	r: 12.50 	f: 10.53
# RL	p: 16.67 	r: 22.22 	f: 19.05
# ST	66.68		W2V	29.56
#
# Hepatocellular carcinoma is a common cause of mortality in the developing world.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (20 tok):
# R1	p: 15.38 	r: 22.22 	f: 18.18
# R2	p: 8.33 	r: 12.50 	f: 10.00
# RL	p: 15.38 	r: 22.22 	f: 18.18
# ST	69.23		W2V	28.41
#
# Hepatocellular carcinoma (hepatoma) is a common cause of mortality in the developing world.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (17 tok):
# R1	p: 16.67 	r: 22.22 	f: 19.05
# R2	p: 9.09 	r: 12.50 	f: 10.53
# RL	p: 16.67 	r: 22.22 	f: 19.05
# ST	65.70		W2V	22.99
#
# Hepatocellular carcinoma (HCC) is a common cause of mortality in developing countries.
#
#
# ####################################################################################################
#
# (9781910797273, 'chp6')
# Promoting repair has been an unexplored sphere of MS therapy. Recently, in animal models of
# demyelination, LINGO antagonists have been shown to promote oligodendrocyte differentiation and
# myelination in vitro. Initiated in 2013, the first multinational Phase II trial of anti-LINGO-1
# antibodies in patients with acute optic neuritis has shown an effect on promoting nerve repair
# following optic neuritis. Ultimately, therapies that successfully promote remyelination and repair
# may be applicable across the spectrum of MS subtypes, including progressive forms of the disease.
# Tyrosine kinase inhibitors. Mastinib has completed a positive Phase IIb study in patients with
# primary and secondary progressive MS, the results of which are reported to include improvement in
# the Multiple Sclerosis Functional Composite (see pages 54 -). A Phase III trial in this population
# is now in progress, and it may prove to be an oral treatment option for this more rare type of MS.
# Mastinib targets mast cells and inhibits several biochemical processes. It is used in the treatment
# of canine diseases and is also being evaluated in stroke, amyotrophic lateral sclerosis and
# Alzheimer's disease.
#
# Reference:
# Anti-LINGO antibody is the first remyelination-promoting therapy to reach Phase II clinical trials
# in optic neuritis. Treatments that overcome molecular obstacles to remyelination may complement
# immune-directed therapies for MS in the future.
# google/pegasus-large (29 tok):
# R1	p: 30.43 	r: 20.00 	f: 24.14
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 21.74 	r: 14.29 	f: 17.24
# ST	60.04		W2V	37.68
#
# Ultimately, therapies that successfully promote remyelination and repair may be applicable across
# the spectrum of MS subtypes, including progressive forms of the disease.
#
# google/pegasus-large (40 tok):
# R1	p: 35.48 	r: 31.43 	f: 33.33
# R2	p: 13.33 	r: 11.76 	f: 12.50
# RL	p: 22.58 	r: 20.00 	f: 21.21
# ST	60.80		W2V	50.06
#
# Initiated in 2013, the first multinational Phase II trial of anti-LINGO-1 antibodies in patients
# with acute optic neuritis has shown an effect on promoting nerve repair following optic neuritis.
#
# google/pegasus-large (40 tok):
# R1	p: 20.59 	r: 20.00 	f: 20.29
# R2	p: 3.03 	r: 2.94 	f: 2.99
# RL	p: 14.71 	r: 14.29 	f: 14.49
# ST	40.60		W2V	31.20
#
# Mastinib has completed a positive Phase IIb study in patients with primary and secondary progressive
# MS, the results of which are reported to include improvement in the Multiple Sclerosis Functional
# Composite (see pages 54 -).
#
# google/pegasus-large (39 tok):
# R1	p: 21.21 	r: 20.00 	f: 20.59
# R2	p: 3.12 	r: 2.94 	f: 3.03
# RL	p: 15.15 	r: 14.29 	f: 14.71
# ST	41.32		W2V	32.02
#
# Mastinib has completed a positive Phase IIb study in patients with primary and secondary progressive
# MS, the results of which are reported to include improvement in the Multiple Functional Composite
# (see pages 54 -).
#
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (26 tok):
# R1	p: 33.33 	r: 20.00 	f: 25.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 23.81 	r: 14.29 	f: 17.86
# ST	57.89		W2V	31.27
#
# Therapies that promote remyelination and repair may be applicable across the spectrum of MS
# subtypes, including progressive forms of the disease.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (44 tok):
# R1	p: 25.00 	r: 25.71 	f: 25.35
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 13.89 	r: 14.29 	f: 14.08
# ST	63.67		W2V	32.10
#
# Therapies that promote remyelination and repair may be applicable across the spectrum of MS
# subtypes, including progressive forms of the disease. Mastinib has completed a Phase IIb study in
# patients with primary and secondary progressive MS.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (19 tok):
# R1	p: 40.00 	r: 17.14 	f: 24.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 26.67 	r: 11.43 	f: 16.00
# ST	54.31		W2V	23.63
#
# Therapies that promote remyelination and repair may be applicable across the spectrum of MS
# subtypes.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (23 tok):
# R1	p: 33.33 	r: 17.14 	f: 22.64
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 22.22 	r: 11.43 	f: 15.09
# ST	51.90		W2V	23.16
#
# Therapies that promote remyelination and repair may be applicable across the spectrum of MS
# subtypes, including progressive forms.
#
#
# ####################################################################################################

# %% [markdown]
# #### Print Val Examples

# %%
print_examples([
    'google/pegasus-large',
    bucket_dir+'fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/'],
    df_val)
# Out:
# (9781908541178, 'ch_6')
# Many anatomic factors can play a primary or a secondary role in the development and progression of
# low back pain syndromes. The most common causes of low back pain are mechanical in origin.
# Mechanical disorders of the lumbar spine are related to injury, overuse or deformity of a spinal
# structure. The most important traumatic factors in low back pain relate to soft tissue structures.
# Precise identification of the injured tissue, and the role of that injury in the consequent pain and
# dysfunction, can be frustratingly difficult. Problems occur in muscles, intervertebral discs, facet
# joints, ligaments or spinal nerves. Aging causes modification of these structures over time, and
# different parts of the spine tend to be at greater risk for change or injury during different
# decades of life. Early in life, muscle injuries are more frequent, while joint problems occur in the
# sixth decade of life (Table 3.1).
#
# Reference:
# Mechanical disorders - muscle strain, spondylolisthesis, herniated intervertebral disc,
# osteoarthritis, spinal stenosis - are the most common causes of low back pain.
#
# google/pegasus-large (15 tok):
# R1	p: 35.71 	r: 25.00 	f: 29.41
# R2	p: 23.08 	r: 15.79 	f: 18.75
# RL	p: 35.71 	r: 25.00 	f: 29.41
# ST	56.32		W2V	38.06
#
# The most important traumatic factors in low back pain relate to soft tissue structures.
#
# google/pegasus-large (31 tok):
# R1	p: 10.34 	r: 15.00 	f: 12.24
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 6.90 	r: 10.00 	f: 8.16
# ST	44.23		W2V	10.56
#
# Aging causes modification of these structures over time, and different parts of the spine tend to be
# at greater risk for change or injury during different decades of life.
#
# google/pegasus-large (19 tok):
# R1	p: 35.29 	r: 30.00 	f: 32.43
# R2	p: 6.25 	r: 5.26 	f: 5.71
# RL	p: 23.53 	r: 20.00 	f: 21.62
# ST	66.01		W2V	35.85
#
# Mechanical disorders of the lumbar spine are related to injury, overuse or deformity of a spinal
# structure.
#
# google/pegasus-large (24 tok):
# R1	p: 19.05 	r: 20.00 	f: 19.51
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 19.05 	r: 20.00 	f: 19.51
# ST	50.40		W2V	21.82
#
# Early in life, muscle injuries are more frequent, while joint problems occur in the sixth decade of
# life (Table 3.1).
#
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (23 tok):
# R1	p: 23.81 	r: 25.00 	f: 24.39
# R2	p: 15.00 	r: 15.79 	f: 15.38
# RL	p: 23.81 	r: 25.00 	f: 24.39
# ST	58.81		W2V	11.55
#
# Many anatomic factors can play a primary or a secondary role in the development and progression of
# low back pain syndromes.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (22 tok):
# R1	p: 25.00 	r: 25.00 	f: 25.00
# R2	p: 15.79 	r: 15.79 	f: 15.79
# RL	p: 25.00 	r: 25.00 	f: 25.00
# ST	59.26		W2V	11.55
#
# Many anatomic factors can play a primary or secondary role in the development and progression of low
# back pain syndromes.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (32 tok):
# R1	p: 27.59 	r: 40.00 	f: 32.65
# R2	p: 17.86 	r: 26.32 	f: 21.28
# RL	p: 17.24 	r: 25.00 	f: 20.41
# ST	63.55		W2V	22.01
#
# Many anatomic factors can play a primary or a secondary role in the development and progression of
# low back pain syndromes; mechanical in origin is the most common cause.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (17 tok):
# R1	p: 62.50 	r: 50.00 	f: 55.56
# R2	p: 46.67 	r: 36.84 	f: 41.18
# RL	p: 50.00 	r: 40.00 	f: 44.44
# ST	71.22		W2V	42.65
#
# The most common causes of low back pain are mechanical in origin and traumatic in origin.
#
#
# ####################################################################################################
#
# (9781912776726, 'ch4')
# Patients with glioblastoma have specific information needs. While the amount of information that
# patients want varies from person to person, and in some cases understanding may be impaired by
# cognitive deficits, patients and their carers need frank but compassionate information on diagnosis,
# prognosis, treatment options, recurrence and end-of-life care. News of a poor prognosis can be
# difficult to process initially. Patients need time to ask questions and receive honest answers. A
# combination of written and verbal information over several consultations and ongoing access to a
# well-resourced specialist nurse and psychologist or counselor are all important in this respect.
# Standard of care for newly diagnosed glioblastoma. The current standard of care for newly diagnosed
# glioblastoma is maximum surgical resection followed by radiotherapy and concomitant temozolomide and
# adjuvant temozolomide.
#
# Reference:
# Radiotherapy and temozolomide is suitable for fit elderly patients with glioblastoma.
#
# google/pegasus-large (52 tok):
# R1	p: 4.55 	r: 18.18 	f: 7.27
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 4.55 	r: 18.18 	f: 7.27
# ST	24.62		W2V	10.30
#
# While the amount of information that patients want varies from person to person, and in some cases
# understanding may be impaired by cognitive deficits, patients and their carers need frank but
# compassionate information on diagnosis, prognosis, treatment options, recurrence and end-of-life
# care.
#
# google/pegasus-large (29 tok):
# R1	p: 27.27 	r: 54.55 	f: 36.36
# R2	p: 4.76 	r: 10.00 	f: 6.45
# RL	p: 13.64 	r: 27.27 	f: 18.18
# ST	67.43		W2V	57.56
#
# The current standard of care for newly diagnosed glioblastoma is maximum surgical resection followed
# by radiotherapy and concomitant temozolomide and adjuvant temozolomide.
#
# google/pegasus-large (29 tok):
# R1	p: 22.73 	r: 45.45 	f: 30.30
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 9.09 	r: 18.18 	f: 12.12
# ST	65.94		W2V	52.32
#
# The current standard of care for newly diagnosed glioblastoma is maximum surgical resection followed
# by radiation and concomitant temozolomide and adjuvant temozolomide.
#
# google/pegasus-large (29 tok):
# R1	p: 28.57 	r: 54.55 	f: 37.50
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 14.29 	r: 27.27 	f: 18.75
# ST	66.72		W2V	55.53
#
# The current standard of care for newly diagnosed glioblastoma is maximum surgical resection followed
# by radiotherapy, concomitant temozolomide and adjuvant temozolomide.
#
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (29 tok):
# R1	p: 27.27 	r: 54.55 	f: 36.36
# R2	p: 4.76 	r: 10.00 	f: 6.45
# RL	p: 13.64 	r: 27.27 	f: 18.18
# ST	67.43		W2V	57.56
#
# The current standard of care for newly diagnosed glioblastoma is maximum surgical resection followed
# by radiotherapy and concomitant temozolomide and adjuvant temozolomide.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (26 tok):
# R1	p: 10.00 	r: 18.18 	f: 12.90
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 5.00 	r: 9.09 	f: 6.45
# ST	40.24		W2V	18.87
#
# Patients and their carers need frank but compassionate information on diagnosis, prognosis,
# treatment options, recurrence and end-of-life care.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (23 tok):
# R1	p: 11.76 	r: 18.18 	f: 14.29
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 5.88 	r: 9.09 	f: 7.14
# ST	39.99		W2V	10.81
#
# Patients need frank but compassionate information on diagnosis, prognosis, treatment options,
# recurrence and end-of-life care.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (25 tok):
# R1	p: 21.05 	r: 36.36 	f: 26.67
# R2	p: 11.11 	r: 20.00 	f: 14.29
# RL	p: 15.79 	r: 27.27 	f: 20.00
# ST	56.29		W2V	33.77
#
# Patients with glioblastoma need frank but compassionate information on diagnosis, prognosis,
# treatment options, recurrence and end-of-life care.
#
#
# ####################################################################################################
#
# (9783318066241, 'ch6')
# Fluid type. Both an open-label and a triple-blind RCT have demonstrated that fluid resuscitation
# using lactated Ringer's solution (a balanced salt solution) is associated with a decreased
# inflammatory response when compared with fluid resuscitation with normal saline (with a high
# chloride content). According to in vitro experiments, it seems that this anti-inflammatory effect
# depends on lactate. However, both studies included a small number of patients, and the influence of
# lactated Ringer's solution on important outcomes such as OF or mortality is unknown. In studies
# addressing other clinical scenarios, balanced fluids such as lactated Ringer's solution seem to be
# associated with a decreased need for blood products and a lower incidence of renal replacement
# therapy, hyperkalemia and postoperative infections when compared with normal saline. For the time
# being, it seems that lactated Ringer's solution is a good choice for fluid resuscitation in AP.
#
# Reference:
# Lactated Ringer's solution is associated with a decreased inflammatory response in AP when compared
# with normal saline.
# google/pegasus-large (52 tok):
# R1	p: 37.21 	r: 88.89 	f: 52.46
# R2	p: 33.33 	r: 82.35 	f: 47.46
# RL	p: 37.21 	r: 88.89 	f: 52.46
# ST	73.95		W2V	61.40
#
# Both an open-label and a triple-blind RCT have demonstrated that fluid resuscitation using lactated
# Ringer's solution (a balanced salt solution) is associated with a decreased inflammatory response
# when compared with fluid resuscitation with normal saline (with a high chloride content).
#
# google/pegasus-large (50 tok):
# R1	p: 33.33 	r: 77.78 	f: 46.67
# R2	p: 24.39 	r: 58.82 	f: 34.48
# RL	p: 30.95 	r: 72.22 	f: 43.33
# ST	60.66		W2V	51.90
#
# In studies addressing other clinical scenarios, balanced fluids such as lactated Ringer's solution
# seem to be associated with a decreased need for blood products and a lower incidence of renal
# replacement therapy, hyperkalemia and postoperative infections when compared with normal saline.
#
# google/pegasus-large (53 tok):
# R1	p: 36.36 	r: 88.89 	f: 51.61
# R2	p: 32.56 	r: 82.35 	f: 46.67
# RL	p: 36.36 	r: 88.89 	f: 51.61
# ST	72.60		W2V	58.76
#
# Both an open-label RCT and a triple-blind RCT have demonstrated that fluid resuscitation using
# lactated Ringer's solution (a balanced salt solution) is associated with a decreased inflammatory
# response when compared with fluid resuscitation with normal saline (with a high chloride content).
#
# google/pegasus-large (52 tok):
# R1	p: 37.21 	r: 88.89 	f: 52.46
# R2	p: 33.33 	r: 82.35 	f: 47.46
# RL	p: 37.21 	r: 88.89 	f: 52.46
# ST	74.07		W2V	61.40
#
# both an open-label and a triple-blind RCT have demonstrated that fluid resuscitation using lactated
# Ringer's solution (a balanced salt solution) is associated with a decreased inflammatory response
# when compared with fluid resuscitation with normal saline (with a high chloride content).
#
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (30 tok):
# R1	p: 66.67 	r: 88.89 	f: 76.19
# R2	p: 60.87 	r: 82.35 	f: 70.00
# RL	p: 66.67 	r: 88.89 	f: 76.19
# ST	84.16		W2V	83.78
#
# Lactated Ringer's solution is associated with a decreased inflammatory response when compared with
# fluid resuscitation with normal saline (with a high chloride content).
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (26 tok):
# R1	p: 72.73 	r: 88.89 	f: 80.00
# R2	p: 66.67 	r: 82.35 	f: 73.68
# RL	p: 72.73 	r: 88.89 	f: 80.00
# ST	76.23		W2V	76.25
#
# Fluid resuscitation using lactated Ringer's solution is associated with a decreased inflammatory
# response when compared with fluid resuscitation with normal saline.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (30 tok):
# R1	p: 69.57 	r: 88.89 	f: 78.05
# R2	p: 63.64 	r: 82.35 	f: 71.79
# RL	p: 69.57 	r: 88.89 	f: 78.05
# ST	85.66		W2V	84.20
#
# Lactated Ringer's solution (a balanced salt solution) is associated with a decreased inflammatory
# response when compared with fluid resuscitation with normal saline.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (24 tok):
# R1	p: 84.21 	r: 88.89 	f: 86.49
# R2	p: 77.78 	r: 82.35 	f: 80.00
# RL	p: 84.21 	r: 88.89 	f: 86.49
# ST	86.64		W2V	87.16
#
# Lactated Ringer's solution is associated with a decreased inflammatory response when compared with
# fluid resuscitation with normal saline.
#
#
# ####################################################################################################
#
# (9781910797662, 'ch07')
# Management of advanced and metastatic disease. A core principle in the management of solid tumors is
# to consider control of both the primary and metastatic disease. Several clinical scenarios occur in
# bladder cancer. Cancers that are clearly confined to the bladder can potentially be cured if the
# primary tumor can be removed or ablated, through surgery, radiation therapy or multimodality
# approaches, and there is no metastatic disease; 5-year survival rates are about 70%. Management of
# these cancers is discussed in chapter on 'Management of non-muscle-invasive disease'.
#
# Reference:
# Management of both local and distant metastatic disease should be considered.
#
# google/pegasus-large (49 tok):
# R1	p: 9.76 	r: 36.36 	f: 15.38
# R2	p: 2.50 	r: 10.00 	f: 4.00
# RL	p: 7.32 	r: 27.27 	f: 11.54
# ST	50.03		W2V	26.90
#
# Cancers that are clearly confined to the bladder can potentially be cured if the primary tumor can
# be removed or ablated, through surgery, radiation therapy or multimodality approaches, and there is
# no metastatic disease; 5-year survival rates are about 70%.
#
# google/pegasus-large (21 tok):
# R1	p: 30.00 	r: 54.55 	f: 38.71
# R2	p: 15.79 	r: 30.00 	f: 20.69
# RL	p: 30.00 	r: 54.55 	f: 38.71
# ST	66.43		W2V	28.36
#
# A core principle in the management of solid tumors is to consider control of both the primary and
# metastatic disease.
#
# google/pegasus-large (42 tok):
# R1	p: 16.67 	r: 54.55 	f: 25.53
# R2	p: 8.57 	r: 30.00 	f: 13.33
# RL	p: 16.67 	r: 54.55 	f: 25.53
# ST	62.85		W2V	20.02
#
# A core principle in the management of solid tumors is to consider control of both the primary and
# metastatic disease. The management of these cancers is discussed in chapter on 'Management of non-
# muscle-invasive disease'.
#
# google/pegasus-large (20 tok):
# R1	p: 20.00 	r: 27.27 	f: 23.08
# R2	p: 7.14 	r: 10.00 	f: 8.33
# RL	p: 20.00 	r: 27.27 	f: 23.08
# ST	51.43		W2V	13.01
#
# Management of these cancers is discussed in chapter on 'Management of non-muscle-invasive disease'.
#
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (21 tok):
# R1	p: 30.00 	r: 54.55 	f: 38.71
# R2	p: 15.79 	r: 30.00 	f: 20.69
# RL	p: 30.00 	r: 54.55 	f: 38.71
# ST	66.43		W2V	28.36
#
# A core principle in the management of solid tumors is to consider control of both the primary and
# metastatic disease.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (19 tok):
# R1	p: 33.33 	r: 54.55 	f: 41.38
# R2	p: 11.76 	r: 20.00 	f: 14.81
# RL	p: 33.33 	r: 54.55 	f: 41.38
# ST	64.70		W2V	29.59
#
# A core principle in the management of solid tumors is to consider both the primary and metastatic
# disease.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (22 tok):
# R1	p: 28.57 	r: 54.55 	f: 37.50
# R2	p: 15.00 	r: 30.00 	f: 20.00
# RL	p: 28.57 	r: 54.55 	f: 37.50
# ST	64.84		W2V	21.59
#
# A core principle in the management of solid tumors is to consider control of both the primary and
# the metastatic disease.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (20 tok):
# R1	p: 31.58 	r: 54.55 	f: 40.00
# R2	p: 16.67 	r: 30.00 	f: 21.43
# RL	p: 31.58 	r: 54.55 	f: 40.00
# ST	67.13		W2V	35.18
#
# A core principle in the management of solid tumors is to consider control of both primary and
# metastatic disease.
#
#
# ####################################################################################################
#
# (9781910797723, 'chp3')
# What types of tumor are potentially susceptible to immuno-oncology?. Clearly, the potential
# sensitivity of a given cancer to immuno-oncology therapies will depend on the ability of the tumor
# to trigger an immune response (immunogenicity). Cancer is characterized by an accumulation of
# genetic mutations, many of which result in the expression of cancer-specific antigens that can bind
# to major histocompatibility complex (MHC) class I molecules on the cancer cell surface. These
# antigen-MHC complexes can be recognized by cytotoxic CD8+ lymphocytes, that, if activated, could
# potentially mount an immune response against the tumor. As a result, tumors with high somatic
# mutation rates may be more susceptible to immuno-oncology therapies than those with lower mutation
# rates. Somatic mutation rates differ markedly, both between tumor types and within an individual
# tumor type: the rate may vary more than 1000-fold between tumors with the highest and lowest rates
# (Figure 3.2). The highest rates are seen in cancers of the skin, lung, bladder and stomach, while
# the lowest are seen in hematologic and pediatric cancers. It is noteworthy that the highest rates
# occur in tumors that are induced by carcinogens such as tobacco smoke or ultraviolet light.
#
# Reference:
# The potential sensitivity of a given cancer to immunotherapy depends on the immunogenicity of the
# tumor, which is related to the somatic mutation rate within tumor cells.- The highest mutation rates
# are seen in cancers of the skin, lung, bladder and stomach, rendering these tumor types more
# sensitive to immunotherapy.
# google/pegasus-large (26 tok):
# R1	p: 30.43 	r: 14.00 	f: 19.18
# R2	p: 9.09 	r: 4.08 	f: 5.63
# RL	p: 26.09 	r: 12.00 	f: 16.44
# ST	75.38		W2V	33.60
#
# As a result, tumors with high somatic mutation rates may be more susceptible to immuno-oncology
# therapies than those with lower mutation rates.
#
# google/pegasus-large (65 tok):
# R1	p: 28.07 	r: 32.00 	f: 29.91
# R2	p: 7.14 	r: 8.16 	f: 7.62
# RL	p: 15.79 	r: 18.00 	f: 16.82
# ST	74.99		W2V	49.03
#
# As a result, tumors with high somatic mutation rates may be more susceptible to immuno-oncology
# therapies than those with lower mutation rates. Somatic mutation rates differ markedly, both between
# tumor types and within an individual tumor type: the rate may vary more than 1000-fold between
# tumors with the highest and lowest rates (Figure 3.2).
#
# google/pegasus-large (39 tok):
# R1	p: 38.24 	r: 26.00 	f: 30.95
# R2	p: 12.12 	r: 8.16 	f: 9.76
# RL	p: 20.59 	r: 14.00 	f: 16.67
# ST	65.98		W2V	43.71
#
# Somatic mutation rates differ markedly, both between tumor types and within an individual tumor
# type: the rate may vary more than 1000-fold between tumors with the highest and lowest rates (Figure
# 3.2).
#
# google/pegasus-large (65 tok):
# R1	p: 27.59 	r: 32.00 	f: 29.63
# R2	p: 7.02 	r: 8.16 	f: 7.55
# RL	p: 15.52 	r: 18.00 	f: 16.67
# ST	74.57		W2V	49.03
#
# As a result, tumors with high somatic mutation rates may be more susceptible to immuno-oncology
# therapies than those with lower mutation rates. Somatic mutation rates differ markedly, both between
# tumor types and within an individual tumor type: the rate may vary more than 1,000-fold between
# tumors with the highest and lowest rates (Figure 3.2).
#
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (43 tok):
# R1	p: 30.56 	r: 22.00 	f: 25.58
# R2	p: 2.86 	r: 2.04 	f: 2.38
# RL	p: 16.67 	r: 12.00 	f: 13.95
# ST	58.66		W2V	54.12
#
# Cancer is characterized by an accumulation of genetic mutations, many of which result in the
# expression of cancer-specific antigens that can bind to major histocompatibility complex (MHC) class
# I molecules on the cancer cell surface.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (43 tok):
# R1	p: 31.43 	r: 22.00 	f: 25.88
# R2	p: 2.94 	r: 2.04 	f: 2.41
# RL	p: 17.14 	r: 12.00 	f: 14.12
# ST	61.12		W2V	50.10
#
# Tumors are characterized by an accumulation of genetic mutations, many of which result in the
# expression of cancer-specific antigens that bind to major histocompatibility complex (MHC) class I
# molecules on the cancer cell surface.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (23 tok):
# R1	p: 30.00 	r: 12.00 	f: 17.14
# R2	p: 10.53 	r: 4.08 	f: 5.88
# RL	p: 25.00 	r: 10.00 	f: 14.29
# ST	68.42		W2V	31.65
#
# Tumors with high somatic mutation rates may be more susceptible to immuno-oncology therapies than
# those with lower mutation rates.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (24 tok):
# R1	p: 28.57 	r: 12.00 	f: 16.90
# R2	p: 10.00 	r: 4.08 	f: 5.80
# RL	p: 23.81 	r: 10.00 	f: 14.08
# ST	66.37		W2V	34.62
#
# Tumors with high somatic mutation rates may be more susceptible to immuno-oncology therapies than
# those with lower somatic mutation rates.
#
#
# ####################################################################################################
#
# (9781910797471, 'ch02')
# Advances in the management of heart failure (HF) over the past 20 years have been informed by a
# better understanding of its pathophysiology. There are few situations in cardiology where treatment
# has been as closely linked to an appreciation of the underlying science. Vicious cycle of heart
# failure. HF is a disease of inappropriate adaptation to injury. The body has a limited range of
# compensatory responses to circulatory impairment, mainly vasoconstriction and sodium and water
# retention (see below). In general, however, these adjustments to hypovolemia are poorly suited to
# pump failure, and increases in the preload and afterload of the failing heart lead to worsening HF
# (Figure 2.1).
#
# Reference:
# Heart failure (HF) is a disease of response to injury, which is initially appropriate and becomes
# inappropriate.
#
# google/pegasus-large (39 tok):
# R1	p: 19.35 	r: 35.29 	f: 25.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 9.68 	r: 17.65 	f: 12.50
# ST	56.61		W2V	16.09
#
# In general, however, these adjustments to hypovolemia are poorly suited to pump failure, and
# increases in the preload and afterload of the failing heart lead to worsening HF (Figure 2.1).
#
# google/pegasus-large (26 tok):
# R1	p: 21.74 	r: 29.41 	f: 25.00
# R2	p: 9.09 	r: 12.50 	f: 10.53
# RL	p: 21.74 	r: 29.41 	f: 25.00
# ST	60.03		W2V	8.05
#
# Advances in the management of heart failure (HF) over the past 20 years have been informed by a
# better understanding of its pathophysiology.
#
# google/pegasus-large (33 tok):
# R1	p: 17.86 	r: 29.41 	f: 22.22
# R2	p: 7.41 	r: 12.50 	f: 9.30
# RL	p: 17.86 	r: 29.41 	f: 22.22
# ST	61.68		W2V	16.94
#
# Advances in the management of heart failure (HF) over the past 20 years have been informed by a
# better understanding of its pathophysiology. Vicious cycle of heart failure.
#
# google/pegasus-large (40 tok):
# R1	p: 19.35 	r: 35.29 	f: 25.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 9.68 	r: 17.65 	f: 12.50
# ST	55.42		W2V	16.09
#
# In general, however, these adjustments to hypovolemia are poorly suited to pump failure, and
# increases in the preload and afterload of the failing heart lead to worsening HF (Figure 2.1)..
#
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (14 tok):
# R1	p: 90.91 	r: 58.82 	f: 71.43
# R2	p: 70.00 	r: 43.75 	f: 53.85
# RL	p: 81.82 	r: 52.94 	f: 64.29
# ST	86.62		W2V	75.24
#
# Heart failure (HF) is a disease of inappropriate adaptation to injury.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (24 tok):
# R1	p: 50.00 	r: 58.82 	f: 54.05
# R2	p: 36.84 	r: 43.75 	f: 40.00
# RL	p: 45.00 	r: 52.94 	f: 48.65
# ST	77.69		W2V	51.88
#
# Heart failure (HF) is a disease of inappropriate adaptation to injury. The body has limited
# compensatory responses to circulatory impairment.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (12 tok):
# R1	p: 77.78 	r: 41.18 	f: 53.85
# R2	p: 50.00 	r: 25.00 	f: 33.33
# RL	p: 77.78 	r: 41.18 	f: 53.85
# ST	77.39		W2V	55.86
#
# Heart failure (HF) is a vicious cycle of injury.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (12 tok):
# R1	p: 66.67 	r: 35.29 	f: 46.15
# R2	p: 50.00 	r: 25.00 	f: 33.33
# RL	p: 66.67 	r: 35.29 	f: 46.15
# ST	72.48		W2V	45.43
#
# Heart failure (HF) is a vicious cycle of dysfunction.
#
#
# ####################################################################################################
#
# (9781910797815, 'chp9')
# There are no specific diagnostic criteria for MPN-BP. The principal criterion is the same as for de
# novo acute myeloid leukemia (AML): more than 20% blasts in bone marrow or peripheral blood.
# Persistence is also important if only peripheral blood blasts are considered. Importantly,
# acceleration or progression of myelofibrosis is usually apparent before the development of overt
# leukemia. Signs of this include.
#
# Reference:
# Signs of accelerating myelofibrosis may precede the development of overt leukemia.
#
# google/pegasus-large (28 tok):
# R1	p: 8.33 	r: 18.18 	f: 11.43
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 8.33 	r: 18.18 	f: 11.43
# ST	42.50		W2V	32.95
#
# The principal criterion is the same as for de novo acute myeloid leukemia (AML): more than 20%
# blasts in bone marrow or peripheral blood.
#
# google/pegasus-large (13 tok):
# R1	p: 0.00 	r: 0.00 	f: 0.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 0.00 	r: 0.00 	f: 0.00
# ST	26.00		W2V	-6.31
#
# Persistence is also important if only peripheral blood blasts are considered.
#
# google/pegasus-large (29 tok):
# R1	p: 8.33 	r: 18.18 	f: 11.43
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 8.33 	r: 18.18 	f: 11.43
# ST	42.03		W2V	33.89
#
# The principal criterion is the same as for de novo acute myelogenous leukemia (AML): more than 20%
# blasts in bone marrow or peripheral blood.
#
# google/pegasus-large (29 tok):
# R1	p: 8.33 	r: 18.18 	f: 11.43
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 8.33 	r: 18.18 	f: 11.43
# ST	41.84		W2V	32.95
#
# The principal criterion is the same as for de novo acute myeloid leukemia (AML): more than 20%
# blasts in bone marrow or peripheral blood..
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (12 tok):
# R1	p: 0.00 	r: 0.00 	f: 0.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 0.00 	r: 0.00 	f: 0.00
# ST	7.89		W2V	-9.79
#
# There are no specific diagnostic criteria for MPN-BP.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (12 tok):
# R1	p: 0.00 	r: 0.00 	f: 0.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 0.00 	r: 0.00 	f: 0.00
# ST	7.77		W2V	-1.59
#
# There is no specific diagnostic criteria for MPN-BP.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (14 tok):
# R1	p: 0.00 	r: 0.00 	f: 0.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 0.00 	r: 0.00 	f: 0.00
# ST	24.43		W2V	4.61
#
# There are no specific diagnostic criteria for myeloproliferative neoplasms-BP.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (14 tok):
# R1	p: 0.00 	r: 0.00 	f: 0.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 0.00 	r: 0.00 	f: 0.00
# ST	24.47		W2V	13.10
#
# There is no specific diagnostic criteria for myeloproliferative neoplasms-BP.
#
#
# ####################################################################################################
#
# (9783318068207, 'hh-7')
# NGS testing for predictive biomarkers. EGFR activation of the RAS/RAF/MEK/ERK pathway (see Chapter
# 1) plays an important role in oncogenesis in CRC. Up to 50% of CRCs show activating mutations of
# KRAS. Anti-EGFR antibodies, such as cetuximab and panitumumab, can be beneficial in patients with
# metastatic CRC provided that there is no downstream mutation activating the RAS/RAF/MEK/ERK pathway.
# Initially, patients with codon 12/13 KRAS mutations did not benefit in clinical trials, and
# subsequently mutations in other codons of KRAS and in NRAS were also shown to confer resistance to
# antibody-based therapies., Thus, guidelines require an 'extended' RAS analysis be performed. At
# present, the minimum testing required to determine whether anti-EGFR therapy may be of benefit is
# this extended RAS testing of KRAS and NRAS. codons 12 and 13 of exon 2. codons 59 and 61 of exon 3.
# codons 117 and 146 of exon 4. Wild-type phenotype for KRAS and NRAS is thus an indication for anti-
# EGFR therapy.
#
# Reference:
# The minimum testing required to determine whether anti-EGFR therapy may be of benefit in CRC is
# extended RAS testing of KRAS and NRAS: codons 12 and 13 of exon 2; codons 59 and 61 of exon 3; and
# codons 117 and 146 of exon 4.
#
# google/pegasus-large (58 tok):
# R1	p: 31.82 	r: 30.43 	f: 31.11
# R2	p: 9.30 	r: 8.89 	f: 9.09
# RL	p: 13.64 	r: 13.04 	f: 13.33
# ST	63.59		W2V	23.46
#
# Initially, patients with codon 12/13 KRAS mutations did not benefit in clinical trials, and
# subsequently mutations in other codons of KRAS and in NRAS were also shown to confer resistance to
# antibody-based therapies., Thus, guidelines require an 'extended' RAS analysis be performed.
#
# google/pegasus-large (45 tok):
# R1	p: 30.00 	r: 19.57 	f: 23.68
# R2	p: 3.45 	r: 2.22 	f: 2.70
# RL	p: 23.33 	r: 15.22 	f: 18.42
# ST	49.68		W2V	24.50
#
# Anti-EGFR antibodies, such as cetuximab and panitumumab, can be beneficial in patients with
# metastatic CRC provided that there is no downstream mutation activating the RAS/RAF/MEK/ERK pathway.
#
# google/pegasus-large (58 tok):
# R1	p: 31.82 	r: 30.43 	f: 31.11
# R2	p: 9.30 	r: 8.89 	f: 9.09
# RL	p: 13.64 	r: 13.04 	f: 13.33
# ST	64.07		W2V	24.56
#
# Initial, patients with codon 12/13 KRAS mutations did not benefit in clinical trials, and
# subsequently mutations in other codons of KRAS and in NRAS were also shown to confer resistance to
# antibody-based therapies., Thus, guidelines require an 'extended' RAS analysis be performed.
#
# google/pegasus-large (31 tok):
# R1	p: 88.00 	r: 47.83 	f: 61.97
# R2	p: 79.17 	r: 42.22 	f: 55.07
# RL	p: 88.00 	r: 47.83 	f: 61.97
# ST	76.95		W2V	71.88
#
# At present, the minimum testing required to determine whether anti-EGFR therapy may be of benefit is
# this extended RAS testing of KRAS and NRAS.
#
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (45 tok):
# R1	p: 33.33 	r: 26.09 	f: 29.27
# R2	p: 2.86 	r: 2.22 	f: 2.50
# RL	p: 19.44 	r: 15.22 	f: 17.07
# ST	51.29		W2V	38.64
#
# Up to 50% of CRCs show activating mutations of the RAS/RAF/MEK/ERK pathway, and anti-EGFR antibodies
# can be beneficial in patients with metastatic CRC provided there is no downstream mutation
# activating the pathway.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (44 tok):
# R1	p: 31.43 	r: 23.91 	f: 27.16
# R2	p: 2.94 	r: 2.22 	f: 2.53
# RL	p: 20.00 	r: 15.22 	f: 17.28
# ST	53.11		W2V	33.43
#
# Up to 50% of CRCs show activating mutations of the RAS/RAF/MEK/ERK pathway; anti-EGFR antibodies can
# be beneficial in patients with metastatic CRC provided there is no downstream mutation activating
# the pathway.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (67 tok):
# R1	p: 40.00 	r: 47.83 	f: 43.56
# R2	p: 25.93 	r: 31.11 	f: 28.28
# RL	p: 30.91 	r: 36.96 	f: 33.66
# ST	67.67		W2V	55.51
#
# Up to 50% of CRCs show activating mutations of the RAS/RAF/MEK/ERK pathway, and anti-EGFR antibodies
# can be beneficial in patients with metastatic CRC provided there is no downstream mutation
# activating the pathway. The minimum testing required to determine whether anti-EGFR therapy may be
# of benefit is this extended RAS analysis.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (69 tok):
# R1	p: 39.29 	r: 47.83 	f: 43.14
# R2	p: 25.45 	r: 31.11 	f: 28.00
# RL	p: 30.36 	r: 36.96 	f: 33.33
# ST	66.93		W2V	57.52
#
# Up to 50% of CRCs show activating mutations of the RAS/RAF/MEK/ERK pathway, and anti-EGFR antibodies
# can be beneficial in patients with metastatic CRC provided there is no downstream mutation
# activating the pathway. However, the minimum testing required to determine whether anti-EGFR therapy
# may be of benefit is this extended RAS analysis.
#
#
# ####################################################################################################
#
# (9781910797815, 'chp4')
# Management of low-risk patients. Treatment to reduce cardiovascular risk factors, and promotion of a
# generally healthy lifestyle, may be sufficient intervention for very-low-risk patients. Smoking
# cessation should be actively promoted because cigarette smoking has been shown to be an independent
# risk factor for thrombosis in patients with ET. Low-dose aspirin has been shown to reduce both
# microvascular symptoms (exempli gratia erythromelalgia) and transient neurological and visual
# disturbances such as hemiparesis, scintillating scotomas, amaurosis fugax (transcient monocular
# blindness) and seizures. There is also evidence that antiplatelet therapy reduces the risk of venous
# thrombosis in patients with JAK2 V617F mutations and cardiovascular risk factors (arterial
# thrombosis). Higher doses of aspirin (up to 500 mg daily) may be required in patients with acute
# erythromelalgia.
#
# Reference:
# All patients should receive interventions to reduce cardiovascular risk factors, particularly
# smoking cessation advice.
#
# google/pegasus-large (27 tok):
# R1	p: 27.27 	r: 42.86 	f: 33.33
# R2	p: 19.05 	r: 30.77 	f: 23.53
# RL	p: 22.73 	r: 35.71 	f: 27.78
# ST	71.87		W2V	38.48
#
# Treatment to reduce cardiovascular risk factors, and promotion of a generally healthy lifestyle, may
# be sufficient intervention for very-low-risk patients.
#
# google/pegasus-large (61 tok):
# R1	p: 12.77 	r: 42.86 	f: 19.67
# R2	p: 8.70 	r: 30.77 	f: 13.56
# RL	p: 10.64 	r: 35.71 	f: 16.39
# ST	64.43		W2V	33.55
#
# Treatment to reduce cardiovascular risk factors, and promotion of a generally healthy lifestyle, may
# be sufficient intervention for very-low-risk patients. There is also evidence that antiplatelet
# therapy reduces the risk of venous thrombosis in patients with JAK2 V617F mutations and
# cardiovascular risk factors (arterial thrombosis).
#
# google/pegasus-large (34 tok):
# R1	p: 16.00 	r: 28.57 	f: 20.51
# R2	p: 8.33 	r: 15.38 	f: 10.81
# RL	p: 16.00 	r: 28.57 	f: 20.51
# ST	48.91		W2V	12.94
#
# There is also evidence that antiplatelet therapy reduces the risk of venous thrombosis in patients
# with JAK2 V617F mutations and cardiovascular risk factors (arterial thrombosis).
#
# google/pegasus-large (61 tok):
# R1	p: 12.77 	r: 42.86 	f: 19.67
# R2	p: 8.70 	r: 30.77 	f: 13.56
# RL	p: 10.64 	r: 35.71 	f: 16.39
# ST	64.29		W2V	34.80
#
# Treatment to reduce cardiovascular risk factors, and promotion of a generally healthy lifestyle, may
# be sufficient intervention for very-low-risk patients. There is also evidence that antiplatelet
# therapy reduces the risk of venous thrombosis in patients with JAK2 V617F mutation and
# cardiovascular risk factors (arterial thrombosis).
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (27 tok):
# R1	p: 27.27 	r: 42.86 	f: 33.33
# R2	p: 19.05 	r: 30.77 	f: 23.53
# RL	p: 22.73 	r: 35.71 	f: 27.78
# ST	71.87		W2V	38.48
#
# Treatment to reduce cardiovascular risk factors, and promotion of a generally healthy lifestyle, may
# be sufficient intervention for very-low-risk patients.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (33 tok):
# R1	p: 10.00 	r: 14.29 	f: 11.76
# R2	p: 5.26 	r: 7.69 	f: 6.25
# RL	p: 10.00 	r: 14.29 	f: 11.76
# ST	33.36		W2V	17.57
#
# Low-dose aspirin has been shown to reduce both microvascular symptoms (exempli gratia
# erythromelalgia) and transient neurological and visual disturbances.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (24 tok):
# R1	p: 14.29 	r: 21.43 	f: 17.14
# R2	p: 5.00 	r: 7.69 	f: 6.06
# RL	p: 9.52 	r: 14.29 	f: 11.43
# ST	38.64		W2V	26.16
#
# Low-dose aspirin has been shown to reduce both microvascular symptoms and transient neurological and
# visual disturbances in patients with ET.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (20 tok):
# R1	p: 11.76 	r: 14.29 	f: 12.90
# R2	p: 6.25 	r: 7.69 	f: 6.90
# RL	p: 11.76 	r: 14.29 	f: 12.90
# ST	37.42		W2V	20.69
#
# Low-dose aspirin has been shown to reduce both microvascular symptoms and transient neurological and
# visual disturbances.
#
#
# ####################################################################################################
#
# (9781908541277, 'ch_11')
# There are no clear data indicating differences in safety among PHT, CBZ, PB and PRM. Current
# evidence suggests that the risk of major congenital malformations is two to four times higher with
# the use of VPA than with other AEDs such as CBZ and LTG. Absolute rates have ranged from 6% to 11%,
# although the risk may be minimized by keeping daily doses at or below 1000 mg. High-dose exposure to
# VPA in utero may impair later cognitive function. The teratogenic risk associated with LTG
# monotherapy is low and is similar to that associated with CBZ, although preliminary data suggest the
# possibility of greater risk of major malformations at higher dosage. There are still insufficient
# data regarding the safety of other modern AEDs.
#
# Reference:
# The risk of major malformations in babies exposed in utero seems to be greater with sodium valproate
# (VPA) than with other AEDs.
#
# google/pegasus-large (40 tok):
# R1	p: 28.12 	r: 40.91 	f: 33.33
# R2	p: 9.68 	r: 14.29 	f: 11.54
# RL	p: 15.62 	r: 22.73 	f: 18.52
# ST	58.25		W2V	50.85
#
# The teratogenic risk associated with LTG monotherapy is low and is similar to that associated with
# CBZ, although preliminary data suggest the possibility of greater risk of major malformations at
# higher dosage.
#
# google/pegasus-large (36 tok):
# R1	p: 40.00 	r: 54.55 	f: 46.15
# R2	p: 24.14 	r: 33.33 	f: 28.00
# RL	p: 40.00 	r: 54.55 	f: 46.15
# ST	73.07		W2V	52.32
#
# Current evidence suggests that the risk of major congenital malformations is two to four times
# higher with the use of VPA than with other AEDs such as CBZ and LTG.
#
# google/pegasus-large (40 tok):
# R1	p: 28.12 	r: 40.91 	f: 33.33
# R2	p: 9.68 	r: 14.29 	f: 11.54
# RL	p: 15.62 	r: 22.73 	f: 18.52
# ST	57.64		W2V	50.51
#
# A teratogenic risk associated with LTG monotherapy is low and is similar to that associated with
# CBZ, although preliminary data suggest the possibility of greater risk of major malformations at
# higher dosage.
#
# google/pegasus-large (41 tok):
# R1	p: 28.12 	r: 40.91 	f: 33.33
# R2	p: 9.68 	r: 14.29 	f: 11.54
# RL	p: 15.62 	r: 22.73 	f: 18.52
# ST	55.30		W2V	50.85
#
# The teratogenic risk associated with LTG monotherapy is low and is similar to that associated with
# CBZ, although preliminary data suggest the possibility of greater risk of major malformations at
# higher dosage..
#
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (14 tok):
# R1	p: 16.67 	r: 9.09 	f: 11.76
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 16.67 	r: 9.09 	f: 11.76
# ST	38.56		W2V	20.84
#
# There are no clear data indicating differences in safety among modern AEDs.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (14 tok):
# R1	p: 16.67 	r: 9.09 	f: 11.76
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 16.67 	r: 9.09 	f: 11.76
# ST	38.66		W2V	22.91
#
# There is no clear data indicating differences in safety among modern AEDs.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (14 tok):
# R1	p: 16.67 	r: 9.09 	f: 11.76
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 16.67 	r: 9.09 	f: 11.76
# ST	39.66		W2V	23.65
#
# There are no clear data indicating differences in safety between modern AEDs.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (13 tok):
# R1	p: 18.18 	r: 9.09 	f: 12.12
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 18.18 	r: 9.09 	f: 12.12
# ST	38.48		W2V	18.06
#
# There are no clear data indicating differences in safety among AEDs.
#
#
# ####################################################################################################

# %% [markdown]
# #### Print Test Examples

# %%
print_examples([
    'google/pegasus-large',
    bucket_dir+'fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/'],
    df_test)
# Out:
# (9781908541277, 'ch_8')
# Indications. OXC has a similar spectrum of efficacy to CBZ against partial and tonic-clonic
# seizures. It tends to be better tolerated than CBZ with fewer neurotoxic side effects. Dosage. The
# recommended starting dose for OXC in adults is 150-600 mg daily in two doses. The dose can be
# titrated upwards as clinically indicated to 3000-4000 mg daily. A starting dose of 5 mg/kg daily in
# children over 3 years of age can be prescribed, increasing gradually to a maintenance dose of about
# 30 mg/kg daily. Patients already on CBZ may be switched immediately to OXC using a dosage ratio of
# 1.5 OXC to 1 CBZ. Particular care in immediate switching needs to be taken when the daily CBZ dose
# exceeds 1200 mg. Plasma concentrations of the clinically active metabolite of OXC increase linearly
# with dose. No studies, however, have attempted to relate elevated plasma levels to efficacy or
# toxicity.
#
# Reference:
# This wider choice of AEDs permits pharmacological treatment to be better matched to the individual
# patient's circumstances.
#
# google/pegasus-large (34 tok):
# R1	p: 10.00 	r: 16.67 	f: 12.50
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 10.00 	r: 16.67 	f: 12.50
# ST	28.12		W2V	16.72
#
# A starting dose of 5 mg/kg daily in children over 3 years of age can be prescribed, increasing
# gradually to a maintenance dose of about 30 mg/kg daily.
#
# google/pegasus-large (25 tok):
# R1	p: 19.05 	r: 22.22 	f: 20.51
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 9.52 	r: 11.11 	f: 10.26
# ST	36.58		W2V	11.01
#
# Patients already on CBZ may be switched immediately to OXC using a dosage ratio of 1.5 OXC to 1 CBZ.
#
# google/pegasus-large (18 tok):
# R1	p: 6.25 	r: 5.56 	f: 5.88
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 6.25 	r: 5.56 	f: 5.88
# ST	30.41		W2V	-0.36
#
# The recommended starting dose for OXC in adults is 150-600 mg daily in two doses.
#
# google/pegasus-large (16 tok):
# R1	p: 15.38 	r: 11.11 	f: 12.90
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 15.38 	r: 11.11 	f: 12.90
# ST	23.90		W2V	0.46
#
# Plasma concentrations of the clinically active metabolite of OXC increase linearly with dose.
#
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (20 tok):
# R1	p: 13.33 	r: 11.11 	f: 12.12
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 13.33 	r: 11.11 	f: 12.12
# ST	34.39		W2V	-0.21
#
# OXC has a similar spectrum of efficacy to CBZ against partial and tonic-clonic seizures.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (19 tok):
# R1	p: 14.29 	r: 11.11 	f: 12.50
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 14.29 	r: 11.11 	f: 12.50
# ST	34.88		W2V	-0.21
#
# OXC has similar spectrum of efficacy to CBZ against partial and tonic-clonic seizures.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (16 tok):
# R1	p: 7.14 	r: 5.56 	f: 6.25
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 7.14 	r: 5.56 	f: 6.25
# ST	32.29		W2V	4.27
#
# The recommended starting dose for OXC is 150-600 mg daily in two doses.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (17 tok):
# R1	p: 8.33 	r: 5.56 	f: 6.67
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 8.33 	r: 5.56 	f: 6.67
# ST	32.01		W2V	-1.77
#
# OXC has similar efficacy to CBZ against partial and tonic-clonic seizures.
#
#
# ####################################################################################################
#
# (9781910797426, 'ch03')
# Symptoms and signs include pain or tenderness and guarding in the right upper quadrant, nausea and
# vomiting, fever, fast pulse (tachycardia) and a positive Murphy's sign (transient cessation of
# breathing due to pain during inspiration while the right upper quadrant is palpated, but not the
# left upper quadrant). Complications include empyema, perforation of the gallbladder, liver abscess
# and emphysematous cholecystitis. An inflamed and distended gallbladder may obstruct the main bile
# duct by pressure from a gallstone causing obstructive jaundice (Mirizzi's syndrome). Laboratory
# tests. Leukocytosis and mild elevation in serum bilirubin and transaminases may be present.
# Transabdominal ultrasonography is the most useful test for acute cholecystitis as it establishes the
# presence of gallstones (Figure 3.5). A thickened gallbladder wall (> 4 mm) and pericholecystic fluid
# are highly suggestive of acute cholecystitis (Figure 3.6). Sonographic Murphy's sign (tenderness
# over the gallbladder from the ultrasound transducer during imaging) is also diagnostic. Radionuclide
# scanning is a useful test if ultrasound is non-diagnostic or inconclusive but there is clinical
# suspicion of acute cholecystitis. A Tc-HIDA (hepatobiliary iminodiacetic acid) scan uses a
# technetium-labeled analog of iminodiacetic acid. Non-visualization of the gallbladder with
# visualization of the tracer in the CBD and the small intestine is consistent with cystic duct
# obstruction. This test is about 95% accurate for the diagnosis of acute cholecystitis. Computed
# tomography is useful for identifying local complications of acute cholecystitis (Figure 3.7).
# Medical treatment of acute cholecystitis involves.
#
# Reference:
# Transabdominal ultrasound is the imaging test of choice, with an accuracy of over 95%, for the
# diagnosis of gallstones in either acute or chronic cholecystitis. A Tc-HIDA (hepatobiliary
# iminodiacetic acid) scan is 95% accurate for the diagnosis of acute cholecystitis.
#
# google/pegasus-large (27 tok):
# R1	p: 50.00 	r: 24.39 	f: 32.79
# R2	p: 15.79 	r: 7.50 	f: 10.17
# RL	p: 45.00 	r: 21.95 	f: 29.51
# ST	69.28		W2V	54.62
#
# Transabdominal ultrasonography is the most useful test for acute cholecystitis as it establishes the
# presence of gallstones (Figure 3.5).
#
# google/pegasus-large (19 tok):
# R1	p: 35.71 	r: 12.20 	f: 18.18
# R2	p: 15.38 	r: 5.00 	f: 7.55
# RL	p: 35.71 	r: 12.20 	f: 18.18
# ST	58.32		W2V	47.89
#
# Computed tomography is useful for identifying local complications of acute cholecystitis (Figure
# 3.7).
#
# google/pegasus-large (56 tok):
# R1	p: 39.02 	r: 39.02 	f: 39.02
# R2	p: 12.50 	r: 12.50 	f: 12.50
# RL	p: 29.27 	r: 29.27 	f: 29.27
# ST	78.20		W2V	56.98
#
# Transabdominal ultrasonography is the most useful test for acute cholecystitis as it establishes the
# presence of gallstones (Figure 3.5). Radionuclide scanning is a useful test if ultrasound is non-
# diagnostic or inconclusive but there is clinical suspicion of acute cholecystiti.
#
# google/pegasus-large (56 tok):
# R1	p: 41.46 	r: 41.46 	f: 41.46
# R2	p: 12.50 	r: 12.50 	f: 12.50
# RL	p: 31.71 	r: 31.71 	f: 31.71
# ST	77.70		W2V	60.65
#
# Transabdominal ultrasonography is the most useful test for acute cholecystitis as it establishes the
# presence of gallstones (Figure 3.5). Radionuclide scanning is a useful test if ultrasound is non-
# diagnostic or inconclusive but there is clinical suspicion of acute Cholecystitis.
#
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (62 tok):
# R1	p: 33.33 	r: 34.15 	f: 33.73
# R2	p: 9.76 	r: 10.00 	f: 9.88
# RL	p: 23.81 	r: 24.39 	f: 24.10
# ST	74.66		W2V	42.49
#
# Transabdominal ultrasonography is the most useful test for acute cholecystitis as it establishes the
# presence of gallstones. A thickened gallbladder wall (> 4 mm) and pericholecystic fluid are highly
# suggestive. Radionuclide scanning is a useful test if ultrasound is non-diagnostic or inconclusive.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (43 tok):
# R1	p: 54.84 	r: 41.46 	f: 47.22
# R2	p: 40.00 	r: 30.00 	f: 34.29
# RL	p: 48.39 	r: 36.59 	f: 41.67
# ST	77.84		W2V	54.23
#
# Radionuclide scanning is a useful test if ultrasound is non-diagnostic or inconclusive but there is
# clinical suspicion of acute cholecystitis. A Tc-HIDA scan is 95% accurate for the diagnosis.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (84 tok):
# R1	p: 29.31 	r: 41.46 	f: 34.34
# R2	p: 7.02 	r: 10.00 	f: 8.25
# RL	p: 17.24 	r: 24.39 	f: 20.20
# ST	74.48		W2V	39.42
#
# Transabdominal ultrasonography is the most useful test for acute cholecystitis as it establishes the
# presence of gallstones. A thickened gallbladder wall (> 4 mm) and pericholecystic fluid are highly
# suggestive. A sonographic Murphy's sign (tenderness over the gallbladder from the ultrasound
# transducer during imaging) is also diagnostic. Radionuclide scanning is useful if ultrasound is non-
# diagnostic or inconclusive.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (44 tok):
# R1	p: 37.93 	r: 26.83 	f: 31.43
# R2	p: 10.71 	r: 7.50 	f: 8.82
# RL	p: 31.03 	r: 21.95 	f: 25.71
# ST	68.07		W2V	46.18
#
# Transabdominal ultrasonography is the most useful test for acute cholecystitis as it establishes the
# presence of gallstones. A thickened gallbladder wall (> 4 mm) and pericholecystic fluid are highly
# suggestive.
#
#
# ####################################################################################################
#
# (9781910797907, 'chp2')
# As discussed in Chapter 1, mutations in the PKLR gene on chromosome 1 are responsible for PK
# deficiency. More than 300 different mutations have been reported; most are very rare, occurring only
# once. Currently, about 25% of patients diagnosed with PK deficiency appear to have a previously
# unrecorded mutation. Although many of the mutations associated with PK deficiency are rare, a few
# are recorded more frequently (Table 2.1). The variability in how PK deficiency manifests is thought
# to reflect the heterogeneity of these causative mutations, as well as the fact that most individuals
# with PK deficiency will be compound heterozygotes (id est they will have a different mutation in
# each copy of the PKLR gene).
#
# Reference:
# About one quarter of patients diagnosed with PK deficiency will have a previously unrecorded
# mutation in the PKLR gene.
# google/pegasus-large (54 tok):
# R1	p: 25.53 	r: 63.16 	f: 36.36
# R2	p: 17.39 	r: 44.44 	f: 25.00
# RL	p: 25.53 	r: 63.16 	f: 36.36
# ST	78.01		W2V	55.99
#
# The variability in how PK deficiency manifests is thought to reflect the heterogeneity of these
# causative mutations, as well as the fact that most individuals with PK deficiency will be compound
# heterozygotes (id est they will have a different mutation in each copy of the PKLR gene).
#
# google/pegasus-large (74 tok):
# R1	p: 18.46 	r: 63.16 	f: 28.57
# R2	p: 14.06 	r: 50.00 	f: 21.95
# RL	p: 18.46 	r: 63.16 	f: 28.57
# ST	79.25		W2V	55.93
#
# As discussed in Chapter 1, mutations in the PKLR gene on chromosome 1 are responsible for PK
# deficiency. The variability in how PK deficiency manifests is thought to reflect the heterogeneity
# of these causative mutations, as well as the fact that most individuals with PK deficiency will be
# compound heterozygotes (id est they will have a different mutation in each copy of the PKLR gene).
#
# google/pegasus-large (74 tok):
# R1	p: 18.46 	r: 63.16 	f: 28.57
# R2	p: 14.06 	r: 50.00 	f: 21.95
# RL	p: 18.46 	r: 63.16 	f: 28.57
# ST	79.37		W2V	55.68
#
# As discussed in Chapter 1, mutations in the PKLR gene on chromosome 1 are responsible for PK
# deficiency. The variability in how PK deficiency manifests is thought to reflect the heterogeneity
# of these causative mutations, as well as the fact that most individuals with PK deficiency will be
# compound heterozygotes (id est them will have a different mutation in each copy of the PKLR gene).
#
# google/pegasus-large (55 tok):
# R1	p: 25.53 	r: 63.16 	f: 36.36
# R2	p: 17.39 	r: 44.44 	f: 25.00
# RL	p: 25.53 	r: 63.16 	f: 36.36
# ST	77.45		W2V	55.99
#
# The variability in how PK deficiency manifests is thought to reflect the heterogeneity of these
# causative mutations, as well as the fact that most individuals with PK deficiency will be compound
# heterozygotes (id est they will have a different mutation in each copy of the PKLR gene)..
#
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (16 tok):
# R1	p: 46.15 	r: 31.58 	f: 37.50
# R2	p: 33.33 	r: 22.22 	f: 26.67
# RL	p: 30.77 	r: 21.05 	f: 25.00
# ST	67.80		W2V	34.91
#
# Mutations in the PKLR gene on chromosome 1 are responsible for PK deficiency.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (14 tok):
# R1	p: 54.55 	r: 31.58 	f: 40.00
# R2	p: 40.00 	r: 22.22 	f: 28.57
# RL	p: 36.36 	r: 21.05 	f: 26.67
# ST	66.33		W2V	38.30
#
# Mutations in the PKLR gene on chromosome 1 cause PK deficiency.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (11 tok):
# R1	p: 75.00 	r: 31.58 	f: 44.44
# R2	p: 57.14 	r: 22.22 	f: 32.00
# RL	p: 50.00 	r: 21.05 	f: 29.63
# ST	68.25		W2V	41.16
#
# Mutations in the PKLR gene cause PK deficiency.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (13 tok):
# R1	p: 60.00 	r: 31.58 	f: 41.38
# R2	p: 44.44 	r: 22.22 	f: 29.63
# RL	p: 40.00 	r: 21.05 	f: 27.59
# ST	68.84		W2V	36.49
#
# Mutations in the PKLR gene are responsible for PK deficiency.
#
#
# ####################################################################################################
#
# (9781910797105, 'ch05')
# The risk is further increased if minor psychotic symptoms pre-exist and if cannabis use starts early
# in adolescence. Research suggests that this effect of cannabis may be mediated by a particular gene.
# Those with a specific version of the catechol- O -methyltransferase (COMT) gene, carried by about a
# quarter of the general population, appear to be especially prone to psychosis after cannabis use.
# Delta-9-THC, the active component of cannabis, disrupts learning and recall in schizophrenia.
# Psychosocial risk factors. There is emerging evidence for the role of non-biological risk factors in
# schizophrenia, such as the effects of urban upbringing and of ethnicity, as noted in Chapter 3.
#
# Reference:
# Psychosocial risk factors are being re-established as important risk factors.
#
# google/pegasus-large (42 tok):
# R1	p: 0.00 	r: 0.00 	f: 0.00
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 0.00 	r: 0.00 	f: 0.00
# ST	18.32		W2V	8.65
#
# Those with a specific version of the catechol- O -methyltransferase (COMT) gene, carried by about a
# quarter of the general population, appear to be especially prone to psychosis after cannabis use.
#
# google/pegasus-large (47 tok):
# R1	p: 8.82 	r: 27.27 	f: 13.33
# R2	p: 6.06 	r: 20.00 	f: 9.30
# RL	p: 8.82 	r: 27.27 	f: 13.33
# ST	35.03		W2V	31.26
#
# Those with a specific version of the catechol- O -methyltransferase (COMT) gene, carried by about a
# quarter of the general population, appear to be especially prone to psychosis after cannabis use.
# Psychosocial risk factors.
#
# google/pegasus-large (63 tok):
# R1	p: 2.00 	r: 9.09 	f: 3.28
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 2.00 	r: 9.09 	f: 3.28
# ST	32.21		W2V	18.45
#
# The risk is further increased if minor psychotic symptoms pre-exist and if cannabis use starts early
# in adolescence. Those with a specific version of the catechol- O -methyltransferase (COMT) gene,
# carried by about a quarter of the general population, appear to be especially prone to psychosis
# after cannabis use.
#
# google/pegasus-large (63 tok):
# R1	p: 2.00 	r: 9.09 	f: 3.28
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 2.00 	r: 9.09 	f: 3.28
# ST	31.06		W2V	18.28
#
# Those with a specific version of the catechol- O -methyltransferase (COMT) gene, carried by about a
# quarter of the general population, appear to be especially prone to psychosis after cannabis use.
# The risk is further increased if minor psychotic symptoms pre-exist and if cannabis use starts early
# in adolescence.
#
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (17 tok):
# R1	p: 28.57 	r: 36.36 	f: 32.00
# R2	p: 23.08 	r: 30.00 	f: 26.09
# RL	p: 28.57 	r: 36.36 	f: 32.00
# ST	57.14		W2V	45.81
#
# Psychosocial risk factors are emerging, including the effects of urban upbringing and of ethnicity.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (16 tok):
# R1	p: 30.77 	r: 36.36 	f: 33.33
# R2	p: 25.00 	r: 30.00 	f: 27.27
# RL	p: 30.77 	r: 36.36 	f: 33.33
# ST	57.21		W2V	48.37
#
# Psychosocial risk factors are emerging, including the effects of urban upbringing and ethnicity.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (18 tok):
# R1	p: 38.46 	r: 45.45 	f: 41.67
# R2	p: 16.67 	r: 20.00 	f: 18.18
# RL	p: 30.77 	r: 36.36 	f: 33.33
# ST	60.46		W2V	52.48
#
# Psychosocial risk factors, such as family history, urban upbringing and ethnicity, are emerging.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (13 tok):
# R1	p: 40.00 	r: 36.36 	f: 38.10
# R2	p: 33.33 	r: 30.00 	f: 31.58
# RL	p: 40.00 	r: 36.36 	f: 38.10
# ST	59.41		W2V	53.63
#
# Psychosocial risk factors are emerging, including urban upbringing and ethnicity.
#
#
# ####################################################################################################
#
# (9781908541680, 'ch_4')
# Overweight/obesity as a whole predisposes to, or is associated with, numerous cardiac complications
# such as coronary heart disease (CHD), atrial fibrillation, heart failure and sudden cardiac death as
# a result of abnormalities in blood glucose, lipids, blood pressure, coagulation and inflammation.
# Independent of any of the other known cardiometabolic risk factors, obesity is associated with
# hypertension, tachycardia, left ventricular hypertrophy, increased collagen deposition, reduced
# cardiac contractility and increased end-diastolic pressure. The major circulatory complications are
# increased total and pulmonary blood volume, high cardiac output and elevated left ventricular end-
# diastolic pressure.
#
# Reference:
# Obesity significantly affects cardiometabolic status and risk.
#
# google/pegasus-large (25 tok):
# R1	p: 4.76 	r: 14.29 	f: 7.14
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 4.76 	r: 14.29 	f: 7.14
# ST	42.81		W2V	6.38
#
# The major circulatory complications are increased total and pulmonary blood volume, high cardiac
# output and elevated left ventricular end-diastolic pressure.
#
# google/pegasus-large (41 tok):
# R1	p: 13.33 	r: 57.14 	f: 21.62
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 6.67 	r: 28.57 	f: 10.81
# ST	59.81		W2V	19.95
#
# Independent of any of the other known cardiometabolic risk factors, obesity is associated with
# hypertension, tachycardia, left ventricular hypertrophy, increased collagen deposition, reduced
# cardiac contractility and increased end-diastolic pressure.
#
# google/pegasus-large (24 tok):
# R1	p: 5.00 	r: 14.29 	f: 7.41
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 5.00 	r: 14.29 	f: 7.41
# ST	42.56		W2V	-1.00
#
# The major circulatory complications are increased total pulmonary blood volume, high cardiac output
# and elevated left ventricular end-diastolic pressure.
#
# google/pegasus-large (41 tok):
# R1	p: 13.33 	r: 57.14 	f: 21.62
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 6.67 	r: 28.57 	f: 10.81
# ST	58.94		W2V	20.70
#
# Independent of any of the other known cardiometabolic risk factors, obesity is associated with
# hypertension, tachycardia, left ventricular hypertrophy, decreased collagen deposition, reduced
# cardiac contractility and increased end-diastolic pressure.
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (51 tok):
# R1	p: 5.26 	r: 28.57 	f: 8.89
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 5.26 	r: 28.57 	f: 8.89
# ST	56.47		W2V	6.21
#
# Overweight/obesity as a whole predisposes to numerous cardiac complications such as coronary heart
# disease (CHD), atrial fibrillation, heart failure and sudden cardiac death as a result of
# abnormalities in blood glucose, lipids, blood pressure, coagulation and inflammation.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (40 tok):
# R1	p: 7.14 	r: 28.57 	f: 11.43
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 7.14 	r: 28.57 	f: 11.43
# ST	53.07		W2V	6.14
#
# Overweight/obesity as a whole predisposes to, or is associated with, numerous cardiac complications
# such as coronary heart disease (CHD), atrial fibrillation, heart failure and sudden cardiac death.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (37 tok):
# R1	p: 7.41 	r: 28.57 	f: 11.76
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 7.41 	r: 28.57 	f: 11.76
# ST	55.20		W2V	4.38
#
# Overweight/obesity as a whole predisposes to, or is associated with, numerous cardiac complications
# such as coronary heart disease, atrial fibrillation, heart failure and sudden cardiac death.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (52 tok):
# R1	p: 5.13 	r: 28.57 	f: 8.70
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 5.13 	r: 28.57 	f: 8.70
# ST	56.91		W2V	5.12
#
# Overweight/obesity as a whole predisposes to numerous cardiac complications such as coronary heart
# disease (CHD), atrial fibrillation, heart failure and sudden cardiac death as a result of
# abnormalities in blood glucose, lipids, blood pressure, coagulation and inflammatory response.
#
#
# ####################################################################################################
#
# (9781908541024, 'ch_12')
# The vast majority of primary brain tumors occur sporadically, but a small number appear to be
# familial. The etiology of sporadic brain tumors is unknown, but environmental factors are suspected.
# Most patients with a family history of primary brain tumors have a hereditary disease that is known
# to be associated with such tumors, such as tuberous sclerosis, neurofibromatosis, familial polyposis
# or Li-Fraumeni syndrome. However, some patients do not have any underlying or obvious hereditary
# disorder that would predispose them to primary brain tumors, but nevertheless give a striking
# history of these tumors in first-degree relatives. Usually, the tumors are found to be high-grade
# gliomas.
#
# Reference:
# There are several syndromes associated with an inherited predisposition to a variety of brain
# tumors. However, the vast majority of brain tumors are not inherited.
#
# google/pegasus-large (46 tok):
# R1	p: 23.53 	r: 32.00 	f: 27.12
# R2	p: 6.06 	r: 8.33 	f: 7.02
# RL	p: 17.65 	r: 24.00 	f: 20.34
# ST	71.47		W2V	34.97
#
# Most patients with a family history of primary brain tumors have a hereditary disease that is known
# to be associated with such tumors, such as tuberous sclerosis, neurofibromatosis, familial polyposis
# or Li-Fraumeni syndrome.
#
# google/pegasus-large (46 tok):
# R1	p: 23.53 	r: 32.00 	f: 27.12
# R2	p: 6.06 	r: 8.33 	f: 7.02
# RL	p: 17.65 	r: 24.00 	f: 20.34
# ST	71.18		W2V	34.97
#
# Most patients with a family history of primary brain tumors have a hereditary disease that is known
# to be associated with such tumors, such as tuberous sclerosis, Neurofibromatosis, familial polyposis
# or Li-Fraumeni syndrome.
#
# google/pegasus-large (49 tok):
# R1	p: 22.86 	r: 32.00 	f: 26.67
# R2	p: 5.88 	r: 8.33 	f: 6.90
# RL	p: 17.14 	r: 24.00 	f: 20.00
# ST	72.41		W2V	34.97
#
# Most patients with a family history of primary brain tumors have a hereditary disease that is known
# to be associated with such tumors, such as tuberous sclerosis, neurodegeneration, neurofibromatosis,
# familial polyposis or Li-Fraumeni syndrome.
#
# google/pegasus-large (37 tok):
# R1	p: 24.24 	r: 32.00 	f: 27.59
# R2	p: 3.12 	r: 4.17 	f: 3.57
# RL	p: 15.15 	r: 20.00 	f: 17.24
# ST	67.40		W2V	37.74
#
# However, some patients do not have any underlying or obvious hereditary disorder that would
# predispose them to primary brain tumors, but nevertheless give a striking history of these tumors in
# first-degree relatives.
#
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (19 tok):
# R1	p: 47.06 	r: 32.00 	f: 38.10
# R2	p: 25.00 	r: 16.67 	f: 20.00
# RL	p: 35.29 	r: 24.00 	f: 28.57
# ST	68.69		W2V	44.46
#
# The vast majority of primary brain tumors occur sporadically, but a small number appear to be
# familial.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (24 tok):
# R1	p: 34.78 	r: 32.00 	f: 33.33
# R2	p: 9.09 	r: 8.33 	f: 8.70
# RL	p: 26.09 	r: 24.00 	f: 25.00
# ST	72.56		W2V	46.39
#
# Most patients with a family history of primary brain tumors have a hereditary disease that is known
# to be associated with such tumors.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (18 tok):
# R1	p: 50.00 	r: 32.00 	f: 39.02
# R2	p: 26.67 	r: 16.67 	f: 20.51
# RL	p: 37.50 	r: 24.00 	f: 29.27
# ST	68.46		W2V	43.63
#
# The vast majority of primary brain tumors occur sporadically; a small number appear to be familial.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (10 tok):
# R1	p: 66.67 	r: 24.00 	f: 35.29
# R2	p: 50.00 	r: 16.67 	f: 25.00
# RL	p: 66.67 	r: 24.00 	f: 35.29
# ST	69.42		W2V	61.85
#
# The vast majority of primary brain tumors occur sporadically.
#
#
# ####################################################################################################
#
# (9781910797211, 'ch04')
# Dopamine agonist versus levodopa. In younger patients, the issues of neuroprotection and dyskinesias
# should be considered. The results of four controlled dopamine-agonist monotherapy trials have been
# published and suggest that initiation of treatment with an agonist is beneficial in the early stages
# of Parkinson's disease. However, the results of the PD Med study, a multicenter real-life pragmatic
# study, reporting on quality of life-related outcomes in both young and old patients with Parkinson's
# disease, is likely to generate considerable controversy regarding the use of dopamine agonists and
# the choice of initial therapy. In total, 1620 patients with early Parkinson's disease were recruited
# and given one of three initial treatment regimens. levodopa formulation (528 patients). levodopa-
# sparing strategy - dopamine agonist (632 patients). levodopa-sparing strategy - MAOB inhibitor
# (selegiline; 460 patients). The study started in 2000 with a median follow-up of 3 years and maximum
# of 7 years. During this time the dopamine agonists varied, including ergot agonists that are no
# longer in widespread use. The randomization to levodopa or alternative regimens was at the
# discretion of the clinician and a large part of the study was conducted in centers for the care of
# the elderly. The findings suggest relatively small but persistent benefits of starting therapy with
# levodopa rather than the listed alternatives. Interestingly, initial treatment with a MAOB inhibitor
# appeared to be at least as effective as treatment with a dopamine agonist.
#
# Reference:
# Trial data indicate that treatment of Parkinson's disease could be initiated with levodopa, oral
# dopamine agonists or a monoamine oxidase B (MAOB) inhibitor. The PD MED study seems to suggest that
# initial therapy with levodopa offers a small but persistent benefit compared with the alternatives,
# and initial MAOB inhibitor treatment is at least as effective as a dopamine agonist.
#
# google/pegasus-large (59 tok):
# R1	p: 36.73 	r: 30.00 	f: 33.03
# R2	p: 14.58 	r: 11.86 	f: 13.08
# RL	p: 20.41 	r: 16.67 	f: 18.35
# ST	59.51		W2V	53.67
#
# However, the results of the PD Med study, a multicenter real-life pragmatic study, reporting on
# quality of life-related outcomes in both young and old patients with Parkinson's disease, is likely
# to generate considerable controversy regarding the use of dopamine agonists and the choice of
# initial therapy.
#
# google/pegasus-large (82 tok):
# R1	p: 50.72 	r: 58.33 	f: 54.26
# R2	p: 20.59 	r: 23.73 	f: 22.05
# RL	p: 30.43 	r: 35.00 	f: 32.56
# ST	72.56		W2V	73.41
#
# However, the results of the PD Med study, a multicenter real-life pragmatic study, reporting on
# quality of life-related outcomes in both young and old patients with Parkinson's disease, is likely
# to generate considerable controversy regarding the use of dopamine agonists and the choice of
# initial therapy. Interestingly, initial treatment with a MAOB inhibitor appeared to be at least as
# effective as treatment with a dopamine agonist.
#
# google/pegasus-large (82 tok):
# R1	p: 30.88 	r: 35.00 	f: 32.81
# R2	p: 10.45 	r: 11.86 	f: 11.11
# RL	p: 19.12 	r: 21.67 	f: 20.31
# ST	62.66		W2V	57.01
#
# However, the results of the PD Med study, a multicenter real-life pragmatic study, reporting on
# quality of life-related outcomes in both young and old patients with Parkinson's disease, is likely
# to generate considerable controversy regarding the use of dopamine agonists and the choice of
# initial therapy. In total, 1620 patients with early Parkinson's disease were recruited and given one
# of three initial treatment regimens.
#
# google/pegasus-large (35 tok):
# R1	p: 45.16 	r: 23.33 	f: 30.77
# R2	p: 16.67 	r: 8.47 	f: 11.24
# RL	p: 19.35 	r: 10.00 	f: 13.19
# ST	71.62		W2V	50.56
#
# The results of four controlled dopamine-agonist monotherapy trials have been published and suggest
# that initiation of treatment with an agonist is beneficial in the early stages of Parkinson's
# disease.
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (47 tok):
# R1	p: 76.19 	r: 53.33 	f: 62.75
# R2	p: 34.15 	r: 23.73 	f: 28.00
# RL	p: 54.76 	r: 38.33 	f: 45.10
# ST	84.80		W2V	73.95
#
# The results of the PD Med study suggest relatively small but persistent benefits of starting therapy
# with levodopa rather than the listed alternatives. Initial treatment with a MAOB inhibitor appeared
# to be at least as effective as treatment with a dopamine agonist.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (47 tok):
# R1	p: 76.19 	r: 53.33 	f: 62.75
# R2	p: 34.15 	r: 23.73 	f: 28.00
# RL	p: 54.76 	r: 38.33 	f: 45.10
# ST	85.66		W2V	74.83
#
# The results of the PD Med study suggest relatively small but persistent benefits of starting therapy
# with levodopa rather than the listed alternatives. Initial treatment with a MAOB inhibitor appears
# to be at least as effective as treatment with a dopamine agonist.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (26 tok):
# R1	p: 60.87 	r: 23.33 	f: 33.73
# R2	p: 31.82 	r: 11.86 	f: 17.28
# RL	p: 52.17 	r: 20.00 	f: 28.92
# ST	72.96		W2V	44.66
#
# The results of the PD Med study suggest relatively small but persistent benefits of starting therapy
# with levodopa rather than the listed alternatives.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (43 tok):
# R1	p: 55.56 	r: 33.33 	f: 41.67
# R2	p: 31.43 	r: 18.64 	f: 23.40
# RL	p: 38.89 	r: 23.33 	f: 29.17
# ST	82.31		W2V	49.37
#
# The results of the PD Med study suggest relatively small but persistent benefits of starting therapy
# with levodopa rather than the listed alternatives. Dopamine agonist therapy is beneficial in the
# early stages of Parkinson's disease.
#
#
# ####################################################################################################
#
# (9781908541963, 'chapter5')
# A rapid deterioration may indicate the development of a complicating cholangiocarcinoma. The risk of
# this malignant transformation is about 6-15% over the course of the disease. Screening for malignant
# transformation is not effective in detecting early disease, and progression to cholangiocarcinoma is
# generally regarded as a contraindication to liver transplantation. Treatment. UDCA, 10-15 mg/kg/day,
# is recommended. This ameliorates pruritus, improves the liver biochemistry and histology and may
# alter the natural history of the disease. Immunosuppressive and antifibrotic therapies have not
# proved effective. Liver transplantation is used widely for advanced disease. The indications for
# transplantation are less precise than they are in PBC, but persistent jaundice of more than 3
# months' duration, in addition to evidence of liver failure or severe portal hypertension, are
# reasonable indications to proceed to liver transplantation. The results of liver transplantation are
# excellent in the absence of cholangiocarcinoma. PSC recurs in 8-15% of cases and is occasionally a
# cause of significant graft dysfunction.
#
# Reference:
# Primary sclerosing cholangitis is strongly associated with ulcerative colitis and is unpredictable;
# late disease can be managed effectively with liver transplantation unless complicated by
# cholangiocarcinoma.
#
# google/pegasus-large (32 tok):
# R1	p: 29.17 	r: 28.00 	f: 28.57
# R2	p: 4.35 	r: 4.17 	f: 4.26
# RL	p: 20.83 	r: 20.00 	f: 20.41
# ST	66.11		W2V	34.57
#
# Screening for malignant transformation is not effective in detecting early disease, and progression
# to cholangiocarcinoma is generally regarded as a contraindication to liver transplantation.
#
# google/pegasus-large (49 tok):
# R1	p: 17.50 	r: 28.00 	f: 21.54
# R2	p: 2.56 	r: 4.17 	f: 3.17
# RL	p: 12.50 	r: 20.00 	f: 15.38
# ST	62.57		W2V	37.15
#
# The risk of this malignant transformation is about 6-15% over the course of the disease. Screening
# for malignant transformation is not effective in detecting early disease, and progression to
# cholangiocarcinoma is generally regarded as a contraindication to liver transplantation.
#
# google/pegasus-large (58 tok):
# R1	p: 14.58 	r: 28.00 	f: 19.18
# R2	p: 2.13 	r: 4.17 	f: 2.82
# RL	p: 10.42 	r: 20.00 	f: 13.70
# ST	65.23		W2V	42.92
#
# The risk of this malignant transformation is about 6-15% over the course of the disease. Screening
# for malignant transformation is not effective in detecting early disease, and progression to
# cholangiocarcinoma is generally regarded as a contraindication to liver transplantation. Liver
# transplantation is used widely for advanced disease.
#
# google/pegasus-large (41 tok):
# R1	p: 21.88 	r: 28.00 	f: 24.56
# R2	p: 3.23 	r: 4.17 	f: 3.64
# RL	p: 15.62 	r: 20.00 	f: 17.54
# ST	67.31		W2V	42.75
#
# Screening for malignant transformation is not effective in detecting early disease, and progression
# to cholangiocarcinoma is generally regarded as a contraindication to liver transplantation. Liver
# transplantation is used widely for advanced disease.
#
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (18 tok):
# R1	p: 25.00 	r: 12.00 	f: 16.22
# R2	p: 9.09 	r: 4.17 	f: 5.71
# RL	p: 25.00 	r: 12.00 	f: 16.22
# ST	51.65		W2V	12.67
#
# The results of liver transplantation are excellent in the absence of cholangiocarcinoma.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (29 tok):
# R1	p: 33.33 	r: 28.00 	f: 30.43
# R2	p: 5.00 	r: 4.17 	f: 4.55
# RL	p: 23.81 	r: 20.00 	f: 21.74
# ST	64.82		W2V	34.80
#
# Screening for malignant transformation is not effective in detecting early disease, and progression
# to cholangiocarcinoma is a contraindication to liver transplantation.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (30 tok):
# R1	p: 31.82 	r: 28.00 	f: 29.79
# R2	p: 4.76 	r: 4.17 	f: 4.44
# RL	p: 22.73 	r: 20.00 	f: 21.28
# ST	65.83		W2V	27.85
#
# Screening for malignant transformation is not effective in detecting early disease, and progression
# to cholangiocarcinoma may be a contraindication to liver transplantation.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (13 tok):
# R1	p: 16.67 	r: 8.00 	f: 10.81
# R2	p: 9.09 	r: 4.17 	f: 5.71
# RL	p: 16.67 	r: 8.00 	f: 10.81
# ST	41.04		W2V	9.73
#
# The results of liver transplantation are excellent in the absence of PSC.
#
#
# ####################################################################################################
#
# (9781910797426, 'ch03')
# Etiology and pathogenesis. Chronic gallbladder inflammation is attributed as an etiologic factor in
# gallbladder cancer along with molecular alterations in p53 and K-ras. Inflammation may occur as a
# result of gallstones, gallbladder polyps, chronic Salmonella infection, congenital biliary cysts,
# abnormal pancreaticobiliary duct junction, carcinogen exposure and certain drugs. There are
# molecular differences between gallbladder cancers associated with gallstones and those with an
# abnormal pancreaticobiliary junction. Epidemiology and risk factors. Gallbladder carcinoma is the
# fifth most common gastrointestinal (GI) cancer in the USA and is the most common GI cancer in Native
# Americans. Incidence and mortality are very high in certain Latin American countries, especially
# Chile. Risk factors for gallbladder cancer are outlined in Table 3.3. The majority of gallbladder
# cancers are adenocarcinomas.
#
# Reference:
# Gallbladder cancer is the most common gastrointestinal cancer in Native Americans in the USA and
# also has a very high incidence in certain Latin American countries, particularly Chile.
#
# google/pegasus-large (35 tok):
# R1	p: 16.00 	r: 14.29 	f: 15.09
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 12.00 	r: 10.71 	f: 11.32
# ST	42.33		W2V	0.74
#
# Inflammation may occur as a result of gallstones, gallbladder polyps, chronic Salmonella infection,
# congenital biliary cysts, abnormal pancreaticobiliary duct junction, carcinogen exposure and certain
# drugs.
#
# google/pegasus-large (21 tok):
# R1	p: 11.76 	r: 7.14 	f: 8.89
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 11.76 	r: 7.14 	f: 8.89
# ST	50.19		W2V	-0.29
#
# There are molecular differences between gallbladder cancers associated with gallstones and those
# with an abnormal pancreaticobiliary junction.
#
# google/pegasus-large (35 tok):
# R1	p: 16.00 	r: 14.29 	f: 15.09
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 12.00 	r: 10.71 	f: 11.32
# ST	42.59		W2V	0.74
#
# Inflammation may occur as a result of gallstones, gallbladder polyps, chronic Salmonella infection,
# congenital biliary cysts, abnormal pancreasobiliary duct junction, carcinogen exposure and certain
# drugs.
#
# google/pegasus-large (9 tok):
# R1	p: 28.57 	r: 7.14 	f: 11.43
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 14.29 	r: 3.57 	f: 5.71
# ST	59.44		W2V	35.31
#
# The majority of gallbladder cancers are adenocarcinomas.
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (28 tok):
# R1	p: 65.22 	r: 53.57 	f: 58.82
# R2	p: 54.55 	r: 44.44 	f: 48.98
# RL	p: 56.52 	r: 46.43 	f: 50.98
# ST	82.05		W2V	80.13
#
# Gallbladder cancer is the fifth most common gastrointestinal (GI) cancer in the USA and is the most
# common GI cancer in Native Americans.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (28 tok):
# R1	p: 65.22 	r: 53.57 	f: 58.82
# R2	p: 45.45 	r: 37.04 	f: 40.82
# RL	p: 52.17 	r: 42.86 	f: 47.06
# ST	78.45		W2V	78.88
#
# Gallbladder carcinoma is the fifth most common gastrointestinal (GI) cancer in the USA and is the
# most common GI cancer in Native Americans.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (27 tok):
# R1	p: 68.18 	r: 53.57 	f: 60.00
# R2	p: 57.14 	r: 44.44 	f: 50.00
# RL	p: 59.09 	r: 46.43 	f: 52.00
# ST	82.14		W2V	79.41
#
# Gallbladder cancer is the fifth most common gastrointestinal (GI) cancer in the USA and the most
# common GI cancer in Native Americans.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (27 tok):
# R1	p: 68.18 	r: 53.57 	f: 60.00
# R2	p: 47.62 	r: 37.04 	f: 41.67
# RL	p: 54.55 	r: 42.86 	f: 48.00
# ST	78.65		W2V	77.97
#
# Gallbladder carcinoma is the fifth most common gastrointestinal (GI) cancer in the USA and the most
# common GI cancer in Native Americans.
#
#
# ####################################################################################################
#
# (9781910797495, 'chp12')
# Acute headache. The immediate, important first step in assessing a new headache is determining
# whether the headache is a serious, potentially life-threatening medical event requiring emergency
# evaluation and management. All the possibilities highlighted in Table 12.1 must be entertained and
# discarded before considering the headache to be caused by a chronic headache condition. Brain
# imaging, including neurovascular studies, may be needed as well as cerebrospinal fluid (CSF)
# pressure measurement and analysis and further evaluation by a neurologist. Chronic headache.
# Assessment. As with all chronic pain, headache must be assessed systematically and classified
# according to its likely origin as well as its temporal pattern, aggravating and ameliorating factors
# and perpetuating factors and comorbidities. The headache diagnoses in Table 12.2 should be
# considered.
#
# Reference:
# In patients without history of chronic headaches, determine whether an acute new headache is a
# serious, potentially life-threatening condition.
#
# google/pegasus-large (25 tok):
# R1	p: 20.00 	r: 25.00 	f: 22.22
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 16.00 	r: 20.00 	f: 17.78
# ST	46.98		W2V	13.62
#
# All the possibilities highlighted in Table 12.1 must be entertained and discarded before considering
# the headache to be caused by a chronic headache condition.
#
# google/pegasus-large (35 tok):
# R1	p: 14.29 	r: 25.00 	f: 18.18
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 11.43 	r: 20.00 	f: 14.55
# ST	45.12		W2V	9.68
#
# All the possibilities highlighted in Table 12.1 must be entertained and discarded before considering
# the headache to be caused by a chronic headache condition. The headache diagnoses in Table 12.2
# should be considered.
#
# google/pegasus-large (35 tok):
# R1	p: 17.14 	r: 30.00 	f: 21.82
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 11.43 	r: 20.00 	f: 14.55
# ST	45.62		W2V	11.31
#
# All the possibilities highlighted in Table 12.1 must be entertained and discarded before considering
# the headache to be caused by a chronic headache condition. The headaches diagnoses in Table 12.2
# should be considered.
#
# google/pegasus-large (10 tok):
# R1	p: 20.00 	r: 10.00 	f: 13.33
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 10.00 	r: 5.00 	f: 6.67
# ST	42.03		W2V	-1.19
#
# The headache diagnoses in Table 12.2 should be considered.
#
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (32 tok):
# R1	p: 35.71 	r: 50.00 	f: 41.67
# R2	p: 25.93 	r: 36.84 	f: 30.43
# RL	p: 32.14 	r: 45.00 	f: 37.50
# ST	77.72		W2V	35.03
#
# The immediate, important first step in assessing a new headache is determining whether the headache
# is a serious, potentially life-threatening medical event requiring emergency evaluation and
# management.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (25 tok):
# R1	p: 20.00 	r: 25.00 	f: 22.22
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 16.00 	r: 20.00 	f: 17.78
# ST	46.98		W2V	13.62
#
# All the possibilities highlighted in Table 12.1 must be entertained and discarded before considering
# the headache to be caused by a chronic headache condition.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (24 tok):
# R1	p: 20.83 	r: 25.00 	f: 22.73
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 16.67 	r: 20.00 	f: 18.18
# ST	45.88		W2V	16.06
#
# All possibilities highlighted in Table 12.1 must be entertained and discarded before considering the
# headache to be caused by a chronic headache condition.
#
# /home/ubuntu/s3/fine-tuning/ft_pegasus_para_wordembed_gas64_lr5e-05/checkpoint-686/ (23 tok):
# R1	p: 22.73 	r: 25.00 	f: 23.81
# R2	p: 0.00 	r: 0.00 	f: 0.00
# RL	p: 18.18 	r: 20.00 	f: 19.05
# ST	65.17		W2V	14.99
#
# All possible causes of headache must be entertained and discarded before considering the headache to
# be caused by a chronic headache condition.
#
#
# ####################################################################################################
